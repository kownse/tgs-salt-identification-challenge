# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 128

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model
def build_vgg_unet_model(input_shape, DropoutRatio = 0.5, weights = 'imagenet'):
    input_layer = Input(input_shape)
    
    # block 1
    conv1 = Conv2D(64, (3, 3), activation='relu', padding="same")(input_layer)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding="same")(conv1)
    pool1 = MaxPooling2D((2, 2), strides=(2,2))(conv1)

    # block 2
    conv2 = Conv2D(128, (3, 3), activation='relu', padding="same")(pool1)
    conv2 = Conv2D(128, (3, 3), activation='relu', padding="same")(conv2)
    pool2 = MaxPooling2D((2, 2), strides=(2,2))(conv2)
    
    # block3
    conv3 = Conv2D(256, (3, 3), activation='relu', padding="same")(pool2)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding="same")(conv3)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding="same")(conv3)
    pool3 = MaxPooling2D((2, 2), strides=(2,2))(conv3)
    
    # block4
    conv4 = Conv2D(512, (3, 3), activation='relu', padding="same")(pool3)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv4)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv4)
    pool4 = MaxPooling2D((2, 2), strides=(2,2))(conv4)
    
    # block5
    conv5 = Conv2D(512, (3, 3), activation='relu', padding="same")(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv5)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv5)
    pool5 = MaxPooling2D((2, 2), strides=(2,2))(conv5)
    
    # Middle
    if DropoutRatio > 0:
        pool5 = Dropout(DropoutRatio)(pool5)
    convm = Conv2D(1024, (3, 3), activation="relu", padding="same")(pool5)
    
    # uconv5
    deconv5 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv5 = concatenate([deconv5, conv5])
    if DropoutRatio > 0:
        uconv5 = Dropout(DropoutRatio)(uconv5)
    uconv5 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv5)
#     uconv5 = residual_block(uconv5,512)
    uconv5 = residual_block(uconv5,512, True)
    
    # uconv4
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(uconv5)
    uconv4 = concatenate([deconv4, conv4])
    if DropoutRatio > 0:
        uconv4 = Dropout(DropoutRatio)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
#     uconv4 = residual_block(uconv4,512)
    uconv4 = residual_block(uconv4,512, True)
    
    # uconv3
    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    if DropoutRatio > 0:
        uconv3 = Dropout(DropoutRatio)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
#     uconv3 = residual_block(uconv3,256)
    uconv3 = residual_block(uconv3,256, True)
    
    # uconv2
    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    if DropoutRatio > 0:
        uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
#     uconv2 = residual_block(uconv2,128)
    uconv2 = residual_block(uconv2,128, True)
    
    # uconv1
    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    if DropoutRatio > 0:
        uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
#     uconv1 = residual_block(uconv1,64)
    uconv1 = residual_block(uconv1,64, True)

    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
#     output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    class_out = layers.Flatten(name='flatten')(pool5)

    class_out = Dense(256)(class_out)
    class_out = BatchActivate(class_out)
    class_out = Dropout(0.5)(class_out)

    class_out = Dense(64)(class_out)
    class_out = BatchActivate(class_out)
    class_out = Dropout(0.5)(class_out)
    
    class_out_layer = layers.Dense(1, activation = 'sigmoid', name='empty_out')(class_out)
    
    final_out_noact = multiply([output_layer_noActi, class_out_layer])
    final_out_noact = BatchNormalization()(final_out_noact)
    final_out =  Activation('sigmoid', name = 'segment_out')(final_out_noact)
    
    model = Model(input_layer, [final_out, class_out_layer])
    
    if weights == 'imagenet':
        vgg = VGG16(input_shape = input_shape, include_top = False, weights = 'imagenet')
        for i in range(1, len(vgg.layers)):
            model.layers[i].set_weights(vgg.layers[i].get_weights())
            model.layers[i].trainable = False
            
    return model

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=False)) for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
train_df['empty'] = train_df['masks'].apply(lambda x: (x.max()!=0) * 1)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test, empty_train, empty_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 3), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
train_df['empty'].values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
empty_train = np.append(empty_train, empty_train, axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 128, 128, 3)
# (800, 128, 128, 1)

# %%
batch_size = 32
dropout = 0.5
base_name = 'Unet_vgg_2loss_{}_{}'.format(batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

losses = {
    'empty_out' : 'binary_crossentropy',
    'segment_out': 'binary_crossentropy',
}
lossWeights = {
    'empty_out' : 0.2,
    'segment_out':2,
}

y_combine_rain = {
    'empty_out' : empty_train,
    'segment_out':y_train,
    #'final_out' : y_train,
}

y_combine_test = {
    'empty_out' : empty_test,
    'segment_out':y_valid,
    #'final_out' : y_valid,
}

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
# Out:
# ../model/Unet_vgg_2loss_32_0.5.model
# ../model/Unet_vgg_2loss_32_0.5.csv

# %%
# model
model1 = build_vgg_unet_model((img_size_target, img_size_target, 3), 
                              DropoutRatio = dropout, weights = 'imagenet')

c = optimizers.adam(lr = 0.01)
model1.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric])

early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200

history = model1.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 103s 16ms/step - loss: 0.7777 - segment_out_loss: 0.3484 - empty_out_loss: 0.4050 - segment_out_my_iou_metric: 0.5052 - empty_out_my_iou_metric: 0.8131 - val_loss: 0.6558 - val_segment_out_loss: 0.2995 - val_empty_out_loss: 0.2839 - val_segment_out_my_iou_metric: 0.5713 - val_empty_out_my_iou_metric: 0.8750
#
# Epoch 00001: val_segment_out_my_iou_metric improved from -inf to 0.57125, saving model to ../model/Unet_vgg_2loss_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.4824 - segment_out_loss: 0.2073 - empty_out_loss: 0.3393 - segment_out_my_iou_metric: 0.6499 - empty_out_my_iou_metric: 0.8525 - val_loss: 0.4497 - val_segment_out_loss: 0.1936 - val_empty_out_loss: 0.3122 - val_segment_out_my_iou_metric: 0.6897 - val_empty_out_my_iou_metric: 0.8575
#
# Epoch 00002: val_segment_out_my_iou_metric improved from 0.57125 to 0.68975, saving model to ../model/Unet_vgg_2loss_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.4003 - segment_out_loss: 0.1694 - empty_out_loss: 0.3070 - segment_out_my_iou_metric: 0.6894 - empty_out_my_iou_metric: 0.8636 - val_loss: 0.4402 - val_segment_out_loss: 0.1906 - val_empty_out_loss: 0.2953 - val_segment_out_my_iou_metric: 0.6984 - val_empty_out_my_iou_metric: 0.8750
#
# Epoch 00003: val_segment_out_my_iou_metric improved from 0.68975 to 0.69837, saving model to ../model/Unet_vgg_2loss_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.3632 - segment_out_loss: 0.1506 - empty_out_loss: 0.3104 - segment_out_my_iou_metric: 0.7127 - empty_out_my_iou_metric: 0.8555 - val_loss: 0.4164 - val_segment_out_loss: 0.1773 - val_empty_out_loss: 0.3094 - val_segment_out_my_iou_metric: 0.7055 - val_empty_out_my_iou_metric: 0.8788
#
# Epoch 00004: val_segment_out_my_iou_metric improved from 0.69837 to 0.70550, saving model to ../model/Unet_vgg_2loss_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.3209 - segment_out_loss: 0.1325 - empty_out_loss: 0.2797 - segment_out_my_iou_metric: 0.7370 - empty_out_my_iou_metric: 0.8772 - val_loss: 0.3809 - val_segment_out_loss: 0.1616 - val_empty_out_loss: 0.2889 - val_segment_out_my_iou_metric: 0.7247 - val_empty_out_my_iou_metric: 0.8712
#
# Epoch 00005: val_segment_out_my_iou_metric improved from 0.70550 to 0.72475, saving model to ../model/Unet_vgg_2loss_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2913 - segment_out_loss: 0.1196 - empty_out_loss: 0.2607 - segment_out_my_iou_metric: 0.7459 - empty_out_my_iou_metric: 0.8858 - val_loss: 0.4142 - val_segment_out_loss: 0.1767 - val_empty_out_loss: 0.3039 - val_segment_out_my_iou_metric: 0.7279 - val_empty_out_my_iou_metric: 0.8700
#
# Epoch 00006: val_segment_out_my_iou_metric improved from 0.72475 to 0.72787, saving model to ../model/Unet_vgg_2loss_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.2719 - segment_out_loss: 0.1088 - empty_out_loss: 0.2718 - segment_out_my_iou_metric: 0.7617 - empty_out_my_iou_metric: 0.8828 - val_loss: 0.3686 - val_segment_out_loss: 0.1550 - val_empty_out_loss: 0.2928 - val_segment_out_my_iou_metric: 0.7281 - val_empty_out_my_iou_metric: 0.8738
#
# Epoch 00007: val_segment_out_my_iou_metric improved from 0.72787 to 0.72813, saving model to ../model/Unet_vgg_2loss_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2601 - segment_out_loss: 0.1042 - empty_out_loss: 0.2586 - segment_out_my_iou_metric: 0.7652 - empty_out_my_iou_metric: 0.8825 - val_loss: 0.4046 - val_segment_out_loss: 0.1733 - val_empty_out_loss: 0.2903 - val_segment_out_my_iou_metric: 0.7124 - val_empty_out_my_iou_metric: 0.8800
#
# Epoch 00008: val_segment_out_my_iou_metric did not improve from 0.72813
# Epoch 9/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.2482 - segment_out_loss: 0.0987 - empty_out_loss: 0.2542 - segment_out_my_iou_metric: 0.7737 - empty_out_my_iou_metric: 0.8948 - val_loss: 0.4869 - val_segment_out_loss: 0.2110 - val_empty_out_loss: 0.3249 - val_segment_out_my_iou_metric: 0.6801 - val_empty_out_my_iou_metric: 0.8525
#
# Epoch 00009: val_segment_out_my_iou_metric did not improve from 0.72813
# Epoch 10/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.2206 - segment_out_loss: 0.0851 - empty_out_loss: 0.2522 - segment_out_my_iou_metric: 0.7902 - empty_out_my_iou_metric: 0.8887 - val_loss: 0.4396 - val_segment_out_loss: 0.1904 - val_empty_out_loss: 0.2938 - val_segment_out_my_iou_metric: 0.7115 - val_empty_out_my_iou_metric: 0.8812
#
# Epoch 00010: val_segment_out_my_iou_metric did not improve from 0.72813
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 11/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.1836 - segment_out_loss: 0.0690 - empty_out_loss: 0.2285 - segment_out_my_iou_metric: 0.8056 - empty_out_my_iou_metric: 0.8964 - val_loss: 0.4072 - val_segment_out_loss: 0.1723 - val_empty_out_loss: 0.3131 - val_segment_out_my_iou_metric: 0.7119 - val_empty_out_my_iou_metric: 0.8625
#
# Epoch 00011: val_segment_out_my_iou_metric did not improve from 0.72813
# Epoch 12/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.1644 - segment_out_loss: 0.0610 - empty_out_loss: 0.2121 - segment_out_my_iou_metric: 0.8172 - empty_out_my_iou_metric: 0.9077 - val_loss: 0.4128 - val_segment_out_loss: 0.1754 - val_empty_out_loss: 0.3097 - val_segment_out_my_iou_metric: 0.7200 - val_empty_out_my_iou_metric: 0.8662
#
# Epoch 00012: val_segment_out_my_iou_metric did not improve from 0.72813
# Epoch 13/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.1646 - segment_out_loss: 0.0602 - empty_out_loss: 0.2204 - segment_out_my_iou_metric: 0.8220 - empty_out_my_iou_metric: 0.9061 - val_loss: 0.3982 - val_segment_out_loss: 0.1696 - val_empty_out_loss: 0.2954 - val_segment_out_my_iou_metric: 0.7209 - val_empty_out_my_iou_metric: 0.8738
#
# Epoch 00013: val_segment_out_my_iou_metric did not improve from 0.72813
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 14/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.1482 - segment_out_loss: 0.0534 - empty_out_loss: 0.2069 - segment_out_my_iou_metric: 0.8267 - empty_out_my_iou_metric: 0.9091 - val_loss: 0.4655 - val_segment_out_loss: 0.2026 - val_empty_out_loss: 0.3016 - val_segment_out_my_iou_metric: 0.7104 - val_empty_out_my_iou_metric: 0.8700
#
# Epoch 00014: val_segment_out_my_iou_metric did not improve from 0.72813
# Epoch 15/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.1366 - segment_out_loss: 0.0480 - empty_out_loss: 0.2037 - segment_out_my_iou_metric: 0.8343 - empty_out_my_iou_metric: 0.9114 - val_loss: 0.4137 - val_segment_out_loss: 0.1768 - val_empty_out_loss: 0.3003 - val_segment_out_my_iou_metric: 0.7141 - val_empty_out_my_iou_metric: 0.8712
#
# Epoch 00015: val_segment_out_my_iou_metric did not improve from 0.72813
# Epoch 16/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1336 - segment_out_loss: 0.0466 - empty_out_loss: 0.2019 - segment_out_my_iou_metric: 0.8390 - empty_out_my_iou_metric: 0.9159 - val_loss: 0.4523 - val_segment_out_loss: 0.1962 - val_empty_out_loss: 0.2995 - val_segment_out_my_iou_metric: 0.7125 - val_empty_out_my_iou_metric: 0.8725
#
# Epoch 00016: val_segment_out_my_iou_metric did not improve from 0.72813
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 17/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1255 - segment_out_loss: 0.0430 - empty_out_loss: 0.1974 - segment_out_my_iou_metric: 0.8435 - empty_out_my_iou_metric: 0.9109 - val_loss: 0.4540 - val_segment_out_loss: 0.1973 - val_empty_out_loss: 0.2973 - val_segment_out_my_iou_metric: 0.7190 - val_empty_out_my_iou_metric: 0.8762
#
# Epoch 00017: val_segment_out_my_iou_metric did not improve from 0.72813
# Epoch 00017: early stopping

# %%
from keras import backend as K
K.clear_session()

model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})

base_name = 'Unet_vgg_2loss_stage2_{}_{}'.format(batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

# %%
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
model1.layers[-1].name = 'segment_out_old'

output_layer = model1.layers[-2]
output_layer.name = 'segment_out'
output_layer = output_layer.output

empty_out = model1.get_layer("empty_out").output
model = Model(input_x, [output_layer, empty_out])
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric_2])
del model1

#model.summary()
early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.00001, verbose=1)
epochs = 200

history = model.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 100s 16ms/step - loss: 0.8194 - segment_out_loss: 0.3709 - empty_out_loss: 0.3883 - segment_out_my_iou_metric_2: 0.6003 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 1.7930 - val_segment_out_loss: 0.8517 - val_empty_out_loss: 0.4479 - val_segment_out_my_iou_metric_2: 0.6734 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00001: val_segment_out_my_iou_metric_2 improved from -inf to 0.67338, saving model to ../model/Unet_vgg_2loss_stage2_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.5878 - segment_out_loss: 0.2522 - empty_out_loss: 0.4167 - segment_out_my_iou_metric_2: 0.4200 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 1.4124 - val_segment_out_loss: 0.6630 - val_empty_out_loss: 0.4316 - val_segment_out_my_iou_metric_2: 0.5665 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00002: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 3/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.4029 - segment_out_loss: 0.1641 - empty_out_loss: 0.3730 - segment_out_my_iou_metric_2: 0.4205 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7069 - val_segment_out_loss: 0.3174 - val_empty_out_loss: 0.3611 - val_segment_out_my_iou_metric_2: 0.5256 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00003: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 4/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.3881 - segment_out_loss: 0.1605 - empty_out_loss: 0.3355 - segment_out_my_iou_metric_2: 0.4167 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6930 - val_segment_out_loss: 0.3092 - val_empty_out_loss: 0.3733 - val_segment_out_my_iou_metric_2: 0.3837 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00004: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 5/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.3858 - segment_out_loss: 0.1574 - empty_out_loss: 0.3545 - segment_out_my_iou_metric_2: 0.4123 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7236 - val_segment_out_loss: 0.3231 - val_empty_out_loss: 0.3866 - val_segment_out_my_iou_metric_2: 0.4125 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00005: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 6/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.5369 - segment_out_loss: 0.2310 - empty_out_loss: 0.3742 - segment_out_my_iou_metric_2: 0.3758 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7383 - val_segment_out_loss: 0.3347 - val_empty_out_loss: 0.3447 - val_segment_out_my_iou_metric_2: 0.3807 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00006: val_segment_out_my_iou_metric_2 did not improve from 0.67338
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 7/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.4560 - segment_out_loss: 0.1936 - empty_out_loss: 0.3436 - segment_out_my_iou_metric_2: 0.3509 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 1.4070 - val_segment_out_loss: 0.6667 - val_empty_out_loss: 0.3675 - val_segment_out_my_iou_metric_2: 0.3802 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00007: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 8/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.3889 - segment_out_loss: 0.1610 - empty_out_loss: 0.3345 - segment_out_my_iou_metric_2: 0.3759 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6561 - val_segment_out_loss: 0.2916 - val_empty_out_loss: 0.3642 - val_segment_out_my_iou_metric_2: 0.3690 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00008: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 9/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.3595 - segment_out_loss: 0.1462 - empty_out_loss: 0.3351 - segment_out_my_iou_metric_2: 0.3867 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6834 - val_segment_out_loss: 0.3036 - val_empty_out_loss: 0.3809 - val_segment_out_my_iou_metric_2: 0.3355 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00009: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 10/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.3319 - segment_out_loss: 0.1322 - empty_out_loss: 0.3371 - segment_out_my_iou_metric_2: 0.3798 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6087 - val_segment_out_loss: 0.2658 - val_empty_out_loss: 0.3861 - val_segment_out_my_iou_metric_2: 0.3554 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00010: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 11/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2926 - segment_out_loss: 0.1145 - empty_out_loss: 0.3177 - segment_out_my_iou_metric_2: 0.4221 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.5997 - val_segment_out_loss: 0.2616 - val_empty_out_loss: 0.3828 - val_segment_out_my_iou_metric_2: 0.3689 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00011: val_segment_out_my_iou_metric_2 did not improve from 0.67338
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 12/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2694 - segment_out_loss: 0.1033 - empty_out_loss: 0.3143 - segment_out_my_iou_metric_2: 0.4201 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6955 - val_segment_out_loss: 0.3114 - val_empty_out_loss: 0.3637 - val_segment_out_my_iou_metric_2: 0.4156 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00012: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 13/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2769 - segment_out_loss: 0.1073 - empty_out_loss: 0.3112 - segment_out_my_iou_metric_2: 0.4403 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6939 - val_segment_out_loss: 0.3108 - val_empty_out_loss: 0.3609 - val_segment_out_my_iou_metric_2: 0.4283 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00013: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 14/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.2727 - segment_out_loss: 0.1057 - empty_out_loss: 0.3067 - segment_out_my_iou_metric_2: 0.3865 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6747 - val_segment_out_loss: 0.3022 - val_empty_out_loss: 0.3510 - val_segment_out_my_iou_metric_2: 0.3872 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00014: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 15/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2734 - segment_out_loss: 0.1076 - empty_out_loss: 0.2913 - segment_out_my_iou_metric_2: 0.4410 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7115 - val_segment_out_loss: 0.3204 - val_empty_out_loss: 0.3533 - val_segment_out_my_iou_metric_2: 0.4159 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00015: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 16/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2463 - segment_out_loss: 0.0943 - empty_out_loss: 0.2883 - segment_out_my_iou_metric_2: 0.4637 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7504 - val_segment_out_loss: 0.3402 - val_empty_out_loss: 0.3503 - val_segment_out_my_iou_metric_2: 0.4639 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00016: val_segment_out_my_iou_metric_2 did not improve from 0.67338
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 17/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2322 - segment_out_loss: 0.0882 - empty_out_loss: 0.2791 - segment_out_my_iou_metric_2: 0.4537 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7666 - val_segment_out_loss: 0.3481 - val_empty_out_loss: 0.3520 - val_segment_out_my_iou_metric_2: 0.4740 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00017: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 18/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2288 - segment_out_loss: 0.0864 - empty_out_loss: 0.2794 - segment_out_my_iou_metric_2: 0.4323 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7859 - val_segment_out_loss: 0.3581 - val_empty_out_loss: 0.3484 - val_segment_out_my_iou_metric_2: 0.4587 - val_empty_out_my_iou_metric_2: 0.6100
# Epoch 00018: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 19/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2272 - segment_out_loss: 0.0860 - empty_out_loss: 0.2757 - segment_out_my_iou_metric_2: 0.4380 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7283 - val_segment_out_loss: 0.3301 - val_empty_out_loss: 0.3410 - val_segment_out_my_iou_metric_2: 0.4386 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00019: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 20/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2254 - segment_out_loss: 0.0859 - empty_out_loss: 0.2680 - segment_out_my_iou_metric_2: 0.4748 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7683 - val_segment_out_loss: 0.3502 - val_empty_out_loss: 0.3391 - val_segment_out_my_iou_metric_2: 0.4735 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00020: val_segment_out_my_iou_metric_2 did not improve from 0.67338
# Epoch 21/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2251 - segment_out_loss: 0.0858 - empty_out_loss: 0.2678 - segment_out_my_iou_metric_2: 0.4827 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.7744 - val_segment_out_loss: 0.3539 - val_empty_out_loss: 0.3333 - val_segment_out_my_iou_metric_2: 0.4955 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00021: val_segment_out_my_iou_metric_2 did not improve from 0.67338
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 00021: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-20da40c9c7c1> in <module>()
# ----> 1 preds_valid = predict_result(model,x_valid,img_size_target)
#       2 ## Scoring for last model, choose threshold by validation data
#       3 thresholds_ori = np.linspace(0.3, 0.7, 31)
#       4 # Reverse sigmoid function: Use code below because the  sigmoid activation was removed
#       5 thresholds = np.log(thresholds_ori/(1-thresholds_ori))
#
# /media/extend/code/kaggle/salt/src/models.py in predict_result(model, x_test, img_size_target)
#     694 def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
#     695     x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
# --> 696     preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
#     697     preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
#     698     preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 3)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
