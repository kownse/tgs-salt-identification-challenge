# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)


# Build model

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block_scSE(conv1,start_neurons * 1)
    conv1 = residual_block_scSE(conv1,start_neurons * 1)
    conv1 = residual_block_scSE(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block_scSE(conv2,start_neurons * 2)
    conv2 = residual_block_scSE(conv2,start_neurons * 2)
    conv2 = residual_block_scSE(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block_scSE(conv3,start_neurons * 4)
    conv3 = residual_block_scSE(conv3,start_neurons * 4)
    conv3 = residual_block_scSE(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block_scSE(conv4,start_neurons * 8)
    conv4 = residual_block_scSE(conv4,start_neurons * 8)
    conv4 = residual_block_scSE(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block_scSE(convm,start_neurons * 16)
    convm = residual_block_scSE(convm,start_neurons * 16)
    convm = residual_block_scSE(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_scSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_scSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_scSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_scSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_scSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_scSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_scSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_scSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_scSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_scSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_scSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_scSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
depth_levels = train_df.z.max() - train_df.z.min()
depth_step = 1 / depth_levels
train_df['z'] = (train_df['z'] - train_df['z'].min()) / depth_levels

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
depth_train = np.append(depth_train, depth_train)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101)
# (800, 101, 101, 1)

# %%
depth_test[:10]
# Out:
# array([0.70594714, 0.27863436, 0.91519824, 0.46365639, 0.35792952,
#        0.38325991, 0.11894273, 0.90748899, 0.81828194, 0.69052863])

# %%
x_train = add_depth_bulk_act(x_train, depth_train)
x_valid = add_depth_bulk_act(x_valid, depth_test)
# Out:
# HBox(children=(IntProgress(value=0, max=6400), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=800), HTML(value='')))

# %%
start_feature = 32
dropout = 0.5
basic_name = '../model/Unet_resnet_depth_se_{}_{}'.format(start_feature, dropout)
save_model_name = basic_name + '_stage1.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# ../model/Unet_resnet_depth_se_32_0.5.csv

# %%
# model
input_layer = Input((img_size_target, img_size_target, 3))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/resunet_depth_se_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=15, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=4, min_lr=0.000001, verbose=1)

epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.5343 - my_iou_metric: 0.3420 - val_loss: 11.6794 - val_my_iou_metric: 0.1331
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.13313, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 2/200
# 6400/6400 [==============================] - 70s 11ms/step - loss: 0.4005 - my_iou_metric: 0.4464 - val_loss: 0.9105 - val_my_iou_metric: 0.4660
#
# Epoch 00002: val_my_iou_metric improved from 0.13313 to 0.46600, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 3/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.3661 - my_iou_metric: 0.4754 - val_loss: 1.0439 - val_my_iou_metric: 0.4653
#
# Epoch 00003: val_my_iou_metric did not improve from 0.46600
# Epoch 4/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.3355 - my_iou_metric: 0.5137 - val_loss: 0.4783 - val_my_iou_metric: 0.3865
#
# Epoch 00004: val_my_iou_metric did not improve from 0.46600
# Epoch 5/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.3092 - my_iou_metric: 0.5399 - val_loss: 0.3748 - val_my_iou_metric: 0.4545
#
# Epoch 00005: val_my_iou_metric did not improve from 0.46600
# Epoch 6/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.2823 - my_iou_metric: 0.5656 - val_loss: 0.6819 - val_my_iou_metric: 0.4080
#
# Epoch 00006: val_my_iou_metric did not improve from 0.46600
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 7/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.2478 - my_iou_metric: 0.5901 - val_loss: 0.3677 - val_my_iou_metric: 0.4495
#
# Epoch 00007: val_my_iou_metric did not improve from 0.46600
# Epoch 8/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.2293 - my_iou_metric: 0.6124 - val_loss: 0.4068 - val_my_iou_metric: 0.4324
#
# Epoch 00008: val_my_iou_metric did not improve from 0.46600
# Epoch 9/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.2221 - my_iou_metric: 0.6271 - val_loss: 0.2850 - val_my_iou_metric: 0.5352
#
# Epoch 00009: val_my_iou_metric improved from 0.46600 to 0.53525, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 10/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.2079 - my_iou_metric: 0.6337 - val_loss: 0.2378 - val_my_iou_metric: 0.6290
#
# Epoch 00010: val_my_iou_metric improved from 0.53525 to 0.62900, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 11/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1975 - my_iou_metric: 0.6464 - val_loss: 0.2079 - val_my_iou_metric: 0.6628
#
# Epoch 00011: val_my_iou_metric improved from 0.62900 to 0.66275, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 12/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1892 - my_iou_metric: 0.6605 - val_loss: 0.2127 - val_my_iou_metric: 0.6352
#
# Epoch 00012: val_my_iou_metric did not improve from 0.66275
# Epoch 13/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1832 - my_iou_metric: 0.6654 - val_loss: 0.1870 - val_my_iou_metric: 0.6759
#
# Epoch 00013: val_my_iou_metric improved from 0.66275 to 0.67587, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 14/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1747 - my_iou_metric: 0.6691 - val_loss: 0.1863 - val_my_iou_metric: 0.6399
#
# Epoch 00014: val_my_iou_metric did not improve from 0.67587
# Epoch 15/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1661 - my_iou_metric: 0.6860 - val_loss: 0.1896 - val_my_iou_metric: 0.6833
#
# Epoch 00015: val_my_iou_metric improved from 0.67587 to 0.68325, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 16/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1668 - my_iou_metric: 0.6844 - val_loss: 0.1813 - val_my_iou_metric: 0.6933
#
# Epoch 00016: val_my_iou_metric improved from 0.68325 to 0.69325, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 17/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1557 - my_iou_metric: 0.6916 - val_loss: 0.2242 - val_my_iou_metric: 0.6664
#
# Epoch 00017: val_my_iou_metric did not improve from 0.69325
# Epoch 18/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1552 - my_iou_metric: 0.6994 - val_loss: 0.1783 - val_my_iou_metric: 0.7077
#
# Epoch 00018: val_my_iou_metric improved from 0.69325 to 0.70775, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 19/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1526 - my_iou_metric: 0.7018 - val_loss: 0.2306 - val_my_iou_metric: 0.6605
#
# Epoch 00019: val_my_iou_metric did not improve from 0.70775
# Epoch 20/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1485 - my_iou_metric: 0.7059 - val_loss: 0.1660 - val_my_iou_metric: 0.7054
#
# Epoch 00020: val_my_iou_metric did not improve from 0.70775
# Epoch 21/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1400 - my_iou_metric: 0.7186 - val_loss: 0.1657 - val_my_iou_metric: 0.7166
#
# Epoch 00021: val_my_iou_metric improved from 0.70775 to 0.71662, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 22/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1364 - my_iou_metric: 0.7219 - val_loss: 0.1836 - val_my_iou_metric: 0.7046
#
# Epoch 00022: val_my_iou_metric did not improve from 0.71662
# Epoch 23/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1375 - my_iou_metric: 0.7242 - val_loss: 0.1601 - val_my_iou_metric: 0.7171
#
# Epoch 00023: val_my_iou_metric improved from 0.71662 to 0.71713, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 24/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1328 - my_iou_metric: 0.7320 - val_loss: 0.1518 - val_my_iou_metric: 0.7273
#
# Epoch 00024: val_my_iou_metric improved from 0.71713 to 0.72725, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 25/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1321 - my_iou_metric: 0.7279 - val_loss: 0.1753 - val_my_iou_metric: 0.7062
#
# Epoch 00025: val_my_iou_metric did not improve from 0.72725
# Epoch 26/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1377 - my_iou_metric: 0.7234 - val_loss: 0.1934 - val_my_iou_metric: 0.6904
#
# Epoch 00026: val_my_iou_metric did not improve from 0.72725
# Epoch 27/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1358 - my_iou_metric: 0.7254 - val_loss: 0.1562 - val_my_iou_metric: 0.7255
#
# Epoch 00027: val_my_iou_metric did not improve from 0.72725
# Epoch 28/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1432 - my_iou_metric: 0.7123 - val_loss: 0.1665 - val_my_iou_metric: 0.7246
#
# Epoch 00028: val_my_iou_metric did not improve from 0.72725
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 29/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1195 - my_iou_metric: 0.7414 - val_loss: 0.1486 - val_my_iou_metric: 0.7339
#
# Epoch 00029: val_my_iou_metric improved from 0.72725 to 0.73388, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 30/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1164 - my_iou_metric: 0.7444 - val_loss: 0.1739 - val_my_iou_metric: 0.7217
#
# Epoch 00030: val_my_iou_metric did not improve from 0.73388
# Epoch 31/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1089 - my_iou_metric: 0.7504 - val_loss: 0.1564 - val_my_iou_metric: 0.7564
#
# Epoch 00031: val_my_iou_metric improved from 0.73388 to 0.75638, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 32/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1058 - my_iou_metric: 0.7587 - val_loss: 0.1521 - val_my_iou_metric: 0.7441
#
# Epoch 00032: val_my_iou_metric did not improve from 0.75638
# Epoch 33/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1037 - my_iou_metric: 0.7578 - val_loss: 0.5321 - val_my_iou_metric: 0.4569
#
# Epoch 00033: val_my_iou_metric did not improve from 0.75638
# Epoch 34/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1171 - my_iou_metric: 0.7416 - val_loss: 0.1514 - val_my_iou_metric: 0.7385
#
# Epoch 00034: val_my_iou_metric did not improve from 0.75638
# Epoch 35/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1029 - my_iou_metric: 0.7547 - val_loss: 0.1515 - val_my_iou_metric: 0.7387
#
# Epoch 00035: val_my_iou_metric did not improve from 0.75638
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 36/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0906 - my_iou_metric: 0.7725 - val_loss: 0.1584 - val_my_iou_metric: 0.7582
#
# Epoch 00036: val_my_iou_metric improved from 0.75638 to 0.75825, saving model to ../model/Unet_resnet_depth_se_32_0.5_stage1.model
# Epoch 37/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0957 - my_iou_metric: 0.7674 - val_loss: 0.1572 - val_my_iou_metric: 0.7489
#
# Epoch 00037: val_my_iou_metric did not improve from 0.75825
# Epoch 38/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0894 - my_iou_metric: 0.7720 - val_loss: 0.1614 - val_my_iou_metric: 0.7541
#
# Epoch 00038: val_my_iou_metric did not improve from 0.75825
# Epoch 39/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0903 - my_iou_metric: 0.7781 - val_loss: 0.1562 - val_my_iou_metric: 0.7544
#
# Epoch 00039: val_my_iou_metric did not improve from 0.75825
# Epoch 40/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0881 - my_iou_metric: 0.7777 - val_loss: 0.1526 - val_my_iou_metric: 0.7556
#
# Epoch 00040: val_my_iou_metric did not improve from 0.75825
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 41/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0828 - my_iou_metric: 0.7774 - val_loss: 0.1570 - val_my_iou_metric: 0.7516
#
# Epoch 00041: val_my_iou_metric did not improve from 0.75825
# Epoch 42/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0805 - my_iou_metric: 0.7824 - val_loss: 0.1562 - val_my_iou_metric: 0.7514
#
# Epoch 00042: val_my_iou_metric did not improve from 0.75825
# Epoch 43/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0808 - my_iou_metric: 0.7809 - val_loss: 0.1552 - val_my_iou_metric: 0.7545
#
# Epoch 00043: val_my_iou_metric did not improve from 0.75825
# Epoch 44/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0780 - my_iou_metric: 0.7848 - val_loss: 0.1652 - val_my_iou_metric: 0.7545
#
# Epoch 00044: val_my_iou_metric did not improve from 0.75825
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 45/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0755 - my_iou_metric: 0.7882 - val_loss: 0.1655 - val_my_iou_metric: 0.7566
#
# Epoch 00045: val_my_iou_metric did not improve from 0.75825
# Epoch 46/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0748 - my_iou_metric: 0.7833 - val_loss: 0.1694 - val_my_iou_metric: 0.7554
#
# Epoch 00046: val_my_iou_metric did not improve from 0.75825
# Epoch 47/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0741 - my_iou_metric: 0.7888 - val_loss: 0.1634 - val_my_iou_metric: 0.7568
#
# Epoch 00047: val_my_iou_metric did not improve from 0.75825
# Epoch 48/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.0721 - my_iou_metric: 0.7943 - val_loss: 0.1699 - val_my_iou_metric: 0.7539
#
# Epoch 00048: val_my_iou_metric did not improve from 0.75825
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 49/200
# 6400/6400 [==============================] - 73s 11ms/step - loss: 0.0740 - my_iou_metric: 0.7902 - val_loss: 0.1682 - val_my_iou_metric: 0.7561
#
# Epoch 00049: val_my_iou_metric did not improve from 0.75825
# Epoch 50/200
# 6400/6400 [==============================] - 73s 11ms/step - loss: 0.0706 - my_iou_metric: 0.7937 - val_loss: 0.1724 - val_my_iou_metric: 0.7550
#
# Epoch 00050: val_my_iou_metric did not improve from 0.75825
# Epoch 51/200
# 6400/6400 [==============================] - 73s 11ms/step - loss: 0.0725 - my_iou_metric: 0.7927 - val_loss: 0.1721 - val_my_iou_metric: 0.7550
#
# Epoch 00051: val_my_iou_metric did not improve from 0.75825
# Epoch 00051: early stopping

# %%
save_model_name = basic_name + '_stage1.model'
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
save_model_name = basic_name + '.model'
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
board = keras.callbacks.TensorBoard(log_dir='log/resunet_depth_se_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.000001, verbose=1)
epochs = 200
batch_size = 16

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: 0.2462 - my_iou_metric_2: 0.7038 - val_loss: 0.2634 - val_my_iou_metric_2: 0.7144
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.71437, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: 0.1568 - my_iou_metric_2: 0.7249 - val_loss: 0.2486 - val_my_iou_metric_2: 0.6974
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.71437
# Epoch 3/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: 0.1777 - my_iou_metric_2: 0.7177 - val_loss: 0.5571 - val_my_iou_metric_2: 0.6519
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.71437
# Epoch 4/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: 0.2056 - my_iou_metric_2: 0.7042 - val_loss: 1.8959 - val_my_iou_metric_2: 0.3514
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.71437
# Epoch 5/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: 0.3305 - my_iou_metric_2: 0.6748 - val_loss: 0.2143 - val_my_iou_metric_2: 0.7155
#
# Epoch 00005: val_my_iou_metric_2 improved from 0.71437 to 0.71550, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: 0.1637 - my_iou_metric_2: 0.7214 - val_loss: 0.4588 - val_my_iou_metric_2: 0.6631
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.71550
# Epoch 7/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: 0.0681 - my_iou_metric_2: 0.7387 - val_loss: 0.1284 - val_my_iou_metric_2: 0.7370
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.71550 to 0.73700, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: 0.0376 - my_iou_metric_2: 0.7453 - val_loss: 0.3031 - val_my_iou_metric_2: 0.7095
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.73700
# Epoch 9/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: 0.0213 - my_iou_metric_2: 0.7481 - val_loss: 0.0518 - val_my_iou_metric_2: 0.7455
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.73700 to 0.74550, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: 0.0161 - my_iou_metric_2: 0.7515 - val_loss: 0.6319 - val_my_iou_metric_2: 0.5950
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.74550
# Epoch 11/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.0082 - my_iou_metric_2: 0.7581 - val_loss: 0.3077 - val_my_iou_metric_2: 0.7105
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.74550
# Epoch 12/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.0115 - my_iou_metric_2: 0.7552 - val_loss: 0.1220 - val_my_iou_metric_2: 0.7603
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.74550 to 0.76025, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.0376 - my_iou_metric_2: 0.7619 - val_loss: 0.9829 - val_my_iou_metric_2: 0.5789
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.76025
# Epoch 14/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.0777 - my_iou_metric_2: 0.7704 - val_loss: -0.0140 - val_my_iou_metric_2: 0.7585
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.76025
# Epoch 15/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: 0.0608 - my_iou_metric_2: 0.7425 - val_loss: 0.0351 - val_my_iou_metric_2: 0.7636
#
# Epoch 00015: val_my_iou_metric_2 improved from 0.76025 to 0.76363, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: 0.0060 - my_iou_metric_2: 0.7552 - val_loss: 0.1375 - val_my_iou_metric_2: 0.7233
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.76363
# Epoch 17/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.0268 - my_iou_metric_2: 0.7594 - val_loss: 0.2033 - val_my_iou_metric_2: 0.7396
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.76363
# Epoch 18/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.0139 - my_iou_metric_2: 0.7561 - val_loss: 0.0696 - val_my_iou_metric_2: 0.7483
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.76363
# Epoch 19/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.0729 - my_iou_metric_2: 0.7697 - val_loss: -0.0024 - val_my_iou_metric_2: 0.7605
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.76363
# Epoch 20/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.1050 - my_iou_metric_2: 0.7775 - val_loss: -0.0229 - val_my_iou_metric_2: 0.7565
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.76363
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 21/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.1854 - my_iou_metric_2: 0.7937 - val_loss: -0.0876 - val_my_iou_metric_2: 0.7849
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.76363 to 0.78488, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.2067 - my_iou_metric_2: 0.7976 - val_loss: -0.1077 - val_my_iou_metric_2: 0.7939
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.78488 to 0.79387, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.2070 - my_iou_metric_2: 0.8002 - val_loss: -0.0888 - val_my_iou_metric_2: 0.7906
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.79387
# Epoch 24/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.2281 - my_iou_metric_2: 0.8015 - val_loss: -0.0114 - val_my_iou_metric_2: 0.7714
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.79387
# Epoch 25/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.2349 - my_iou_metric_2: 0.8033 - val_loss: -0.0899 - val_my_iou_metric_2: 0.7809
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.79387
# Epoch 26/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.2470 - my_iou_metric_2: 0.8055 - val_loss: -0.1364 - val_my_iou_metric_2: 0.7941
#
# Epoch 00026: val_my_iou_metric_2 improved from 0.79387 to 0.79412, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 27/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.2513 - my_iou_metric_2: 0.8076 - val_loss: 6.6814e-04 - val_my_iou_metric_2: 0.7835
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.79412
# Epoch 28/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.2672 - my_iou_metric_2: 0.8090 - val_loss: -0.0846 - val_my_iou_metric_2: 0.7753
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.79412
# Epoch 29/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.2606 - my_iou_metric_2: 0.8086 - val_loss: -0.1077 - val_my_iou_metric_2: 0.7930
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.79412
# Epoch 30/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.2753 - my_iou_metric_2: 0.8140 - val_loss: -0.0314 - val_my_iou_metric_2: 0.7752
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.79412
# Epoch 31/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.2793 - my_iou_metric_2: 0.8128 - val_loss: -0.0835 - val_my_iou_metric_2: 0.7909
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.79412
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 32/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.3441 - my_iou_metric_2: 0.8264 - val_loss: -0.1399 - val_my_iou_metric_2: 0.8029
#
# Epoch 00032: val_my_iou_metric_2 improved from 0.79412 to 0.80287, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 33/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.3483 - my_iou_metric_2: 0.8251 - val_loss: -0.0626 - val_my_iou_metric_2: 0.7949
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 34/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.3695 - my_iou_metric_2: 0.8319 - val_loss: -0.0996 - val_my_iou_metric_2: 0.7934
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 35/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.3678 - my_iou_metric_2: 0.8326 - val_loss: -0.1000 - val_my_iou_metric_2: 0.7945
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 36/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.3801 - my_iou_metric_2: 0.8360 - val_loss: -0.1120 - val_my_iou_metric_2: 0.8013
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 37/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.3901 - my_iou_metric_2: 0.8355 - val_loss: -0.1386 - val_my_iou_metric_2: 0.7950
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.80287
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 38/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4066 - my_iou_metric_2: 0.8414 - val_loss: -0.0965 - val_my_iou_metric_2: 0.7949
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 39/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4282 - my_iou_metric_2: 0.8427 - val_loss: -0.0930 - val_my_iou_metric_2: 0.7988
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 40/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4262 - my_iou_metric_2: 0.8424 - val_loss: -0.0816 - val_my_iou_metric_2: 0.7985
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 41/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4299 - my_iou_metric_2: 0.8446 - val_loss: -0.1118 - val_my_iou_metric_2: 0.7986
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 42/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4346 - my_iou_metric_2: 0.8456 - val_loss: -0.1017 - val_my_iou_metric_2: 0.7981
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.80287
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 43/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4539 - my_iou_metric_2: 0.8480 - val_loss: -0.1040 - val_my_iou_metric_2: 0.7996
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 44/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4602 - my_iou_metric_2: 0.8508 - val_loss: -0.0936 - val_my_iou_metric_2: 0.8018
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.80287
# Epoch 45/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4568 - my_iou_metric_2: 0.8492 - val_loss: -0.0888 - val_my_iou_metric_2: 0.8040
#
# Epoch 00045: val_my_iou_metric_2 improved from 0.80287 to 0.80400, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 46/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4631 - my_iou_metric_2: 0.8506 - val_loss: -0.0874 - val_my_iou_metric_2: 0.7999
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 47/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.4687 - my_iou_metric_2: 0.8523 - val_loss: -0.0766 - val_my_iou_metric_2: 0.8019
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 48/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4737 - my_iou_metric_2: 0.8517 - val_loss: -0.0911 - val_my_iou_metric_2: 0.8018
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 49/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4705 - my_iou_metric_2: 0.8514 - val_loss: -0.0687 - val_my_iou_metric_2: 0.8034
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 50/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4697 - my_iou_metric_2: 0.8519 - val_loss: -0.0742 - val_my_iou_metric_2: 0.8014
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.80400
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 51/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.4814 - my_iou_metric_2: 0.8525 - val_loss: -0.0676 - val_my_iou_metric_2: 0.8019
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 52/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.4919 - my_iou_metric_2: 0.8545 - val_loss: -0.0488 - val_my_iou_metric_2: 0.8028
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 53/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.4834 - my_iou_metric_2: 0.8546 - val_loss: -0.0593 - val_my_iou_metric_2: 0.8040
#
# Epoch 00053: val_my_iou_metric_2 improved from 0.80400 to 0.80400, saving model to ../model/Unet_resnet_depth_se_32_0.5.model
# Epoch 54/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4919 - my_iou_metric_2: 0.8573 - val_loss: -0.0586 - val_my_iou_metric_2: 0.8039
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 55/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4941 - my_iou_metric_2: 0.8565 - val_loss: -0.0622 - val_my_iou_metric_2: 0.8020
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.80400
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 56/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5019 - my_iou_metric_2: 0.8578 - val_loss: -0.0541 - val_my_iou_metric_2: 0.8003
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 57/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5015 - my_iou_metric_2: 0.8570 - val_loss: -0.0476 - val_my_iou_metric_2: 0.7991
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 58/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4981 - my_iou_metric_2: 0.8555 - val_loss: -0.0516 - val_my_iou_metric_2: 0.8008
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 59/200
# 6384/6400 [============================>.] - ETA: 0s - loss: -0.4969 - my_iou_metric_2: 0.8572

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target)
x_test = add_depth_bulk(x_test)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/res_depthinchannel.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = False, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
