# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
start_feature = 32
dropout = 0.5
basic_name = '../model/Unet_resnet_deeper_{}_{}'.format(start_feature, dropout)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/resunet_deeper_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/Unet_resnet_deeper_32_0.5.model
# ../model/Unet_resnet_deeper_32_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 90s 14ms/step - loss: 0.4707 - my_iou_metric: 0.2814 - val_loss: 2.8470 - val_my_iou_metric: 0.3900
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.39000, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.3772 - my_iou_metric: 0.4060 - val_loss: 0.6772 - val_my_iou_metric: 0.0976
#
# Epoch 00002: val_my_iou_metric did not improve from 0.39000
# Epoch 3/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.3148 - my_iou_metric: 0.5013 - val_loss: 0.5809 - val_my_iou_metric: 0.2722
#
# Epoch 00003: val_my_iou_metric did not improve from 0.39000
# Epoch 4/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2990 - my_iou_metric: 0.5302 - val_loss: 0.4708 - val_my_iou_metric: 0.2126
#
# Epoch 00004: val_my_iou_metric did not improve from 0.39000
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 5/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2497 - my_iou_metric: 0.5559 - val_loss: 0.2827 - val_my_iou_metric: 0.5326
#
# Epoch 00005: val_my_iou_metric improved from 0.39000 to 0.53262, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2349 - my_iou_metric: 0.5704 - val_loss: 0.3252 - val_my_iou_metric: 0.4723
#
# Epoch 00006: val_my_iou_metric did not improve from 0.53262
# Epoch 7/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2325 - my_iou_metric: 0.5692 - val_loss: 0.2378 - val_my_iou_metric: 0.6066
#
# Epoch 00007: val_my_iou_metric improved from 0.53262 to 0.60663, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2296 - my_iou_metric: 0.5835 - val_loss: 0.2362 - val_my_iou_metric: 0.5860
#
# Epoch 00008: val_my_iou_metric did not improve from 0.60663
# Epoch 9/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2129 - my_iou_metric: 0.5942 - val_loss: 0.2696 - val_my_iou_metric: 0.5205
#
# Epoch 00009: val_my_iou_metric did not improve from 0.60663
# Epoch 10/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2128 - my_iou_metric: 0.6022 - val_loss: 0.2102 - val_my_iou_metric: 0.6125
#
# Epoch 00010: val_my_iou_metric improved from 0.60663 to 0.61250, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.2059 - my_iou_metric: 0.6103 - val_loss: 0.2860 - val_my_iou_metric: 0.4765
#
# Epoch 00011: val_my_iou_metric did not improve from 0.61250
# Epoch 12/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1904 - my_iou_metric: 0.6322 - val_loss: 0.2130 - val_my_iou_metric: 0.6309
#
# Epoch 00012: val_my_iou_metric improved from 0.61250 to 0.63088, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1971 - my_iou_metric: 0.6225 - val_loss: 0.2089 - val_my_iou_metric: 0.6377
#
# Epoch 00013: val_my_iou_metric improved from 0.63088 to 0.63775, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1854 - my_iou_metric: 0.6426 - val_loss: 0.2042 - val_my_iou_metric: 0.5920
#
# Epoch 00014: val_my_iou_metric did not improve from 0.63775
# Epoch 15/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1859 - my_iou_metric: 0.6370 - val_loss: 0.2044 - val_my_iou_metric: 0.6605
#
# Epoch 00015: val_my_iou_metric improved from 0.63775 to 0.66050, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1752 - my_iou_metric: 0.6550 - val_loss: 0.1990 - val_my_iou_metric: 0.6436
#
# Epoch 00016: val_my_iou_metric did not improve from 0.66050
# Epoch 17/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1746 - my_iou_metric: 0.6566 - val_loss: 0.1938 - val_my_iou_metric: 0.6175
#
# Epoch 00017: val_my_iou_metric did not improve from 0.66050
# Epoch 18/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1647 - my_iou_metric: 0.6738 - val_loss: 0.1819 - val_my_iou_metric: 0.6764
#
# Epoch 00018: val_my_iou_metric improved from 0.66050 to 0.67638, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1688 - my_iou_metric: 0.6623 - val_loss: 0.1902 - val_my_iou_metric: 0.6876
#
# Epoch 00019: val_my_iou_metric improved from 0.67638 to 0.68763, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1622 - my_iou_metric: 0.6806 - val_loss: 0.1744 - val_my_iou_metric: 0.6596
#
# Epoch 00020: val_my_iou_metric did not improve from 0.68763
# Epoch 21/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1576 - my_iou_metric: 0.6862 - val_loss: 0.1810 - val_my_iou_metric: 0.6179
#
# Epoch 00021: val_my_iou_metric did not improve from 0.68763
# Epoch 22/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1562 - my_iou_metric: 0.6897 - val_loss: 0.2069 - val_my_iou_metric: 0.6810
#
# Epoch 00022: val_my_iou_metric did not improve from 0.68763
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 23/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1402 - my_iou_metric: 0.7054 - val_loss: 0.1697 - val_my_iou_metric: 0.6899
#
# Epoch 00023: val_my_iou_metric improved from 0.68763 to 0.68988, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1346 - my_iou_metric: 0.7092 - val_loss: 0.1521 - val_my_iou_metric: 0.6778
#
# Epoch 00024: val_my_iou_metric did not improve from 0.68988
# Epoch 25/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1308 - my_iou_metric: 0.7182 - val_loss: 0.1694 - val_my_iou_metric: 0.7075
#
# Epoch 00025: val_my_iou_metric improved from 0.68988 to 0.70750, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 26/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1299 - my_iou_metric: 0.7183 - val_loss: 0.1636 - val_my_iou_metric: 0.6574
#
# Epoch 00026: val_my_iou_metric did not improve from 0.70750
# Epoch 27/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1261 - my_iou_metric: 0.7268 - val_loss: 0.1511 - val_my_iou_metric: 0.7171
#
# Epoch 00027: val_my_iou_metric improved from 0.70750 to 0.71713, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1255 - my_iou_metric: 0.7287 - val_loss: 0.1498 - val_my_iou_metric: 0.7237
#
# Epoch 00028: val_my_iou_metric improved from 0.71713 to 0.72375, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 29/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1197 - my_iou_metric: 0.7280 - val_loss: 0.1515 - val_my_iou_metric: 0.7087
#
# Epoch 00029: val_my_iou_metric did not improve from 0.72375
# Epoch 30/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1189 - my_iou_metric: 0.7319 - val_loss: 0.1697 - val_my_iou_metric: 0.6662
#
# Epoch 00030: val_my_iou_metric did not improve from 0.72375
# Epoch 31/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1188 - my_iou_metric: 0.7339 - val_loss: 0.1586 - val_my_iou_metric: 0.7132
#
# Epoch 00031: val_my_iou_metric did not improve from 0.72375
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 32/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1056 - my_iou_metric: 0.7500 - val_loss: 0.1391 - val_my_iou_metric: 0.7376
#
# Epoch 00032: val_my_iou_metric improved from 0.72375 to 0.73763, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 33/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1054 - my_iou_metric: 0.7529 - val_loss: 0.1355 - val_my_iou_metric: 0.7495
#
# Epoch 00033: val_my_iou_metric improved from 0.73763 to 0.74950, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 34/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0996 - my_iou_metric: 0.7527 - val_loss: 0.1423 - val_my_iou_metric: 0.7377
#
# Epoch 00034: val_my_iou_metric did not improve from 0.74950
# Epoch 35/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0986 - my_iou_metric: 0.7566 - val_loss: 0.1218 - val_my_iou_metric: 0.7550
#
# Epoch 00035: val_my_iou_metric improved from 0.74950 to 0.75500, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 36/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0958 - my_iou_metric: 0.7600 - val_loss: 0.1281 - val_my_iou_metric: 0.7470
#
# Epoch 00036: val_my_iou_metric did not improve from 0.75500
# Epoch 37/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0932 - my_iou_metric: 0.7639 - val_loss: 0.1437 - val_my_iou_metric: 0.7349
#
# Epoch 00037: val_my_iou_metric did not improve from 0.75500
# Epoch 38/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0944 - my_iou_metric: 0.7622 - val_loss: 0.1417 - val_my_iou_metric: 0.7562
#
# Epoch 00038: val_my_iou_metric improved from 0.75500 to 0.75625, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 39/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0899 - my_iou_metric: 0.7624 - val_loss: 0.1538 - val_my_iou_metric: 0.7523
#
# Epoch 00039: val_my_iou_metric did not improve from 0.75625
# Epoch 40/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0873 - my_iou_metric: 0.7679 - val_loss: 0.1444 - val_my_iou_metric: 0.7459
#
# Epoch 00040: val_my_iou_metric did not improve from 0.75625
# Epoch 41/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0864 - my_iou_metric: 0.7676 - val_loss: 0.1735 - val_my_iou_metric: 0.7411
#
# Epoch 00041: val_my_iou_metric did not improve from 0.75625
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 42/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0802 - my_iou_metric: 0.7770 - val_loss: 0.1425 - val_my_iou_metric: 0.7634
#
# Epoch 00042: val_my_iou_metric improved from 0.75625 to 0.76338, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 43/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0786 - my_iou_metric: 0.7813 - val_loss: 0.1526 - val_my_iou_metric: 0.7695
#
# Epoch 00043: val_my_iou_metric improved from 0.76338 to 0.76950, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 44/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0760 - my_iou_metric: 0.7813 - val_loss: 0.1554 - val_my_iou_metric: 0.7686
#
# Epoch 00044: val_my_iou_metric did not improve from 0.76950
# Epoch 45/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0750 - my_iou_metric: 0.7803 - val_loss: 0.1585 - val_my_iou_metric: 0.7607
#
# Epoch 00045: val_my_iou_metric did not improve from 0.76950
# Epoch 46/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0742 - my_iou_metric: 0.7851 - val_loss: 0.1568 - val_my_iou_metric: 0.7651
#
# Epoch 00046: val_my_iou_metric did not improve from 0.76950
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 47/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0690 - my_iou_metric: 0.7902 - val_loss: 0.1513 - val_my_iou_metric: 0.7690
#
# Epoch 00047: val_my_iou_metric did not improve from 0.76950
# Epoch 48/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0711 - my_iou_metric: 0.7895 - val_loss: 0.1541 - val_my_iou_metric: 0.7730
#
# Epoch 00048: val_my_iou_metric improved from 0.76950 to 0.77300, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 49/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0712 - my_iou_metric: 0.7909 - val_loss: 0.1486 - val_my_iou_metric: 0.7629
#
# Epoch 00049: val_my_iou_metric did not improve from 0.77300
# Epoch 50/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0686 - my_iou_metric: 0.7939 - val_loss: 0.1562 - val_my_iou_metric: 0.7739
#
# Epoch 00050: val_my_iou_metric improved from 0.77300 to 0.77387, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 51/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0665 - my_iou_metric: 0.7969 - val_loss: 0.1524 - val_my_iou_metric: 0.7682
#
# Epoch 00051: val_my_iou_metric did not improve from 0.77387
# Epoch 52/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0658 - my_iou_metric: 0.7948 - val_loss: 0.1569 - val_my_iou_metric: 0.7610
#
# Epoch 00052: val_my_iou_metric did not improve from 0.77387
# Epoch 53/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0670 - my_iou_metric: 0.7879 - val_loss: 0.1555 - val_my_iou_metric: 0.7740
#
# Epoch 00053: val_my_iou_metric improved from 0.77387 to 0.77400, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 54/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0645 - my_iou_metric: 0.7964 - val_loss: 0.1573 - val_my_iou_metric: 0.7716
#
# Epoch 00054: val_my_iou_metric did not improve from 0.77400
# Epoch 55/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0650 - my_iou_metric: 0.7973 - val_loss: 0.1554 - val_my_iou_metric: 0.7658
#
# Epoch 00055: val_my_iou_metric did not improve from 0.77400
# Epoch 56/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0637 - my_iou_metric: 0.7952 - val_loss: 0.1603 - val_my_iou_metric: 0.7705
#
# Epoch 00056: val_my_iou_metric did not improve from 0.77400
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 57/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0632 - my_iou_metric: 0.7972 - val_loss: 0.1596 - val_my_iou_metric: 0.7727
#
# Epoch 00057: val_my_iou_metric did not improve from 0.77400
# Epoch 58/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0620 - my_iou_metric: 0.7952 - val_loss: 0.1642 - val_my_iou_metric: 0.7778
#
# Epoch 00058: val_my_iou_metric improved from 0.77400 to 0.77775, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 59/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0643 - my_iou_metric: 0.7979 - val_loss: 0.1553 - val_my_iou_metric: 0.7699
#
# Epoch 00059: val_my_iou_metric did not improve from 0.77775
# Epoch 60/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0628 - my_iou_metric: 0.7963 - val_loss: 0.1595 - val_my_iou_metric: 0.7721
#
# Epoch 00060: val_my_iou_metric did not improve from 0.77775
# Epoch 61/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0611 - my_iou_metric: 0.8016 - val_loss: 0.1591 - val_my_iou_metric: 0.7759
#
# Epoch 00061: val_my_iou_metric did not improve from 0.77775
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 62/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0617 - my_iou_metric: 0.7994 - val_loss: 0.1615 - val_my_iou_metric: 0.7715
#
# Epoch 00062: val_my_iou_metric did not improve from 0.77775
# Epoch 63/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0611 - my_iou_metric: 0.7987 - val_loss: 0.1623 - val_my_iou_metric: 0.7746
#
# Epoch 00063: val_my_iou_metric did not improve from 0.77775
# Epoch 64/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0602 - my_iou_metric: 0.8023 - val_loss: 0.1620 - val_my_iou_metric: 0.7715
#
# Epoch 00064: val_my_iou_metric did not improve from 0.77775
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 65/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0603 - my_iou_metric: 0.8027 - val_loss: 0.1617 - val_my_iou_metric: 0.7716
#
# Epoch 00065: val_my_iou_metric did not improve from 0.77775
# Epoch 66/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0600 - my_iou_metric: 0.8045 - val_loss: 0.1630 - val_my_iou_metric: 0.7736
#
# Epoch 00066: val_my_iou_metric did not improve from 0.77775
# Epoch 67/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0594 - my_iou_metric: 0.8005 - val_loss: 0.1605 - val_my_iou_metric: 0.7759
#
# Epoch 00067: val_my_iou_metric did not improve from 0.77775
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 68/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.0594 - my_iou_metric: 0.8017 - val_loss: 0.1625 - val_my_iou_metric: 0.7722
#
# Epoch 00068: val_my_iou_metric did not improve from 0.77775
# Epoch 00068: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)
epochs = 200
batch_size = 32

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 139s 22ms/step - loss: 0.1568 - my_iou_metric_2: 0.7311 - val_loss: 1.1364 - val_my_iou_metric_2: 0.5271
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.52712, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: 0.0898 - my_iou_metric_2: 0.7439 - val_loss: 0.3250 - val_my_iou_metric_2: 0.6791
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.52712 to 0.67913, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: 0.0768 - my_iou_metric_2: 0.7428 - val_loss: 0.1805 - val_my_iou_metric_2: 0.7226
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.67913 to 0.72263, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: 0.0534 - my_iou_metric_2: 0.7521 - val_loss: 0.2630 - val_my_iou_metric_2: 0.7081
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.72263
# Epoch 5/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: 0.0203 - my_iou_metric_2: 0.7571 - val_loss: 0.2591 - val_my_iou_metric_2: 0.7036
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.72263
# Epoch 6/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: 0.0047 - my_iou_metric_2: 0.7599 - val_loss: 0.1078 - val_my_iou_metric_2: 0.7409
#
# Epoch 00006: val_my_iou_metric_2 improved from 0.72263 to 0.74087, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0326 - my_iou_metric_2: 0.7695 - val_loss: 0.0184 - val_my_iou_metric_2: 0.7677
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.74087 to 0.76775, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0710 - my_iou_metric_2: 0.7764 - val_loss: 0.1266 - val_my_iou_metric_2: 0.7540
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.76775
# Epoch 9/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0618 - my_iou_metric_2: 0.7762 - val_loss: 0.1986 - val_my_iou_metric_2: 0.7260
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.76775
# Epoch 10/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.0946 - my_iou_metric_2: 0.7826 - val_loss: 0.1272 - val_my_iou_metric_2: 0.7457
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.76775
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 11/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.1775 - my_iou_metric_2: 0.8031 - val_loss: -0.0489 - val_my_iou_metric_2: 0.7804
#
# Epoch 00011: val_my_iou_metric_2 improved from 0.76775 to 0.78037, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 12/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.2138 - my_iou_metric_2: 0.8094 - val_loss: -0.0675 - val_my_iou_metric_2: 0.7860
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.78037 to 0.78600, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.2301 - my_iou_metric_2: 0.8108 - val_loss: -0.0685 - val_my_iou_metric_2: 0.7821
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.78600
# Epoch 14/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.2476 - my_iou_metric_2: 0.8157 - val_loss: -0.0164 - val_my_iou_metric_2: 0.7732
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.78600
# Epoch 15/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.2414 - my_iou_metric_2: 0.8126 - val_loss: 0.0520 - val_my_iou_metric_2: 0.7655
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.78600
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 16/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.3073 - my_iou_metric_2: 0.8282 - val_loss: -0.1450 - val_my_iou_metric_2: 0.8007
#
# Epoch 00016: val_my_iou_metric_2 improved from 0.78600 to 0.80075, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.3154 - my_iou_metric_2: 0.8279 - val_loss: -0.1346 - val_my_iou_metric_2: 0.8096
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.80075 to 0.80963, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 18/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.3305 - my_iou_metric_2: 0.8321 - val_loss: -0.1324 - val_my_iou_metric_2: 0.8050
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80963
# Epoch 19/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.3341 - my_iou_metric_2: 0.8303 - val_loss: -0.1213 - val_my_iou_metric_2: 0.8001
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80963
# Epoch 20/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.3509 - my_iou_metric_2: 0.8367 - val_loss: -0.1160 - val_my_iou_metric_2: 0.8080
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.80963
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 21/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.3923 - my_iou_metric_2: 0.8448 - val_loss: -0.1739 - val_my_iou_metric_2: 0.8179
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.80963 to 0.81787, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4048 - my_iou_metric_2: 0.8461 - val_loss: -0.1513 - val_my_iou_metric_2: 0.8205
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.81787 to 0.82050, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4141 - my_iou_metric_2: 0.8495 - val_loss: -0.1484 - val_my_iou_metric_2: 0.8083
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.82050
# Epoch 24/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.4162 - my_iou_metric_2: 0.8492 - val_loss: -0.1717 - val_my_iou_metric_2: 0.8136
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.82050
# Epoch 25/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4237 - my_iou_metric_2: 0.8500 - val_loss: -0.1509 - val_my_iou_metric_2: 0.8169
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.82050
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 26/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4485 - my_iou_metric_2: 0.8532 - val_loss: -0.1165 - val_my_iou_metric_2: 0.8156
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.82050
# Epoch 27/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4487 - my_iou_metric_2: 0.8550 - val_loss: -0.1668 - val_my_iou_metric_2: 0.8185
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.82050
# Epoch 28/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4535 - my_iou_metric_2: 0.8552 - val_loss: -0.1514 - val_my_iou_metric_2: 0.8184
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.82050
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 29/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4716 - my_iou_metric_2: 0.8593 - val_loss: -0.1542 - val_my_iou_metric_2: 0.8165
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.82050
# Epoch 30/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4675 - my_iou_metric_2: 0.8591 - val_loss: -0.1493 - val_my_iou_metric_2: 0.8191
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.82050
# Epoch 31/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4725 - my_iou_metric_2: 0.8590 - val_loss: -0.1562 - val_my_iou_metric_2: 0.8200
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.82050
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 32/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4799 - my_iou_metric_2: 0.8613 - val_loss: -0.1488 - val_my_iou_metric_2: 0.8207
#
# Epoch 00032: val_my_iou_metric_2 improved from 0.82050 to 0.82075, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 33/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4808 - my_iou_metric_2: 0.8612 - val_loss: -0.1593 - val_my_iou_metric_2: 0.8220
#
# Epoch 00033: val_my_iou_metric_2 improved from 0.82075 to 0.82200, saving model to ../model/Unet_resnet_deeper_32_0.5.model
# Epoch 34/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4711 - my_iou_metric_2: 0.8586 - val_loss: -0.1477 - val_my_iou_metric_2: 0.8185
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.82200
# Epoch 35/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.4833 - my_iou_metric_2: 0.8602 - val_loss: -0.1461 - val_my_iou_metric_2: 0.8195
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.82200
# Epoch 36/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.4753 - my_iou_metric_2: 0.8576 - val_loss: -0.1465 - val_my_iou_metric_2: 0.8191
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.82200
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 37/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4866 - my_iou_metric_2: 0.8616 - val_loss: -0.1468 - val_my_iou_metric_2: 0.8186
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.82200
# Epoch 38/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.4808 - my_iou_metric_2: 0.8600 - val_loss: -0.1537 - val_my_iou_metric_2: 0.8207
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.82200
# Epoch 39/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.4848 - my_iou_metric_2: 0.8612 - val_loss: -0.1504 - val_my_iou_metric_2: 0.8201
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.82200
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 40/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.4805 - my_iou_metric_2: 0.8606 - val_loss: -0.1488 - val_my_iou_metric_2: 0.8201
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.82200
# Epoch 41/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4872 - my_iou_metric_2: 0.8609 - val_loss: -0.1510 - val_my_iou_metric_2: 0.8207
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.82200
# Epoch 42/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4861 - my_iou_metric_2: 0.8622 - val_loss: -0.1517 - val_my_iou_metric_2: 0.8201
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.82200
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 43/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.4904 - my_iou_metric_2: 0.8617 - val_loss: -0.1478 - val_my_iou_metric_2: 0.8201
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.82200
# Epoch 00043: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.817    0.81775  0.818625 0.82175  0.823375 0.824    0.824375 0.824625
#  0.824375 0.824375 0.824625 0.82475  0.825    0.8245   0.8245   0.82425
#  0.8245   0.824125 0.822875 0.822875 0.82275  0.82275  0.822375 0.821875
#  0.8215   0.820875 0.821    0.820375 0.82     0.81975  0.819125]

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/res_unet_101.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = False, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Usedtime = 5.695587635040283 s
# save result
# upload result
# cmd: kaggle competitions submit -c tgs-salt-identification-challenge -f ../result/res_unet_101.csv.7z -m "submit"
# Kernel run time = 3.1739089763826795 hours
