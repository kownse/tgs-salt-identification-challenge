# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=False)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 3), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 3)
# (800, 101, 101, 1)

# %%
start_feature = 32
batch_size = 32
dropout = 0.5
base_name = 'Unet_resnet_deeper_3channel_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 3))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# ../model/Unet_resnet_deeper_3channel_32_32_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 91s 14ms/step - loss: 0.4180 - my_iou_metric: 0.3596 - val_loss: 2.0638 - val_my_iou_metric: 0.1153
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.11525, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.3219 - my_iou_metric: 0.5254 - val_loss: 0.8461 - val_my_iou_metric: 0.3870
#
# Epoch 00002: val_my_iou_metric improved from 0.11525 to 0.38700, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2774 - my_iou_metric: 0.5587 - val_loss: 0.4402 - val_my_iou_metric: 0.4912
#
# Epoch 00003: val_my_iou_metric improved from 0.38700 to 0.49125, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2609 - my_iou_metric: 0.5550 - val_loss: 0.4344 - val_my_iou_metric: 0.5495
#
# Epoch 00004: val_my_iou_metric improved from 0.49125 to 0.54950, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.2331 - my_iou_metric: 0.5776 - val_loss: 0.2571 - val_my_iou_metric: 0.6170
#
# Epoch 00005: val_my_iou_metric improved from 0.54950 to 0.61700, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2269 - my_iou_metric: 0.5835 - val_loss: 0.5015 - val_my_iou_metric: 0.4189
#
# Epoch 00006: val_my_iou_metric did not improve from 0.61700
# Epoch 7/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.2059 - my_iou_metric: 0.6226 - val_loss: 0.2200 - val_my_iou_metric: 0.6332
#
# Epoch 00009: val_my_iou_metric did not improve from 0.66850
# Epoch 10/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1851 - my_iou_metric: 0.6486 - val_loss: 0.2340 - val_my_iou_metric: 0.6676
#
# Epoch 00010: val_my_iou_metric did not improve from 0.66850
# Epoch 11/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1775 - my_iou_metric: 0.6635 - val_loss: 0.3097 - val_my_iou_metric: 0.3954
#
# Epoch 00011: val_my_iou_metric did not improve from 0.66850
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 12/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1557 - my_iou_metric: 0.6956 - val_loss: 0.1626 - val_my_iou_metric: 0.7029
#
# Epoch 00012: val_my_iou_metric improved from 0.66850 to 0.70287, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1502 - my_iou_metric: 0.7053 - val_loss: 0.1931 - val_my_iou_metric: 0.6581
#
# Epoch 00013: val_my_iou_metric did not improve from 0.70287
# Epoch 14/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1443 - my_iou_metric: 0.7084 - val_loss: 0.1760 - val_my_iou_metric: 0.7277
#
# Epoch 00014: val_my_iou_metric improved from 0.70287 to 0.72775, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1384 - my_iou_metric: 0.7192 - val_loss: 0.1897 - val_my_iou_metric: 0.6834
#
# Epoch 00015: val_my_iou_metric did not improve from 0.72775
# Epoch 16/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1395 - my_iou_metric: 0.7205 - val_loss: 0.1449 - val_my_iou_metric: 0.7235
#
# Epoch 00016: val_my_iou_metric did not improve from 0.72775
# Epoch 17/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1311 - my_iou_metric: 0.7272 - val_loss: 0.1398 - val_my_iou_metric: 0.7514
#
# Epoch 00017: val_my_iou_metric improved from 0.72775 to 0.75138, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 18/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1334 - my_iou_metric: 0.7245 - val_loss: 0.1620 - val_my_iou_metric: 0.7019
#
# Epoch 00018: val_my_iou_metric did not improve from 0.75138
# Epoch 19/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1309 - my_iou_metric: 0.7349 - val_loss: 0.1551 - val_my_iou_metric: 0.7229
#
# Epoch 00019: val_my_iou_metric did not improve from 0.75138
# Epoch 20/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1243 - my_iou_metric: 0.7436 - val_loss: 0.1322 - val_my_iou_metric: 0.7606
#
# Epoch 00020: val_my_iou_metric improved from 0.75138 to 0.76062, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1184 - my_iou_metric: 0.7426 - val_loss: 0.1705 - val_my_iou_metric: 0.7163
#
# Epoch 00021: val_my_iou_metric did not improve from 0.76062
# Epoch 22/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1183 - my_iou_metric: 0.7444 - val_loss: 0.1254 - val_my_iou_metric: 0.7619
#
# Epoch 00022: val_my_iou_metric improved from 0.76062 to 0.76187, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1172 - my_iou_metric: 0.7465 - val_loss: 0.1419 - val_my_iou_metric: 0.7176
#
# Epoch 00023: val_my_iou_metric did not improve from 0.76187
# Epoch 24/200
# 1120/6400 [====>.........................] - ETA: 1:03 - loss: 0.1176 - my_iou_metric: 0.7429
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0598 - my_iou_metric: 0.8085 - val_loss: 0.1278 - val_my_iou_metric: 0.7784
#
# Epoch 00055: val_my_iou_metric did not improve from 0.78412
# Epoch 00055: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.00001, verbose=1)
epochs = 200

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 139s 22ms/step - loss: 0.0245 - my_iou_metric_2: 0.7639 - val_loss: 0.1300 - val_my_iou_metric_2: 0.7454
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.74537, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0217 - my_iou_metric_2: 0.7711 - val_loss: 0.1442 - val_my_iou_metric_2: 0.7411
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.74537
# Epoch 3/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0389 - my_iou_metric_2: 0.7734 - val_loss: 0.2376 - val_my_iou_metric_2: 0.7276
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.74537
# Epoch 4/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0629 - my_iou_metric_2: 0.7799 - val_loss: 0.1244 - val_my_iou_metric_2: 0.7436
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.74537
# Epoch 5/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0596 - my_iou_metric_2: 0.7752 - val_loss: 0.2238 - val_my_iou_metric_2: 0.7034
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.74537
# Epoch 6/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0826 - my_iou_metric_2: 0.7801 - val_loss: 0.1334 - val_my_iou_metric_2: 0.7345
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.74537
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 7/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.1663 - my_iou_metric_2: 0.8000 - val_loss: -0.1368 - val_my_iou_metric_2: 0.8028
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.74537 to 0.80275, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2118 - my_iou_metric_2: 0.8097 - val_loss: -0.0828 - val_my_iou_metric_2: 0.7930
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.80275
# Epoch 9/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2174 - my_iou_metric_2: 0.8116 - val_loss: -0.0944 - val_my_iou_metric_2: 0.8002
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.80275
# Epoch 10/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2446 - my_iou_metric_2: 0.8154 - val_loss: -0.1292 - val_my_iou_metric_2: 0.7997
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.80275
# Epoch 11/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2487 - my_iou_metric_2: 0.8162 - val_loss: -0.1013 - val_my_iou_metric_2: 0.7889
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.80275
# Epoch 12/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2488 - my_iou_metric_2: 0.8178 - val_loss: -0.1426 - val_my_iou_metric_2: 0.8050
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.80275 to 0.80500, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2607 - my_iou_metric_2: 0.8190 - val_loss: -0.0607 - val_my_iou_metric_2: 0.7880
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.80500
# Epoch 14/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2592 - my_iou_metric_2: 0.8192 - val_loss: -0.1541 - val_my_iou_metric_2: 0.8056
#
# Epoch 00014: val_my_iou_metric_2 improved from 0.80500 to 0.80563, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2866 - my_iou_metric_2: 0.8256 - val_loss: -0.0863 - val_my_iou_metric_2: 0.7905
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 16/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2770 - my_iou_metric_2: 0.8227 - val_loss: -0.0804 - val_my_iou_metric_2: 0.7904
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 17/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3056 - my_iou_metric_2: 0.8261 - val_loss: -0.0795 - val_my_iou_metric_2: 0.7924
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 18/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3120 - my_iou_metric_2: 0.8309 - val_loss: -0.1158 - val_my_iou_metric_2: 0.7937
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80563
# Epoch 19/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3204 - my_iou_metric_2: 0.8303 - val_loss: -0.1134 - val_my_iou_metric_2: 0.8031
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80563
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 20/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3793 - my_iou_metric_2: 0.8440 - val_loss: -0.1245 - val_my_iou_metric_2: 0.8064
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.80563 to 0.80638, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3825 - my_iou_metric_2: 0.8445 - val_loss: -0.1781 - val_my_iou_metric_2: 0.8151
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.80638 to 0.81512, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3947 - my_iou_metric_2: 0.8467 - val_loss: -0.0874 - val_my_iou_metric_2: 0.8037
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.81512
# Epoch 23/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3974 - my_iou_metric_2: 0.8464 - val_loss: -0.1799 - val_my_iou_metric_2: 0.8236
#
# Epoch 00023: val_my_iou_metric_2 improved from 0.81512 to 0.82362, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4141 - my_iou_metric_2: 0.8522 - val_loss: -0.1548 - val_my_iou_metric_2: 0.8138
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.82362
# Epoch 25/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4193 - my_iou_metric_2: 0.8519 - val_loss: -0.1587 - val_my_iou_metric_2: 0.8172
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.82362
# Epoch 26/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4300 - my_iou_metric_2: 0.8557 - val_loss: -0.1099 - val_my_iou_metric_2: 0.8083
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.82362
# Epoch 27/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4389 - my_iou_metric_2: 0.8558 - val_loss: -0.1509 - val_my_iou_metric_2: 0.8176
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.82362
# Epoch 28/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4396 - my_iou_metric_2: 0.8555 - val_loss: -0.1411 - val_my_iou_metric_2: 0.8104
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.82362
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 29/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4572 - my_iou_metric_2: 0.8591 - val_loss: -0.1674 - val_my_iou_metric_2: 0.8224
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.82362
# Epoch 30/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4784 - my_iou_metric_2: 0.8631 - val_loss: -0.1691 - val_my_iou_metric_2: 0.8240
#
# Epoch 00030: val_my_iou_metric_2 improved from 0.82362 to 0.82400, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 31/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4804 - my_iou_metric_2: 0.8645 - val_loss: -0.1521 - val_my_iou_metric_2: 0.8153
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 32/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4899 - my_iou_metric_2: 0.8653 - val_loss: -0.1498 - val_my_iou_metric_2: 0.8207
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 33/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4981 - my_iou_metric_2: 0.8676 - val_loss: -0.1591 - val_my_iou_metric_2: 0.8202
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 34/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4905 - my_iou_metric_2: 0.8654 - val_loss: -0.1431 - val_my_iou_metric_2: 0.8147
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 35/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4974 - my_iou_metric_2: 0.8673 - val_loss: -0.1458 - val_my_iou_metric_2: 0.8227
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.82400
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 36/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5077 - my_iou_metric_2: 0.8693 - val_loss: -0.1377 - val_my_iou_metric_2: 0.8212
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 37/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5120 - my_iou_metric_2: 0.8717 - val_loss: -0.1528 - val_my_iou_metric_2: 0.8229
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 38/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5116 - my_iou_metric_2: 0.8715 - val_loss: -0.1575 - val_my_iou_metric_2: 0.8209
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 39/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5242 - my_iou_metric_2: 0.8731 - val_loss: -0.1468 - val_my_iou_metric_2: 0.8220
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.82400
# Epoch 40/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5268 - my_iou_metric_2: 0.8741 - val_loss: -0.1568 - val_my_iou_metric_2: 0.8239
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.82400
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 41/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5370 - my_iou_metric_2: 0.8757 - val_loss: -0.1415 - val_my_iou_metric_2: 0.8259
#
# Epoch 00041: val_my_iou_metric_2 improved from 0.82400 to 0.82588, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 42/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5389 - my_iou_metric_2: 0.8757 - val_loss: -0.1467 - val_my_iou_metric_2: 0.8241
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.82588
# Epoch 43/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5382 - my_iou_metric_2: 0.8750 - val_loss: -0.1440 - val_my_iou_metric_2: 0.8250
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.82588
# Epoch 44/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5392 - my_iou_metric_2: 0.8760 - val_loss: -0.1289 - val_my_iou_metric_2: 0.8257
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.82588
# Epoch 45/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5383 - my_iou_metric_2: 0.8758 - val_loss: -0.1211 - val_my_iou_metric_2: 0.8250
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.82588
# Epoch 46/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5468 - my_iou_metric_2: 0.8772 - val_loss: -0.1411 - val_my_iou_metric_2: 0.8271
#
# Epoch 00046: val_my_iou_metric_2 improved from 0.82588 to 0.82712, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 47/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5399 - my_iou_metric_2: 0.8759 - val_loss: -0.1211 - val_my_iou_metric_2: 0.8229
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.82712
# Epoch 48/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5381 - my_iou_metric_2: 0.8758 - val_loss: -0.1323 - val_my_iou_metric_2: 0.8245
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.82712
# Epoch 49/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5397 - my_iou_metric_2: 0.8751 - val_loss: -0.1380 - val_my_iou_metric_2: 0.8272
#
# Epoch 00049: val_my_iou_metric_2 improved from 0.82712 to 0.82725, saving model to ../model/Unet_resnet_deeper_3channel_32_32_0.5.model
# Epoch 50/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5447 - my_iou_metric_2: 0.8770 - val_loss: -0.1250 - val_my_iou_metric_2: 0.8231
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 51/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5386 - my_iou_metric_2: 0.8752 - val_loss: -0.1319 - val_my_iou_metric_2: 0.8246
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 52/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5430 - my_iou_metric_2: 0.8758 - val_loss: -0.1246 - val_my_iou_metric_2: 0.8254
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 53/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5422 - my_iou_metric_2: 0.8759 - val_loss: -0.1317 - val_my_iou_metric_2: 0.8240
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 54/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5518 - my_iou_metric_2: 0.8774 - val_loss: -0.1210 - val_my_iou_metric_2: 0.8250
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.82725
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 55/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5549 - my_iou_metric_2: 0.8780 - val_loss: -0.1187 - val_my_iou_metric_2: 0.8254
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 56/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5517 - my_iou_metric_2: 0.8800 - val_loss: -0.1183 - val_my_iou_metric_2: 0.8247
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 57/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5563 - my_iou_metric_2: 0.8794 - val_loss: -0.1199 - val_my_iou_metric_2: 0.8221
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 58/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5581 - my_iou_metric_2: 0.8792 - val_loss: -0.1204 - val_my_iou_metric_2: 0.8241
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 59/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5524 - my_iou_metric_2: 0.8795 - val_loss: -0.1196 - val_my_iou_metric_2: 0.8246
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.82725
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 60/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5564 - my_iou_metric_2: 0.8799 - val_loss: -0.1193 - val_my_iou_metric_2: 0.8234
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 61/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.5515 - my_iou_metric_2: 0.8771 - val_loss: -0.1212 - val_my_iou_metric_2: 0.8270
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 62/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5569 - my_iou_metric_2: 0.8805 - val_loss: -0.1176 - val_my_iou_metric_2: 0.8249
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 63/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5586 - my_iou_metric_2: 0.8808 - val_loss: -0.1184 - val_my_iou_metric_2: 0.8237
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 64/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5596 - my_iou_metric_2: 0.8807 - val_loss: -0.1151 - val_my_iou_metric_2: 0.8235
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.82725
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 65/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5567 - my_iou_metric_2: 0.8795 - val_loss: -0.1111 - val_my_iou_metric_2: 0.8256
#
# Epoch 00065: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 66/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5623 - my_iou_metric_2: 0.8817 - val_loss: -0.1116 - val_my_iou_metric_2: 0.8250
#
# Epoch 00067: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 68/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5679 - my_iou_metric_2: 0.8808 - val_loss: -0.1102 - val_my_iou_metric_2: 0.8234
#
# Epoch 00068: val_my_iou_metric_2 did not improve from 0.82725
# Epoch 69/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5609 - my_iou_metric_2: 0.8799 - val_loss: -0.1098 - val_my_iou_metric_2: 0.8216
#
# Epoch 00069: val_my_iou_metric_2 did not improve from 0.82725
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 00069: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.825    0.825125 0.825625 0.8265   0.827    0.82675  0.827    0.82725
#  0.827375 0.827375 0.827375 0.8275   0.8275   0.827625 0.826875 0.826375
#  0.827125 0.827375 0.82675  0.826125 0.82575  0.825625 0.825125 0.8245
#  0.8245   0.824125 0.822125 0.821875 0.822875 0.822    0.822625]

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-706f9e725848> in <module>()
#       1 x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
#       2
# ----> 3 preds_test = predict_result(model,x_test,img_size_target)
#
# /media/extend/code/kaggle/salt/src/models.py in predict_result(model, x_test, img_size_target)
#     694 def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
#     695     x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
# --> 696     preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
#     697     preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
#     698     preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1145                              'argument.')
#    1146         # Validate user data.
# -> 1147         x, _, _ = self._standardize_user_data(x)
#    1148         if self.stateful:
#    1149             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     747             feed_input_shapes,
#     748             check_batch_axis=False,  # Don't enforce the batch size.
# --> 749             exception_prefix='input')
#     750
#     751         if y is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     135                             ': expected ' + names[i] + ' to have shape ' +
#     136                             str(shape) + ' but got array with shape ' +
# --> 137                             str(data_shape))
#     138     return data
#     139
#
# ValueError: Error when checking input: expected input_1 to have shape (101, 101, 3) but got array with shape (101, 101, 1)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
