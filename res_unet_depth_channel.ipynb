# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
x_train = add_depth_bulk(x_train)
x_valid = add_depth_bulk(x_valid)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101)
# (800, 101, 101, 1)

# %%
start_feature = 32
dropout = 0.5
basic_name = '../model/Unet_resnet_depthinchannel_{}_{}'.format(start_feature, dropout)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 3))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/resunet_depthinchannel_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/Unet_resnet_depthinchannel_32_0.5.model
# ../model/Unet_resnet_depthinchannel_32_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 91s 14ms/step - loss: 0.4663 - my_iou_metric: 0.3805 - val_loss: 0.5837 - val_my_iou_metric: 0.4180
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.41800, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.3607 - my_iou_metric: 0.4867 - val_loss: 1.0557 - val_my_iou_metric: 0.3900
#
# Epoch 00002: val_my_iou_metric did not improve from 0.41800
# Epoch 3/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.3243 - my_iou_metric: 0.5363 - val_loss: 0.3506 - val_my_iou_metric: 0.5670
#
# Epoch 00003: val_my_iou_metric improved from 0.41800 to 0.56700, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2857 - my_iou_metric: 0.5607 - val_loss: 0.3934 - val_my_iou_metric: 0.4932
#
# Epoch 00004: val_my_iou_metric did not improve from 0.56700
# Epoch 5/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2689 - my_iou_metric: 0.5727 - val_loss: 0.3273 - val_my_iou_metric: 0.4849
#
# Epoch 00005: val_my_iou_metric did not improve from 0.56700
# Epoch 6/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2393 - my_iou_metric: 0.5912 - val_loss: 0.2422 - val_my_iou_metric: 0.5944
#
# Epoch 00006: val_my_iou_metric improved from 0.56700 to 0.59437, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2207 - my_iou_metric: 0.6095 - val_loss: 0.2914 - val_my_iou_metric: 0.5647
#
# Epoch 00007: val_my_iou_metric did not improve from 0.59437
# Epoch 8/200
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.2067 - my_iou_metric: 0.6340 - val_loss: 0.2123 - val_my_iou_metric: 0.6556
#
# Epoch 00008: val_my_iou_metric improved from 0.59437 to 0.65563, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1920 - my_iou_metric: 0.6483 - val_loss: 0.1943 - val_my_iou_metric: 0.6666
#
# Epoch 00009: val_my_iou_metric improved from 0.65563 to 0.66662, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1803 - my_iou_metric: 0.6566 - val_loss: 0.1734 - val_my_iou_metric: 0.6813
#
# Epoch 00010: val_my_iou_metric improved from 0.66662 to 0.68125, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1786 - my_iou_metric: 0.6619 - val_loss: 0.1709 - val_my_iou_metric: 0.6904
#
# Epoch 00011: val_my_iou_metric improved from 0.68125 to 0.69038, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 12/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1668 - my_iou_metric: 0.6825 - val_loss: 0.1864 - val_my_iou_metric: 0.6894
#
# Epoch 00012: val_my_iou_metric did not improve from 0.69038
# Epoch 13/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1610 - my_iou_metric: 0.6837 - val_loss: 0.1666 - val_my_iou_metric: 0.7130
#
# Epoch 00013: val_my_iou_metric improved from 0.69038 to 0.71300, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1602 - my_iou_metric: 0.6898 - val_loss: 0.1727 - val_my_iou_metric: 0.7071
#
# Epoch 00014: val_my_iou_metric did not improve from 0.71300
# Epoch 15/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1593 - my_iou_metric: 0.6983 - val_loss: 0.1732 - val_my_iou_metric: 0.7064
#
# Epoch 00015: val_my_iou_metric did not improve from 0.71300
# Epoch 16/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1489 - my_iou_metric: 0.7118 - val_loss: 0.1556 - val_my_iou_metric: 0.7297
#
# Epoch 00016: val_my_iou_metric improved from 0.71300 to 0.72975, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1468 - my_iou_metric: 0.7137 - val_loss: 0.2047 - val_my_iou_metric: 0.6869
#
# Epoch 00017: val_my_iou_metric did not improve from 0.72975
# Epoch 18/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1401 - my_iou_metric: 0.7184 - val_loss: 0.1448 - val_my_iou_metric: 0.7334
#
# Epoch 00018: val_my_iou_metric improved from 0.72975 to 0.73338, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1338 - my_iou_metric: 0.7226 - val_loss: 0.1977 - val_my_iou_metric: 0.7078
#
# Epoch 00019: val_my_iou_metric did not improve from 0.73338
# Epoch 20/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1391 - my_iou_metric: 0.7194 - val_loss: 0.1733 - val_my_iou_metric: 0.7091
#
# Epoch 00020: val_my_iou_metric did not improve from 0.73338
# Epoch 21/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1323 - my_iou_metric: 0.7296 - val_loss: 0.1545 - val_my_iou_metric: 0.7234
#
# Epoch 00021: val_my_iou_metric did not improve from 0.73338
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 22/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1188 - my_iou_metric: 0.7444 - val_loss: 0.1563 - val_my_iou_metric: 0.7475
#
# Epoch 00022: val_my_iou_metric improved from 0.73338 to 0.74750, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1144 - my_iou_metric: 0.7462 - val_loss: 0.1445 - val_my_iou_metric: 0.7582
#
# Epoch 00023: val_my_iou_metric improved from 0.74750 to 0.75825, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1087 - my_iou_metric: 0.7582 - val_loss: 0.1406 - val_my_iou_metric: 0.7662
#
# Epoch 00024: val_my_iou_metric improved from 0.75825 to 0.76625, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.1053 - my_iou_metric: 0.7614 - val_loss: 0.1418 - val_my_iou_metric: 0.7652
#
# Epoch 00025: val_my_iou_metric did not improve from 0.76625
# Epoch 26/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1021 - my_iou_metric: 0.7630 - val_loss: 0.1470 - val_my_iou_metric: 0.7530
#
# Epoch 00026: val_my_iou_metric did not improve from 0.76625
# Epoch 27/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1025 - my_iou_metric: 0.7640 - val_loss: 0.1451 - val_my_iou_metric: 0.7589
#
# Epoch 00027: val_my_iou_metric did not improve from 0.76625
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 28/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0893 - my_iou_metric: 0.7796 - val_loss: 0.1312 - val_my_iou_metric: 0.7731
#
# Epoch 00028: val_my_iou_metric improved from 0.76625 to 0.77312, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 29/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0870 - my_iou_metric: 0.7792 - val_loss: 0.1454 - val_my_iou_metric: 0.7670
#
# Epoch 00029: val_my_iou_metric did not improve from 0.77312
# Epoch 30/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0835 - my_iou_metric: 0.7821 - val_loss: 0.1272 - val_my_iou_metric: 0.7729
#
# Epoch 00030: val_my_iou_metric did not improve from 0.77312
# Epoch 31/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0825 - my_iou_metric: 0.7798 - val_loss: 0.1313 - val_my_iou_metric: 0.7761
#
# Epoch 00031: val_my_iou_metric improved from 0.77312 to 0.77612, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0797 - my_iou_metric: 0.7877 - val_loss: 0.1318 - val_my_iou_metric: 0.7755
#
# Epoch 00032: val_my_iou_metric did not improve from 0.77612
# Epoch 33/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0783 - my_iou_metric: 0.7903 - val_loss: 0.1263 - val_my_iou_metric: 0.7729
#
# Epoch 00033: val_my_iou_metric did not improve from 0.77612
# Epoch 34/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0780 - my_iou_metric: 0.7898 - val_loss: 0.1349 - val_my_iou_metric: 0.7757
#
# Epoch 00034: val_my_iou_metric did not improve from 0.77612
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 35/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0704 - my_iou_metric: 0.7966 - val_loss: 0.1378 - val_my_iou_metric: 0.7756
#
# Epoch 00035: val_my_iou_metric did not improve from 0.77612
# Epoch 36/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0689 - my_iou_metric: 0.8016 - val_loss: 0.1510 - val_my_iou_metric: 0.7729
#
# Epoch 00036: val_my_iou_metric did not improve from 0.77612
# Epoch 37/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0658 - my_iou_metric: 0.8037 - val_loss: 0.1507 - val_my_iou_metric: 0.7710
#
# Epoch 00037: val_my_iou_metric did not improve from 0.77612
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 38/200
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0633 - my_iou_metric: 0.8043 - val_loss: 0.1429 - val_my_iou_metric: 0.7756
#
# Epoch 00038: val_my_iou_metric did not improve from 0.77612
# Epoch 39/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0617 - my_iou_metric: 0.8088 - val_loss: 0.1478 - val_my_iou_metric: 0.7789
#
# Epoch 00039: val_my_iou_metric improved from 0.77612 to 0.77887, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 40/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0600 - my_iou_metric: 0.8096 - val_loss: 0.1472 - val_my_iou_metric: 0.7739
#
# Epoch 00040: val_my_iou_metric did not improve from 0.77887
# Epoch 41/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0615 - my_iou_metric: 0.8072 - val_loss: 0.1504 - val_my_iou_metric: 0.7752
#
# Epoch 00041: val_my_iou_metric did not improve from 0.77887
# Epoch 42/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0600 - my_iou_metric: 0.8109 - val_loss: 0.1537 - val_my_iou_metric: 0.7761
#
# Epoch 00042: val_my_iou_metric did not improve from 0.77887
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 43/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0593 - my_iou_metric: 0.8136 - val_loss: 0.1501 - val_my_iou_metric: 0.7801
#
# Epoch 00043: val_my_iou_metric improved from 0.77887 to 0.78013, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 44/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0579 - my_iou_metric: 0.8129 - val_loss: 0.1504 - val_my_iou_metric: 0.7810
#
# Epoch 00044: val_my_iou_metric improved from 0.78013 to 0.78100, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 45/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0579 - my_iou_metric: 0.8100 - val_loss: 0.1560 - val_my_iou_metric: 0.7757
#
# Epoch 00045: val_my_iou_metric did not improve from 0.78100
# Epoch 46/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0593 - my_iou_metric: 0.8111 - val_loss: 0.1573 - val_my_iou_metric: 0.7780
#
# Epoch 00046: val_my_iou_metric did not improve from 0.78100
# Epoch 47/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0570 - my_iou_metric: 0.8155 - val_loss: 0.1531 - val_my_iou_metric: 0.7770
#
# Epoch 00047: val_my_iou_metric did not improve from 0.78100
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 48/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0560 - my_iou_metric: 0.8151 - val_loss: 0.1544 - val_my_iou_metric: 0.7790
#
# Epoch 00048: val_my_iou_metric did not improve from 0.78100
# Epoch 49/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0560 - my_iou_metric: 0.8132 - val_loss: 0.1533 - val_my_iou_metric: 0.7786
#
# Epoch 00049: val_my_iou_metric did not improve from 0.78100
# Epoch 50/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0552 - my_iou_metric: 0.8143 - val_loss: 0.1572 - val_my_iou_metric: 0.7792
#
# Epoch 00050: val_my_iou_metric did not improve from 0.78100
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 51/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0548 - my_iou_metric: 0.8183 - val_loss: 0.1551 - val_my_iou_metric: 0.7777
#
# Epoch 00051: val_my_iou_metric did not improve from 0.78100
# Epoch 52/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0549 - my_iou_metric: 0.8171 - val_loss: 0.1575 - val_my_iou_metric: 0.7774
#
# Epoch 00052: val_my_iou_metric did not improve from 0.78100
# Epoch 53/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0556 - my_iou_metric: 0.8124 - val_loss: 0.1587 - val_my_iou_metric: 0.7785
#
# Epoch 00053: val_my_iou_metric did not improve from 0.78100
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 54/200
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0554 - my_iou_metric: 0.8169 - val_loss: 0.1582 - val_my_iou_metric: 0.7789
#
# Epoch 00054: val_my_iou_metric did not improve from 0.78100
# Epoch 00054: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)
epochs = 200
batch_size = 32

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 140s 22ms/step - loss: -0.0359 - my_iou_metric_2: 0.7779 - val_loss: 0.0354 - val_my_iou_metric_2: 0.7664
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.76637, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0600 - my_iou_metric_2: 0.7771 - val_loss: 0.1055 - val_my_iou_metric_2: 0.7608
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.76637
# Epoch 3/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.0947 - my_iou_metric_2: 0.7836 - val_loss: 0.0050 - val_my_iou_metric_2: 0.7702
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.76637 to 0.77025, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.1174 - my_iou_metric_2: 0.7857 - val_loss: 0.2092 - val_my_iou_metric_2: 0.7330
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.77025
# Epoch 5/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.1353 - my_iou_metric_2: 0.7890 - val_loss: -0.0245 - val_my_iou_metric_2: 0.7775
#
# Epoch 00005: val_my_iou_metric_2 improved from 0.77025 to 0.77750, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.1518 - my_iou_metric_2: 0.7922 - val_loss: -0.0938 - val_my_iou_metric_2: 0.7854
#
# Epoch 00006: val_my_iou_metric_2 improved from 0.77750 to 0.78538, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.1598 - my_iou_metric_2: 0.7930 - val_loss: -0.0915 - val_my_iou_metric_2: 0.7871
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.78538 to 0.78712, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.1874 - my_iou_metric_2: 0.7981 - val_loss: -0.0972 - val_my_iou_metric_2: 0.7931
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.78712 to 0.79312, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2257 - my_iou_metric_2: 0.8076 - val_loss: -0.0613 - val_my_iou_metric_2: 0.7898
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.79312
# Epoch 10/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2367 - my_iou_metric_2: 0.8078 - val_loss: -0.0132 - val_my_iou_metric_2: 0.7723
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.79312
# Epoch 11/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.2069 - my_iou_metric_2: 0.8012 - val_loss: 0.0546 - val_my_iou_metric_2: 0.7546
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.79312
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 12/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3142 - my_iou_metric_2: 0.8242 - val_loss: -0.0842 - val_my_iou_metric_2: 0.7935
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.79312 to 0.79350, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3468 - my_iou_metric_2: 0.8300 - val_loss: -0.0941 - val_my_iou_metric_2: 0.7985
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.79350 to 0.79850, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3461 - my_iou_metric_2: 0.8305 - val_loss: -0.0837 - val_my_iou_metric_2: 0.7967
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.79850
# Epoch 15/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3671 - my_iou_metric_2: 0.8350 - val_loss: -0.0658 - val_my_iou_metric_2: 0.7967
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.79850
# Epoch 16/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.3618 - my_iou_metric_2: 0.8342 - val_loss: -0.0925 - val_my_iou_metric_2: 0.7956
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.79850
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 17/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4189 - my_iou_metric_2: 0.8440 - val_loss: -0.0917 - val_my_iou_metric_2: 0.8068
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.79850 to 0.80675, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 18/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4394 - my_iou_metric_2: 0.8481 - val_loss: -0.0737 - val_my_iou_metric_2: 0.8031
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80675
# Epoch 19/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4552 - my_iou_metric_2: 0.8520 - val_loss: -0.0711 - val_my_iou_metric_2: 0.7982
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80675
# Epoch 20/200
# 6400/6400 [==============================] - 127s 20ms/step - loss: -0.4594 - my_iou_metric_2: 0.8519 - val_loss: -0.0555 - val_my_iou_metric_2: 0.8026
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.80675
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 21/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.4804 - my_iou_metric_2: 0.8562 - val_loss: -0.0910 - val_my_iou_metric_2: 0.8086
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.80675 to 0.80862, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5030 - my_iou_metric_2: 0.8620 - val_loss: -0.0646 - val_my_iou_metric_2: 0.8093
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.80862 to 0.80925, saving model to ../model/Unet_resnet_depthinchannel_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5047 - my_iou_metric_2: 0.8627 - val_loss: -0.0547 - val_my_iou_metric_2: 0.8033
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 24/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5056 - my_iou_metric_2: 0.8612 - val_loss: -0.0320 - val_my_iou_metric_2: 0.7969
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 25/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5190 - my_iou_metric_2: 0.8639 - val_loss: -0.0211 - val_my_iou_metric_2: 0.8033
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.80925
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 26/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5356 - my_iou_metric_2: 0.8664 - val_loss: -0.0182 - val_my_iou_metric_2: 0.8036
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 27/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5309 - my_iou_metric_2: 0.8654 - val_loss: -0.0358 - val_my_iou_metric_2: 0.8034
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 28/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5415 - my_iou_metric_2: 0.8678 - val_loss: -0.0012 - val_my_iou_metric_2: 0.8047
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.80925
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 29/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5488 - my_iou_metric_2: 0.8679 - val_loss: -0.0154 - val_my_iou_metric_2: 0.8046
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 30/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5521 - my_iou_metric_2: 0.8696 - val_loss: -0.0236 - val_my_iou_metric_2: 0.8041
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 31/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5525 - my_iou_metric_2: 0.8684 - val_loss: 6.1162e-04 - val_my_iou_metric_2: 0.8033
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.80925
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 32/200
# 6400/6400 [==============================] - 128s 20ms/step - loss: -0.5513 - my_iou_metric_2: 0.8699 - val_loss: -0.0098 - val_my_iou_metric_2: 0.8025
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 00032: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.804625 0.80475  0.8045   0.805    0.806625 0.806625 0.806875 0.808875
#  0.81     0.811625 0.81175  0.8115   0.8135   0.8135   0.813125 0.812875
#  0.81225  0.8125   0.813    0.81325  0.814    0.81375  0.813    0.812875
#  0.813375 0.812125 0.812125 0.81325  0.812    0.8115   0.809875]

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target)
x_test = add_depth_bulk(x_test)

preds_test = predict_result(model,x_test,img_size_target)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/res_depthinchannel.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Usedtime = 5.137999534606934 s
# save result
# upload result
# cmd: kaggle competitions submit -c tgs-salt-identification-challenge -f ../result/res_depthinchannel.csv.7z -m "submit"
# Kernel run time = 2.53469294945399 hours
