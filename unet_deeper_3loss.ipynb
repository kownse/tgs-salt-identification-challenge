# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalAveragePooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer = Conv2D(1, (1,1), padding="same", activation='relu')(uconv1)
    
#     output_layer =  Activation('sigmoid')(output_layer_noActi)

    ga = GlobalAveragePooling2D()(convm)
    ga = Dropout(DropoutRatio)(ga)
    empty = Dense(512)(ga)
    empty = BatchActivate(empty)
    empty = Dense(128)(empty)
    empty = BatchActivate(empty)
    out_empty = Dense(1, activation='sigmoid', name='empty_out')(empty)
    
    final_out_noact = multiply([output_layer, out_empty])
    final_out_noact = BatchNormalization()(final_out_noact)
    final_out =  Activation('sigmoid', name = 'segment_out')(final_out_noact)
    
    return final_out, out_empty

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
train_df['empty'] = train_df['masks'].apply(lambda x: (x.max()!=0) * 1)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df['empty'].value_counts()
# Out:
# 1    2438
# 0    1562
# Name: empty, dtype: int64

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test, empty_train, empty_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
train_df['empty'].values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
empty_train = np.append(empty_train, empty_train, axis=0)
print(x_train.shape)
print(y_valid.shape)
print(empty_train.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)
# (6400,)

# %%
start_feature = 32
batch_size = 32
dropout = 0.5
base_name = 'Unet_resnet_3loss_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer, out_empty = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, [output_layer, out_empty])

losses = {
    'empty_out' : 'binary_crossentropy',
    'segment_out': 'binary_crossentropy',
    #'final_out' : lovasz_loss,
}
lossWeights = {
    'empty_out' : 0.2,
    'segment_out':2,
    #'final_out' : 3,
}
c = optimizers.adam(lr = 0.01)
model1.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric])
# Out:
# ../model/Unet_resnet_3loss_32_32_0.5.model
# ../model/Unet_resnet_3loss_32_32_0.5.csv

# %%
y_combine_rain = {
    'empty_out' : empty_train,
    'segment_out':y_train,
    #'final_out' : y_train,
}

y_combine_test = {
    'empty_out' : empty_test,
    'segment_out':y_valid,
    #'final_out' : y_valid,
}

epochs = 200

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric', mode = 'max',patience=12, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)


history = model1.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 1.0752 - segment_out_loss: 0.4773 - empty_out_loss: 0.6027 - segment_out_my_iou_metric: 0.3632 - empty_out_my_iou_metric: 0.6816 - val_loss: 2.3064 - val_segment_out_loss: 0.6331 - val_empty_out_loss: 5.2016 - val_segment_out_my_iou_metric: 0.3900 - val_empty_out_my_iou_metric: 0.3975
#
# Epoch 00001: val_segment_out_my_iou_metric improved from -inf to 0.39000, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.8198 - segment_out_loss: 0.3579 - empty_out_loss: 0.5199 - segment_out_my_iou_metric: 0.5346 - empty_out_my_iou_metric: 0.7219 - val_loss: 3.5728 - val_segment_out_loss: 1.6691 - val_empty_out_loss: 1.1734 - val_segment_out_my_iou_metric: 0.1940 - val_empty_out_my_iou_metric: 0.6125
#
# Epoch 00002: val_segment_out_my_iou_metric did not improve from 0.39000
# Epoch 3/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.7187 - segment_out_loss: 0.3096 - empty_out_loss: 0.4978 - segment_out_my_iou_metric: 0.5604 - empty_out_my_iou_metric: 0.7467 - val_loss: 1.0558 - val_segment_out_loss: 0.4674 - val_empty_out_loss: 0.6052 - val_segment_out_my_iou_metric: 0.4133 - val_empty_out_my_iou_metric: 0.6225
#
# Epoch 00003: val_segment_out_my_iou_metric improved from 0.39000 to 0.41325, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.6590 - segment_out_loss: 0.2821 - empty_out_loss: 0.4744 - segment_out_my_iou_metric: 0.5756 - empty_out_my_iou_metric: 0.7659 - val_loss: 0.8196 - val_segment_out_loss: 0.3557 - val_empty_out_loss: 0.5410 - val_segment_out_my_iou_metric: 0.4906 - val_empty_out_my_iou_metric: 0.7612
#
# Epoch 00004: val_segment_out_my_iou_metric improved from 0.41325 to 0.49063, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.6058 - segment_out_loss: 0.2587 - empty_out_loss: 0.4422 - segment_out_my_iou_metric: 0.5979 - empty_out_my_iou_metric: 0.7784 - val_loss: 0.8191 - val_segment_out_loss: 0.3344 - val_empty_out_loss: 0.7515 - val_segment_out_my_iou_metric: 0.4246 - val_empty_out_my_iou_metric: 0.6763
#
# Epoch 00005: val_segment_out_my_iou_metric did not improve from 0.49063
# Epoch 6/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.5769 - segment_out_loss: 0.2457 - empty_out_loss: 0.4280 - segment_out_my_iou_metric: 0.6045 - empty_out_my_iou_metric: 0.7872 - val_loss: 0.6053 - val_segment_out_loss: 0.2586 - val_empty_out_loss: 0.4402 - val_segment_out_my_iou_metric: 0.5731 - val_empty_out_my_iou_metric: 0.7937
#
# Epoch 00006: val_segment_out_my_iou_metric improved from 0.49063 to 0.57312, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.5406 - segment_out_loss: 0.2284 - empty_out_loss: 0.4194 - segment_out_my_iou_metric: 0.6252 - empty_out_my_iou_metric: 0.7980 - val_loss: 0.7010 - val_segment_out_loss: 0.3005 - val_empty_out_loss: 0.4998 - val_segment_out_my_iou_metric: 0.5664 - val_empty_out_my_iou_metric: 0.8150
#
# Epoch 00007: val_segment_out_my_iou_metric did not improve from 0.57312
# Epoch 8/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.5018 - segment_out_loss: 0.2117 - empty_out_loss: 0.3915 - segment_out_my_iou_metric: 0.6402 - empty_out_my_iou_metric: 0.8200 - val_loss: 0.5207 - val_segment_out_loss: 0.2150 - val_empty_out_loss: 0.4540 - val_segment_out_my_iou_metric: 0.6761 - val_empty_out_my_iou_metric: 0.8225
#
# Epoch 00008: val_segment_out_my_iou_metric improved from 0.57312 to 0.67612, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.4749 - segment_out_loss: 0.2010 - empty_out_loss: 0.3642 - segment_out_my_iou_metric: 0.6626 - empty_out_my_iou_metric: 0.8305 - val_loss: 1.5426 - val_segment_out_loss: 0.6534 - val_empty_out_loss: 1.1796 - val_segment_out_my_iou_metric: 0.4986 - val_empty_out_my_iou_metric: 0.6088
#
# Epoch 00009: val_segment_out_my_iou_metric did not improve from 0.67612
# Epoch 10/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.4750 - segment_out_loss: 0.2015 - empty_out_loss: 0.3597 - segment_out_my_iou_metric: 0.6652 - empty_out_my_iou_metric: 0.8314 - val_loss: 0.6438 - val_segment_out_loss: 0.2391 - val_empty_out_loss: 0.8281 - val_segment_out_my_iou_metric: 0.6489 - val_empty_out_my_iou_metric: 0.6600
#
# Epoch 00010: val_segment_out_my_iou_metric did not improve from 0.67612
# Epoch 11/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.4331 - segment_out_loss: 0.1828 - empty_out_loss: 0.3371 - segment_out_my_iou_metric: 0.6869 - empty_out_my_iou_metric: 0.8375 - val_loss: 0.4429 - val_segment_out_loss: 0.1862 - val_empty_out_loss: 0.3521 - val_segment_out_my_iou_metric: 0.6898 - val_empty_out_my_iou_metric: 0.8425
#
# Epoch 00011: val_segment_out_my_iou_metric improved from 0.67612 to 0.68975, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 12/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.4257 - segment_out_loss: 0.1798 - empty_out_loss: 0.3304 - segment_out_my_iou_metric: 0.6884 - empty_out_my_iou_metric: 0.8552 - val_loss: 0.8143 - val_segment_out_loss: 0.3489 - val_empty_out_loss: 0.5822 - val_segment_out_my_iou_metric: 0.5989 - val_empty_out_my_iou_metric: 0.7150
#
# Epoch 00012: val_segment_out_my_iou_metric did not improve from 0.68975
# Epoch 13/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.4381 - segment_out_loss: 0.1860 - empty_out_loss: 0.3306 - segment_out_my_iou_metric: 0.6876 - empty_out_my_iou_metric: 0.8502 - val_loss: 0.6486 - val_segment_out_loss: 0.2797 - val_empty_out_loss: 0.4458 - val_segment_out_my_iou_metric: 0.6180 - val_empty_out_my_iou_metric: 0.7875
#
# Epoch 00013: val_segment_out_my_iou_metric did not improve from 0.68975
# Epoch 14/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.4060 - segment_out_loss: 0.1720 - empty_out_loss: 0.3104 - segment_out_my_iou_metric: 0.7057 - empty_out_my_iou_metric: 0.8613 - val_loss: 0.4490 - val_segment_out_loss: 0.1898 - val_empty_out_loss: 0.3473 - val_segment_out_my_iou_metric: 0.6879 - val_empty_out_my_iou_metric: 0.8500
#
# Epoch 00014: val_segment_out_my_iou_metric did not improve from 0.68975
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 15/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3535 - segment_out_loss: 0.1488 - empty_out_loss: 0.2791 - segment_out_my_iou_metric: 0.7352 - empty_out_my_iou_metric: 0.8812 - val_loss: 0.3836 - val_segment_out_loss: 0.1618 - val_empty_out_loss: 0.2995 - val_segment_out_my_iou_metric: 0.7295 - val_empty_out_my_iou_metric: 0.8662
#
# Epoch 00015: val_segment_out_my_iou_metric improved from 0.68975 to 0.72950, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3483 - segment_out_loss: 0.1463 - empty_out_loss: 0.2783 - segment_out_my_iou_metric: 0.7378 - empty_out_my_iou_metric: 0.8806 - val_loss: 0.3930 - val_segment_out_loss: 0.1656 - val_empty_out_loss: 0.3086 - val_segment_out_my_iou_metric: 0.7223 - val_empty_out_my_iou_metric: 0.8525
#
# Epoch 00016: val_segment_out_my_iou_metric did not improve from 0.72950
# Epoch 17/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3392 - segment_out_loss: 0.1424 - empty_out_loss: 0.2723 - segment_out_my_iou_metric: 0.7426 - empty_out_my_iou_metric: 0.8859 - val_loss: 0.4265 - val_segment_out_loss: 0.1813 - val_empty_out_loss: 0.3190 - val_segment_out_my_iou_metric: 0.7220 - val_empty_out_my_iou_metric: 0.8550
#
# Epoch 00017: val_segment_out_my_iou_metric did not improve from 0.72950
# Epoch 18/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3291 - segment_out_loss: 0.1388 - empty_out_loss: 0.2573 - segment_out_my_iou_metric: 0.7491 - empty_out_my_iou_metric: 0.8883 - val_loss: 0.3947 - val_segment_out_loss: 0.1602 - val_empty_out_loss: 0.3713 - val_segment_out_my_iou_metric: 0.7412 - val_empty_out_my_iou_metric: 0.8525
#
# Epoch 00018: val_segment_out_my_iou_metric improved from 0.72950 to 0.74125, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3269 - segment_out_loss: 0.1375 - empty_out_loss: 0.2597 - segment_out_my_iou_metric: 0.7537 - empty_out_my_iou_metric: 0.8942 - val_loss: 0.3590 - val_segment_out_loss: 0.1495 - val_empty_out_loss: 0.3003 - val_segment_out_my_iou_metric: 0.7580 - val_empty_out_my_iou_metric: 0.8700
#
# Epoch 00019: val_segment_out_my_iou_metric improved from 0.74125 to 0.75800, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3576 - segment_out_loss: 0.1503 - empty_out_loss: 0.2847 - segment_out_my_iou_metric: 0.7395 - empty_out_my_iou_metric: 0.8733 - val_loss: 0.3520 - val_segment_out_loss: 0.1477 - val_empty_out_loss: 0.2830 - val_segment_out_my_iou_metric: 0.7494 - val_empty_out_my_iou_metric: 0.8775
#
# Epoch 00020: val_segment_out_my_iou_metric did not improve from 0.75800
# Epoch 21/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3098 - segment_out_loss: 0.1298 - empty_out_loss: 0.2511 - segment_out_my_iou_metric: 0.7603 - empty_out_my_iou_metric: 0.8970 - val_loss: 0.3785 - val_segment_out_loss: 0.1513 - val_empty_out_loss: 0.3791 - val_segment_out_my_iou_metric: 0.7459 - val_empty_out_my_iou_metric: 0.8525
#
# Epoch 00021: val_segment_out_my_iou_metric did not improve from 0.75800
# Epoch 22/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.3137 - segment_out_loss: 0.1308 - empty_out_loss: 0.2604 - segment_out_my_iou_metric: 0.7534 - empty_out_my_iou_metric: 0.8884 - val_loss: 0.6018 - val_segment_out_loss: 0.2551 - val_empty_out_loss: 0.4580 - val_segment_out_my_iou_metric: 0.6698 - val_empty_out_my_iou_metric: 0.8075
#
# Epoch 00022: val_segment_out_my_iou_metric did not improve from 0.75800
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 23/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2770 - segment_out_loss: 0.1152 - empty_out_loss: 0.2334 - segment_out_my_iou_metric: 0.7738 - empty_out_my_iou_metric: 0.8967 - val_loss: 0.3200 - val_segment_out_loss: 0.1334 - val_empty_out_loss: 0.2659 - val_segment_out_my_iou_metric: 0.7617 - val_empty_out_my_iou_metric: 0.8738
#
# Epoch 00023: val_segment_out_my_iou_metric improved from 0.75800 to 0.76175, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2654 - segment_out_loss: 0.1101 - empty_out_loss: 0.2256 - segment_out_my_iou_metric: 0.7798 - empty_out_my_iou_metric: 0.9009 - val_loss: 0.3479 - val_segment_out_loss: 0.1482 - val_empty_out_loss: 0.2579 - val_segment_out_my_iou_metric: 0.7732 - val_empty_out_my_iou_metric: 0.8812
#
# Epoch 00024: val_segment_out_my_iou_metric improved from 0.76175 to 0.77325, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2650 - segment_out_loss: 0.1104 - empty_out_loss: 0.2208 - segment_out_my_iou_metric: 0.7796 - empty_out_my_iou_metric: 0.9045 - val_loss: 0.3410 - val_segment_out_loss: 0.1433 - val_empty_out_loss: 0.2720 - val_segment_out_my_iou_metric: 0.7707 - val_empty_out_my_iou_metric: 0.8812
#
# Epoch 00025: val_segment_out_my_iou_metric did not improve from 0.77325
# Epoch 26/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2544 - segment_out_loss: 0.1055 - empty_out_loss: 0.2175 - segment_out_my_iou_metric: 0.7844 - empty_out_my_iou_metric: 0.9078 - val_loss: 0.4048 - val_segment_out_loss: 0.1721 - val_empty_out_loss: 0.3034 - val_segment_out_my_iou_metric: 0.7454 - val_empty_out_my_iou_metric: 0.8550
#
# Epoch 00026: val_segment_out_my_iou_metric did not improve from 0.77325
# Epoch 27/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2547 - segment_out_loss: 0.1062 - empty_out_loss: 0.2111 - segment_out_my_iou_metric: 0.7807 - empty_out_my_iou_metric: 0.9102 - val_loss: 0.3285 - val_segment_out_loss: 0.1378 - val_empty_out_loss: 0.2648 - val_segment_out_my_iou_metric: 0.7715 - val_empty_out_my_iou_metric: 0.8788
#
# Epoch 00027: val_segment_out_my_iou_metric did not improve from 0.77325
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 28/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2361 - segment_out_loss: 0.0980 - empty_out_loss: 0.2003 - segment_out_my_iou_metric: 0.7945 - empty_out_my_iou_metric: 0.9150 - val_loss: 0.3262 - val_segment_out_loss: 0.1372 - val_empty_out_loss: 0.2589 - val_segment_out_my_iou_metric: 0.7782 - val_empty_out_my_iou_metric: 0.8875
#
# Epoch 00028: val_segment_out_my_iou_metric improved from 0.77325 to 0.77825, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 29/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2070 - segment_out_loss: 0.0853 - empty_out_loss: 0.1825 - segment_out_my_iou_metric: 0.8025 - empty_out_my_iou_metric: 0.9288 - val_loss: 0.3340 - val_segment_out_loss: 0.1410 - val_empty_out_loss: 0.2595 - val_segment_out_my_iou_metric: 0.7809 - val_empty_out_my_iou_metric: 0.8875
#
# Epoch 00029: val_segment_out_my_iou_metric improved from 0.77825 to 0.78087, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2242 - segment_out_loss: 0.0926 - empty_out_loss: 0.1945 - segment_out_my_iou_metric: 0.7969 - empty_out_my_iou_metric: 0.9233 - val_loss: 0.3438 - val_segment_out_loss: 0.1452 - val_empty_out_loss: 0.2670 - val_segment_out_my_iou_metric: 0.7810 - val_empty_out_my_iou_metric: 0.8925
#
# Epoch 00030: val_segment_out_my_iou_metric improved from 0.78087 to 0.78100, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 31/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2135 - segment_out_loss: 0.0888 - empty_out_loss: 0.1798 - segment_out_my_iou_metric: 0.8013 - empty_out_my_iou_metric: 0.9244 - val_loss: 0.3351 - val_segment_out_loss: 0.1406 - val_empty_out_loss: 0.2698 - val_segment_out_my_iou_metric: 0.7829 - val_empty_out_my_iou_metric: 0.8888
#
# Epoch 00031: val_segment_out_my_iou_metric improved from 0.78100 to 0.78288, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2044 - segment_out_loss: 0.0847 - empty_out_loss: 0.1755 - segment_out_my_iou_metric: 0.8059 - empty_out_my_iou_metric: 0.9289 - val_loss: 0.3346 - val_segment_out_loss: 0.1405 - val_empty_out_loss: 0.2678 - val_segment_out_my_iou_metric: 0.7805 - val_empty_out_my_iou_metric: 0.8875
#
# Epoch 00032: val_segment_out_my_iou_metric did not improve from 0.78288
# Epoch 33/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2025 - segment_out_loss: 0.0841 - empty_out_loss: 0.1715 - segment_out_my_iou_metric: 0.8053 - empty_out_my_iou_metric: 0.9319 - val_loss: 0.3343 - val_segment_out_loss: 0.1406 - val_empty_out_loss: 0.2656 - val_segment_out_my_iou_metric: 0.7851 - val_empty_out_my_iou_metric: 0.8912
#
# Epoch 00033: val_segment_out_my_iou_metric improved from 0.78288 to 0.78513, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 34/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.2001 - segment_out_loss: 0.0831 - empty_out_loss: 0.1690 - segment_out_my_iou_metric: 0.8066 - empty_out_my_iou_metric: 0.9298 - val_loss: 0.3499 - val_segment_out_loss: 0.1490 - val_empty_out_loss: 0.2595 - val_segment_out_my_iou_metric: 0.7801 - val_empty_out_my_iou_metric: 0.8888
#
# Epoch 00034: val_segment_out_my_iou_metric did not improve from 0.78513
# Epoch 35/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1933 - segment_out_loss: 0.0794 - empty_out_loss: 0.1721 - segment_out_my_iou_metric: 0.8075 - empty_out_my_iou_metric: 0.9314 - val_loss: 0.3688 - val_segment_out_loss: 0.1529 - val_empty_out_loss: 0.3146 - val_segment_out_my_iou_metric: 0.7844 - val_empty_out_my_iou_metric: 0.8875
#
# Epoch 00035: val_segment_out_my_iou_metric did not improve from 0.78513
# Epoch 36/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1847 - segment_out_loss: 0.0763 - empty_out_loss: 0.1606 - segment_out_my_iou_metric: 0.8110 - empty_out_my_iou_metric: 0.9344 - val_loss: 0.3598 - val_segment_out_loss: 0.1521 - val_empty_out_loss: 0.2784 - val_segment_out_my_iou_metric: 0.7732 - val_empty_out_my_iou_metric: 0.8825
#
# Epoch 00036: val_segment_out_my_iou_metric did not improve from 0.78513
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 37/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1789 - segment_out_loss: 0.0740 - empty_out_loss: 0.1550 - segment_out_my_iou_metric: 0.8137 - empty_out_my_iou_metric: 0.9359 - val_loss: 0.3425 - val_segment_out_loss: 0.1460 - val_empty_out_loss: 0.2525 - val_segment_out_my_iou_metric: 0.7847 - val_empty_out_my_iou_metric: 0.8875
#
# Epoch 00037: val_segment_out_my_iou_metric did not improve from 0.78513
# Epoch 38/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1689 - segment_out_loss: 0.0699 - empty_out_loss: 0.1454 - segment_out_my_iou_metric: 0.8205 - empty_out_my_iou_metric: 0.9425 - val_loss: 0.3639 - val_segment_out_loss: 0.1563 - val_empty_out_loss: 0.2564 - val_segment_out_my_iou_metric: 0.7833 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00038: val_segment_out_my_iou_metric did not improve from 0.78513
# Epoch 39/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1655 - segment_out_loss: 0.0681 - empty_out_loss: 0.1463 - segment_out_my_iou_metric: 0.8211 - empty_out_my_iou_metric: 0.9437 - val_loss: 0.3611 - val_segment_out_loss: 0.1541 - val_empty_out_loss: 0.2643 - val_segment_out_my_iou_metric: 0.7890 - val_empty_out_my_iou_metric: 0.8988
#
# Epoch 00039: val_segment_out_my_iou_metric improved from 0.78513 to 0.78900, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 40/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1670 - segment_out_loss: 0.0690 - empty_out_loss: 0.1451 - segment_out_my_iou_metric: 0.8225 - empty_out_my_iou_metric: 0.9431 - val_loss: 0.3361 - val_segment_out_loss: 0.1428 - val_empty_out_loss: 0.2525 - val_segment_out_my_iou_metric: 0.7876 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00040: val_segment_out_my_iou_metric did not improve from 0.78900
# Epoch 41/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1670 - segment_out_loss: 0.0689 - empty_out_loss: 0.1466 - segment_out_my_iou_metric: 0.8215 - empty_out_my_iou_metric: 0.9433 - val_loss: 0.3782 - val_segment_out_loss: 0.1572 - val_empty_out_loss: 0.3196 - val_segment_out_my_iou_metric: 0.7891 - val_empty_out_my_iou_metric: 0.8800
#
# Epoch 00041: val_segment_out_my_iou_metric improved from 0.78900 to 0.78912, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 42/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1626 - segment_out_loss: 0.0664 - empty_out_loss: 0.1496 - segment_out_my_iou_metric: 0.8230 - empty_out_my_iou_metric: 0.9406 - val_loss: 0.3529 - val_segment_out_loss: 0.1506 - val_empty_out_loss: 0.2587 - val_segment_out_my_iou_metric: 0.7937 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00042: val_segment_out_my_iou_metric improved from 0.78912 to 0.79375, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 43/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1569 - segment_out_loss: 0.0650 - empty_out_loss: 0.1349 - segment_out_my_iou_metric: 0.8253 - empty_out_my_iou_metric: 0.9455 - val_loss: 0.3383 - val_segment_out_loss: 0.1438 - val_empty_out_loss: 0.2536 - val_segment_out_my_iou_metric: 0.7969 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00043: val_segment_out_my_iou_metric improved from 0.79375 to 0.79688, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 44/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1592 - segment_out_loss: 0.0654 - empty_out_loss: 0.1420 - segment_out_my_iou_metric: 0.8284 - empty_out_my_iou_metric: 0.9466 - val_loss: 0.3609 - val_segment_out_loss: 0.1522 - val_empty_out_loss: 0.2824 - val_segment_out_my_iou_metric: 0.7929 - val_empty_out_my_iou_metric: 0.8975
#
# Epoch 00044: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 45/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1563 - segment_out_loss: 0.0650 - empty_out_loss: 0.1316 - segment_out_my_iou_metric: 0.8263 - empty_out_my_iou_metric: 0.9455 - val_loss: 0.3782 - val_segment_out_loss: 0.1619 - val_empty_out_loss: 0.2720 - val_segment_out_my_iou_metric: 0.7921 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00045: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 46/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1610 - segment_out_loss: 0.0664 - empty_out_loss: 0.1405 - segment_out_my_iou_metric: 0.8253 - empty_out_my_iou_metric: 0.9434 - val_loss: 0.3396 - val_segment_out_loss: 0.1450 - val_empty_out_loss: 0.2486 - val_segment_out_my_iou_metric: 0.7929 - val_empty_out_my_iou_metric: 0.8912
#
# Epoch 00046: val_segment_out_my_iou_metric did not improve from 0.79688
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 47/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1532 - segment_out_loss: 0.0627 - empty_out_loss: 0.1397 - segment_out_my_iou_metric: 0.8284 - empty_out_my_iou_metric: 0.9466 - val_loss: 0.3676 - val_segment_out_loss: 0.1574 - val_empty_out_loss: 0.2642 - val_segment_out_my_iou_metric: 0.7896 - val_empty_out_my_iou_metric: 0.8900
#
# Epoch 00047: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 48/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1460 - segment_out_loss: 0.0601 - empty_out_loss: 0.1294 - segment_out_my_iou_metric: 0.8302 - empty_out_my_iou_metric: 0.9466 - val_loss: 0.3638 - val_segment_out_loss: 0.1560 - val_empty_out_loss: 0.2591 - val_segment_out_my_iou_metric: 0.7907 - val_empty_out_my_iou_metric: 0.8875
#
# Epoch 00048: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 49/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1491 - segment_out_loss: 0.0619 - empty_out_loss: 0.1263 - segment_out_my_iou_metric: 0.8289 - empty_out_my_iou_metric: 0.9498 - val_loss: 0.3591 - val_segment_out_loss: 0.1532 - val_empty_out_loss: 0.2638 - val_segment_out_my_iou_metric: 0.7909 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00049: val_segment_out_my_iou_metric did not improve from 0.79688
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 50/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1468 - segment_out_loss: 0.0607 - empty_out_loss: 0.1268 - segment_out_my_iou_metric: 0.8296 - empty_out_my_iou_metric: 0.9466 - val_loss: 0.3549 - val_segment_out_loss: 0.1513 - val_empty_out_loss: 0.2618 - val_segment_out_my_iou_metric: 0.7961 - val_empty_out_my_iou_metric: 0.8975
#
# Epoch 00050: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 51/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1394 - segment_out_loss: 0.0577 - empty_out_loss: 0.1201 - segment_out_my_iou_metric: 0.8345 - empty_out_my_iou_metric: 0.9520 - val_loss: 0.3616 - val_segment_out_loss: 0.1538 - val_empty_out_loss: 0.2699 - val_segment_out_my_iou_metric: 0.7961 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00051: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 52/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1468 - segment_out_loss: 0.0610 - empty_out_loss: 0.1235 - segment_out_my_iou_metric: 0.8325 - empty_out_my_iou_metric: 0.9480 - val_loss: 0.3522 - val_segment_out_loss: 0.1497 - val_empty_out_loss: 0.2638 - val_segment_out_my_iou_metric: 0.7953 - val_empty_out_my_iou_metric: 0.8950
# Epoch 00052: val_segment_out_my_iou_metric did not improve from 0.79688
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 53/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1439 - segment_out_loss: 0.0599 - empty_out_loss: 0.1209 - segment_out_my_iou_metric: 0.8317 - empty_out_my_iou_metric: 0.9495 - val_loss: 0.3570 - val_segment_out_loss: 0.1523 - val_empty_out_loss: 0.2618 - val_segment_out_my_iou_metric: 0.7963 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00053: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 54/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1421 - segment_out_loss: 0.0587 - empty_out_loss: 0.1231 - segment_out_my_iou_metric: 0.8306 - empty_out_my_iou_metric: 0.9502 - val_loss: 0.3661 - val_segment_out_loss: 0.1562 - val_empty_out_loss: 0.2682 - val_segment_out_my_iou_metric: 0.7945 - val_empty_out_my_iou_metric: 0.9000
#
# Epoch 00054: val_segment_out_my_iou_metric did not improve from 0.79688
# Epoch 55/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1386 - segment_out_loss: 0.0573 - empty_out_loss: 0.1197 - segment_out_my_iou_metric: 0.8343 - empty_out_my_iou_metric: 0.9512 - val_loss: 0.3627 - val_segment_out_loss: 0.1549 - val_empty_out_loss: 0.2644 - val_segment_out_my_iou_metric: 0.7974 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00055: val_segment_out_my_iou_metric improved from 0.79688 to 0.79738, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 56/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1393 - segment_out_loss: 0.0577 - empty_out_loss: 0.1198 - segment_out_my_iou_metric: 0.8341 - empty_out_my_iou_metric: 0.9527 - val_loss: 0.3621 - val_segment_out_loss: 0.1545 - val_empty_out_loss: 0.2649 - val_segment_out_my_iou_metric: 0.7971 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00056: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 57/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1372 - segment_out_loss: 0.0570 - empty_out_loss: 0.1163 - segment_out_my_iou_metric: 0.8355 - empty_out_my_iou_metric: 0.9533 - val_loss: 0.3680 - val_segment_out_loss: 0.1573 - val_empty_out_loss: 0.2672 - val_segment_out_my_iou_metric: 0.7961 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00057: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 58/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1363 - segment_out_loss: 0.0563 - empty_out_loss: 0.1182 - segment_out_my_iou_metric: 0.8349 - empty_out_my_iou_metric: 0.9492 - val_loss: 0.3672 - val_segment_out_loss: 0.1571 - val_empty_out_loss: 0.2648 - val_segment_out_my_iou_metric: 0.7945 - val_empty_out_my_iou_metric: 0.8988
#
# Epoch 00058: val_segment_out_my_iou_metric did not improve from 0.79738
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 59/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1390 - segment_out_loss: 0.0579 - empty_out_loss: 0.1158 - segment_out_my_iou_metric: 0.8344 - empty_out_my_iou_metric: 0.9541 - val_loss: 0.3654 - val_segment_out_loss: 0.1553 - val_empty_out_loss: 0.2743 - val_segment_out_my_iou_metric: 0.7971 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00059: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 60/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1397 - segment_out_loss: 0.0577 - empty_out_loss: 0.1219 - segment_out_my_iou_metric: 0.8323 - empty_out_my_iou_metric: 0.9514 - val_loss: 0.3657 - val_segment_out_loss: 0.1559 - val_empty_out_loss: 0.2693 - val_segment_out_my_iou_metric: 0.7960 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00060: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 61/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1415 - segment_out_loss: 0.0586 - empty_out_loss: 0.1218 - segment_out_my_iou_metric: 0.8344 - empty_out_my_iou_metric: 0.9545 - val_loss: 0.3645 - val_segment_out_loss: 0.1556 - val_empty_out_loss: 0.2664 - val_segment_out_my_iou_metric: 0.7966 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00061: val_segment_out_my_iou_metric did not improve from 0.79738
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 62/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1393 - segment_out_loss: 0.0579 - empty_out_loss: 0.1176 - segment_out_my_iou_metric: 0.8361 - empty_out_my_iou_metric: 0.9531 - val_loss: 0.3664 - val_segment_out_loss: 0.1566 - val_empty_out_loss: 0.2663 - val_segment_out_my_iou_metric: 0.7972 - val_empty_out_my_iou_metric: 0.8925
#
# Epoch 00062: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 63/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1359 - segment_out_loss: 0.0560 - empty_out_loss: 0.1191 - segment_out_my_iou_metric: 0.8343 - empty_out_my_iou_metric: 0.9531 - val_loss: 0.3634 - val_segment_out_loss: 0.1552 - val_empty_out_loss: 0.2649 - val_segment_out_my_iou_metric: 0.7969 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00063: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 64/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1348 - segment_out_loss: 0.0553 - empty_out_loss: 0.1209 - segment_out_my_iou_metric: 0.8360 - empty_out_my_iou_metric: 0.9523 - val_loss: 0.3637 - val_segment_out_loss: 0.1554 - val_empty_out_loss: 0.2647 - val_segment_out_my_iou_metric: 0.7973 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00064: val_segment_out_my_iou_metric did not improve from 0.79738
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 65/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1359 - segment_out_loss: 0.0561 - empty_out_loss: 0.1185 - segment_out_my_iou_metric: 0.8375 - empty_out_my_iou_metric: 0.9531 - val_loss: 0.3639 - val_segment_out_loss: 0.1555 - val_empty_out_loss: 0.2646 - val_segment_out_my_iou_metric: 0.7969 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00065: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 66/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1390 - segment_out_loss: 0.0575 - empty_out_loss: 0.1203 - segment_out_my_iou_metric: 0.8353 - empty_out_my_iou_metric: 0.9525 - val_loss: 0.3652 - val_segment_out_loss: 0.1560 - val_empty_out_loss: 0.2660 - val_segment_out_my_iou_metric: 0.7966 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00066: val_segment_out_my_iou_metric did not improve from 0.79738
# Epoch 67/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1365 - segment_out_loss: 0.0571 - empty_out_loss: 0.1119 - segment_out_my_iou_metric: 0.8365 - empty_out_my_iou_metric: 0.9538 - val_loss: 0.3641 - val_segment_out_loss: 0.1557 - val_empty_out_loss: 0.2634 - val_segment_out_my_iou_metric: 0.7979 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00067: val_segment_out_my_iou_metric improved from 0.79738 to 0.79788, saving model to ../model/Unet_resnet_3loss_32_32_0.5.model
# Epoch 68/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1396 - segment_out_loss: 0.0575 - empty_out_loss: 0.1228 - segment_out_my_iou_metric: 0.8345 - empty_out_my_iou_metric: 0.9498 - val_loss: 0.3677 - val_segment_out_loss: 0.1573 - val_empty_out_loss: 0.2659 - val_segment_out_my_iou_metric: 0.7974 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00068: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 69/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1396 - segment_out_loss: 0.0577 - empty_out_loss: 0.1212 - segment_out_my_iou_metric: 0.8340 - empty_out_my_iou_metric: 0.9498 - val_loss: 0.3649 - val_segment_out_loss: 0.1560 - val_empty_out_loss: 0.2643 - val_segment_out_my_iou_metric: 0.7959 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00069: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 70/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1340 - segment_out_loss: 0.0553 - empty_out_loss: 0.1175 - segment_out_my_iou_metric: 0.8368 - empty_out_my_iou_metric: 0.9528 - val_loss: 0.3652 - val_segment_out_loss: 0.1561 - val_empty_out_loss: 0.2645 - val_segment_out_my_iou_metric: 0.7966 - val_empty_out_my_iou_metric: 0.8950
# Epoch 00070: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 71/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1352 - segment_out_loss: 0.0557 - empty_out_loss: 0.1191 - segment_out_my_iou_metric: 0.8368 - empty_out_my_iou_metric: 0.9544 - val_loss: 0.3625 - val_segment_out_loss: 0.1550 - val_empty_out_loss: 0.2627 - val_segment_out_my_iou_metric: 0.7969 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00071: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 72/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1378 - segment_out_loss: 0.0571 - empty_out_loss: 0.1179 - segment_out_my_iou_metric: 0.8352 - empty_out_my_iou_metric: 0.9536 - val_loss: 0.3659 - val_segment_out_loss: 0.1565 - val_empty_out_loss: 0.2648 - val_segment_out_my_iou_metric: 0.7971 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00072: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 73/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1361 - segment_out_loss: 0.0567 - empty_out_loss: 0.1135 - segment_out_my_iou_metric: 0.8350 - empty_out_my_iou_metric: 0.9541 - val_loss: 0.3674 - val_segment_out_loss: 0.1570 - val_empty_out_loss: 0.2671 - val_segment_out_my_iou_metric: 0.7969 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00073: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 74/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1397 - segment_out_loss: 0.0580 - empty_out_loss: 0.1187 - segment_out_my_iou_metric: 0.8337 - empty_out_my_iou_metric: 0.9514 - val_loss: 0.3672 - val_segment_out_loss: 0.1570 - val_empty_out_loss: 0.2661 - val_segment_out_my_iou_metric: 0.7976 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00074: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 75/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1362 - segment_out_loss: 0.0560 - empty_out_loss: 0.1212 - segment_out_my_iou_metric: 0.8362 - empty_out_my_iou_metric: 0.9525 - val_loss: 0.3667 - val_segment_out_loss: 0.1569 - val_empty_out_loss: 0.2649 - val_segment_out_my_iou_metric: 0.7952 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00075: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 76/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1383 - segment_out_loss: 0.0568 - empty_out_loss: 0.1235 - segment_out_my_iou_metric: 0.8373 - empty_out_my_iou_metric: 0.9525 - val_loss: 0.3649 - val_segment_out_loss: 0.1560 - val_empty_out_loss: 0.2642 - val_segment_out_my_iou_metric: 0.7961 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00076: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 77/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1340 - segment_out_loss: 0.0553 - empty_out_loss: 0.1167 - segment_out_my_iou_metric: 0.8380 - empty_out_my_iou_metric: 0.9520 - val_loss: 0.3671 - val_segment_out_loss: 0.1570 - val_empty_out_loss: 0.2652 - val_segment_out_my_iou_metric: 0.7969 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00077: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 78/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: 0.1406 - segment_out_loss: 0.0579 - empty_out_loss: 0.1241 - segment_out_my_iou_metric: 0.8354 - empty_out_my_iou_metric: 0.9503 - val_loss: 0.3691 - val_segment_out_loss: 0.1579 - val_empty_out_loss: 0.2666 - val_segment_out_my_iou_metric: 0.7958 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00078: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 79/200
# 6400/6400 [==============================] - 60s 9ms/step - loss: 0.1356 - segment_out_loss: 0.0560 - empty_out_loss: 0.1176 - segment_out_my_iou_metric: 0.8357 - empty_out_my_iou_metric: 0.9542 - val_loss: 0.3669 - val_segment_out_loss: 0.1569 - val_empty_out_loss: 0.2660 - val_segment_out_my_iou_metric: 0.7964 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00079: val_segment_out_my_iou_metric did not improve from 0.79788
# Epoch 00079: early stopping

# %%
base_name = 'Unet_resnet_3loss_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'

model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})

# %%
base_name = 'Unet_resnet_3loss_stage2_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

input_x = model1.layers[0].input
model1.layers[-1].name = 'segment_out_old'

output_layer = model1.layers[-2]
output_layer.name = 'segment_out'
output_layer = output_layer.output

empty_out = model1.get_layer("empty_out").output
model = Model(input_x, [output_layer, empty_out])
c = optimizers.adam(lr = 0.01)

losses = {
    'empty_out' : 'binary_crossentropy',
    'segment_out': lovasz_loss,
    #'final_out' : lovasz_loss,
}
lossWeights = {
    'empty_out' : 0.2,
    'segment_out':2,
    #'final_out' : 3,
}
model.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric_2])

early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric_2', mode = 'max',patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric_2', mode = 'max',factor=0.5, patience=4, min_lr=0.00001, verbose=1)


history = model.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 110s 17ms/step - loss: 0.2401 - segment_out_loss: 0.0865 - empty_out_loss: 0.3355 - segment_out_my_iou_metric_2: 0.7395 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.2852 - val_segment_out_loss: 0.1129 - val_empty_out_loss: 0.2969 - val_segment_out_my_iou_metric_2: 0.7305 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00001: val_segment_out_my_iou_metric_2 improved from -inf to 0.73050, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: -0.0955 - segment_out_loss: -0.0777 - empty_out_loss: 0.2999 - segment_out_my_iou_metric_2: 0.7653 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.2866 - val_segment_out_loss: 0.1159 - val_empty_out_loss: 0.2741 - val_segment_out_my_iou_metric_2: 0.7425 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00002: val_segment_out_my_iou_metric_2 improved from 0.73050 to 0.74250, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1551 - segment_out_loss: -0.1054 - empty_out_loss: 0.2787 - segment_out_my_iou_metric_2: 0.7695 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0393 - val_segment_out_loss: -0.0096 - val_empty_out_loss: 0.2925 - val_segment_out_my_iou_metric_2: 0.7479 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00003: val_segment_out_my_iou_metric_2 improved from 0.74250 to 0.74788, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.2403 - segment_out_loss: -0.1448 - empty_out_loss: 0.2464 - segment_out_my_iou_metric_2: 0.7747 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.4515 - val_segment_out_loss: 0.1947 - val_empty_out_loss: 0.3103 - val_segment_out_my_iou_metric_2: 0.7420 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00004: val_segment_out_my_iou_metric_2 did not improve from 0.74788
# Epoch 5/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.2779 - segment_out_loss: -0.1627 - empty_out_loss: 0.2373 - segment_out_my_iou_metric_2: 0.7800 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1408 - val_segment_out_loss: -0.0963 - val_empty_out_loss: 0.2593 - val_segment_out_my_iou_metric_2: 0.7742 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00005: val_segment_out_my_iou_metric_2 improved from 0.74788 to 0.77425, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.2785 - segment_out_loss: -0.1622 - empty_out_loss: 0.2299 - segment_out_my_iou_metric_2: 0.7848 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.6566 - val_segment_out_loss: 0.2838 - val_empty_out_loss: 0.4450 - val_segment_out_my_iou_metric_2: 0.7051 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00006: val_segment_out_my_iou_metric_2 did not improve from 0.77425
# Epoch 7/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3072 - segment_out_loss: -0.1760 - empty_out_loss: 0.2242 - segment_out_my_iou_metric_2: 0.7854 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0013 - val_segment_out_loss: -0.0271 - val_empty_out_loss: 0.2775 - val_segment_out_my_iou_metric_2: 0.7808 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00007: val_segment_out_my_iou_metric_2 improved from 0.77425 to 0.78075, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3624 - segment_out_loss: -0.2027 - empty_out_loss: 0.2151 - segment_out_my_iou_metric_2: 0.7879 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.5011 - val_segment_out_loss: 0.2066 - val_empty_out_loss: 0.4392 - val_segment_out_my_iou_metric_2: 0.7479 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00008: val_segment_out_my_iou_metric_2 did not improve from 0.78075
# Epoch 9/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4102 - segment_out_loss: -0.2251 - empty_out_loss: 0.2001 - segment_out_my_iou_metric_2: 0.7955 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0136 - val_segment_out_loss: -0.0349 - val_empty_out_loss: 0.2812 - val_segment_out_my_iou_metric_2: 0.7623 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00009: val_segment_out_my_iou_metric_2 did not improve from 0.78075
# Epoch 10/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4330 - segment_out_loss: -0.2359 - empty_out_loss: 0.1934 - segment_out_my_iou_metric_2: 0.7963 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0298 - val_segment_out_loss: -0.0471 - val_empty_out_loss: 0.3214 - val_segment_out_my_iou_metric_2: 0.7805 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00010: val_segment_out_my_iou_metric_2 did not improve from 0.78075
# Epoch 11/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4565 - segment_out_loss: -0.2476 - empty_out_loss: 0.1940 - segment_out_my_iou_metric_2: 0.8004 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0334 - val_segment_out_loss: -0.0154 - val_empty_out_loss: 0.3207 - val_segment_out_my_iou_metric_2: 0.7666 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00011: val_segment_out_my_iou_metric_2 did not improve from 0.78075
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 12/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.6102 - segment_out_loss: -0.3219 - empty_out_loss: 0.1676 - segment_out_my_iou_metric_2: 0.8190 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2845 - val_segment_out_loss: -0.1679 - val_empty_out_loss: 0.2559 - val_segment_out_my_iou_metric_2: 0.7926 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00012: val_segment_out_my_iou_metric_2 improved from 0.78075 to 0.79262, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.6755 - segment_out_loss: -0.3530 - empty_out_loss: 0.1528 - segment_out_my_iou_metric_2: 0.8265 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.3730 - val_segment_out_loss: 0.1256 - val_empty_out_loss: 0.6090 - val_segment_out_my_iou_metric_2: 0.7771 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00013: val_segment_out_my_iou_metric_2 did not improve from 0.79262
# Epoch 14/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.6693 - segment_out_loss: -0.3498 - empty_out_loss: 0.1514 - segment_out_my_iou_metric_2: 0.8262 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1153 - val_segment_out_loss: -0.0880 - val_empty_out_loss: 0.3032 - val_segment_out_my_iou_metric_2: 0.7942 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00014: val_segment_out_my_iou_metric_2 improved from 0.79262 to 0.79425, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.6803 - segment_out_loss: -0.3549 - empty_out_loss: 0.1472 - segment_out_my_iou_metric_2: 0.8260 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1760 - val_segment_out_loss: -0.1138 - val_empty_out_loss: 0.2581 - val_segment_out_my_iou_metric_2: 0.7904 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00015: val_segment_out_my_iou_metric_2 did not improve from 0.79425
# Epoch 16/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.7372 - segment_out_loss: -0.3826 - empty_out_loss: 0.1399 - segment_out_my_iou_metric_2: 0.8290 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2168 - val_segment_out_loss: -0.1342 - val_empty_out_loss: 0.2579 - val_segment_out_my_iou_metric_2: 0.7913 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00016: val_segment_out_my_iou_metric_2 did not improve from 0.79425
# Epoch 17/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.7543 - segment_out_loss: -0.3906 - empty_out_loss: 0.1343 - segment_out_my_iou_metric_2: 0.8323 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2411 - val_segment_out_loss: -0.1482 - val_empty_out_loss: 0.2761 - val_segment_out_my_iou_metric_2: 0.7931 - val_empty_out_my_iou_metric_2: 0.6100
# Epoch 00017: val_segment_out_my_iou_metric_2 did not improve from 0.79425
# Epoch 18/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.7329 - segment_out_loss: -0.3797 - empty_out_loss: 0.1319 - segment_out_my_iou_metric_2: 0.8314 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1616 - val_segment_out_loss: -0.1151 - val_empty_out_loss: 0.3426 - val_segment_out_my_iou_metric_2: 0.8017 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00018: val_segment_out_my_iou_metric_2 improved from 0.79425 to 0.80175, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.8042 - segment_out_loss: -0.4145 - empty_out_loss: 0.1245 - segment_out_my_iou_metric_2: 0.8375 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.2171 - val_segment_out_loss: 0.0502 - val_empty_out_loss: 0.5838 - val_segment_out_my_iou_metric_2: 0.7885 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00019: val_segment_out_my_iou_metric_2 did not improve from 0.80175
# Epoch 20/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.7676 - segment_out_loss: -0.3971 - empty_out_loss: 0.1331 - segment_out_my_iou_metric_2: 0.8336 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1083 - val_segment_out_loss: -0.0881 - val_empty_out_loss: 0.3399 - val_segment_out_my_iou_metric_2: 0.7949 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00020: val_segment_out_my_iou_metric_2 did not improve from 0.80175
# Epoch 21/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.8132 - segment_out_loss: -0.4188 - empty_out_loss: 0.1217 - segment_out_my_iou_metric_2: 0.8381 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2896 - val_segment_out_loss: -0.1740 - val_empty_out_loss: 0.2923 - val_segment_out_my_iou_metric_2: 0.8056 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00021: val_segment_out_my_iou_metric_2 improved from 0.80175 to 0.80563, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.8620 - segment_out_loss: -0.4424 - empty_out_loss: 0.1137 - segment_out_my_iou_metric_2: 0.8438 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2060 - val_segment_out_loss: -0.1354 - val_empty_out_loss: 0.3235 - val_segment_out_my_iou_metric_2: 0.8016 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00022: val_segment_out_my_iou_metric_2 did not improve from 0.80563
# Epoch 23/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.8380 - segment_out_loss: -0.4310 - empty_out_loss: 0.1200 - segment_out_my_iou_metric_2: 0.8436 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0816 - val_segment_out_loss: -0.0719 - val_empty_out_loss: 0.3109 - val_segment_out_my_iou_metric_2: 0.7891 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00023: val_segment_out_my_iou_metric_2 did not improve from 0.80563
# Epoch 24/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.8456 - segment_out_loss: -0.4343 - empty_out_loss: 0.1152 - segment_out_my_iou_metric_2: 0.8405 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0277 - val_segment_out_loss: -0.0466 - val_empty_out_loss: 0.3276 - val_segment_out_my_iou_metric_2: 0.7767 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00024: val_segment_out_my_iou_metric_2 did not improve from 0.80563
# Epoch 25/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.8921 - segment_out_loss: -0.4569 - empty_out_loss: 0.1084 - segment_out_my_iou_metric_2: 0.8478 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1626 - val_segment_out_loss: -0.1140 - val_empty_out_loss: 0.3273 - val_segment_out_my_iou_metric_2: 0.8028 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00025: val_segment_out_my_iou_metric_2 did not improve from 0.80563
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 26/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.9853 - segment_out_loss: -0.5020 - empty_out_loss: 0.0935 - segment_out_my_iou_metric_2: 0.8579 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0267 - val_segment_out_loss: -0.0503 - val_empty_out_loss: 0.3694 - val_segment_out_my_iou_metric_2: 0.8033 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00026: val_segment_out_my_iou_metric_2 did not improve from 0.80563
# Epoch 27/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.0280 - segment_out_loss: -0.5219 - empty_out_loss: 0.0787 - segment_out_my_iou_metric_2: 0.8606 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2846 - val_segment_out_loss: -0.1698 - val_empty_out_loss: 0.2747 - val_segment_out_my_iou_metric_2: 0.8080 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00027: val_segment_out_my_iou_metric_2 improved from 0.80563 to 0.80800, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.0406 - segment_out_loss: -0.5280 - empty_out_loss: 0.0765 - segment_out_my_iou_metric_2: 0.8647 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2029 - val_segment_out_loss: -0.1295 - val_empty_out_loss: 0.2803 - val_segment_out_my_iou_metric_2: 0.8034 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00028: val_segment_out_my_iou_metric_2 did not improve from 0.80800
# Epoch 29/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.0285 - segment_out_loss: -0.5223 - empty_out_loss: 0.0804 - segment_out_my_iou_metric_2: 0.8617 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2329 - val_segment_out_loss: -0.1445 - val_empty_out_loss: 0.2809 - val_segment_out_my_iou_metric_2: 0.8005 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00029: val_segment_out_my_iou_metric_2 did not improve from 0.80800
# Epoch 30/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.0614 - segment_out_loss: -0.5380 - empty_out_loss: 0.0730 - segment_out_my_iou_metric_2: 0.8667 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1688 - val_segment_out_loss: -0.1137 - val_empty_out_loss: 0.2931 - val_segment_out_my_iou_metric_2: 0.8031 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00030: val_segment_out_my_iou_metric_2 did not improve from 0.80800
# Epoch 31/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.0406 - segment_out_loss: -0.5280 - empty_out_loss: 0.0771 - segment_out_my_iou_metric_2: 0.8623 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3248 - val_segment_out_loss: -0.1874 - val_empty_out_loss: 0.2507 - val_segment_out_my_iou_metric_2: 0.8091 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00031: val_segment_out_my_iou_metric_2 improved from 0.80800 to 0.80913, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.0775 - segment_out_loss: -0.5457 - empty_out_loss: 0.0698 - segment_out_my_iou_metric_2: 0.8676 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1685 - val_segment_out_loss: -0.1140 - val_empty_out_loss: 0.2971 - val_segment_out_my_iou_metric_2: 0.7989 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00032: val_segment_out_my_iou_metric_2 did not improve from 0.80913
# Epoch 33/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.1018 - segment_out_loss: -0.5572 - empty_out_loss: 0.0633 - segment_out_my_iou_metric_2: 0.8679 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1555 - val_segment_out_loss: -0.1107 - val_empty_out_loss: 0.3295 - val_segment_out_my_iou_metric_2: 0.8101 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00033: val_segment_out_my_iou_metric_2 improved from 0.80913 to 0.81012, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 34/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.0919 - segment_out_loss: -0.5528 - empty_out_loss: 0.0681 - segment_out_my_iou_metric_2: 0.8709 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0438 - val_segment_out_loss: -0.0138 - val_empty_out_loss: 0.3572 - val_segment_out_my_iou_metric_2: 0.7948 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00034: val_segment_out_my_iou_metric_2 did not improve from 0.81012
# Epoch 35/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.1091 - segment_out_loss: -0.5608 - empty_out_loss: 0.0619 - segment_out_my_iou_metric_2: 0.8713 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1278 - val_segment_out_loss: -0.0945 - val_empty_out_loss: 0.3062 - val_segment_out_my_iou_metric_2: 0.7983 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00035: val_segment_out_my_iou_metric_2 did not improve from 0.81012
# Epoch 36/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.1120 - segment_out_loss: -0.5626 - empty_out_loss: 0.0660 - segment_out_my_iou_metric_2: 0.8717 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1665 - val_segment_out_loss: -0.1157 - val_empty_out_loss: 0.3252 - val_segment_out_my_iou_metric_2: 0.8095 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00036: val_segment_out_my_iou_metric_2 did not improve from 0.81012
# Epoch 37/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.1203 - segment_out_loss: -0.5663 - empty_out_loss: 0.0611 - segment_out_my_iou_metric_2: 0.8706 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1008 - val_segment_out_loss: -0.0864 - val_empty_out_loss: 0.3597 - val_segment_out_my_iou_metric_2: 0.8051 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00037: val_segment_out_my_iou_metric_2 did not improve from 0.81012
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 38/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.1526 - segment_out_loss: -0.5822 - empty_out_loss: 0.0595 - segment_out_my_iou_metric_2: 0.8757 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2679 - val_segment_out_loss: -0.1636 - val_empty_out_loss: 0.2969 - val_segment_out_my_iou_metric_2: 0.8105 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00038: val_segment_out_my_iou_metric_2 improved from 0.81012 to 0.81050, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 39/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.1731 - segment_out_loss: -0.5920 - empty_out_loss: 0.0544 - segment_out_my_iou_metric_2: 0.8782 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1711 - val_segment_out_loss: -0.1187 - val_empty_out_loss: 0.3317 - val_segment_out_my_iou_metric_2: 0.8102 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00039: val_segment_out_my_iou_metric_2 did not improve from 0.81050
# Epoch 40/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.1988 - segment_out_loss: -0.6041 - empty_out_loss: 0.0469 - segment_out_my_iou_metric_2: 0.8810 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1531 - val_segment_out_loss: -0.1094 - val_empty_out_loss: 0.3283 - val_segment_out_my_iou_metric_2: 0.8037 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00040: val_segment_out_my_iou_metric_2 did not improve from 0.81050
# Epoch 41/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2016 - segment_out_loss: -0.6058 - empty_out_loss: 0.0501 - segment_out_my_iou_metric_2: 0.8813 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1598 - val_segment_out_loss: -0.1130 - val_empty_out_loss: 0.3313 - val_segment_out_my_iou_metric_2: 0.8084 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00041: val_segment_out_my_iou_metric_2 did not improve from 0.81050
# Epoch 42/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2124 - segment_out_loss: -0.6109 - empty_out_loss: 0.0472 - segment_out_my_iou_metric_2: 0.8833 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0749 - val_segment_out_loss: -0.0759 - val_empty_out_loss: 0.3844 - val_segment_out_my_iou_metric_2: 0.8081 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00042: val_segment_out_my_iou_metric_2 did not improve from 0.81050
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 43/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2297 - segment_out_loss: -0.6194 - empty_out_loss: 0.0451 - segment_out_my_iou_metric_2: 0.8848 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0821 - val_segment_out_loss: -0.0777 - val_empty_out_loss: 0.3662 - val_segment_out_my_iou_metric_2: 0.8074 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00043: val_segment_out_my_iou_metric_2 did not improve from 0.81050
# Epoch 44/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2307 - segment_out_loss: -0.6199 - empty_out_loss: 0.0452 - segment_out_my_iou_metric_2: 0.8861 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1084 - val_segment_out_loss: -0.0891 - val_empty_out_loss: 0.3490 - val_segment_out_my_iou_metric_2: 0.8100 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00044: val_segment_out_my_iou_metric_2 did not improve from 0.81050
# Epoch 45/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2494 - segment_out_loss: -0.6289 - empty_out_loss: 0.0420 - segment_out_my_iou_metric_2: 0.8872 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0978 - val_segment_out_loss: -0.0858 - val_empty_out_loss: 0.3690 - val_segment_out_my_iou_metric_2: 0.8091 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00045: val_segment_out_my_iou_metric_2 did not improve from 0.81050
# Epoch 46/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2454 - segment_out_loss: -0.6271 - empty_out_loss: 0.0439 - segment_out_my_iou_metric_2: 0.8888 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1339 - val_segment_out_loss: -0.1006 - val_empty_out_loss: 0.3364 - val_segment_out_my_iou_metric_2: 0.8075 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00046: val_segment_out_my_iou_metric_2 did not improve from 0.81050
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 47/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2424 - segment_out_loss: -0.6254 - empty_out_loss: 0.0421 - segment_out_my_iou_metric_2: 0.8873 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1635 - val_segment_out_loss: -0.1151 - val_empty_out_loss: 0.3333 - val_segment_out_my_iou_metric_2: 0.8096 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00047: val_segment_out_my_iou_metric_2 did not improve from 0.81050
# Epoch 48/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2500 - segment_out_loss: -0.6293 - empty_out_loss: 0.0434 - segment_out_my_iou_metric_2: 0.8872 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1498 - val_segment_out_loss: -0.1088 - val_empty_out_loss: 0.3388 - val_segment_out_my_iou_metric_2: 0.8125 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00048: val_segment_out_my_iou_metric_2 improved from 0.81050 to 0.81250, saving model to ../model/Unet_resnet_3loss_stage2_32_32_0.5.model
# Epoch 49/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2673 - segment_out_loss: -0.6376 - empty_out_loss: 0.0394 - segment_out_my_iou_metric_2: 0.8899 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1823 - val_segment_out_loss: -0.1234 - val_empty_out_loss: 0.3222 - val_segment_out_my_iou_metric_2: 0.8111 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00049: val_segment_out_my_iou_metric_2 did not improve from 0.81250
# Epoch 50/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2672 - segment_out_loss: -0.6375 - empty_out_loss: 0.0389 - segment_out_my_iou_metric_2: 0.8900 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1259 - val_segment_out_loss: -0.0977 - val_empty_out_loss: 0.3478 - val_segment_out_my_iou_metric_2: 0.8106 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00050: val_segment_out_my_iou_metric_2 did not improve from 0.81250
# Epoch 51/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2635 - segment_out_loss: -0.6356 - empty_out_loss: 0.0384 - segment_out_my_iou_metric_2: 0.8890 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1564 - val_segment_out_loss: -0.1104 - val_empty_out_loss: 0.3219 - val_segment_out_my_iou_metric_2: 0.8104 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00051: val_segment_out_my_iou_metric_2 did not improve from 0.81250
# Epoch 52/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2697 - segment_out_loss: -0.6386 - empty_out_loss: 0.0376 - segment_out_my_iou_metric_2: 0.8906 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1516 - val_segment_out_loss: -0.1089 - val_empty_out_loss: 0.3308 - val_segment_out_my_iou_metric_2: 0.8105 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00052: val_segment_out_my_iou_metric_2 did not improve from 0.81250
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 53/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2641 - segment_out_loss: -0.6358 - empty_out_loss: 0.0376 - segment_out_my_iou_metric_2: 0.8898 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1426 - val_segment_out_loss: -0.1050 - val_empty_out_loss: 0.3370 - val_segment_out_my_iou_metric_2: 0.8087 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00053: val_segment_out_my_iou_metric_2 did not improve from 0.81250
# Epoch 54/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2880 - segment_out_loss: -0.6474 - empty_out_loss: 0.0344 - segment_out_my_iou_metric_2: 0.8917 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1541 - val_segment_out_loss: -0.1109 - val_empty_out_loss: 0.3386 - val_segment_out_my_iou_metric_2: 0.8100 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00054: val_segment_out_my_iou_metric_2 did not improve from 0.81250
# Epoch 55/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -1.2820 - segment_out_loss: -0.6447 - empty_out_loss: 0.0371 - segment_out_my_iou_metric_2: 0.8922 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1363 - val_segment_out_loss: -0.1021 - val_empty_out_loss: 0.3398 - val_segment_out_my_iou_metric_2: 0.8112 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00055: val_segment_out_my_iou_metric_2 did not improve from 0.81250
# Epoch 56/200
# 5472/6400 [========================>.....] - ETA: 13s - loss: -1.2790 - segment_out_loss: -0.6431 - empty_out_loss: 0.0361 - segment_out_my_iou_metric_2: 0.8920 - empty_out_my_iou_metric_2: 0.6056
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-8973dd949c8e> in <module>()
#      39                     batch_size=batch_size,
#      40                     callbacks=[board, early_stopping, model_checkpoint,reduce_lr],
# ---> 41                     verbose=1)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
