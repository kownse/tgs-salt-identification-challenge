# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalAveragePooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer = Conv2D(1, (1,1), padding="same", activation='relu')(uconv1)
    
#     output_layer =  Activation('sigmoid')(output_layer_noActi)

    ga = GlobalAveragePooling2D()(convm)
    ga = Dropout(DropoutRatio)(ga)
    empty = Dense(512, kernel_initializer='he_uniform')(ga)
    empty = BatchActivate(empty)
    empty = Dense(128, kernel_initializer='he_uniform')(empty)
    empty = BatchActivate(empty)
    out_empty = Dense(1, activation='sigmoid', name='empty_out')(empty)
    
    final_out_noact = multiply([output_layer, out_empty])
    final_out_noact = BatchNormalization()(final_out_noact)
    final_out =  Activation('sigmoid', name = 'segment_out')(final_out_noact)
    
    return final_out, out_empty

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
train_df['empty'] = train_df['masks'].apply(lambda x: (x.max()!=0) * 1)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df['empty'].value_counts()
# Out:
# 1    2438
# 0    1562
# Name: empty, dtype: int64

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test, empty_train, empty_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
train_df['empty'].values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
empty_train = np.append(empty_train, empty_train, axis=0)
print(x_train.shape)
print(y_valid.shape)
print(empty_train.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)
# (6400,)

# %%
start_feature = 32
batch_size = 32
dropout = 0.5
base_name = 'Unet_resnet_3loss_cse_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer, out_empty = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, [output_layer, out_empty])

losses = {
    'empty_out' : 'binary_crossentropy',
    'segment_out': 'binary_crossentropy',
    #'final_out' : lovasz_loss,
}
lossWeights = {
    'empty_out' : 0.2,
    'segment_out':2,
    #'final_out' : 3,
}
c = optimizers.adam(lr = 0.01)
model1.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric])
# Out:
# ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# ../model/Unet_resnet_3loss_cse_32_32_0.5.csv

# %%
y_combine_rain = {
    'empty_out' : empty_train,
    'segment_out':y_train,
    #'final_out' : y_train,
}

y_combine_test = {
    'empty_out' : empty_test,
    'segment_out':y_valid,
    #'final_out' : y_valid,
}

epochs = 200

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric', mode = 'max',patience=12, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)


history = model1.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 82s 13ms/step - loss: 1.0547 - segment_out_loss: 0.4701 - empty_out_loss: 0.5723 - segment_out_my_iou_metric: 0.4262 - empty_out_my_iou_metric: 0.7047 - val_loss: 2.8564 - val_segment_out_loss: 0.6282 - val_empty_out_loss: 8.0001 - val_segment_out_my_iou_metric: 0.3900 - val_empty_out_my_iou_metric: 0.4000
#
# Epoch 00001: val_segment_out_my_iou_metric improved from -inf to 0.39000, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.8273 - segment_out_loss: 0.3635 - empty_out_loss: 0.5012 - segment_out_my_iou_metric: 0.5081 - empty_out_my_iou_metric: 0.7694 - val_loss: 1.6388 - val_segment_out_loss: 0.6879 - val_empty_out_loss: 1.3148 - val_segment_out_my_iou_metric: 0.3969 - val_empty_out_my_iou_metric: 0.4650
#
# Epoch 00002: val_segment_out_my_iou_metric improved from 0.39000 to 0.39688, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.7017 - segment_out_loss: 0.3067 - empty_out_loss: 0.4413 - segment_out_my_iou_metric: 0.5620 - empty_out_my_iou_metric: 0.7897 - val_loss: 1.0570 - val_segment_out_loss: 0.4840 - val_empty_out_loss: 0.4445 - val_segment_out_my_iou_metric: 0.4872 - val_empty_out_my_iou_metric: 0.8050
#
# Epoch 00003: val_segment_out_my_iou_metric improved from 0.39688 to 0.48725, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.6427 - segment_out_loss: 0.2800 - empty_out_loss: 0.4130 - segment_out_my_iou_metric: 0.5887 - empty_out_my_iou_metric: 0.7988 - val_loss: 1.0633 - val_segment_out_loss: 0.4785 - val_empty_out_loss: 0.5318 - val_segment_out_my_iou_metric: 0.4564 - val_empty_out_my_iou_metric: 0.7250
#
# Epoch 00004: val_segment_out_my_iou_metric did not improve from 0.48725
# Epoch 5/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.5981 - segment_out_loss: 0.2585 - empty_out_loss: 0.4056 - segment_out_my_iou_metric: 0.6111 - empty_out_my_iou_metric: 0.7953 - val_loss: 0.7682 - val_segment_out_loss: 0.3427 - val_empty_out_loss: 0.4133 - val_segment_out_my_iou_metric: 0.5650 - val_empty_out_my_iou_metric: 0.8237
#
# Epoch 00005: val_segment_out_my_iou_metric improved from 0.48725 to 0.56500, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.5780 - segment_out_loss: 0.2487 - empty_out_loss: 0.4029 - segment_out_my_iou_metric: 0.6185 - empty_out_my_iou_metric: 0.8039 - val_loss: 0.6876 - val_segment_out_loss: 0.2986 - val_empty_out_loss: 0.4519 - val_segment_out_my_iou_metric: 0.6169 - val_empty_out_my_iou_metric: 0.7800
#
# Epoch 00006: val_segment_out_my_iou_metric improved from 0.56500 to 0.61687, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.5336 - segment_out_loss: 0.2284 - empty_out_loss: 0.3839 - segment_out_my_iou_metric: 0.6395 - empty_out_my_iou_metric: 0.8175 - val_loss: 0.8268 - val_segment_out_loss: 0.3563 - val_empty_out_loss: 0.5711 - val_segment_out_my_iou_metric: 0.5241 - val_empty_out_my_iou_metric: 0.7575
#
# Epoch 00007: val_segment_out_my_iou_metric did not improve from 0.61687
# Epoch 8/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.5078 - segment_out_loss: 0.2165 - empty_out_loss: 0.3740 - segment_out_my_iou_metric: 0.6520 - empty_out_my_iou_metric: 0.8198 - val_loss: 0.9594 - val_segment_out_loss: 0.3954 - val_empty_out_loss: 0.8428 - val_segment_out_my_iou_metric: 0.4286 - val_empty_out_my_iou_metric: 0.6825
#
# Epoch 00008: val_segment_out_my_iou_metric did not improve from 0.61687
# Epoch 9/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.4751 - segment_out_loss: 0.2020 - empty_out_loss: 0.3553 - segment_out_my_iou_metric: 0.6688 - empty_out_my_iou_metric: 0.8358 - val_loss: 0.4686 - val_segment_out_loss: 0.1952 - val_empty_out_loss: 0.3914 - val_segment_out_my_iou_metric: 0.6684 - val_empty_out_my_iou_metric: 0.8075
#
# Epoch 00009: val_segment_out_my_iou_metric improved from 0.61687 to 0.66837, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.4590 - segment_out_loss: 0.1949 - empty_out_loss: 0.3461 - segment_out_my_iou_metric: 0.6834 - empty_out_my_iou_metric: 0.8392 - val_loss: 0.8172 - val_segment_out_loss: 0.3600 - val_empty_out_loss: 0.4862 - val_segment_out_my_iou_metric: 0.5923 - val_empty_out_my_iou_metric: 0.7312
#
# Epoch 00010: val_segment_out_my_iou_metric did not improve from 0.66837
# Epoch 11/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.4425 - segment_out_loss: 0.1874 - empty_out_loss: 0.3391 - segment_out_my_iou_metric: 0.6940 - empty_out_my_iou_metric: 0.8422 - val_loss: 0.6172 - val_segment_out_loss: 0.2614 - val_empty_out_loss: 0.4719 - val_segment_out_my_iou_metric: 0.6285 - val_empty_out_my_iou_metric: 0.7412
#
# Epoch 00011: val_segment_out_my_iou_metric did not improve from 0.66837
# Epoch 12/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.4255 - segment_out_loss: 0.1799 - empty_out_loss: 0.3282 - segment_out_my_iou_metric: 0.7030 - empty_out_my_iou_metric: 0.8516 - val_loss: 0.8240 - val_segment_out_loss: 0.3523 - val_empty_out_loss: 0.5967 - val_segment_out_my_iou_metric: 0.6040 - val_empty_out_my_iou_metric: 0.7225
#
# Epoch 00012: val_segment_out_my_iou_metric did not improve from 0.66837
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 13/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.3848 - segment_out_loss: 0.1626 - empty_out_loss: 0.2975 - segment_out_my_iou_metric: 0.7207 - empty_out_my_iou_metric: 0.8689 - val_loss: 0.4137 - val_segment_out_loss: 0.1735 - val_empty_out_loss: 0.3333 - val_segment_out_my_iou_metric: 0.7244 - val_empty_out_my_iou_metric: 0.8638
#
# Epoch 00013: val_segment_out_my_iou_metric improved from 0.66837 to 0.72437, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.3543 - segment_out_loss: 0.1494 - empty_out_loss: 0.2777 - segment_out_my_iou_metric: 0.7362 - empty_out_my_iou_metric: 0.8780 - val_loss: 0.6324 - val_segment_out_loss: 0.2622 - val_empty_out_loss: 0.5399 - val_segment_out_my_iou_metric: 0.6489 - val_empty_out_my_iou_metric: 0.7762
#
# Epoch 00014: val_segment_out_my_iou_metric did not improve from 0.72437
# Epoch 15/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.3654 - segment_out_loss: 0.1538 - empty_out_loss: 0.2886 - segment_out_my_iou_metric: 0.7318 - empty_out_my_iou_metric: 0.8733 - val_loss: 0.3750 - val_segment_out_loss: 0.1563 - val_empty_out_loss: 0.3125 - val_segment_out_my_iou_metric: 0.7347 - val_empty_out_my_iou_metric: 0.8562
#
# Epoch 00015: val_segment_out_my_iou_metric improved from 0.72437 to 0.73475, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.3431 - segment_out_loss: 0.1442 - empty_out_loss: 0.2735 - segment_out_my_iou_metric: 0.7463 - empty_out_my_iou_metric: 0.8822 - val_loss: 0.3636 - val_segment_out_loss: 0.1517 - val_empty_out_loss: 0.3011 - val_segment_out_my_iou_metric: 0.7468 - val_empty_out_my_iou_metric: 0.8625
#
# Epoch 00016: val_segment_out_my_iou_metric improved from 0.73475 to 0.74675, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.3436 - segment_out_loss: 0.1438 - empty_out_loss: 0.2803 - segment_out_my_iou_metric: 0.7465 - empty_out_my_iou_metric: 0.8783 - val_loss: 0.3418 - val_segment_out_loss: 0.1426 - val_empty_out_loss: 0.2825 - val_segment_out_my_iou_metric: 0.7410 - val_empty_out_my_iou_metric: 0.8638
#
# Epoch 00017: val_segment_out_my_iou_metric did not improve from 0.74675
# Epoch 18/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.3276 - segment_out_loss: 0.1362 - empty_out_loss: 0.2764 - segment_out_my_iou_metric: 0.7502 - empty_out_my_iou_metric: 0.8816 - val_loss: 0.3379 - val_segment_out_loss: 0.1396 - val_empty_out_loss: 0.2941 - val_segment_out_my_iou_metric: 0.7560 - val_empty_out_my_iou_metric: 0.8575
#
# Epoch 00018: val_segment_out_my_iou_metric improved from 0.74675 to 0.75600, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.3260 - segment_out_loss: 0.1366 - empty_out_loss: 0.2639 - segment_out_my_iou_metric: 0.7543 - empty_out_my_iou_metric: 0.8842 - val_loss: 0.3817 - val_segment_out_loss: 0.1601 - val_empty_out_loss: 0.3077 - val_segment_out_my_iou_metric: 0.7464 - val_empty_out_my_iou_metric: 0.8588
#
# Epoch 00019: val_segment_out_my_iou_metric did not improve from 0.75600
# Epoch 20/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.3272 - segment_out_loss: 0.1371 - empty_out_loss: 0.2647 - segment_out_my_iou_metric: 0.7523 - empty_out_my_iou_metric: 0.8850 - val_loss: 1.7579 - val_segment_out_loss: 0.7408 - val_empty_out_loss: 1.3818 - val_segment_out_my_iou_metric: 0.5086 - val_empty_out_my_iou_metric: 0.5713
#
# Epoch 00020: val_segment_out_my_iou_metric did not improve from 0.75600
# Epoch 21/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.3109 - segment_out_loss: 0.1305 - empty_out_loss: 0.2489 - segment_out_my_iou_metric: 0.7587 - empty_out_my_iou_metric: 0.8938 - val_loss: 0.3784 - val_segment_out_loss: 0.1609 - val_empty_out_loss: 0.2830 - val_segment_out_my_iou_metric: 0.7320 - val_empty_out_my_iou_metric: 0.8662
#
# Epoch 00021: val_segment_out_my_iou_metric did not improve from 0.75600
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 22/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.2781 - segment_out_loss: 0.1155 - empty_out_loss: 0.2351 - segment_out_my_iou_metric: 0.7742 - empty_out_my_iou_metric: 0.9025 - val_loss: 0.3380 - val_segment_out_loss: 0.1412 - val_empty_out_loss: 0.2785 - val_segment_out_my_iou_metric: 0.7708 - val_empty_out_my_iou_metric: 0.8788
#
# Epoch 00022: val_segment_out_my_iou_metric improved from 0.75600 to 0.77075, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.2741 - segment_out_loss: 0.1138 - empty_out_loss: 0.2324 - segment_out_my_iou_metric: 0.7765 - empty_out_my_iou_metric: 0.9028 - val_loss: 0.3066 - val_segment_out_loss: 0.1280 - val_empty_out_loss: 0.2534 - val_segment_out_my_iou_metric: 0.7598 - val_empty_out_my_iou_metric: 0.8888
#
# Epoch 00023: val_segment_out_my_iou_metric did not improve from 0.77075
# Epoch 24/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2591 - segment_out_loss: 0.1078 - empty_out_loss: 0.2170 - segment_out_my_iou_metric: 0.7790 - empty_out_my_iou_metric: 0.9092 - val_loss: 0.3291 - val_segment_out_loss: 0.1370 - val_empty_out_loss: 0.2756 - val_segment_out_my_iou_metric: 0.7678 - val_empty_out_my_iou_metric: 0.8800
#
# Epoch 00024: val_segment_out_my_iou_metric did not improve from 0.77075
# Epoch 25/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2641 - segment_out_loss: 0.1099 - empty_out_loss: 0.2211 - segment_out_my_iou_metric: 0.7835 - empty_out_my_iou_metric: 0.9087 - val_loss: 0.3483 - val_segment_out_loss: 0.1355 - val_empty_out_loss: 0.3862 - val_segment_out_my_iou_metric: 0.7585 - val_empty_out_my_iou_metric: 0.8588
#
# Epoch 00025: val_segment_out_my_iou_metric did not improve from 0.77075
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 26/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2399 - segment_out_loss: 0.0986 - empty_out_loss: 0.2137 - segment_out_my_iou_metric: 0.7922 - empty_out_my_iou_metric: 0.9078 - val_loss: 0.2999 - val_segment_out_loss: 0.1252 - val_empty_out_loss: 0.2478 - val_segment_out_my_iou_metric: 0.7820 - val_empty_out_my_iou_metric: 0.9038
#
# Epoch 00026: val_segment_out_my_iou_metric improved from 0.77075 to 0.78200, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 27/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.2328 - segment_out_loss: 0.0966 - empty_out_loss: 0.1984 - segment_out_my_iou_metric: 0.7923 - empty_out_my_iou_metric: 0.9209 - val_loss: 0.3384 - val_segment_out_loss: 0.1332 - val_empty_out_loss: 0.3600 - val_segment_out_my_iou_metric: 0.7754 - val_empty_out_my_iou_metric: 0.8725
#
# Epoch 00027: val_segment_out_my_iou_metric did not improve from 0.78200
# Epoch 28/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2320 - segment_out_loss: 0.0959 - empty_out_loss: 0.2013 - segment_out_my_iou_metric: 0.7942 - empty_out_my_iou_metric: 0.9194 - val_loss: 0.3539 - val_segment_out_loss: 0.1380 - val_empty_out_loss: 0.3895 - val_segment_out_my_iou_metric: 0.7739 - val_empty_out_my_iou_metric: 0.8675
#
# Epoch 00028: val_segment_out_my_iou_metric did not improve from 0.78200
# Epoch 29/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2321 - segment_out_loss: 0.0955 - empty_out_loss: 0.2055 - segment_out_my_iou_metric: 0.7955 - empty_out_my_iou_metric: 0.9144 - val_loss: 0.2927 - val_segment_out_loss: 0.1216 - val_empty_out_loss: 0.2475 - val_segment_out_my_iou_metric: 0.7826 - val_empty_out_my_iou_metric: 0.9012
#
# Epoch 00029: val_segment_out_my_iou_metric improved from 0.78200 to 0.78262, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.2292 - segment_out_loss: 0.0947 - empty_out_loss: 0.1986 - segment_out_my_iou_metric: 0.8013 - empty_out_my_iou_metric: 0.9205 - val_loss: 0.3087 - val_segment_out_loss: 0.1280 - val_empty_out_loss: 0.2637 - val_segment_out_my_iou_metric: 0.7824 - val_empty_out_my_iou_metric: 0.8975
#
# Epoch 00030: val_segment_out_my_iou_metric did not improve from 0.78262
# Epoch 31/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2234 - segment_out_loss: 0.0928 - empty_out_loss: 0.1895 - segment_out_my_iou_metric: 0.7995 - empty_out_my_iou_metric: 0.9242 - val_loss: 0.3010 - val_segment_out_loss: 0.1228 - val_empty_out_loss: 0.2773 - val_segment_out_my_iou_metric: 0.7755 - val_empty_out_my_iou_metric: 0.8912
#
# Epoch 00031: val_segment_out_my_iou_metric did not improve from 0.78262
# Epoch 32/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2101 - segment_out_loss: 0.0866 - empty_out_loss: 0.1843 - segment_out_my_iou_metric: 0.8051 - empty_out_my_iou_metric: 0.9294 - val_loss: 0.2998 - val_segment_out_loss: 0.1240 - val_empty_out_loss: 0.2585 - val_segment_out_my_iou_metric: 0.7778 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00032: val_segment_out_my_iou_metric did not improve from 0.78262
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 33/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2032 - segment_out_loss: 0.0837 - empty_out_loss: 0.1788 - segment_out_my_iou_metric: 0.8079 - empty_out_my_iou_metric: 0.9272 - val_loss: 0.3128 - val_segment_out_loss: 0.1289 - val_empty_out_loss: 0.2748 - val_segment_out_my_iou_metric: 0.7791 - val_empty_out_my_iou_metric: 0.8900
#
# Epoch 00033: val_segment_out_my_iou_metric did not improve from 0.78262
# Epoch 34/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.2047 - segment_out_loss: 0.0844 - empty_out_loss: 0.1798 - segment_out_my_iou_metric: 0.8081 - empty_out_my_iou_metric: 0.9291 - val_loss: 0.3043 - val_segment_out_loss: 0.1239 - val_empty_out_loss: 0.2826 - val_segment_out_my_iou_metric: 0.7845 - val_empty_out_my_iou_metric: 0.8838
#
# Epoch 00034: val_segment_out_my_iou_metric improved from 0.78262 to 0.78450, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 35/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1951 - segment_out_loss: 0.0801 - empty_out_loss: 0.1748 - segment_out_my_iou_metric: 0.8101 - empty_out_my_iou_metric: 0.9292 - val_loss: 0.2940 - val_segment_out_loss: 0.1183 - val_empty_out_loss: 0.2872 - val_segment_out_my_iou_metric: 0.7845 - val_empty_out_my_iou_metric: 0.8925
#
# Epoch 00035: val_segment_out_my_iou_metric improved from 0.78450 to 0.78450, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 36/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1937 - segment_out_loss: 0.0798 - empty_out_loss: 0.1707 - segment_out_my_iou_metric: 0.8128 - empty_out_my_iou_metric: 0.9344 - val_loss: 0.3330 - val_segment_out_loss: 0.1371 - val_empty_out_loss: 0.2934 - val_segment_out_my_iou_metric: 0.7806 - val_empty_out_my_iou_metric: 0.8775
#
# Epoch 00036: val_segment_out_my_iou_metric did not improve from 0.78450
# Epoch 37/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.1892 - segment_out_loss: 0.0781 - empty_out_loss: 0.1649 - segment_out_my_iou_metric: 0.8125 - empty_out_my_iou_metric: 0.9369 - val_loss: 0.2932 - val_segment_out_loss: 0.1213 - val_empty_out_loss: 0.2528 - val_segment_out_my_iou_metric: 0.7870 - val_empty_out_my_iou_metric: 0.8975
#
# Epoch 00037: val_segment_out_my_iou_metric improved from 0.78450 to 0.78700, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 38/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1932 - segment_out_loss: 0.0788 - empty_out_loss: 0.1777 - segment_out_my_iou_metric: 0.8118 - empty_out_my_iou_metric: 0.9320 - val_loss: 0.3492 - val_segment_out_loss: 0.1356 - val_empty_out_loss: 0.3900 - val_segment_out_my_iou_metric: 0.7719 - val_empty_out_my_iou_metric: 0.8712
#
# Epoch 00038: val_segment_out_my_iou_metric did not improve from 0.78700
# Epoch 39/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1921 - segment_out_loss: 0.0791 - empty_out_loss: 0.1695 - segment_out_my_iou_metric: 0.8136 - empty_out_my_iou_metric: 0.9330 - val_loss: 0.3113 - val_segment_out_loss: 0.1313 - val_empty_out_loss: 0.2434 - val_segment_out_my_iou_metric: 0.7840 - val_empty_out_my_iou_metric: 0.8988
#
# Epoch 00039: val_segment_out_my_iou_metric did not improve from 0.78700
# Epoch 40/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1892 - segment_out_loss: 0.0779 - empty_out_loss: 0.1668 - segment_out_my_iou_metric: 0.8122 - empty_out_my_iou_metric: 0.9308 - val_loss: 0.3199 - val_segment_out_loss: 0.1327 - val_empty_out_loss: 0.2723 - val_segment_out_my_iou_metric: 0.7843 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00040: val_segment_out_my_iou_metric did not improve from 0.78700
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 41/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.1807 - segment_out_loss: 0.0743 - empty_out_loss: 0.1604 - segment_out_my_iou_metric: 0.8179 - empty_out_my_iou_metric: 0.9375 - val_loss: 0.3185 - val_segment_out_loss: 0.1319 - val_empty_out_loss: 0.2731 - val_segment_out_my_iou_metric: 0.7856 - val_empty_out_my_iou_metric: 0.8900
#
# Epoch 00041: val_segment_out_my_iou_metric did not improve from 0.78700
# Epoch 42/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1752 - segment_out_loss: 0.0722 - empty_out_loss: 0.1542 - segment_out_my_iou_metric: 0.8218 - empty_out_my_iou_metric: 0.9370 - val_loss: 0.3236 - val_segment_out_loss: 0.1342 - val_empty_out_loss: 0.2760 - val_segment_out_my_iou_metric: 0.7855 - val_empty_out_my_iou_metric: 0.8925
#
# Epoch 00042: val_segment_out_my_iou_metric did not improve from 0.78700
# Epoch 43/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1766 - segment_out_loss: 0.0724 - empty_out_loss: 0.1585 - segment_out_my_iou_metric: 0.8194 - empty_out_my_iou_metric: 0.9372 - val_loss: 0.3133 - val_segment_out_loss: 0.1294 - val_empty_out_loss: 0.2722 - val_segment_out_my_iou_metric: 0.7856 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00043: val_segment_out_my_iou_metric did not improve from 0.78700
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 44/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1661 - segment_out_loss: 0.0683 - empty_out_loss: 0.1480 - segment_out_my_iou_metric: 0.8243 - empty_out_my_iou_metric: 0.9383 - val_loss: 0.3228 - val_segment_out_loss: 0.1339 - val_empty_out_loss: 0.2750 - val_segment_out_my_iou_metric: 0.7874 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00044: val_segment_out_my_iou_metric improved from 0.78700 to 0.78738, saving model to ../model/Unet_resnet_3loss_cse_32_32_0.5.model
# Epoch 45/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1750 - segment_out_loss: 0.0718 - empty_out_loss: 0.1573 - segment_out_my_iou_metric: 0.8202 - empty_out_my_iou_metric: 0.9373 - val_loss: 0.3184 - val_segment_out_loss: 0.1325 - val_empty_out_loss: 0.2668 - val_segment_out_my_iou_metric: 0.7868 - val_empty_out_my_iou_metric: 0.8925
#
# Epoch 00045: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 46/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1733 - segment_out_loss: 0.0711 - empty_out_loss: 0.1554 - segment_out_my_iou_metric: 0.8224 - empty_out_my_iou_metric: 0.9387 - val_loss: 0.3125 - val_segment_out_loss: 0.1298 - val_empty_out_loss: 0.2643 - val_segment_out_my_iou_metric: 0.7866 - val_empty_out_my_iou_metric: 0.8962
#
# Epoch 00046: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 47/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.1651 - segment_out_loss: 0.0673 - empty_out_loss: 0.1524 - segment_out_my_iou_metric: 0.8244 - empty_out_my_iou_metric: 0.9439 - val_loss: 0.3142 - val_segment_out_loss: 0.1307 - val_empty_out_loss: 0.2634 - val_segment_out_my_iou_metric: 0.7841 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00047: val_segment_out_my_iou_metric did not improve from 0.78738
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 48/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1688 - segment_out_loss: 0.0691 - empty_out_loss: 0.1532 - segment_out_my_iou_metric: 0.8210 - empty_out_my_iou_metric: 0.9411 - val_loss: 0.3187 - val_segment_out_loss: 0.1324 - val_empty_out_loss: 0.2694 - val_segment_out_my_iou_metric: 0.7846 - val_empty_out_my_iou_metric: 0.8912
#
# Epoch 00048: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 49/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1637 - segment_out_loss: 0.0666 - empty_out_loss: 0.1526 - segment_out_my_iou_metric: 0.8235 - empty_out_my_iou_metric: 0.9402 - val_loss: 0.3239 - val_segment_out_loss: 0.1346 - val_empty_out_loss: 0.2734 - val_segment_out_my_iou_metric: 0.7830 - val_empty_out_my_iou_metric: 0.8925
#
# Epoch 00049: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 50/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.1675 - segment_out_loss: 0.0687 - empty_out_loss: 0.1504 - segment_out_my_iou_metric: 0.8210 - empty_out_my_iou_metric: 0.9403 - val_loss: 0.3223 - val_segment_out_loss: 0.1346 - val_empty_out_loss: 0.2653 - val_segment_out_my_iou_metric: 0.7835 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00050: val_segment_out_my_iou_metric did not improve from 0.78738
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 51/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1664 - segment_out_loss: 0.0678 - empty_out_loss: 0.1545 - segment_out_my_iou_metric: 0.8223 - empty_out_my_iou_metric: 0.9391 - val_loss: 0.3285 - val_segment_out_loss: 0.1367 - val_empty_out_loss: 0.2751 - val_segment_out_my_iou_metric: 0.7855 - val_empty_out_my_iou_metric: 0.8925
#
# Epoch 00051: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 52/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.1659 - segment_out_loss: 0.0677 - empty_out_loss: 0.1520 - segment_out_my_iou_metric: 0.8224 - empty_out_my_iou_metric: 0.9402 - val_loss: 0.3220 - val_segment_out_loss: 0.1344 - val_empty_out_loss: 0.2660 - val_segment_out_my_iou_metric: 0.7840 - val_empty_out_my_iou_metric: 0.8950
# Epoch 00052: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 53/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1668 - segment_out_loss: 0.0684 - empty_out_loss: 0.1495 - segment_out_my_iou_metric: 0.8241 - empty_out_my_iou_metric: 0.9391 - val_loss: 0.3249 - val_segment_out_loss: 0.1354 - val_empty_out_loss: 0.2704 - val_segment_out_my_iou_metric: 0.7849 - val_empty_out_my_iou_metric: 0.8912
#
# Epoch 00053: val_segment_out_my_iou_metric did not improve from 0.78738
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 54/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1692 - segment_out_loss: 0.0693 - empty_out_loss: 0.1531 - segment_out_my_iou_metric: 0.8219 - empty_out_my_iou_metric: 0.9370 - val_loss: 0.3234 - val_segment_out_loss: 0.1346 - val_empty_out_loss: 0.2711 - val_segment_out_my_iou_metric: 0.7844 - val_empty_out_my_iou_metric: 0.8950
#
# Epoch 00054: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 55/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.1702 - segment_out_loss: 0.0701 - empty_out_loss: 0.1497 - segment_out_my_iou_metric: 0.8234 - empty_out_my_iou_metric: 0.9425 - val_loss: 0.3221 - val_segment_out_loss: 0.1341 - val_empty_out_loss: 0.2694 - val_segment_out_my_iou_metric: 0.7854 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00055: val_segment_out_my_iou_metric did not improve from 0.78738
# Epoch 56/200
# 6400/6400 [==============================] - 66s 10ms/step - loss: 0.1643 - segment_out_loss: 0.0669 - empty_out_loss: 0.1519 - segment_out_my_iou_metric: 0.8239 - empty_out_my_iou_metric: 0.9425 - val_loss: 0.3244 - val_segment_out_loss: 0.1350 - val_empty_out_loss: 0.2725 - val_segment_out_my_iou_metric: 0.7843 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00056: val_segment_out_my_iou_metric did not improve from 0.78738
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 00056: early stopping

# %%
base_name = 'Unet_resnet_3loss_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'

model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})

# %%
base_name = 'Unet_resnet_3loss_cse_stage2_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

input_x = model1.layers[0].input
model1.layers[-1].name = 'segment_out_old'

output_layer = model1.layers[-2]
output_layer.name = 'segment_out'
output_layer = output_layer.output

empty_out = model1.get_layer("empty_out").output
model = Model(input_x, [output_layer, empty_out])
c = optimizers.adam(lr = 0.01)

losses = {
    'empty_out' : 'binary_crossentropy',
    'segment_out': lovasz_loss,
    #'final_out' : lovasz_loss,
}
lossWeights = {
    'empty_out' : 0.2,
    'segment_out':2,
    #'final_out' : 3,
}
model.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric_2])

early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric_2', mode = 'max',patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric_2', mode = 'max',factor=0.5, patience=4, min_lr=0.00001, verbose=1)


history = model.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 108s 17ms/step - loss: -0.0301 - segment_out_loss: -0.0423 - empty_out_loss: 0.2726 - segment_out_my_iou_metric_2: 0.7638 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.2052 - val_segment_out_loss: 0.0746 - val_empty_out_loss: 0.2798 - val_segment_out_my_iou_metric_2: 0.7456 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00001: val_segment_out_my_iou_metric_2 improved from -inf to 0.74562, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.1409 - segment_out_loss: -0.0959 - empty_out_loss: 0.2544 - segment_out_my_iou_metric_2: 0.7711 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.1811 - val_segment_out_loss: 0.0572 - val_empty_out_loss: 0.3330 - val_segment_out_my_iou_metric_2: 0.7430 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00002: val_segment_out_my_iou_metric_2 did not improve from 0.74562
# Epoch 3/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.1904 - segment_out_loss: -0.1197 - empty_out_loss: 0.2452 - segment_out_my_iou_metric_2: 0.7751 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.4227 - val_segment_out_loss: 0.1763 - val_empty_out_loss: 0.3504 - val_segment_out_my_iou_metric_2: 0.7354 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00003: val_segment_out_my_iou_metric_2 did not improve from 0.74562
# Epoch 4/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.2194 - segment_out_loss: -0.1337 - empty_out_loss: 0.2402 - segment_out_my_iou_metric_2: 0.7783 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.4325 - val_segment_out_loss: 0.1798 - val_empty_out_loss: 0.3645 - val_segment_out_my_iou_metric_2: 0.7279 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00004: val_segment_out_my_iou_metric_2 did not improve from 0.74562
# Epoch 5/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: -0.2609 - segment_out_loss: -0.1532 - empty_out_loss: 0.2271 - segment_out_my_iou_metric_2: 0.7808 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0672 - val_segment_out_loss: 0.0045 - val_empty_out_loss: 0.2913 - val_segment_out_my_iou_metric_2: 0.7636 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00005: val_segment_out_my_iou_metric_2 improved from 0.74562 to 0.76362, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.2873 - segment_out_loss: -0.1661 - empty_out_loss: 0.2240 - segment_out_my_iou_metric_2: 0.7862 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0977 - val_segment_out_loss: 0.0173 - val_empty_out_loss: 0.3151 - val_segment_out_my_iou_metric_2: 0.7521 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00006: val_segment_out_my_iou_metric_2 did not improve from 0.76362
# Epoch 7/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.3000 - segment_out_loss: -0.1711 - empty_out_loss: 0.2103 - segment_out_my_iou_metric_2: 0.7864 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0080 - val_segment_out_loss: -0.0383 - val_empty_out_loss: 0.3430 - val_segment_out_my_iou_metric_2: 0.7782 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00007: val_segment_out_my_iou_metric_2 improved from 0.76362 to 0.77825, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.3445 - segment_out_loss: -0.1935 - empty_out_loss: 0.2127 - segment_out_my_iou_metric_2: 0.7917 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1308 - val_segment_out_loss: -0.0901 - val_empty_out_loss: 0.2472 - val_segment_out_my_iou_metric_2: 0.7776 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00008: val_segment_out_my_iou_metric_2 did not improve from 0.77825
# Epoch 9/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.3698 - segment_out_loss: -0.2059 - empty_out_loss: 0.2102 - segment_out_my_iou_metric_2: 0.7927 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1586 - val_segment_out_loss: -0.1085 - val_empty_out_loss: 0.2926 - val_segment_out_my_iou_metric_2: 0.7919 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00009: val_segment_out_my_iou_metric_2 improved from 0.77825 to 0.79187, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.3943 - segment_out_loss: -0.2175 - empty_out_loss: 0.2040 - segment_out_my_iou_metric_2: 0.7967 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0157 - val_segment_out_loss: -0.0235 - val_empty_out_loss: 0.3137 - val_segment_out_my_iou_metric_2: 0.7783 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00010: val_segment_out_my_iou_metric_2 did not improve from 0.79187
# Epoch 11/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.3834 - segment_out_loss: -0.2123 - empty_out_loss: 0.2061 - segment_out_my_iou_metric_2: 0.7955 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.5206 - val_segment_out_loss: 0.2187 - val_empty_out_loss: 0.4160 - val_segment_out_my_iou_metric_2: 0.7220 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00011: val_segment_out_my_iou_metric_2 did not improve from 0.79187
# Epoch 12/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.4549 - segment_out_loss: -0.2465 - empty_out_loss: 0.1904 - segment_out_my_iou_metric_2: 0.8045 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2057 - val_segment_out_loss: -0.1278 - val_empty_out_loss: 0.2490 - val_segment_out_my_iou_metric_2: 0.7795 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00012: val_segment_out_my_iou_metric_2 did not improve from 0.79187
# Epoch 13/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.4461 - segment_out_loss: -0.2423 - empty_out_loss: 0.1929 - segment_out_my_iou_metric_2: 0.8023 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0148 - val_segment_out_loss: -0.0375 - val_empty_out_loss: 0.3007 - val_segment_out_my_iou_metric_2: 0.7761 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00013: val_segment_out_my_iou_metric_2 did not improve from 0.79187
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 14/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.6576 - segment_out_loss: -0.3445 - empty_out_loss: 0.1569 - segment_out_my_iou_metric_2: 0.8254 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2883 - val_segment_out_loss: -0.1680 - val_empty_out_loss: 0.2384 - val_segment_out_my_iou_metric_2: 0.8034 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00014: val_segment_out_my_iou_metric_2 improved from 0.79187 to 0.80337, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.6760 - segment_out_loss: -0.3533 - empty_out_loss: 0.1530 - segment_out_my_iou_metric_2: 0.8295 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2933 - val_segment_out_loss: -0.1734 - val_empty_out_loss: 0.2672 - val_segment_out_my_iou_metric_2: 0.7939 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00015: val_segment_out_my_iou_metric_2 did not improve from 0.80337
# Epoch 16/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.7250 - segment_out_loss: -0.3768 - empty_out_loss: 0.1427 - segment_out_my_iou_metric_2: 0.8328 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0114 - val_segment_out_loss: -0.0304 - val_empty_out_loss: 0.3614 - val_segment_out_my_iou_metric_2: 0.7840 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00016: val_segment_out_my_iou_metric_2 did not improve from 0.80337
# Epoch 17/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.7184 - segment_out_loss: -0.3735 - empty_out_loss: 0.1429 - segment_out_my_iou_metric_2: 0.8339 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2413 - val_segment_out_loss: -0.1471 - val_empty_out_loss: 0.2645 - val_segment_out_my_iou_metric_2: 0.7939 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00017: val_segment_out_my_iou_metric_2 did not improve from 0.80337
# Epoch 18/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.7358 - segment_out_loss: -0.3817 - empty_out_loss: 0.1384 - segment_out_my_iou_metric_2: 0.8345 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1844 - val_segment_out_loss: -0.1174 - val_empty_out_loss: 0.2519 - val_segment_out_my_iou_metric_2: 0.7950 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00018: val_segment_out_my_iou_metric_2 did not improve from 0.80337
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 19/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.8564 - segment_out_loss: -0.4399 - empty_out_loss: 0.1167 - segment_out_my_iou_metric_2: 0.8465 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2928 - val_segment_out_loss: -0.1739 - val_empty_out_loss: 0.2750 - val_segment_out_my_iou_metric_2: 0.8071 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00019: val_segment_out_my_iou_metric_2 improved from 0.80337 to 0.80713, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.9104 - segment_out_loss: -0.4658 - empty_out_loss: 0.1064 - segment_out_my_iou_metric_2: 0.8528 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3330 - val_segment_out_loss: -0.1921 - val_empty_out_loss: 0.2560 - val_segment_out_my_iou_metric_2: 0.8068 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00020: val_segment_out_my_iou_metric_2 did not improve from 0.80713
# Epoch 21/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.9183 - segment_out_loss: -0.4692 - empty_out_loss: 0.1002 - segment_out_my_iou_metric_2: 0.8530 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2792 - val_segment_out_loss: -0.1672 - val_empty_out_loss: 0.2758 - val_segment_out_my_iou_metric_2: 0.8073 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00021: val_segment_out_my_iou_metric_2 improved from 0.80713 to 0.80725, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.9442 - segment_out_loss: -0.4819 - empty_out_loss: 0.0982 - segment_out_my_iou_metric_2: 0.8553 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1908 - val_segment_out_loss: -0.1234 - val_empty_out_loss: 0.2805 - val_segment_out_my_iou_metric_2: 0.7974 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00022: val_segment_out_my_iou_metric_2 did not improve from 0.80725
# Epoch 23/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.9485 - segment_out_loss: -0.4835 - empty_out_loss: 0.0919 - segment_out_my_iou_metric_2: 0.8566 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2817 - val_segment_out_loss: -0.1690 - val_empty_out_loss: 0.2817 - val_segment_out_my_iou_metric_2: 0.8056 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00023: val_segment_out_my_iou_metric_2 did not improve from 0.80725
# Epoch 24/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.9776 - segment_out_loss: -0.4976 - empty_out_loss: 0.0883 - segment_out_my_iou_metric_2: 0.8586 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3284 - val_segment_out_loss: -0.1903 - val_empty_out_loss: 0.2607 - val_segment_out_my_iou_metric_2: 0.8062 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00024: val_segment_out_my_iou_metric_2 did not improve from 0.80725
# Epoch 25/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -0.9735 - segment_out_loss: -0.4960 - empty_out_loss: 0.0922 - segment_out_my_iou_metric_2: 0.8576 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2705 - val_segment_out_loss: -0.1607 - val_empty_out_loss: 0.2540 - val_segment_out_my_iou_metric_2: 0.8008 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00025: val_segment_out_my_iou_metric_2 did not improve from 0.80725
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 26/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.0254 - segment_out_loss: -0.5206 - empty_out_loss: 0.0790 - segment_out_my_iou_metric_2: 0.8625 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3353 - val_segment_out_loss: -0.1975 - val_empty_out_loss: 0.2980 - val_segment_out_my_iou_metric_2: 0.8065 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00026: val_segment_out_my_iou_metric_2 did not improve from 0.80725
# Epoch 27/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.0711 - segment_out_loss: -0.5427 - empty_out_loss: 0.0718 - segment_out_my_iou_metric_2: 0.8689 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2766 - val_segment_out_loss: -0.1683 - val_empty_out_loss: 0.3003 - val_segment_out_my_iou_metric_2: 0.8109 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00027: val_segment_out_my_iou_metric_2 improved from 0.80725 to 0.81088, saving model to ../model/Unet_resnet_3loss_cse_stage2_32_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.0778 - segment_out_loss: -0.5456 - empty_out_loss: 0.0670 - segment_out_my_iou_metric_2: 0.8682 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2821 - val_segment_out_loss: -0.1711 - val_empty_out_loss: 0.3008 - val_segment_out_my_iou_metric_2: 0.8074 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00028: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 29/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.0757 - segment_out_loss: -0.5450 - empty_out_loss: 0.0716 - segment_out_my_iou_metric_2: 0.8695 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2546 - val_segment_out_loss: -0.1574 - val_empty_out_loss: 0.3013 - val_segment_out_my_iou_metric_2: 0.8087 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00029: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 30/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1071 - segment_out_loss: -0.5599 - empty_out_loss: 0.0634 - segment_out_my_iou_metric_2: 0.8734 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2469 - val_segment_out_loss: -0.1521 - val_empty_out_loss: 0.2861 - val_segment_out_my_iou_metric_2: 0.8080 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00030: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 31/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.0911 - segment_out_loss: -0.5523 - empty_out_loss: 0.0670 - segment_out_my_iou_metric_2: 0.8707 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1909 - val_segment_out_loss: -0.1269 - val_empty_out_loss: 0.3145 - val_segment_out_my_iou_metric_2: 0.7944 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00031: val_segment_out_my_iou_metric_2 did not improve from 0.81088
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 32/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1231 - segment_out_loss: -0.5678 - empty_out_loss: 0.0621 - segment_out_my_iou_metric_2: 0.8744 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2261 - val_segment_out_loss: -0.1435 - val_empty_out_loss: 0.3045 - val_segment_out_my_iou_metric_2: 0.8090 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00032: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 33/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1394 - segment_out_loss: -0.5754 - empty_out_loss: 0.0568 - segment_out_my_iou_metric_2: 0.8749 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2817 - val_segment_out_loss: -0.1693 - val_empty_out_loss: 0.2847 - val_segment_out_my_iou_metric_2: 0.8083 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00033: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 34/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1494 - segment_out_loss: -0.5803 - empty_out_loss: 0.0557 - segment_out_my_iou_metric_2: 0.8762 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2781 - val_segment_out_loss: -0.1661 - val_empty_out_loss: 0.2706 - val_segment_out_my_iou_metric_2: 0.8095 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00034: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 35/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1403 - segment_out_loss: -0.5760 - empty_out_loss: 0.0586 - segment_out_my_iou_metric_2: 0.8743 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2581 - val_segment_out_loss: -0.1569 - val_empty_out_loss: 0.2784 - val_segment_out_my_iou_metric_2: 0.8081 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00035: val_segment_out_my_iou_metric_2 did not improve from 0.81088
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 36/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1745 - segment_out_loss: -0.5924 - empty_out_loss: 0.0511 - segment_out_my_iou_metric_2: 0.8788 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2304 - val_segment_out_loss: -0.1452 - val_empty_out_loss: 0.3001 - val_segment_out_my_iou_metric_2: 0.8061 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00036: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 37/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1703 - segment_out_loss: -0.5903 - empty_out_loss: 0.0513 - segment_out_my_iou_metric_2: 0.8782 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2120 - val_segment_out_loss: -0.1366 - val_empty_out_loss: 0.3059 - val_segment_out_my_iou_metric_2: 0.8033 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00037: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 38/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1773 - segment_out_loss: -0.5936 - empty_out_loss: 0.0498 - segment_out_my_iou_metric_2: 0.8797 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1857 - val_segment_out_loss: -0.1246 - val_empty_out_loss: 0.3178 - val_segment_out_my_iou_metric_2: 0.8048 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00038: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 39/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1703 - segment_out_loss: -0.5904 - empty_out_loss: 0.0526 - segment_out_my_iou_metric_2: 0.8791 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2297 - val_segment_out_loss: -0.1451 - val_empty_out_loss: 0.3031 - val_segment_out_my_iou_metric_2: 0.8078 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00039: val_segment_out_my_iou_metric_2 did not improve from 0.81088
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 40/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1837 - segment_out_loss: -0.5968 - empty_out_loss: 0.0490 - segment_out_my_iou_metric_2: 0.8794 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2139 - val_segment_out_loss: -0.1377 - val_empty_out_loss: 0.3075 - val_segment_out_my_iou_metric_2: 0.8107 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00040: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 41/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1882 - segment_out_loss: -0.5991 - empty_out_loss: 0.0500 - segment_out_my_iou_metric_2: 0.8813 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2116 - val_segment_out_loss: -0.1371 - val_empty_out_loss: 0.3131 - val_segment_out_my_iou_metric_2: 0.8079 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00041: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 42/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1868 - segment_out_loss: -0.5981 - empty_out_loss: 0.0468 - segment_out_my_iou_metric_2: 0.8811 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1921 - val_segment_out_loss: -0.1278 - val_empty_out_loss: 0.3178 - val_segment_out_my_iou_metric_2: 0.8082 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00042: val_segment_out_my_iou_metric_2 did not improve from 0.81088
# Epoch 43/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: -1.1914 - segment_out_loss: -0.6004 - empty_out_loss: 0.0468 - segment_out_my_iou_metric_2: 0.8806 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1901 - val_segment_out_loss: -0.1269 - val_empty_out_loss: 0.3186 - val_segment_out_my_iou_metric_2: 0.8055 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00043: val_segment_out_my_iou_metric_2 did not improve from 0.81088
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 00043: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-20da40c9c7c1> in <module>()
# ----> 1 preds_valid = predict_result(model,x_valid,img_size_target)
#       2 ## Scoring for last model, choose threshold by validation data
#       3 thresholds_ori = np.linspace(0.3, 0.7, 31)
#       4 # Reverse sigmoid function: Use code below because the  sigmoid activation was removed
#       5 thresholds = np.log(thresholds_ori/(1-thresholds_ori))
#
# /media/extend/code/kaggle/salt/src/models.py in predict_result(model, x_test, img_size_target)
#     699 def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
#     700     x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
# --> 701     preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
#     702     preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
#     703     preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
