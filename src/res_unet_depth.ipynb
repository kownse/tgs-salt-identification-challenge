# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add, Dense
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate, multiply
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model
def build_model(input_layer, input_depth, start_neurons, DropoutRatio = 0.5):
    x2 = Dense(4, input_dim=1, activation='relu')(input_depth)
    x2 = Dense(1, activation='sigmoid')(x2)
    
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer_noActi = multiply([output_layer_noActi, x2])
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
train_df.z = (train_df.z.max() - train_df.z) / (train_df.z.max() - train_df.z.min())

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
depth_train = np.append(depth_train, depth_train, axis=0)
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(depth_train.shape)
print(x_train.shape)
print(y_valid.shape)

train_input = {
    'depth': depth_train,
    'img': x_train
}

val_input = {
    'depth' : depth_test,
    'img' : x_valid
}
# Out:
# (6400,)
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
start_feature = 16
dropout = 0.5
basic_name = '../model/Unet_resnet_depth_{}_{}'.format(start_feature, dropout)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 1), name='img')
input_depth_layer = Input([1], name='depth')
output_layer = build_model(input_layer,input_depth_layer, start_feature,dropout)

model1 = Model([input_layer, input_depth_layer], output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/resunet_depth_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200
batch_size = 32
history = model1.fit(train_input, y_train,
                    validation_data=[val_input, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/Unet_resnet_depth_16_0.5.model
# ../model/Unet_resnet_depth_16_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 31s 5ms/step - loss: 0.4013 - my_iou_metric: 0.3885 - val_loss: 0.6671 - val_my_iou_metric: 0.3225
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.32250, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.3228 - my_iou_metric: 0.5162 - val_loss: 0.3876 - val_my_iou_metric: 0.4364
#
# Epoch 00002: val_my_iou_metric improved from 0.32250 to 0.43637, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 22s 3ms/step - loss: 0.2883 - my_iou_metric: 0.5370 - val_loss: 0.4390 - val_my_iou_metric: 0.4769
#
# Epoch 00003: val_my_iou_metric improved from 0.43637 to 0.47687, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 22s 3ms/step - loss: 0.2643 - my_iou_metric: 0.5512 - val_loss: 0.2692 - val_my_iou_metric: 0.5500
#
# Epoch 00004: val_my_iou_metric improved from 0.47687 to 0.55000, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.2389 - my_iou_metric: 0.5723 - val_loss: 0.2415 - val_my_iou_metric: 0.6119
#
# Epoch 00005: val_my_iou_metric improved from 0.55000 to 0.61187, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.2421 - my_iou_metric: 0.5614 - val_loss: 0.2189 - val_my_iou_metric: 0.5409
#
# Epoch 00006: val_my_iou_metric did not improve from 0.61187
# Epoch 7/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.2260 - my_iou_metric: 0.5838 - val_loss: 0.2295 - val_my_iou_metric: 0.6328
#
# Epoch 00007: val_my_iou_metric improved from 0.61187 to 0.63275, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.2162 - my_iou_metric: 0.5998 - val_loss: 0.2847 - val_my_iou_metric: 0.4775
#
# Epoch 00008: val_my_iou_metric did not improve from 0.63275
# Epoch 9/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.2083 - my_iou_metric: 0.6153 - val_loss: 0.1983 - val_my_iou_metric: 0.6244
#
# Epoch 00009: val_my_iou_metric did not improve from 0.63275
# Epoch 10/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.2001 - my_iou_metric: 0.6230 - val_loss: 0.2060 - val_my_iou_metric: 0.6574
#
# Epoch 00010: val_my_iou_metric improved from 0.63275 to 0.65737, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.2006 - my_iou_metric: 0.6340 - val_loss: 0.2908 - val_my_iou_metric: 0.5594
#
# Epoch 00011: val_my_iou_metric did not improve from 0.65737
# Epoch 12/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1881 - my_iou_metric: 0.6427 - val_loss: 0.3187 - val_my_iou_metric: 0.4338
#
# Epoch 00012: val_my_iou_metric did not improve from 0.65737
# Epoch 13/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1917 - my_iou_metric: 0.6387 - val_loss: 0.2303 - val_my_iou_metric: 0.6358
#
# Epoch 00013: val_my_iou_metric did not improve from 0.65737
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 14/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1687 - my_iou_metric: 0.6687 - val_loss: 0.1777 - val_my_iou_metric: 0.6676
#
# Epoch 00014: val_my_iou_metric improved from 0.65737 to 0.66763, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1594 - my_iou_metric: 0.6771 - val_loss: 0.2181 - val_my_iou_metric: 0.6816
#
# Epoch 00015: val_my_iou_metric improved from 0.66763 to 0.68162, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1583 - my_iou_metric: 0.6819 - val_loss: 0.1803 - val_my_iou_metric: 0.6910
#
# Epoch 00016: val_my_iou_metric improved from 0.68162 to 0.69100, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1560 - my_iou_metric: 0.6844 - val_loss: 0.1633 - val_my_iou_metric: 0.6791
#
# Epoch 00017: val_my_iou_metric did not improve from 0.69100
# Epoch 18/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1532 - my_iou_metric: 0.6951 - val_loss: 0.1719 - val_my_iou_metric: 0.6647
#
# Epoch 00018: val_my_iou_metric did not improve from 0.69100
# Epoch 19/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1455 - my_iou_metric: 0.6950 - val_loss: 0.1627 - val_my_iou_metric: 0.6986
#
# Epoch 00019: val_my_iou_metric improved from 0.69100 to 0.69862, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1460 - my_iou_metric: 0.7010 - val_loss: 0.1652 - val_my_iou_metric: 0.6625
#
# Epoch 00020: val_my_iou_metric did not improve from 0.69862
# Epoch 21/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1413 - my_iou_metric: 0.7043 - val_loss: 0.1609 - val_my_iou_metric: 0.6920
#
# Epoch 00021: val_my_iou_metric did not improve from 0.69862
# Epoch 22/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1551 - my_iou_metric: 0.6965 - val_loss: 0.1539 - val_my_iou_metric: 0.7221
#
# Epoch 00022: val_my_iou_metric improved from 0.69862 to 0.72212, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1408 - my_iou_metric: 0.7129 - val_loss: 0.1520 - val_my_iou_metric: 0.7243
#
# Epoch 00023: val_my_iou_metric improved from 0.72212 to 0.72425, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1398 - my_iou_metric: 0.7094 - val_loss: 0.1471 - val_my_iou_metric: 0.7181
#
# Epoch 00024: val_my_iou_metric did not improve from 0.72425
# Epoch 25/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1367 - my_iou_metric: 0.7118 - val_loss: 0.1714 - val_my_iou_metric: 0.6989
#
# Epoch 00025: val_my_iou_metric did not improve from 0.72425
# Epoch 26/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1316 - my_iou_metric: 0.7223 - val_loss: 0.1868 - val_my_iou_metric: 0.6360
#
# Epoch 00026: val_my_iou_metric did not improve from 0.72425
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 27/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1227 - my_iou_metric: 0.7292 - val_loss: 0.1420 - val_my_iou_metric: 0.7268
#
# Epoch 00027: val_my_iou_metric improved from 0.72425 to 0.72675, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1208 - my_iou_metric: 0.7311 - val_loss: 0.1514 - val_my_iou_metric: 0.7289
#
# Epoch 00028: val_my_iou_metric improved from 0.72675 to 0.72888, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 29/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1164 - my_iou_metric: 0.7399 - val_loss: 0.1413 - val_my_iou_metric: 0.7316
#
# Epoch 00029: val_my_iou_metric improved from 0.72888 to 0.73163, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1166 - my_iou_metric: 0.7364 - val_loss: 0.1320 - val_my_iou_metric: 0.7429
#
# Epoch 00030: val_my_iou_metric improved from 0.73163 to 0.74287, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 31/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1113 - my_iou_metric: 0.7412 - val_loss: 0.1379 - val_my_iou_metric: 0.7113
#
# Epoch 00031: val_my_iou_metric did not improve from 0.74287
# Epoch 32/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1113 - my_iou_metric: 0.7427 - val_loss: 0.1509 - val_my_iou_metric: 0.7451
# Epoch 00032: val_my_iou_metric improved from 0.74287 to 0.74513, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 33/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1144 - my_iou_metric: 0.7416 - val_loss: 0.1555 - val_my_iou_metric: 0.7406
#
# Epoch 00033: val_my_iou_metric did not improve from 0.74513
# Epoch 34/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1157 - my_iou_metric: 0.7357 - val_loss: 0.2072 - val_my_iou_metric: 0.6585
#
# Epoch 00034: val_my_iou_metric did not improve from 0.74513
# Epoch 35/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.1126 - my_iou_metric: 0.7434 - val_loss: 0.1455 - val_my_iou_metric: 0.7374
#
# Epoch 00035: val_my_iou_metric did not improve from 0.74513
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 36/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.1017 - my_iou_metric: 0.7554 - val_loss: 0.1437 - val_my_iou_metric: 0.7570
#
# Epoch 00036: val_my_iou_metric improved from 0.74513 to 0.75700, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 37/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.0984 - my_iou_metric: 0.7576 - val_loss: 0.1445 - val_my_iou_metric: 0.7472
#
# Epoch 00037: val_my_iou_metric did not improve from 0.75700
# Epoch 38/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.0972 - my_iou_metric: 0.7564 - val_loss: 0.1326 - val_my_iou_metric: 0.7676
#
# Epoch 00038: val_my_iou_metric improved from 0.75700 to 0.76762, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 39/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.0989 - my_iou_metric: 0.7593 - val_loss: 0.1380 - val_my_iou_metric: 0.7511
#
# Epoch 00039: val_my_iou_metric did not improve from 0.76762
# Epoch 40/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.0963 - my_iou_metric: 0.7560 - val_loss: 0.1450 - val_my_iou_metric: 0.7571
#
# Epoch 00040: val_my_iou_metric did not improve from 0.76762
# Epoch 41/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.0969 - my_iou_metric: 0.7554 - val_loss: 0.1381 - val_my_iou_metric: 0.7521
#
# Epoch 00041: val_my_iou_metric did not improve from 0.76762
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 42/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.0932 - my_iou_metric: 0.7601 - val_loss: 0.1375 - val_my_iou_metric: 0.7604
#
# Epoch 00042: val_my_iou_metric did not improve from 0.76762
# Epoch 43/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.0904 - my_iou_metric: 0.7647 - val_loss: 0.1416 - val_my_iou_metric: 0.7626
#
# Epoch 00043: val_my_iou_metric did not improve from 0.76762
# Epoch 44/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.0899 - my_iou_metric: 0.7673 - val_loss: 0.1457 - val_my_iou_metric: 0.7569
#
# Epoch 00044: val_my_iou_metric did not improve from 0.76762
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 45/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.0886 - my_iou_metric: 0.7640 - val_loss: 0.1454 - val_my_iou_metric: 0.7591
#
# Epoch 00045: val_my_iou_metric did not improve from 0.76762
# Epoch 46/200
# 6400/6400 [==============================] - 22s 4ms/step - loss: 0.0867 - my_iou_metric: 0.7735 - val_loss: 0.1451 - val_my_iou_metric: 0.7671
#
# Epoch 00046: val_my_iou_metric did not improve from 0.76762
# Epoch 47/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.0887 - my_iou_metric: 0.7678 - val_loss: 0.1479 - val_my_iou_metric: 0.7598
#
# Epoch 00047: val_my_iou_metric did not improve from 0.76762
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 48/200
# 6400/6400 [==============================] - 23s 4ms/step - loss: 0.0852 - my_iou_metric: 0.7722 - val_loss: 0.1479 - val_my_iou_metric: 0.7671
#
# Epoch 00048: val_my_iou_metric did not improve from 0.76762
# Epoch 00048: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
model1.layers[0]

# %%
inputs = []
for i in range(len(model1.layers)):
    if type(model1.layers[i]) == keras.engine.input_layer.InputLayer:
        print(i, model1.layers[i])
        inputs.append(model1.layers[i].input)
# Out:
# 0 <keras.engine.input_layer.InputLayer object at 0x7eff805384a8>
# 173 <keras.engine.input_layer.InputLayer object at 0x7eff811f37f0>

# %%
# remove layter activation layer and use losvasz loss
# input_x = model1.layers[0].input
output_layer = model1.layers[-1].input

# input_layer = Input((img_size_target, img_size_target, 1), name='img')
# input_depth_layer = Input([1], name='depth')
# model = Model([input_layer, input_depth_layer], output_layer)
model = Model(inputs, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)
epochs = 200
batch_size = 32

history = model.fit(train_input, y_train,
                    validation_data=[val_input, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 67s 10ms/step - loss: 0.1197 - my_iou_metric_2: 0.7432 - val_loss: 0.2104 - val_my_iou_metric_2: 0.7266
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.72663, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 58s 9ms/step - loss: 0.1062 - my_iou_metric_2: 0.7420 - val_loss: 0.4428 - val_my_iou_metric_2: 0.6710
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.72663
# Epoch 3/200
# 6400/6400 [==============================] - 58s 9ms/step - loss: 0.0351 - my_iou_metric_2: 0.7569 - val_loss: 0.3140 - val_my_iou_metric_2: 0.7021
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.72663
# Epoch 4/200
# 6400/6400 [==============================] - 58s 9ms/step - loss: 0.0765 - my_iou_metric_2: 0.7464 - val_loss: 0.2169 - val_my_iou_metric_2: 0.7160
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.72663
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 5/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.0266 - my_iou_metric_2: 0.7687 - val_loss: 0.0044 - val_my_iou_metric_2: 0.7702
#
# Epoch 00005: val_my_iou_metric_2 improved from 0.72663 to 0.77025, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.0602 - my_iou_metric_2: 0.7750 - val_loss: 0.0376 - val_my_iou_metric_2: 0.7611
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.77025
# Epoch 7/200
# 6400/6400 [==============================] - 58s 9ms/step - loss: -0.0836 - my_iou_metric_2: 0.7817 - val_loss: 0.1169 - val_my_iou_metric_2: 0.7481
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.77025
# Epoch 8/200
# 6400/6400 [==============================] - 58s 9ms/step - loss: -0.0861 - my_iou_metric_2: 0.7804 - val_loss: -0.0362 - val_my_iou_metric_2: 0.7728
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.77025 to 0.77275, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1163 - my_iou_metric_2: 0.7878 - val_loss: -0.0466 - val_my_iou_metric_2: 0.7770
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.77275 to 0.77700, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1180 - my_iou_metric_2: 0.7877 - val_loss: 0.0294 - val_my_iou_metric_2: 0.7599
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.77700
# Epoch 11/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1186 - my_iou_metric_2: 0.7883 - val_loss: -0.0314 - val_my_iou_metric_2: 0.7820
#
# Epoch 00011: val_my_iou_metric_2 improved from 0.77700 to 0.78200, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 12/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1260 - my_iou_metric_2: 0.7895 - val_loss: -0.0067 - val_my_iou_metric_2: 0.7671
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.78200
# Epoch 13/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1497 - my_iou_metric_2: 0.7938 - val_loss: -0.0381 - val_my_iou_metric_2: 0.7780
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.78200
# Epoch 14/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1530 - my_iou_metric_2: 0.7946 - val_loss: -0.0333 - val_my_iou_metric_2: 0.7834
#
# Epoch 00014: val_my_iou_metric_2 improved from 0.78200 to 0.78337, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1648 - my_iou_metric_2: 0.7967 - val_loss: 0.0073 - val_my_iou_metric_2: 0.7800
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.78337
# Epoch 16/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1736 - my_iou_metric_2: 0.7997 - val_loss: -0.0680 - val_my_iou_metric_2: 0.7839
#
# Epoch 00016: val_my_iou_metric_2 improved from 0.78337 to 0.78387, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1634 - my_iou_metric_2: 0.7949 - val_loss: -0.0803 - val_my_iou_metric_2: 0.7889
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.78387 to 0.78888, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 18/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1835 - my_iou_metric_2: 0.7990 - val_loss: -0.1018 - val_my_iou_metric_2: 0.7897
#
# Epoch 00018: val_my_iou_metric_2 improved from 0.78888 to 0.78975, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1686 - my_iou_metric_2: 0.7972 - val_loss: 0.0180 - val_my_iou_metric_2: 0.7737
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.78975
# Epoch 20/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1955 - my_iou_metric_2: 0.8036 - val_loss: -0.0592 - val_my_iou_metric_2: 0.7831
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.78975
# Epoch 21/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.1832 - my_iou_metric_2: 0.8004 - val_loss: -0.0481 - val_my_iou_metric_2: 0.7849
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.78975
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 22/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.2420 - my_iou_metric_2: 0.8124 - val_loss: -0.0447 - val_my_iou_metric_2: 0.7907
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.78975 to 0.79075, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.2664 - my_iou_metric_2: 0.8161 - val_loss: -0.0911 - val_my_iou_metric_2: 0.7936
#
# Epoch 00023: val_my_iou_metric_2 improved from 0.79075 to 0.79363, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.2686 - my_iou_metric_2: 0.8194 - val_loss: -0.1048 - val_my_iou_metric_2: 0.7887
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.79363
# Epoch 25/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.2705 - my_iou_metric_2: 0.8193 - val_loss: -0.0469 - val_my_iou_metric_2: 0.7853
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.79363
# Epoch 26/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.2805 - my_iou_metric_2: 0.8229 - val_loss: -0.0050 - val_my_iou_metric_2: 0.7796
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.79363
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 27/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.2967 - my_iou_metric_2: 0.8264 - val_loss: -0.0836 - val_my_iou_metric_2: 0.7962
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.79363 to 0.79625, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3248 - my_iou_metric_2: 0.8298 - val_loss: -0.1147 - val_my_iou_metric_2: 0.7949
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.79625
# Epoch 29/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3211 - my_iou_metric_2: 0.8299 - val_loss: -0.1206 - val_my_iou_metric_2: 0.8040
#
# Epoch 00029: val_my_iou_metric_2 improved from 0.79625 to 0.80400, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3350 - my_iou_metric_2: 0.8328 - val_loss: -0.1093 - val_my_iou_metric_2: 0.7970
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 31/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3277 - my_iou_metric_2: 0.8318 - val_loss: -0.0866 - val_my_iou_metric_2: 0.7973
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 32/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3361 - my_iou_metric_2: 0.8324 - val_loss: -0.0995 - val_my_iou_metric_2: 0.7964
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.80400
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 33/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3413 - my_iou_metric_2: 0.8328 - val_loss: -0.1022 - val_my_iou_metric_2: 0.8033
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 34/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3516 - my_iou_metric_2: 0.8353 - val_loss: -0.1164 - val_my_iou_metric_2: 0.8031
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.80400
# Epoch 35/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3491 - my_iou_metric_2: 0.8341 - val_loss: -0.1193 - val_my_iou_metric_2: 0.8034
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.80400
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 36/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3654 - my_iou_metric_2: 0.8373 - val_loss: -0.1184 - val_my_iou_metric_2: 0.8043
#
# Epoch 00036: val_my_iou_metric_2 improved from 0.80400 to 0.80425, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 37/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3669 - my_iou_metric_2: 0.8380 - val_loss: -0.1075 - val_my_iou_metric_2: 0.8044
#
# Epoch 00037: val_my_iou_metric_2 improved from 0.80425 to 0.80437, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 38/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3596 - my_iou_metric_2: 0.8367 - val_loss: -0.1241 - val_my_iou_metric_2: 0.8041
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.80437
# Epoch 39/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3714 - my_iou_metric_2: 0.8378 - val_loss: -0.1219 - val_my_iou_metric_2: 0.8034
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.80437
# Epoch 40/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3781 - my_iou_metric_2: 0.8419 - val_loss: -0.1155 - val_my_iou_metric_2: 0.8054
#
# Epoch 00040: val_my_iou_metric_2 improved from 0.80437 to 0.80537, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 41/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3788 - my_iou_metric_2: 0.8397 - val_loss: -0.1105 - val_my_iou_metric_2: 0.8057
#
# Epoch 00041: val_my_iou_metric_2 improved from 0.80537 to 0.80575, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 42/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3716 - my_iou_metric_2: 0.8372 - val_loss: -0.1114 - val_my_iou_metric_2: 0.8057
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.80575
# Epoch 43/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3735 - my_iou_metric_2: 0.8393 - val_loss: -0.1121 - val_my_iou_metric_2: 0.8062
#
# Epoch 00043: val_my_iou_metric_2 improved from 0.80575 to 0.80625, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 44/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3616 - my_iou_metric_2: 0.8365 - val_loss: -0.1193 - val_my_iou_metric_2: 0.8049
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.80625
# Epoch 45/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3666 - my_iou_metric_2: 0.8378 - val_loss: -0.1224 - val_my_iou_metric_2: 0.8064
#
# Epoch 00045: val_my_iou_metric_2 improved from 0.80625 to 0.80638, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 46/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3762 - my_iou_metric_2: 0.8411 - val_loss: -0.1264 - val_my_iou_metric_2: 0.8094
#
# Epoch 00046: val_my_iou_metric_2 improved from 0.80638 to 0.80937, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 47/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3803 - my_iou_metric_2: 0.8393 - val_loss: -0.1313 - val_my_iou_metric_2: 0.8064
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.80937
# Epoch 48/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3856 - my_iou_metric_2: 0.8410 - val_loss: -0.1217 - val_my_iou_metric_2: 0.8081
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.80937
# Epoch 49/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3823 - my_iou_metric_2: 0.8409 - val_loss: -0.1216 - val_my_iou_metric_2: 0.8099
#
# Epoch 00049: val_my_iou_metric_2 improved from 0.80937 to 0.80988, saving model to ../model/Unet_resnet_depth_16_0.5.model
# Epoch 50/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3844 - my_iou_metric_2: 0.8417 - val_loss: -0.1155 - val_my_iou_metric_2: 0.8083
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.80988
# Epoch 51/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3775 - my_iou_metric_2: 0.8395 - val_loss: -0.1091 - val_my_iou_metric_2: 0.8081
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.80988
# Epoch 52/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3869 - my_iou_metric_2: 0.8431 - val_loss: -0.1055 - val_my_iou_metric_2: 0.8059
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.80988
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 53/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3838 - my_iou_metric_2: 0.8422 - val_loss: -0.1195 - val_my_iou_metric_2: 0.8084
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.80988
# Epoch 54/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3856 - my_iou_metric_2: 0.8405 - val_loss: -0.1080 - val_my_iou_metric_2: 0.8066
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.80988
# Epoch 55/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3798 - my_iou_metric_2: 0.8402 - val_loss: -0.1094 - val_my_iou_metric_2: 0.8075
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.80988
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 56/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3806 - my_iou_metric_2: 0.8412 - val_loss: -0.1134 - val_my_iou_metric_2: 0.8080
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.80988
# Epoch 57/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3883 - my_iou_metric_2: 0.8428 - val_loss: -0.1135 - val_my_iou_metric_2: 0.8078
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.80988
# Epoch 58/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3872 - my_iou_metric_2: 0.8410 - val_loss: -0.1153 - val_my_iou_metric_2: 0.8088
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.80988
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 59/200
# 6400/6400 [==============================] - 59s 9ms/step - loss: -0.3894 - my_iou_metric_2: 0.8426 - val_loss: -0.1150 - val_my_iou_metric_2: 0.8087
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.80988
# Epoch 00059: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/res_unet_101.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")

# %%
save_result(sub, '../result/res_unet_101.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = False, index = False)
