# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

from sklearn.model_selection import train_test_split, StratifiedKFold

from tqdm import tqdm #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

from albumentations import (
    PadIfNeeded,
    HorizontalFlip,
    VerticalFlip,    
    CenterCrop,    
    Crop,
    Compose,
    Transpose,
    RandomRotate90,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    RandomSizedCrop,
    OneOf,
    CLAHE,
    RandomContrast,
    RandomGamma,
    RandomBrightness
)

import time
from kaggle_util import *
from models import *

t_start = time.time()
start_feature = 32
batch_size = 16
dropout = 0.5
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True, act = 'elu')
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True, act = 'elu')
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True, act = 'elu')
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True, act = 'elu')
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True, act = 'elu')
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True, act = 'elu')
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True, act = 'elu')

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True, act = 'elu')
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True, act = 'elu')
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

unfit_df = pd.read_csv("../result/iou_elu.csv")
train_df = train_df.reset_index()
train_unfit = pd.merge(unfit_df, train_df, on='id', how = 'left')
train_df = train_unfit
train_df = train_df.set_index('id')
train_df['unfit'] = (train_df['iou'] < 0.7) * 1

# %%
train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
train_df['hassalt'] = train_df['masks'].apply(lambda x: (x.max()!=0) * 1)
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]/home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 100%|██████████| 4000/4000 [00:02<00:00, 1492.58it/s]
# 100%|██████████| 4000/4000 [00:01<00:00, 2279.08it/s]

# %%
def get_splits(train_df, train_idx, val_idx):
    X_train = train_df.iloc[train_idx]
    X_valid = train_df.iloc[val_idx]
    x_train = np.array(X_train.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    x_valid = np.array(X_valid.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    msk_train = np.array(X_train.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    msk_val = np.array(X_valid.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    y_train = X_train.hassalt.values
    y_valid = X_valid.hassalt.values
    id_train = X_train.index.values
    id_valid = X_valid.index.values
    return x_train, x_valid, msk_train, msk_val, y_train, y_valid, id_train, id_valid

def argument(x_train, msk_train, y_train):
    aug_img = []
    aug_msk = []
    aug_y = []
    augments = [
        (1, HorizontalFlip(p=1)),
#         (0.25, VerticalFlip(p=1)),
#         (0.25, RandomRotate90(p=1)),
#         (0.25, Transpose(p=1)),
#         (0.25, ElasticTransform(p=1, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03)),
#         (0.25, GridDistortion(p=1)),
#         (0.25, OpticalDistortion(p=1, distort_limit=2, shift_limit=0.5)),
#         (0.5, RandomSizedCrop(p=1, min_max_height=(int(img_size_ori / 2), img_size_ori), height=img_size_ori, width=img_size_ori)),
    ]

    for ratio, aug in tqdm(augments):
        selidx = np.random.choice(x_train.shape[0], int(x_train.shape[0] * ratio), replace=False)
        for idx in tqdm(selidx):
            augmented = aug(image=x_train[idx], mask=msk_train[idx])
            aimg = augmented['image']
            amsk = augmented['mask']
            if len(aimg.shape) < 3:
                aimg = aimg[...,np.newaxis]
            if len(amsk.shape) < 3:
                amsk = amsk[...,np.newaxis]
            aug_img.append(aimg)
            aug_msk.append(amsk)
            aug_y.append(y_train[idx])

    aug_img = np.asarray(aug_img)
    aug_msk = np.asarray(aug_msk)
    aug_y = np.asarray(aug_y)
    x_train = np.append(x_train, aug_img, axis=0)
    msk_train = np.append(msk_train, aug_msk, axis=0)
    y_train = np.append(y_train, aug_y, axis=0)
    print(x_train.shape)
    print(msk_train.shape)
    print(y_train.shape)
    
    return x_train, msk_train, y_train

# %%
def train_model(fold, x_train, y_train, x_valid, y_valid, id_valid):
    
    cur_base_name = 'Unet_resnet_deeper_elu_fix2_{}_{}_{}_{}'.format(start_feature, batch_size, dropout, fold)
    cur_save_model_name = '../model/segmenter/{}.model'.format(cur_base_name)
    if False: #os.path.exists(cur_save_model_name):
        print('load from continue', cur_save_model_name)
        model = load_model(cur_save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})
    else:
    
        base_name = 'Unet_resnet_deeper_elu_fix_{}_{}_{}_{}'.format(start_feature, batch_size, dropout, 3)
        save_model_name = '../model/segmenter/{}.model'.format(base_name)
        submission_dir = '../result/segmenter/{}.csv'.format(base_name)
        oof_dir = '../result/segmenter_oof/{}'.format(base_name)

        print('load from last run', save_model_name)
        model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                       'lovasz_loss': lovasz_loss})
    
    base_name = 'Unet_resnet_deeper_elu_fix2_{}_{}_{}_{}'.format(start_feature, batch_size, dropout, fold)
    save_model_name = '../model/segmenter/{}.model'.format(base_name)
    submission_dir = '../result/segmenter/{}.csv'.format(base_name)
    oof_dir = '../result/segmenter_oof/{}'.format(base_name)

    print(save_model_name)
    print(submission_dir)
    print(oof_dir)

    c = optimizers.adam(lr = 0.01)
#     c = optimizers.SGD(lr = 0.01, momentum=0.9, decay=0.0001)
    model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

    #model.summary()
    board = keras.callbacks.TensorBoard(log_dir='log/segmenter/{}'.format(base_name),
                           histogram_freq=0, write_graph=True, write_images=False)
    early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
    model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                       mode = 'max', save_best_only=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.00001, verbose=1)
    epochs = 200

    history = model.fit(x_train, y_train,
                        validation_data=[x_valid, y_valid], 
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                        verbose=1)

# %%
folds = [0,1,2,3,4]

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1234)
for fold, (train_idx, val_idx) in enumerate(skf.split(train_df, train_df['hassalt'])):
    if fold not in folds:
        print('skip fold', fold)
        continue
        
    x_train, x_valid, msk_train, msk_val, y_train, y_valid, id_train, id_valid = get_splits(train_df, train_idx, val_idx)
    x_train, msk_train, y_train = argument(x_train, msk_train, y_train)
    
    model = train_model(fold, x_train, msk_train, x_valid, msk_val, id_valid)
    
    from keras import backend as K
    K.clear_session()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3199 [00:00<?, ?it/s]
#  18%|█▊        | 586/3199 [00:00<00:00, 5802.95it/s]
#  34%|███▍      | 1097/3199 [00:00<00:00, 5458.11it/s]
#  51%|█████     | 1624/3199 [00:00<00:00, 5393.48it/s]
#  69%|██████▉   | 2210/3199 [00:00<00:00, 5509.50it/s]
#  87%|████████▋ | 2796/3199 [00:00<00:00, 5579.54it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.74it/s].69it/s]
# (6398, 101, 101, 1)
# (6398, 101, 101, 1)
# (6398,)
# load from last run ../model/segmenter/Unet_resnet_deeper_elu_32_16_0.5_3.model
# ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# ../result/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.csv
# ../result/segmenter_oof/Unet_resnet_deeper_elu_fix_32_16_0.5_0
# Train on 6398 samples, validate on 801 samples
# Epoch 1/200
# 6398/6398 [==============================] - 119s 19ms/step - loss: -0.4335 - my_iou_metric_2: 0.8520 - val_loss: -0.3568 - val_my_iou_metric_2: 0.8387
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.83870, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 2/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4404 - my_iou_metric_2: 0.8538 - val_loss: -0.4051 - val_my_iou_metric_2: 0.8472
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.83870 to 0.84719, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 3/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4556 - my_iou_metric_2: 0.8557 - val_loss: -0.3769 - val_my_iou_metric_2: 0.8442
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.84719
# Epoch 4/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4426 - my_iou_metric_2: 0.8493 - val_loss: -0.3961 - val_my_iou_metric_2: 0.8463
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.84719
# Epoch 5/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4584 - my_iou_metric_2: 0.8541 - val_loss: -0.3504 - val_my_iou_metric_2: 0.8413
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.84719
# Epoch 6/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4804 - my_iou_metric_2: 0.8581 - val_loss: -0.4092 - val_my_iou_metric_2: 0.8507
#
# Epoch 00006: val_my_iou_metric_2 improved from 0.84719 to 0.85069, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 7/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4754 - my_iou_metric_2: 0.8566 - val_loss: 0.4659 - val_my_iou_metric_2: 0.7322
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.85069
# Epoch 8/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4959 - my_iou_metric_2: 0.8598 - val_loss: -0.3850 - val_my_iou_metric_2: 0.8409
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.85069
# Epoch 9/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4948 - my_iou_metric_2: 0.8600 - val_loss: -0.1961 - val_my_iou_metric_2: 0.8212
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.85069
# Epoch 10/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4817 - my_iou_metric_2: 0.8564 - val_loss: -0.3663 - val_my_iou_metric_2: 0.8429
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.85069
# Epoch 11/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.5128 - my_iou_metric_2: 0.8627 - val_loss: -0.2769 - val_my_iou_metric_2: 0.8272
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.85069
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 12/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.5710 - my_iou_metric_2: 0.8763 - val_loss: -0.4694 - val_my_iou_metric_2: 0.8557
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.85069 to 0.85568, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 13/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6102 - my_iou_metric_2: 0.8848 - val_loss: -0.4627 - val_my_iou_metric_2: 0.8617
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.85568 to 0.86167, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 14/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.6102 - my_iou_metric_2: 0.8841 - val_loss: -0.4501 - val_my_iou_metric_2: 0.8558
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.86167
# Epoch 15/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6170 - my_iou_metric_2: 0.8873 - val_loss: -0.4384 - val_my_iou_metric_2: 0.8622
#
# Epoch 00015: val_my_iou_metric_2 improved from 0.86167 to 0.86217, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 16/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6238 - my_iou_metric_2: 0.8889 - val_loss: -0.4337 - val_my_iou_metric_2: 0.8586
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.86217
# Epoch 17/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6282 - my_iou_metric_2: 0.8905 - val_loss: -0.4601 - val_my_iou_metric_2: 0.8618
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.86217
# Epoch 18/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6290 - my_iou_metric_2: 0.8914 - val_loss: -0.2616 - val_my_iou_metric_2: 0.8448
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.86217
# Epoch 19/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6392 - my_iou_metric_2: 0.8924 - val_loss: -0.4066 - val_my_iou_metric_2: 0.8593
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.86217
# Epoch 20/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6411 - my_iou_metric_2: 0.8938 - val_loss: -0.4274 - val_my_iou_metric_2: 0.8586
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.86217
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 21/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6640 - my_iou_metric_2: 0.9005 - val_loss: -0.4556 - val_my_iou_metric_2: 0.8638
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.86217 to 0.86380, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 22/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6759 - my_iou_metric_2: 0.9032 - val_loss: -0.4715 - val_my_iou_metric_2: 0.8643
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.86380 to 0.86429, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 23/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6713 - my_iou_metric_2: 0.9034 - val_loss: -0.4033 - val_my_iou_metric_2: 0.8566
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 24/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6878 - my_iou_metric_2: 0.9063 - val_loss: -0.4489 - val_my_iou_metric_2: 0.8638
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 25/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6871 - my_iou_metric_2: 0.9076 - val_loss: -0.4028 - val_my_iou_metric_2: 0.8619
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 26/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6875 - my_iou_metric_2: 0.9087 - val_loss: -0.3782 - val_my_iou_metric_2: 0.8581
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 27/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6958 - my_iou_metric_2: 0.9100 - val_loss: -0.3786 - val_my_iou_metric_2: 0.8554
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.86429
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 28/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7022 - my_iou_metric_2: 0.9134 - val_loss: -0.4268 - val_my_iou_metric_2: 0.8607
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 29/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7121 - my_iou_metric_2: 0.9152 - val_loss: -0.4331 - val_my_iou_metric_2: 0.8643
#
# Epoch 00029: val_my_iou_metric_2 improved from 0.86429 to 0.86429, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 30/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7090 - my_iou_metric_2: 0.9150 - val_loss: -0.4204 - val_my_iou_metric_2: 0.8609
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 31/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7148 - my_iou_metric_2: 0.9159 - val_loss: -0.4237 - val_my_iou_metric_2: 0.8624
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 32/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7155 - my_iou_metric_2: 0.9160 - val_loss: -0.3956 - val_my_iou_metric_2: 0.8617
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.86429
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 33/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7243 - my_iou_metric_2: 0.9188 - val_loss: -0.4044 - val_my_iou_metric_2: 0.8627
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 34/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7133 - my_iou_metric_2: 0.9184 - val_loss: -0.4154 - val_my_iou_metric_2: 0.8614
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 35/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7237 - my_iou_metric_2: 0.9197 - val_loss: -0.4062 - val_my_iou_metric_2: 0.8609
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 36/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7239 - my_iou_metric_2: 0.9184 - val_loss: -0.4301 - val_my_iou_metric_2: 0.8638
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.86429
# Epoch 37/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7258 - my_iou_metric_2: 0.9210 - val_loss: -0.4216 - val_my_iou_metric_2: 0.8652
#
# Epoch 00037: val_my_iou_metric_2 improved from 0.86429 to 0.86517, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 38/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7244 - my_iou_metric_2: 0.9207 - val_loss: -0.4151 - val_my_iou_metric_2: 0.8663
#
# Epoch 00038: val_my_iou_metric_2 improved from 0.86517 to 0.86629, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 39/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7271 - my_iou_metric_2: 0.9209 - val_loss: -0.4262 - val_my_iou_metric_2: 0.8663
#
# Epoch 00039: val_my_iou_metric_2 improved from 0.86629 to 0.86629, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 40/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7297 - my_iou_metric_2: 0.9208 - val_loss: -0.4185 - val_my_iou_metric_2: 0.8662
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.86629
# Epoch 41/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7276 - my_iou_metric_2: 0.9209 - val_loss: -0.4185 - val_my_iou_metric_2: 0.8663
#
# Epoch 00041: val_my_iou_metric_2 improved from 0.86629 to 0.86629, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 42/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7346 - my_iou_metric_2: 0.9228 - val_loss: -0.4096 - val_my_iou_metric_2: 0.8640
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.86629
# Epoch 43/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7339 - my_iou_metric_2: 0.9234 - val_loss: -0.4194 - val_my_iou_metric_2: 0.8677
#
# Epoch 00043: val_my_iou_metric_2 improved from 0.86629 to 0.86767, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 44/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7360 - my_iou_metric_2: 0.9229 - val_loss: -0.4284 - val_my_iou_metric_2: 0.8692
#
# Epoch 00044: val_my_iou_metric_2 improved from 0.86767 to 0.86916, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_0.model
# Epoch 45/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7386 - my_iou_metric_2: 0.9234 - val_loss: -0.4218 - val_my_iou_metric_2: 0.8648
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 46/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7360 - my_iou_metric_2: 0.9233 - val_loss: -0.4140 - val_my_iou_metric_2: 0.8670
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 47/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7372 - my_iou_metric_2: 0.9246 - val_loss: -0.4132 - val_my_iou_metric_2: 0.8654
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 48/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7362 - my_iou_metric_2: 0.9238 - val_loss: -0.4234 - val_my_iou_metric_2: 0.8659
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 49/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7382 - my_iou_metric_2: 0.9249 - val_loss: -0.4146 - val_my_iou_metric_2: 0.8654
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.86916
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 50/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7404 - my_iou_metric_2: 0.9258 - val_loss: -0.4077 - val_my_iou_metric_2: 0.8632
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 51/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7416 - my_iou_metric_2: 0.9264 - val_loss: -0.4122 - val_my_iou_metric_2: 0.8638
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 52/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7435 - my_iou_metric_2: 0.9261 - val_loss: -0.4088 - val_my_iou_metric_2: 0.8653
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 53/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7436 - my_iou_metric_2: 0.9277 - val_loss: -0.4147 - val_my_iou_metric_2: 0.8663
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 54/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7446 - my_iou_metric_2: 0.9270 - val_loss: -0.4180 - val_my_iou_metric_2: 0.8670
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.86916
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 55/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7458 - my_iou_metric_2: 0.9269 - val_loss: -0.4146 - val_my_iou_metric_2: 0.8664
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 56/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7448 - my_iou_metric_2: 0.9282 - val_loss: -0.4220 - val_my_iou_metric_2: 0.8682
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 57/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7453 - my_iou_metric_2: 0.9274 - val_loss: -0.4201 - val_my_iou_metric_2: 0.8667
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 58/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7484 - my_iou_metric_2: 0.9287 - val_loss: -0.4052 - val_my_iou_metric_2: 0.8665
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 59/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7478 - my_iou_metric_2: 0.9277 - val_loss: -0.4111 - val_my_iou_metric_2: 0.8672
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.86916
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 60/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7479 - my_iou_metric_2: 0.9293 - val_loss: -0.4122 - val_my_iou_metric_2: 0.8673
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 61/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7486 - my_iou_metric_2: 0.9277 - val_loss: -0.4147 - val_my_iou_metric_2: 0.8672
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 62/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7472 - my_iou_metric_2: 0.9275 - val_loss: -0.4133 - val_my_iou_metric_2: 0.8670
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 63/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7483 - my_iou_metric_2: 0.9287 - val_loss: -0.4101 - val_my_iou_metric_2: 0.8673
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.86916
# Epoch 64/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7491 - my_iou_metric_2: 0.9287 - val_loss: -0.4137 - val_my_iou_metric_2: 0.8679
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.86916
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 00064: early stopping
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3199 [00:00<?, ?it/s]
#  20%|█▉        | 631/3199 [00:00<00:00, 6255.97it/s]
#  39%|███▉      | 1243/3199 [00:00<00:00, 6191.35it/s]
#  58%|█████▊    | 1855/3199 [00:00<00:00, 6160.94it/s]
#  74%|███████▍  | 2367/3199 [00:00<00:00, 5900.08it/s]
#  93%|█████████▎| 2984/3199 [00:00<00:00, 5949.95it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.83it/s].00it/s]
# (6398, 101, 101, 1)
# (6398, 101, 101, 1)
# (6398,)
# load from last run ../model/segmenter/Unet_resnet_deeper_elu_32_16_0.5_3.model
# ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# ../result/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.csv
# ../result/segmenter_oof/Unet_resnet_deeper_elu_fix_32_16_0.5_1
# Train on 6398 samples, validate on 801 samples
# Epoch 1/200
# 6398/6398 [==============================] - 117s 18ms/step - loss: -0.4441 - my_iou_metric_2: 0.8526 - val_loss: -0.3832 - val_my_iou_metric_2: 0.8439
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.84395, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 2/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4255 - my_iou_metric_2: 0.8475 - val_loss: -0.4226 - val_my_iou_metric_2: 0.8494
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.84395 to 0.84944, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 3/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.4455 - my_iou_metric_2: 0.8522 - val_loss: -0.4136 - val_my_iou_metric_2: 0.8544
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.84944 to 0.85443, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 4/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.4623 - my_iou_metric_2: 0.8540 - val_loss: -0.3145 - val_my_iou_metric_2: 0.8278
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.85443
# Epoch 5/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.4787 - my_iou_metric_2: 0.8572 - val_loss: -0.2336 - val_my_iou_metric_2: 0.8211
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.85443
# Epoch 6/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.4607 - my_iou_metric_2: 0.8546 - val_loss: -0.0693 - val_my_iou_metric_2: 0.8029
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.85443
# Epoch 7/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.4658 - my_iou_metric_2: 0.8524 - val_loss: -0.1558 - val_my_iou_metric_2: 0.8201
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.85443
# Epoch 8/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.5083 - my_iou_metric_2: 0.8614 - val_loss: -0.2458 - val_my_iou_metric_2: 0.8275
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.85443
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 9/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.5611 - my_iou_metric_2: 0.8750 - val_loss: -0.4304 - val_my_iou_metric_2: 0.8589
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.85443 to 0.85893, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 10/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.5927 - my_iou_metric_2: 0.8809 - val_loss: -0.3379 - val_my_iou_metric_2: 0.8468
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.85893
# Epoch 11/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.5981 - my_iou_metric_2: 0.8828 - val_loss: -0.4352 - val_my_iou_metric_2: 0.8599
#
# Epoch 00011: val_my_iou_metric_2 improved from 0.85893 to 0.85993, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 12/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.6061 - my_iou_metric_2: 0.8839 - val_loss: -0.3680 - val_my_iou_metric_2: 0.8534
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.85993
# Epoch 13/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.6051 - my_iou_metric_2: 0.8837 - val_loss: -0.4143 - val_my_iou_metric_2: 0.8576
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.85993
# Epoch 14/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.6093 - my_iou_metric_2: 0.8861 - val_loss: -0.3558 - val_my_iou_metric_2: 0.8453
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.85993
# Epoch 15/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.6267 - my_iou_metric_2: 0.8895 - val_loss: -0.3284 - val_my_iou_metric_2: 0.8464
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.85993
# Epoch 16/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.6305 - my_iou_metric_2: 0.8909 - val_loss: -0.4004 - val_my_iou_metric_2: 0.8596
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.85993
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 17/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.6474 - my_iou_metric_2: 0.8968 - val_loss: -0.4226 - val_my_iou_metric_2: 0.8623
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.85993 to 0.86230, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 18/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6682 - my_iou_metric_2: 0.9012 - val_loss: -0.3973 - val_my_iou_metric_2: 0.8610
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.86230
# Epoch 19/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.6732 - my_iou_metric_2: 0.9026 - val_loss: -0.3872 - val_my_iou_metric_2: 0.8588
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.86230
# Epoch 20/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.6735 - my_iou_metric_2: 0.9041 - val_loss: -0.4217 - val_my_iou_metric_2: 0.8652
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.86230 to 0.86517, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 21/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.6824 - my_iou_metric_2: 0.9049 - val_loss: -0.3734 - val_my_iou_metric_2: 0.8623
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.86517
# Epoch 22/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6860 - my_iou_metric_2: 0.9060 - val_loss: -0.3816 - val_my_iou_metric_2: 0.8669
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.86517 to 0.86692, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 23/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6884 - my_iou_metric_2: 0.9069 - val_loss: -0.3938 - val_my_iou_metric_2: 0.8629
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 24/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6695 - my_iou_metric_2: 0.9043 - val_loss: -0.4036 - val_my_iou_metric_2: 0.8640
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 25/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.6862 - my_iou_metric_2: 0.9081 - val_loss: -0.4348 - val_my_iou_metric_2: 0.8655
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 26/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.6992 - my_iou_metric_2: 0.9103 - val_loss: -0.3587 - val_my_iou_metric_2: 0.8618
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 27/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.6943 - my_iou_metric_2: 0.9108 - val_loss: -0.4173 - val_my_iou_metric_2: 0.8662
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.86692
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 28/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7046 - my_iou_metric_2: 0.9137 - val_loss: -0.4256 - val_my_iou_metric_2: 0.8657
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 29/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7126 - my_iou_metric_2: 0.9146 - val_loss: -0.4114 - val_my_iou_metric_2: 0.8662
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 30/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7158 - my_iou_metric_2: 0.9163 - val_loss: -0.4057 - val_my_iou_metric_2: 0.8638
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 31/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7150 - my_iou_metric_2: 0.9173 - val_loss: -0.3834 - val_my_iou_metric_2: 0.8658
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.86692
# Epoch 32/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7169 - my_iou_metric_2: 0.9174 - val_loss: -0.4011 - val_my_iou_metric_2: 0.8644
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.86692
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 33/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7242 - my_iou_metric_2: 0.9195 - val_loss: -0.4063 - val_my_iou_metric_2: 0.8673
#
# Epoch 00033: val_my_iou_metric_2 improved from 0.86692 to 0.86729, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 34/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7293 - my_iou_metric_2: 0.9215 - val_loss: -0.3949 - val_my_iou_metric_2: 0.8663
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 35/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7291 - my_iou_metric_2: 0.9207 - val_loss: -0.4005 - val_my_iou_metric_2: 0.8658
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 36/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7270 - my_iou_metric_2: 0.9207 - val_loss: -0.3792 - val_my_iou_metric_2: 0.8663
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 37/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7305 - my_iou_metric_2: 0.9216 - val_loss: -0.3781 - val_my_iou_metric_2: 0.8659
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 38/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7321 - my_iou_metric_2: 0.9223 - val_loss: -0.3956 - val_my_iou_metric_2: 0.8645
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.86729
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 39/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7392 - my_iou_metric_2: 0.9239 - val_loss: -0.3925 - val_my_iou_metric_2: 0.8667
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 40/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7353 - my_iou_metric_2: 0.9232 - val_loss: -0.3970 - val_my_iou_metric_2: 0.8649
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 41/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7345 - my_iou_metric_2: 0.9247 - val_loss: -0.3860 - val_my_iou_metric_2: 0.8652
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 42/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7397 - my_iou_metric_2: 0.9253 - val_loss: -0.3903 - val_my_iou_metric_2: 0.8653
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 43/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7361 - my_iou_metric_2: 0.9241 - val_loss: -0.3821 - val_my_iou_metric_2: 0.8659
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.86729
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 44/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7354 - my_iou_metric_2: 0.9230 - val_loss: -0.3866 - val_my_iou_metric_2: 0.8663
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 45/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7277 - my_iou_metric_2: 0.9244 - val_loss: -0.3974 - val_my_iou_metric_2: 0.8660
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.86729
# Epoch 46/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7401 - my_iou_metric_2: 0.9253 - val_loss: -0.3930 - val_my_iou_metric_2: 0.8677
#
# Epoch 00046: val_my_iou_metric_2 improved from 0.86729 to 0.86767, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 47/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7420 - my_iou_metric_2: 0.9254 - val_loss: -0.3957 - val_my_iou_metric_2: 0.8660
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 48/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7383 - my_iou_metric_2: 0.9259 - val_loss: -0.3905 - val_my_iou_metric_2: 0.8668
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 49/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7416 - my_iou_metric_2: 0.9263 - val_loss: -0.3848 - val_my_iou_metric_2: 0.8669
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 50/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7416 - my_iou_metric_2: 0.9249 - val_loss: -0.3811 - val_my_iou_metric_2: 0.8663
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 51/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7442 - my_iou_metric_2: 0.9263 - val_loss: -0.3772 - val_my_iou_metric_2: 0.8665
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.86767
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 52/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7404 - my_iou_metric_2: 0.9264 - val_loss: -0.3741 - val_my_iou_metric_2: 0.8658
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 53/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7429 - my_iou_metric_2: 0.9255 - val_loss: -0.3804 - val_my_iou_metric_2: 0.8664
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 54/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7441 - my_iou_metric_2: 0.9266 - val_loss: -0.3812 - val_my_iou_metric_2: 0.8662
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 55/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7439 - my_iou_metric_2: 0.9264 - val_loss: -0.3818 - val_my_iou_metric_2: 0.8662
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 56/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7433 - my_iou_metric_2: 0.9264 - val_loss: -0.3820 - val_my_iou_metric_2: 0.8650
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.86767
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 57/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7460 - my_iou_metric_2: 0.9265 - val_loss: -0.3823 - val_my_iou_metric_2: 0.8667
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.86767
# Epoch 58/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7426 - my_iou_metric_2: 0.9257 - val_loss: -0.3837 - val_my_iou_metric_2: 0.8679
#
# Epoch 00058: val_my_iou_metric_2 improved from 0.86767 to 0.86792, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_1.model
# Epoch 59/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7441 - my_iou_metric_2: 0.9262 - val_loss: -0.3815 - val_my_iou_metric_2: 0.8674
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 60/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7429 - my_iou_metric_2: 0.9268 - val_loss: -0.3849 - val_my_iou_metric_2: 0.8657
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 61/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7422 - my_iou_metric_2: 0.9257 - val_loss: -0.3839 - val_my_iou_metric_2: 0.8668
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 62/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7363 - my_iou_metric_2: 0.9255 - val_loss: -0.3876 - val_my_iou_metric_2: 0.8659
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 63/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7445 - my_iou_metric_2: 0.9267 - val_loss: -0.3857 - val_my_iou_metric_2: 0.8652
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.86792
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 64/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7418 - my_iou_metric_2: 0.9260 - val_loss: -0.3868 - val_my_iou_metric_2: 0.8650
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 65/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7444 - my_iou_metric_2: 0.9268 - val_loss: -0.3882 - val_my_iou_metric_2: 0.8659
#
# Epoch 00065: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 66/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7438 - my_iou_metric_2: 0.9264 - val_loss: -0.3833 - val_my_iou_metric_2: 0.8668
#
# Epoch 00066: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 67/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7452 - my_iou_metric_2: 0.9273 - val_loss: -0.3863 - val_my_iou_metric_2: 0.8652
#
# Epoch 00067: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 68/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7443 - my_iou_metric_2: 0.9286 - val_loss: -0.3917 - val_my_iou_metric_2: 0.8654
#
# Epoch 00068: val_my_iou_metric_2 did not improve from 0.86792
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 69/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7439 - my_iou_metric_2: 0.9259 - val_loss: -0.3898 - val_my_iou_metric_2: 0.8653
#
# Epoch 00069: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 70/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7438 - my_iou_metric_2: 0.9268 - val_loss: -0.3920 - val_my_iou_metric_2: 0.8649
#
# Epoch 00070: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 71/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7457 - my_iou_metric_2: 0.9278 - val_loss: -0.3894 - val_my_iou_metric_2: 0.8659
#
# Epoch 00071: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 72/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7438 - my_iou_metric_2: 0.9265 - val_loss: -0.3876 - val_my_iou_metric_2: 0.8657
#
# Epoch 00072: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 73/200
# 6398/6398 [==============================] - 106s 16ms/step - loss: -0.7447 - my_iou_metric_2: 0.9272 - val_loss: -0.3823 - val_my_iou_metric_2: 0.8668
#
# Epoch 00073: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 74/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7435 - my_iou_metric_2: 0.9265 - val_loss: -0.3857 - val_my_iou_metric_2: 0.8677
#
# Epoch 00074: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 75/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7435 - my_iou_metric_2: 0.9265 - val_loss: -0.3845 - val_my_iou_metric_2: 0.8664
#
# Epoch 00075: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 76/200
# 6398/6398 [==============================] - 105s 16ms/step - loss: -0.7445 - my_iou_metric_2: 0.9264 - val_loss: -0.3881 - val_my_iou_metric_2: 0.8662
#
# Epoch 00076: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 77/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7331 - my_iou_metric_2: 0.9264 - val_loss: -0.3865 - val_my_iou_metric_2: 0.8650
#
# Epoch 00077: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 78/200
# 6398/6398 [==============================] - 106s 17ms/step - loss: -0.7411 - my_iou_metric_2: 0.9264 - val_loss: -0.3875 - val_my_iou_metric_2: 0.8643
#
# Epoch 00078: val_my_iou_metric_2 did not improve from 0.86792
# Epoch 00078: early stopping
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3200 [00:00<?, ?it/s]
#  21%|██        | 668/3200 [00:00<00:00, 6615.86it/s]
#  39%|███▉      | 1259/3200 [00:00<00:00, 6268.09it/s]
#  58%|█████▊    | 1847/3200 [00:00<00:00, 6140.00it/s]
#  74%|███████▍  | 2374/3200 [00:00<00:00, 5920.82it/s]
#  91%|█████████▏| 2925/3200 [00:00<00:00, 5838.13it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.80it/s].29it/s]
# (6400, 101, 101, 1)
# (6400, 101, 101, 1)
# (6400,)
# load from last run ../model/segmenter/Unet_resnet_deeper_elu_32_16_0.5_3.model
# ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# ../result/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.csv
# ../result/segmenter_oof/Unet_resnet_deeper_elu_fix_32_16_0.5_2
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 117s 18ms/step - loss: -0.4364 - my_iou_metric_2: 0.8529 - val_loss: -0.5028 - val_my_iou_metric_2: 0.8619
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.86187, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 2/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.4297 - my_iou_metric_2: 0.8476 - val_loss: -0.2970 - val_my_iou_metric_2: 0.8263
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.86187
# Epoch 3/200
# 6400/6400 [==============================] - 106s 17ms/step - loss: -0.4524 - my_iou_metric_2: 0.8520 - val_loss: -0.4054 - val_my_iou_metric_2: 0.8479
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.86187
# Epoch 4/200
# 6400/6400 [==============================] - 106s 17ms/step - loss: -0.4559 - my_iou_metric_2: 0.8516 - val_loss: -0.3953 - val_my_iou_metric_2: 0.8482
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.86187
# Epoch 5/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.4634 - my_iou_metric_2: 0.8528 - val_loss: -0.3287 - val_my_iou_metric_2: 0.8253
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.86187
# Epoch 6/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.4606 - my_iou_metric_2: 0.8549 - val_loss: -0.3076 - val_my_iou_metric_2: 0.8340
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.86187
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 7/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.5437 - my_iou_metric_2: 0.8703 - val_loss: -0.3878 - val_my_iou_metric_2: 0.8444
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.86187
# Epoch 8/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.5746 - my_iou_metric_2: 0.8758 - val_loss: -0.5058 - val_my_iou_metric_2: 0.8685
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.86187 to 0.86850, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 9/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.5697 - my_iou_metric_2: 0.8760 - val_loss: -0.5020 - val_my_iou_metric_2: 0.8686
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.86850 to 0.86862, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 10/200
# 6400/6400 [==============================] - 106s 17ms/step - loss: -0.5916 - my_iou_metric_2: 0.8802 - val_loss: -0.4420 - val_my_iou_metric_2: 0.8560
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 11/200
# 6400/6400 [==============================] - 106s 17ms/step - loss: -0.5996 - my_iou_metric_2: 0.8845 - val_loss: -0.4565 - val_my_iou_metric_2: 0.8618
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 12/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6050 - my_iou_metric_2: 0.8844 - val_loss: -0.4736 - val_my_iou_metric_2: 0.8600
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 13/200
# 6400/6400 [==============================] - 106s 17ms/step - loss: -0.6052 - my_iou_metric_2: 0.8847 - val_loss: -0.4971 - val_my_iou_metric_2: 0.8667
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 14/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6101 - my_iou_metric_2: 0.8852 - val_loss: -0.4438 - val_my_iou_metric_2: 0.8567
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.86862
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 15/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6365 - my_iou_metric_2: 0.8938 - val_loss: -0.4872 - val_my_iou_metric_2: 0.8680
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 16/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.6484 - my_iou_metric_2: 0.8984 - val_loss: -0.4644 - val_my_iou_metric_2: 0.8662
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 17/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6557 - my_iou_metric_2: 0.8979 - val_loss: -0.4817 - val_my_iou_metric_2: 0.8638
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 18/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.6686 - my_iou_metric_2: 0.9020 - val_loss: -0.4710 - val_my_iou_metric_2: 0.8661
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.86862
# Epoch 19/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6695 - my_iou_metric_2: 0.9025 - val_loss: -0.4806 - val_my_iou_metric_2: 0.8710
#
# Epoch 00019: val_my_iou_metric_2 improved from 0.86862 to 0.87100, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 20/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.6697 - my_iou_metric_2: 0.9032 - val_loss: -0.4529 - val_my_iou_metric_2: 0.8657
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.87100
# Epoch 21/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6776 - my_iou_metric_2: 0.9047 - val_loss: -0.4922 - val_my_iou_metric_2: 0.8696
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.87100
# Epoch 22/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.6723 - my_iou_metric_2: 0.9034 - val_loss: -0.4664 - val_my_iou_metric_2: 0.8679
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.87100
# Epoch 23/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.6808 - my_iou_metric_2: 0.9044 - val_loss: -0.4426 - val_my_iou_metric_2: 0.8695
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.87100
# Epoch 24/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6808 - my_iou_metric_2: 0.9061 - val_loss: -0.4730 - val_my_iou_metric_2: 0.8676
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.87100
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 25/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6777 - my_iou_metric_2: 0.9084 - val_loss: -0.4805 - val_my_iou_metric_2: 0.8728
#
# Epoch 00025: val_my_iou_metric_2 improved from 0.87100 to 0.87275, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 26/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.7013 - my_iou_metric_2: 0.9112 - val_loss: -0.4917 - val_my_iou_metric_2: 0.8731
#
# Epoch 00026: val_my_iou_metric_2 improved from 0.87275 to 0.87313, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 27/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.6953 - my_iou_metric_2: 0.9121 - val_loss: -0.4820 - val_my_iou_metric_2: 0.8764
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.87313 to 0.87638, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 28/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.7036 - my_iou_metric_2: 0.9129 - val_loss: -0.4682 - val_my_iou_metric_2: 0.8691
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.87638
# Epoch 29/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.7067 - my_iou_metric_2: 0.9144 - val_loss: -0.4533 - val_my_iou_metric_2: 0.8715
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.87638
# Epoch 30/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.7064 - my_iou_metric_2: 0.9149 - val_loss: -0.4677 - val_my_iou_metric_2: 0.8718
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.87638
# Epoch 31/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.7107 - my_iou_metric_2: 0.9152 - val_loss: -0.4580 - val_my_iou_metric_2: 0.8724
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.87638
# Epoch 32/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.7041 - my_iou_metric_2: 0.9150 - val_loss: -0.4725 - val_my_iou_metric_2: 0.8739
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.87638
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 33/200
# 6400/6400 [==============================] - 106s 17ms/step - loss: -0.7203 - my_iou_metric_2: 0.9181 - val_loss: -0.4595 - val_my_iou_metric_2: 0.8714
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.87638
# Epoch 34/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.7192 - my_iou_metric_2: 0.9187 - val_loss: -0.4832 - val_my_iou_metric_2: 0.8754
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.87638
# Epoch 35/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.7236 - my_iou_metric_2: 0.9200 - val_loss: -0.4806 - val_my_iou_metric_2: 0.8772
#
# Epoch 00035: val_my_iou_metric_2 improved from 0.87638 to 0.87725, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_2.model
# Epoch 36/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.7240 - my_iou_metric_2: 0.9198 - val_loss: -0.4724 - val_my_iou_metric_2: 0.8750
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.87725
# Epoch 37/200
# 6400/6400 [==============================] - 106s 16ms/step - loss: -0.7246 - my_iou_metric_2: 0.9205 - val_loss: -0.4849 - val_my_iou_metric_2: 0.8764
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.87725
# Epoch 38/200
# 6400/6400 [==============================] - 105s 16ms/step - loss: -0.7235 - my_iou_metric_2: 0.9202 - val_loss: -0.4823 - val_my_iou_metric_2: 0.8755
#
# ...
# ../result/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.csv
# ../result/segmenter_oof/Unet_resnet_deeper_elu_fix_32_16_0.5_4
# Train on 6402 samples, validate on 799 samples
# Epoch 1/200
# 6402/6402 [==============================] - 117s 18ms/step - loss: -0.4179 - my_iou_metric_2: 0.8492 - val_loss: -0.4076 - val_my_iou_metric_2: 0.8557
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.85569, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 2/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.4142 - my_iou_metric_2: 0.8446 - val_loss: 0.5406 - val_my_iou_metric_2: 0.7160
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.85569
# Epoch 3/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.3826 - my_iou_metric_2: 0.8367 - val_loss: -0.4567 - val_my_iou_metric_2: 0.8583
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.85569 to 0.85832, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 4/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.4488 - my_iou_metric_2: 0.8515 - val_loss: -0.4601 - val_my_iou_metric_2: 0.8549
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.85832
# Epoch 5/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.4577 - my_iou_metric_2: 0.8523 - val_loss: -0.2660 - val_my_iou_metric_2: 0.8382
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.85832
# Epoch 6/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.4674 - my_iou_metric_2: 0.8547 - val_loss: -0.2663 - val_my_iou_metric_2: 0.8305
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.85832
# Epoch 7/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.4572 - my_iou_metric_2: 0.8532 - val_loss: -0.3103 - val_my_iou_metric_2: 0.8364
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.85832
# Epoch 8/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.4828 - my_iou_metric_2: 0.8572 - val_loss: -0.3797 - val_my_iou_metric_2: 0.8449
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.85832
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 9/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.5209 - my_iou_metric_2: 0.8650 - val_loss: -0.4245 - val_my_iou_metric_2: 0.8503
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.85832
# Epoch 10/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.5704 - my_iou_metric_2: 0.8754 - val_loss: -0.4441 - val_my_iou_metric_2: 0.8579
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.85832
# Epoch 11/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.5812 - my_iou_metric_2: 0.8790 - val_loss: -0.4788 - val_my_iou_metric_2: 0.8655
#
# Epoch 00011: val_my_iou_metric_2 improved from 0.85832 to 0.86546, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 12/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.5724 - my_iou_metric_2: 0.8769 - val_loss: -0.5100 - val_my_iou_metric_2: 0.8692
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.86546 to 0.86921, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 13/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.5932 - my_iou_metric_2: 0.8810 - val_loss: 0.0100 - val_my_iou_metric_2: 0.8046
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.86921
# Epoch 14/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6048 - my_iou_metric_2: 0.8849 - val_loss: -0.2657 - val_my_iou_metric_2: 0.8491
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.86921
# Epoch 15/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6047 - my_iou_metric_2: 0.8841 - val_loss: -0.4980 - val_my_iou_metric_2: 0.8618
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.86921
# Epoch 16/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.5996 - my_iou_metric_2: 0.8845 - val_loss: -0.4563 - val_my_iou_metric_2: 0.8631
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.86921
# Epoch 17/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6188 - my_iou_metric_2: 0.8882 - val_loss: -0.4835 - val_my_iou_metric_2: 0.8673
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.86921
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 18/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6267 - my_iou_metric_2: 0.8916 - val_loss: -0.5079 - val_my_iou_metric_2: 0.8706
#
# Epoch 00018: val_my_iou_metric_2 improved from 0.86921 to 0.87059, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 19/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6497 - my_iou_metric_2: 0.8970 - val_loss: -0.4663 - val_my_iou_metric_2: 0.8686
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.87059
# Epoch 20/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6507 - my_iou_metric_2: 0.8969 - val_loss: -0.4780 - val_my_iou_metric_2: 0.8767
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.87059 to 0.87672, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 21/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6559 - my_iou_metric_2: 0.8991 - val_loss: -0.4434 - val_my_iou_metric_2: 0.8692
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 22/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6667 - my_iou_metric_2: 0.9014 - val_loss: -0.4824 - val_my_iou_metric_2: 0.8678
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 23/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6708 - my_iou_metric_2: 0.9017 - val_loss: -0.4785 - val_my_iou_metric_2: 0.8737
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 24/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6697 - my_iou_metric_2: 0.9010 - val_loss: -0.4429 - val_my_iou_metric_2: 0.8685
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 25/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6725 - my_iou_metric_2: 0.9026 - val_loss: -0.4272 - val_my_iou_metric_2: 0.8662
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.87672
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 26/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6836 - my_iou_metric_2: 0.9064 - val_loss: -0.4997 - val_my_iou_metric_2: 0.8760
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 27/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6909 - my_iou_metric_2: 0.9083 - val_loss: -0.5004 - val_my_iou_metric_2: 0.8756
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 28/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6921 - my_iou_metric_2: 0.9083 - val_loss: -0.5014 - val_my_iou_metric_2: 0.8748
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 29/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6952 - my_iou_metric_2: 0.9089 - val_loss: -0.5033 - val_my_iou_metric_2: 0.8755
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.87672
# Epoch 30/200
# 6402/6402 [==============================] - 106s 17ms/step - loss: -0.6944 - my_iou_metric_2: 0.9104 - val_loss: -0.4977 - val_my_iou_metric_2: 0.8791
#
# Epoch 00030: val_my_iou_metric_2 improved from 0.87672 to 0.87910, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 31/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6991 - my_iou_metric_2: 0.9102 - val_loss: -0.5083 - val_my_iou_metric_2: 0.8765
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 32/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7006 - my_iou_metric_2: 0.9114 - val_loss: -0.4615 - val_my_iou_metric_2: 0.8745
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 33/200
# 6402/6402 [==============================] - 106s 16ms/step - loss: -0.6986 - my_iou_metric_2: 0.9110 - val_loss: -0.4993 - val_my_iou_metric_2: 0.8743
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 34/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.6959 - my_iou_metric_2: 0.9106 - val_loss: -0.4793 - val_my_iou_metric_2: 0.8755
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 35/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7060 - my_iou_metric_2: 0.9130 - val_loss: -0.4939 - val_my_iou_metric_2: 0.8773
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.87910
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 36/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7136 - my_iou_metric_2: 0.9152 - val_loss: -0.4992 - val_my_iou_metric_2: 0.8765
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 37/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7145 - my_iou_metric_2: 0.9162 - val_loss: -0.4836 - val_my_iou_metric_2: 0.8741
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 38/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7100 - my_iou_metric_2: 0.9164 - val_loss: -0.4895 - val_my_iou_metric_2: 0.8760
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 39/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7162 - my_iou_metric_2: 0.9170 - val_loss: -0.5021 - val_my_iou_metric_2: 0.8775
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 40/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7170 - my_iou_metric_2: 0.9168 - val_loss: -0.4973 - val_my_iou_metric_2: 0.8783
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.87910
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 41/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7147 - my_iou_metric_2: 0.9169 - val_loss: -0.5022 - val_my_iou_metric_2: 0.8790
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 42/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7176 - my_iou_metric_2: 0.9170 - val_loss: -0.5005 - val_my_iou_metric_2: 0.8783
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.87910
# Epoch 43/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7168 - my_iou_metric_2: 0.9178 - val_loss: -0.4928 - val_my_iou_metric_2: 0.8796
#
# Epoch 00043: val_my_iou_metric_2 improved from 0.87910 to 0.87960, saving model to ../model/segmenter/Unet_resnet_deeper_elu_fix_32_16_0.5_4.model
# Epoch 44/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7212 - my_iou_metric_2: 0.9183 - val_loss: -0.4928 - val_my_iou_metric_2: 0.8772
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 45/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7226 - my_iou_metric_2: 0.9193 - val_loss: -0.4902 - val_my_iou_metric_2: 0.8770
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 46/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7230 - my_iou_metric_2: 0.9190 - val_loss: -0.5027 - val_my_iou_metric_2: 0.8761
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 47/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7245 - my_iou_metric_2: 0.9189 - val_loss: -0.4903 - val_my_iou_metric_2: 0.8783
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 48/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7229 - my_iou_metric_2: 0.9187 - val_loss: -0.4842 - val_my_iou_metric_2: 0.8760
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.87960
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 49/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7243 - my_iou_metric_2: 0.9201 - val_loss: -0.4873 - val_my_iou_metric_2: 0.8781
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 50/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7253 - my_iou_metric_2: 0.9206 - val_loss: -0.4885 - val_my_iou_metric_2: 0.8783
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 51/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7250 - my_iou_metric_2: 0.9204 - val_loss: -0.4944 - val_my_iou_metric_2: 0.8781
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 52/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7264 - my_iou_metric_2: 0.9205 - val_loss: -0.4979 - val_my_iou_metric_2: 0.8790
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 53/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7243 - my_iou_metric_2: 0.9191 - val_loss: -0.4920 - val_my_iou_metric_2: 0.8778
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.87960
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 54/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7266 - my_iou_metric_2: 0.9200 - val_loss: -0.4910 - val_my_iou_metric_2: 0.8777
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 55/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7264 - my_iou_metric_2: 0.9196 - val_loss: -0.4929 - val_my_iou_metric_2: 0.8782
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 56/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7234 - my_iou_metric_2: 0.9199 - val_loss: -0.4934 - val_my_iou_metric_2: 0.8783
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 57/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7277 - my_iou_metric_2: 0.9207 - val_loss: -0.4937 - val_my_iou_metric_2: 0.8782
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 58/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7269 - my_iou_metric_2: 0.9208 - val_loss: -0.4974 - val_my_iou_metric_2: 0.8787
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.87960
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 59/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7283 - my_iou_metric_2: 0.9218 - val_loss: -0.4965 - val_my_iou_metric_2: 0.8788
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 60/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7291 - my_iou_metric_2: 0.9212 - val_loss: -0.4919 - val_my_iou_metric_2: 0.8782
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 61/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7279 - my_iou_metric_2: 0.9208 - val_loss: -0.4929 - val_my_iou_metric_2: 0.8782
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 62/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7286 - my_iou_metric_2: 0.9200 - val_loss: -0.4955 - val_my_iou_metric_2: 0.8785
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.87960
# Epoch 63/200
# 6402/6402 [==============================] - 105s 16ms/step - loss: -0.7283 - my_iou_metric_2: 0.9207 - val_loss: -0.4944 - val_my_iou_metric_2: 0.8788
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.87960
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 00063: early stopping

# %%
pred_vals = []
msk_vals = []
pred_tests = []
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1234)
for fold, (train_idx, val_idx) in enumerate(skf.split(train_df, train_df['hassalt'])):
    print('predict for fold', fold)
    
    
    base_name = 'Unet_resnet_deeper_elu_fix2_{}_{}_{}_{}'.format(start_feature, batch_size, dropout, fold)
    basic_name = '../model/segmenter/{}'.format(base_name)
    save_model_name = basic_name + '.model'

    model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})
    
    x_train, x_valid, msk_train, msk_val, y_train, y_valid, id_train, id_valid = get_splits(train_df, train_idx, 
                                                                                            val_idx)
    
    preds_valid = predict_result(model,x_valid,img_size_target)
    pred_vals.append(preds_valid)
    msk_vals.append(msk_val)
    
    preds_test = predict_result(model,x_test,img_size_target)
    pred_tests.append(preds_test)

    from keras import backend as K
    K.clear_session()
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# predict for fold 0
# 801/801 [==============================] - 4s 4ms/step
# 18000/18000 [==============================] - 45s 2ms/step
# predict for fold 1
# 801/801 [==============================] - 3s 4ms/step
# 18000/18000 [==============================] - 45s 2ms/step
# predict for fold 2
# 800/800 [==============================] - 3s 4ms/step
# 18000/18000 [==============================] - 45s 2ms/step
# predict for fold 3
# 799/799 [==============================] - 4s 4ms/step
# 18000/18000 [==============================] - 45s 2ms/step
# predict for fold 4
# 799/799 [==============================] - 3s 4ms/step
# 18000/18000 [==============================] - 45s 2ms/step

# %%
val_ids = []
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1234)
for fold, (train_idx, val_idx) in enumerate(skf.split(train_df, train_df['hassalt'])):
    val_ids += list(train_df.iloc[val_idx].index.values)
    
pred_all = np.concatenate(pred_vals, axis=0)
msk_all = np.concatenate(msk_vals, axis= 0)

thresholds_ori = np.linspace(0.3, 0.7, 35)
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(msk_all, pred_all > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# HBox(children=(IntProgress(value=0, max=35), HTML(value='')))
# [0.8738   0.874525 0.874675 0.87475  0.87485  0.875525 0.87565  0.87595
#  0.876025 0.876825 0.8768   0.876675 0.876775 0.87675  0.87715  0.877125
#  0.877075 0.877075 0.876925 0.876375 0.8758   0.875575 0.875225 0.87475
#  0.8744   0.8744   0.8747   0.874775 0.87475  0.87415  0.8732   0.8725
#  0.87215  0.87195  0.87155 ]

# %%
val_all = (pred_all > threshold_best) * 1
df_iou = pd.DataFrame(columns=['id', 'iou'])
cnt = 0
for i in tqdm_notebook(range(len(val_all))):
    id = val_ids[i]
    iou = iou_metric_batch(msk_all[i], val_all[i])
    df_iou = df_iou.append({'id':id, 'iou':iou}, ignore_index=True)

df_iou.to_csv('../result/iou_elu.csv', index = False)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
pred_tests_act = pred_tests
pred_test_all = np.zeros_like(pred_tests_act[0], dtype=np.float32)
for pre in pred_tests_act:
    pred_test_all += pre / len(pred_tests_act)
    
pred_dict = {idx: rle_encode(np.round(downsample(pred_test_all[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/segmenter/unet_resnet_elu_fix2_avg.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# save result
# upload result
# cmd: kaggle competitions submit -c tgs-salt-identification-challenge -f ../result/segmenter/unet_resnet_elu_fix_avg.csv.7z -m "submit"
