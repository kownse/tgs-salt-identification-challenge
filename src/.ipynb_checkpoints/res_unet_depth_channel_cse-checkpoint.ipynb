# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
x_train = add_depth_bulk(x_train)
x_valid = add_depth_bulk(x_valid)
print(x_train.shape)
print(y_valid.shape)
# Out:
# HBox(children=(IntProgress(value=0, max=6400), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=800), HTML(value='')))
# (6400, 101, 101, 3)
# (800, 101, 101, 1)

# %%
start_feature = 32
dropout = 0.5
batch_size = 8
base_name = 'Unet_resnet_depthinchannel_cse_{}_{}'.format(batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 3))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# ../model/Unet_resnet_depthinchannel_up_32_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 109s 17ms/step - loss: 0.5617 - my_iou_metric: 0.3470 - val_loss: 8.4443 - val_my_iou_metric: 0.1015
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.10150, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.4010 - my_iou_metric: 0.4259 - val_loss: 0.6573 - val_my_iou_metric: 0.3900
#
# Epoch 00002: val_my_iou_metric improved from 0.10150 to 0.39000, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.3587 - my_iou_metric: 0.4831 - val_loss: 0.3447 - val_my_iou_metric: 0.5269
#
# Epoch 00003: val_my_iou_metric improved from 0.39000 to 0.52687, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.3242 - my_iou_metric: 0.5242 - val_loss: 0.3695 - val_my_iou_metric: 0.5444
#
# Epoch 00004: val_my_iou_metric improved from 0.52687 to 0.54437, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2820 - my_iou_metric: 0.5516 - val_loss: 0.3619 - val_my_iou_metric: 0.4751
#
# Epoch 00005: val_my_iou_metric did not improve from 0.54437
# Epoch 6/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2560 - my_iou_metric: 0.5784 - val_loss: 0.2498 - val_my_iou_metric: 0.5976
#
# Epoch 00006: val_my_iou_metric improved from 0.54437 to 0.59762, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2285 - my_iou_metric: 0.6055 - val_loss: 0.2239 - val_my_iou_metric: 0.6004
#
# Epoch 00007: val_my_iou_metric improved from 0.59762 to 0.60038, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.2137 - my_iou_metric: 0.6224 - val_loss: 0.2713 - val_my_iou_metric: 0.5901
#
# Epoch 00008: val_my_iou_metric did not improve from 0.60038
# Epoch 9/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1941 - my_iou_metric: 0.6453 - val_loss: 0.1792 - val_my_iou_metric: 0.6867
#
# Epoch 00009: val_my_iou_metric improved from 0.60038 to 0.68675, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1881 - my_iou_metric: 0.6561 - val_loss: 0.1910 - val_my_iou_metric: 0.6531
#
# Epoch 00010: val_my_iou_metric did not improve from 0.68675
# Epoch 11/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1788 - my_iou_metric: 0.6691 - val_loss: 0.2010 - val_my_iou_metric: 0.6884
#
# Epoch 00011: val_my_iou_metric improved from 0.68675 to 0.68837, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 12/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1667 - my_iou_metric: 0.6866 - val_loss: 0.2213 - val_my_iou_metric: 0.6564
#
# Epoch 00012: val_my_iou_metric did not improve from 0.68837
# Epoch 13/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1646 - my_iou_metric: 0.6960 - val_loss: 0.2142 - val_my_iou_metric: 0.6986
#
# Epoch 00013: val_my_iou_metric improved from 0.68837 to 0.69863, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1575 - my_iou_metric: 0.7008 - val_loss: 0.1636 - val_my_iou_metric: 0.7149
#
# Epoch 00014: val_my_iou_metric improved from 0.69863 to 0.71487, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1528 - my_iou_metric: 0.7072 - val_loss: 0.1493 - val_my_iou_metric: 0.7361
#
# Epoch 00015: val_my_iou_metric improved from 0.71487 to 0.73612, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1502 - my_iou_metric: 0.7139 - val_loss: 0.1475 - val_my_iou_metric: 0.7260
#
# Epoch 00016: val_my_iou_metric did not improve from 0.73612
# Epoch 17/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1458 - my_iou_metric: 0.7177 - val_loss: 0.1448 - val_my_iou_metric: 0.7281
#
# Epoch 00017: val_my_iou_metric did not improve from 0.73612
# Epoch 18/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1375 - my_iou_metric: 0.7269 - val_loss: 0.1593 - val_my_iou_metric: 0.7251
#
# Epoch 00018: val_my_iou_metric did not improve from 0.73612
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 19/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1266 - my_iou_metric: 0.7415 - val_loss: 0.1523 - val_my_iou_metric: 0.7429
#
# Epoch 00019: val_my_iou_metric improved from 0.73612 to 0.74288, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1171 - my_iou_metric: 0.7538 - val_loss: 0.1443 - val_my_iou_metric: 0.7656
#
# Epoch 00020: val_my_iou_metric improved from 0.74288 to 0.76563, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1184 - my_iou_metric: 0.7491 - val_loss: 0.1429 - val_my_iou_metric: 0.7483
#
# Epoch 00021: val_my_iou_metric did not improve from 0.76563
# Epoch 22/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1152 - my_iou_metric: 0.7551 - val_loss: 0.1450 - val_my_iou_metric: 0.7514
#
# Epoch 00022: val_my_iou_metric did not improve from 0.76563
# Epoch 23/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1105 - my_iou_metric: 0.7604 - val_loss: 0.1372 - val_my_iou_metric: 0.7616
#
# Epoch 00023: val_my_iou_metric did not improve from 0.76563
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 24/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1019 - my_iou_metric: 0.7709 - val_loss: 0.1364 - val_my_iou_metric: 0.7660
#
# Epoch 00024: val_my_iou_metric improved from 0.76563 to 0.76600, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0969 - my_iou_metric: 0.7741 - val_loss: 0.1450 - val_my_iou_metric: 0.7649
#
# Epoch 00025: val_my_iou_metric did not improve from 0.76600
# Epoch 26/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0923 - my_iou_metric: 0.7766 - val_loss: 0.1319 - val_my_iou_metric: 0.7721
#
# Epoch 00026: val_my_iou_metric improved from 0.76600 to 0.77212, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 27/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0914 - my_iou_metric: 0.7799 - val_loss: 0.1248 - val_my_iou_metric: 0.7726
#
# Epoch 00027: val_my_iou_metric improved from 0.77212 to 0.77263, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0894 - my_iou_metric: 0.7791 - val_loss: 0.1469 - val_my_iou_metric: 0.7631
#
# Epoch 00028: val_my_iou_metric did not improve from 0.77263
# Epoch 29/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0842 - my_iou_metric: 0.7834 - val_loss: 0.1414 - val_my_iou_metric: 0.7655
#
# Epoch 00029: val_my_iou_metric did not improve from 0.77263
# Epoch 30/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0881 - my_iou_metric: 0.7818 - val_loss: 0.1424 - val_my_iou_metric: 0.7736
#
# Epoch 00030: val_my_iou_metric improved from 0.77263 to 0.77363, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 31/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0828 - my_iou_metric: 0.7874 - val_loss: 0.1558 - val_my_iou_metric: 0.7773
#
# Epoch 00031: val_my_iou_metric improved from 0.77363 to 0.77725, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0872 - my_iou_metric: 0.7792 - val_loss: 0.1404 - val_my_iou_metric: 0.7755
#
# Epoch 00032: val_my_iou_metric did not improve from 0.77725
# Epoch 33/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.0806 - my_iou_metric: 0.7884 - val_loss: 0.1312 - val_my_iou_metric: 0.7724
#
# Epoch 00033: val_my_iou_metric did not improve from 0.77725
# Epoch 34/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.0805 - my_iou_metric: 0.7890 - val_loss: 0.1409 - val_my_iou_metric: 0.7755
#
# Epoch 00034: val_my_iou_metric did not improve from 0.77725
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 35/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.0709 - my_iou_metric: 0.7986 - val_loss: 0.1498 - val_my_iou_metric: 0.7756
#
# Epoch 00035: val_my_iou_metric did not improve from 0.77725
# Epoch 36/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.0688 - my_iou_metric: 0.8016 - val_loss: 0.1505 - val_my_iou_metric: 0.7734
#
# Epoch 00036: val_my_iou_metric did not improve from 0.77725
# Epoch 37/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: 0.0739 - my_iou_metric: 0.7980 - val_loss: 0.1448 - val_my_iou_metric: 0.7784
#
# Epoch 00037: val_my_iou_metric improved from 0.77725 to 0.77837, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 38/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0704 - my_iou_metric: 0.7973 - val_loss: 0.1452 - val_my_iou_metric: 0.7800
#
# Epoch 00038: val_my_iou_metric improved from 0.77837 to 0.78000, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 39/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0685 - my_iou_metric: 0.7996 - val_loss: 0.1463 - val_my_iou_metric: 0.7747
#
# Epoch 00039: val_my_iou_metric did not improve from 0.78000
# Epoch 40/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0652 - my_iou_metric: 0.8001 - val_loss: 0.1466 - val_my_iou_metric: 0.7784
#
# Epoch 00040: val_my_iou_metric did not improve from 0.78000
# Epoch 41/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0664 - my_iou_metric: 0.8047 - val_loss: 0.1343 - val_my_iou_metric: 0.7858
#
# Epoch 00041: val_my_iou_metric improved from 0.78000 to 0.78575, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 42/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0654 - my_iou_metric: 0.8045 - val_loss: 0.1535 - val_my_iou_metric: 0.7798
#
# Epoch 00042: val_my_iou_metric did not improve from 0.78575
# Epoch 43/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0644 - my_iou_metric: 0.8070 - val_loss: 0.1347 - val_my_iou_metric: 0.7826
#
# Epoch 00043: val_my_iou_metric did not improve from 0.78575
# Epoch 44/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0621 - my_iou_metric: 0.8068 - val_loss: 0.1516 - val_my_iou_metric: 0.7785
#
# Epoch 00044: val_my_iou_metric did not improve from 0.78575
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 45/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0614 - my_iou_metric: 0.8083 - val_loss: 0.1397 - val_my_iou_metric: 0.7819
#
# Epoch 00045: val_my_iou_metric did not improve from 0.78575
# Epoch 46/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0587 - my_iou_metric: 0.8105 - val_loss: 0.1404 - val_my_iou_metric: 0.7788
#
# Epoch 00046: val_my_iou_metric did not improve from 0.78575
# Epoch 47/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0598 - my_iou_metric: 0.8101 - val_loss: 0.1521 - val_my_iou_metric: 0.7815
#
# Epoch 00047: val_my_iou_metric did not improve from 0.78575
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 48/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0571 - my_iou_metric: 0.8155 - val_loss: 0.1569 - val_my_iou_metric: 0.7831
#
# Epoch 00048: val_my_iou_metric did not improve from 0.78575
# Epoch 49/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0565 - my_iou_metric: 0.8158 - val_loss: 0.1551 - val_my_iou_metric: 0.7836
#
# Epoch 00049: val_my_iou_metric did not improve from 0.78575
# Epoch 50/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0553 - my_iou_metric: 0.8130 - val_loss: 0.1577 - val_my_iou_metric: 0.7862
#
# Epoch 00050: val_my_iou_metric improved from 0.78575 to 0.78625, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 51/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0558 - my_iou_metric: 0.8133 - val_loss: 0.1539 - val_my_iou_metric: 0.7809
#
# Epoch 00051: val_my_iou_metric did not improve from 0.78625
# Epoch 52/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0585 - my_iou_metric: 0.8177 - val_loss: 0.1545 - val_my_iou_metric: 0.7802
#
# Epoch 00052: val_my_iou_metric did not improve from 0.78625
# Epoch 53/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0573 - my_iou_metric: 0.8143 - val_loss: 0.1550 - val_my_iou_metric: 0.7877
#
# Epoch 00053: val_my_iou_metric improved from 0.78625 to 0.78775, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 54/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0544 - my_iou_metric: 0.8167 - val_loss: 0.1588 - val_my_iou_metric: 0.7832
#
# Epoch 00054: val_my_iou_metric did not improve from 0.78775
# Epoch 55/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0550 - my_iou_metric: 0.8151 - val_loss: 0.1628 - val_my_iou_metric: 0.7851
#
# Epoch 00055: val_my_iou_metric did not improve from 0.78775
# Epoch 56/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0535 - my_iou_metric: 0.8208 - val_loss: 0.1558 - val_my_iou_metric: 0.7866
#
# Epoch 00056: val_my_iou_metric did not improve from 0.78775
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 57/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0538 - my_iou_metric: 0.8204 - val_loss: 0.1569 - val_my_iou_metric: 0.7859
#
# Epoch 00057: val_my_iou_metric did not improve from 0.78775
# Epoch 58/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0547 - my_iou_metric: 0.8173 - val_loss: 0.1636 - val_my_iou_metric: 0.7846
#
# Epoch 00058: val_my_iou_metric did not improve from 0.78775
# Epoch 59/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0553 - my_iou_metric: 0.8164 - val_loss: 0.1603 - val_my_iou_metric: 0.7853
#
# Epoch 00059: val_my_iou_metric did not improve from 0.78775
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 60/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0530 - my_iou_metric: 0.8163 - val_loss: 0.1623 - val_my_iou_metric: 0.7844
#
# Epoch 00060: val_my_iou_metric did not improve from 0.78775
# Epoch 61/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0517 - my_iou_metric: 0.8190 - val_loss: 0.1605 - val_my_iou_metric: 0.7846
#
# Epoch 00061: val_my_iou_metric did not improve from 0.78775
# Epoch 62/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0539 - my_iou_metric: 0.8158 - val_loss: 0.1604 - val_my_iou_metric: 0.7844
#
# Epoch 00062: val_my_iou_metric did not improve from 0.78775
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 63/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.0524 - my_iou_metric: 0.8197 - val_loss: 0.1595 - val_my_iou_metric: 0.7835
#
# Epoch 00063: val_my_iou_metric did not improve from 0.78775
# Epoch 00063: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.00001, verbose=1)
epochs = 200

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 156s 24ms/step - loss: -0.0253 - my_iou_metric_2: 0.7750 - val_loss: 0.1160 - val_my_iou_metric_2: 0.7536
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.75363, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.0626 - my_iou_metric_2: 0.7797 - val_loss: 0.0247 - val_my_iou_metric_2: 0.7720
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.75363 to 0.77200, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.0769 - my_iou_metric_2: 0.7810 - val_loss: -0.0153 - val_my_iou_metric_2: 0.7800
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.77200 to 0.78000, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.1023 - my_iou_metric_2: 0.7877 - val_loss: 0.0317 - val_my_iou_metric_2: 0.7660
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.78000
# Epoch 5/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.0936 - my_iou_metric_2: 0.7857 - val_loss: -0.0518 - val_my_iou_metric_2: 0.7819
#
# Epoch 00005: val_my_iou_metric_2 improved from 0.78000 to 0.78187, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.1324 - my_iou_metric_2: 0.7908 - val_loss: 0.0557 - val_my_iou_metric_2: 0.7559
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.78187
# Epoch 7/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.1659 - my_iou_metric_2: 0.7981 - val_loss: -0.0679 - val_my_iou_metric_2: 0.7916
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.78187 to 0.79163, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.1778 - my_iou_metric_2: 0.8013 - val_loss: 0.0676 - val_my_iou_metric_2: 0.7535
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.79163
# Epoch 9/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.1743 - my_iou_metric_2: 0.7989 - val_loss: -0.0347 - val_my_iou_metric_2: 0.7811
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.79163
# Epoch 10/200
# 6400/6400 [==============================] - 144s 22ms/step - loss: -0.2064 - my_iou_metric_2: 0.8061 - val_loss: 0.0648 - val_my_iou_metric_2: 0.7634
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.79163
# Epoch 11/200
# 6400/6400 [==============================] - 144s 22ms/step - loss: -0.2115 - my_iou_metric_2: 0.8055 - val_loss: -0.0575 - val_my_iou_metric_2: 0.7815
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.79163
# Epoch 12/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.2333 - my_iou_metric_2: 0.8106 - val_loss: 0.0301 - val_my_iou_metric_2: 0.7514
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.79163
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 13/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.3044 - my_iou_metric_2: 0.8238 - val_loss: -0.0970 - val_my_iou_metric_2: 0.8003
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.79163 to 0.80025, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.3376 - my_iou_metric_2: 0.8317 - val_loss: -0.1088 - val_my_iou_metric_2: 0.7896
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.80025
# Epoch 15/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.3382 - my_iou_metric_2: 0.8315 - val_loss: -0.1213 - val_my_iou_metric_2: 0.8052
#
# Epoch 00015: val_my_iou_metric_2 improved from 0.80025 to 0.80525, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.3538 - my_iou_metric_2: 0.8333 - val_loss: -0.1244 - val_my_iou_metric_2: 0.7964
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 17/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.3725 - my_iou_metric_2: 0.8377 - val_loss: -0.0585 - val_my_iou_metric_2: 0.7949
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 18/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.3751 - my_iou_metric_2: 0.8388 - val_loss: -0.1265 - val_my_iou_metric_2: 0.8020
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 19/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.3881 - my_iou_metric_2: 0.8416 - val_loss: -0.0682 - val_my_iou_metric_2: 0.7979
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 20/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.4019 - my_iou_metric_2: 0.8443 - val_loss: -0.1053 - val_my_iou_metric_2: 0.8051
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.80525
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 21/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.4459 - my_iou_metric_2: 0.8541 - val_loss: -0.1091 - val_my_iou_metric_2: 0.8133
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.80525 to 0.81325, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.4731 - my_iou_metric_2: 0.8596 - val_loss: -0.0881 - val_my_iou_metric_2: 0.8070
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.81325
# Epoch 23/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.4837 - my_iou_metric_2: 0.8602 - val_loss: -0.0601 - val_my_iou_metric_2: 0.8115
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.81325
# Epoch 24/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.4892 - my_iou_metric_2: 0.8624 - val_loss: -0.0938 - val_my_iou_metric_2: 0.8119
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.81325
# Epoch 25/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.4833 - my_iou_metric_2: 0.8594 - val_loss: -0.1336 - val_my_iou_metric_2: 0.8126
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.81325
# Epoch 26/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.4958 - my_iou_metric_2: 0.8600 - val_loss: -0.0682 - val_my_iou_metric_2: 0.8089
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.81325
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 27/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5076 - my_iou_metric_2: 0.8641 - val_loss: -0.1007 - val_my_iou_metric_2: 0.8200
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.81325 to 0.82000, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5312 - my_iou_metric_2: 0.8704 - val_loss: -0.1016 - val_my_iou_metric_2: 0.8191
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 29/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5342 - my_iou_metric_2: 0.8703 - val_loss: -0.1054 - val_my_iou_metric_2: 0.8184
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 30/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5325 - my_iou_metric_2: 0.8703 - val_loss: -0.0912 - val_my_iou_metric_2: 0.8184
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 31/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5291 - my_iou_metric_2: 0.8677 - val_loss: -0.0487 - val_my_iou_metric_2: 0.8140
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 32/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5490 - my_iou_metric_2: 0.8695 - val_loss: -0.0407 - val_my_iou_metric_2: 0.8121
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.82000
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 33/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5579 - my_iou_metric_2: 0.8720 - val_loss: -0.0341 - val_my_iou_metric_2: 0.8144
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 34/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5600 - my_iou_metric_2: 0.8737 - val_loss: -0.0459 - val_my_iou_metric_2: 0.8144
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 35/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5683 - my_iou_metric_2: 0.8747 - val_loss: -0.0330 - val_my_iou_metric_2: 0.8155
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 36/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5679 - my_iou_metric_2: 0.8775 - val_loss: -0.0387 - val_my_iou_metric_2: 0.8159
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 37/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5700 - my_iou_metric_2: 0.8757 - val_loss: -0.0291 - val_my_iou_metric_2: 0.8116
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.82000
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 38/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5836 - my_iou_metric_2: 0.8770 - val_loss: -0.0456 - val_my_iou_metric_2: 0.8204
#
# Epoch 00038: val_my_iou_metric_2 improved from 0.82000 to 0.82037, saving model to ../model/Unet_resnet_depthinchannel_up_32_0.5.model
# Epoch 39/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5802 - my_iou_metric_2: 0.8777 - val_loss: -0.0400 - val_my_iou_metric_2: 0.8160
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.82037
# Epoch 40/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5812 - my_iou_metric_2: 0.8779 - val_loss: -0.0320 - val_my_iou_metric_2: 0.8172
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.82037
# Epoch 41/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5836 - my_iou_metric_2: 0.8794 - val_loss: -0.0184 - val_my_iou_metric_2: 0.8166
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.82037
# Epoch 42/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5811 - my_iou_metric_2: 0.8777 - val_loss: -0.0226 - val_my_iou_metric_2: 0.8177
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.82037
# Epoch 43/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5832 - my_iou_metric_2: 0.8785 - val_loss: -0.0106 - val_my_iou_metric_2: 0.8145
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.82037
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 44/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5853 - my_iou_metric_2: 0.8786 - val_loss: -0.0216 - val_my_iou_metric_2: 0.8145
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.82037
# Epoch 45/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5910 - my_iou_metric_2: 0.8810 - val_loss: -0.0160 - val_my_iou_metric_2: 0.8169
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.82037
# Epoch 46/200
# 6400/6400 [==============================] - 143s 22ms/step - loss: -0.5855 - my_iou_metric_2: 0.8785 - val_loss: -0.0223 - val_my_iou_metric_2: 0.8169
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.82037
# Epoch 47/200
#  224/6400 [>.............................] - ETA: 2:10 - loss: -0.6568 - my_iou_metric_2: 0.8951

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target)
x_test = add_depth_bulk(x_test)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
