# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
batch_size = 32
start_feature = 32
dropout = 0.5
basic_name = '../model/resunet_deeper_cse_up_{}_{}'.format(batch_size, dropout)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/resunet_deeper_cse_up_{}_{}'.format(batch_size, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/resunet_deeper_cse_up_32_0.5.model
# ../model/resunet_deeper_cse_up_32_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 74s 12ms/step - loss: 0.4826 - my_iou_metric: 0.3336 - val_loss: 0.5884 - val_my_iou_metric: 0.3696
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.36963, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 61s 9ms/step - loss: 0.4657 - my_iou_metric: 0.3483 - val_loss: 0.6554 - val_my_iou_metric: 0.0327
#
# Epoch 00002: val_my_iou_metric did not improve from 0.36963
# Epoch 3/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.3737 - my_iou_metric: 0.4766 - val_loss: 0.5363 - val_my_iou_metric: 0.3864
#
# Epoch 00003: val_my_iou_metric improved from 0.36963 to 0.38638, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.3735 - my_iou_metric: 0.4787 - val_loss: 0.6339 - val_my_iou_metric: 0.3900
#
# Epoch 00004: val_my_iou_metric improved from 0.38638 to 0.39000, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.3283 - my_iou_metric: 0.5332 - val_loss: 0.5205 - val_my_iou_metric: 0.3900
#
# Epoch 00005: val_my_iou_metric did not improve from 0.39000
# Epoch 6/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.3149 - my_iou_metric: 0.5402 - val_loss: 0.7823 - val_my_iou_metric: 0.4280
#
# Epoch 00006: val_my_iou_metric improved from 0.39000 to 0.42800, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.2786 - my_iou_metric: 0.5601 - val_loss: 0.3413 - val_my_iou_metric: 0.5376
#
# Epoch 00007: val_my_iou_metric improved from 0.42800 to 0.53762, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.2563 - my_iou_metric: 0.5690 - val_loss: 0.6825 - val_my_iou_metric: 0.1383
#
# Epoch 00008: val_my_iou_metric did not improve from 0.53762
# Epoch 9/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.2377 - my_iou_metric: 0.5890 - val_loss: 0.2463 - val_my_iou_metric: 0.6061
#
# Epoch 00009: val_my_iou_metric improved from 0.53762 to 0.60613, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.2192 - my_iou_metric: 0.6111 - val_loss: 0.4128 - val_my_iou_metric: 0.4339
#
# Epoch 00010: val_my_iou_metric did not improve from 0.60613
# Epoch 11/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.2080 - my_iou_metric: 0.6220 - val_loss: 0.3316 - val_my_iou_metric: 0.5155
#
# Epoch 00011: val_my_iou_metric did not improve from 0.60613
# Epoch 12/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1976 - my_iou_metric: 0.6285 - val_loss: 0.2073 - val_my_iou_metric: 0.6185
#
# Epoch 00012: val_my_iou_metric improved from 0.60613 to 0.61850, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1854 - my_iou_metric: 0.6446 - val_loss: 0.2175 - val_my_iou_metric: 0.6420
#
# Epoch 00013: val_my_iou_metric improved from 0.61850 to 0.64200, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1819 - my_iou_metric: 0.6530 - val_loss: 0.2340 - val_my_iou_metric: 0.6182
#
# Epoch 00014: val_my_iou_metric did not improve from 0.64200
# Epoch 15/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.1777 - my_iou_metric: 0.6630 - val_loss: 0.3300 - val_my_iou_metric: 0.5737
#
# Epoch 00015: val_my_iou_metric did not improve from 0.64200
# Epoch 16/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1742 - my_iou_metric: 0.6632 - val_loss: 0.1675 - val_my_iou_metric: 0.6998
#
# Epoch 00016: val_my_iou_metric improved from 0.64200 to 0.69975, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1660 - my_iou_metric: 0.6774 - val_loss: 0.2230 - val_my_iou_metric: 0.6336
#
# Epoch 00017: val_my_iou_metric did not improve from 0.69975
# Epoch 18/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.1568 - my_iou_metric: 0.6945 - val_loss: 0.2102 - val_my_iou_metric: 0.6399
#
# Epoch 00018: val_my_iou_metric did not improve from 0.69975
# Epoch 19/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.1541 - my_iou_metric: 0.6966 - val_loss: 0.1819 - val_my_iou_metric: 0.7135
#
# Epoch 00019: val_my_iou_metric improved from 0.69975 to 0.71350, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1473 - my_iou_metric: 0.7002 - val_loss: 0.1664 - val_my_iou_metric: 0.7146
#
# Epoch 00020: val_my_iou_metric improved from 0.71350 to 0.71463, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1454 - my_iou_metric: 0.7047 - val_loss: 0.1864 - val_my_iou_metric: 0.6619
#
# Epoch 00021: val_my_iou_metric did not improve from 0.71463
# Epoch 22/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.1436 - my_iou_metric: 0.7091 - val_loss: 0.1672 - val_my_iou_metric: 0.7207
#
# Epoch 00022: val_my_iou_metric improved from 0.71463 to 0.72075, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 62s 10ms/step - loss: 0.1423 - my_iou_metric: 0.7051 - val_loss: 0.1487 - val_my_iou_metric: 0.7353
#
# Epoch 00023: val_my_iou_metric improved from 0.72075 to 0.73525, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1474 - my_iou_metric: 0.7095 - val_loss: 0.2488 - val_my_iou_metric: 0.6018
#
# Epoch 00024: val_my_iou_metric did not improve from 0.73525
# Epoch 25/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1436 - my_iou_metric: 0.7102 - val_loss: 0.1659 - val_my_iou_metric: 0.7207
#
# Epoch 00025: val_my_iou_metric did not improve from 0.73525
# Epoch 26/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1366 - my_iou_metric: 0.7207 - val_loss: 0.1473 - val_my_iou_metric: 0.6919
#
# Epoch 00026: val_my_iou_metric did not improve from 0.73525
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 27/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1193 - my_iou_metric: 0.7458 - val_loss: 0.1380 - val_my_iou_metric: 0.7515
#
# Epoch 00027: val_my_iou_metric improved from 0.73525 to 0.75150, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1151 - my_iou_metric: 0.7453 - val_loss: 0.3914 - val_my_iou_metric: 0.5605
#
# Epoch 00028: val_my_iou_metric did not improve from 0.75150
# Epoch 29/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1131 - my_iou_metric: 0.7520 - val_loss: 0.1273 - val_my_iou_metric: 0.7516
#
# Epoch 00029: val_my_iou_metric improved from 0.75150 to 0.75162, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1100 - my_iou_metric: 0.7526 - val_loss: 0.1348 - val_my_iou_metric: 0.7460
#
# Epoch 00030: val_my_iou_metric did not improve from 0.75162
# Epoch 31/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1073 - my_iou_metric: 0.7555 - val_loss: 0.1385 - val_my_iou_metric: 0.7459
#
# Epoch 00031: val_my_iou_metric did not improve from 0.75162
# Epoch 32/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1050 - my_iou_metric: 0.7529 - val_loss: 0.1438 - val_my_iou_metric: 0.7540
#
# Epoch 00032: val_my_iou_metric improved from 0.75162 to 0.75400, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 33/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1042 - my_iou_metric: 0.7548 - val_loss: 0.1650 - val_my_iou_metric: 0.7135
#
# Epoch 00033: val_my_iou_metric did not improve from 0.75400
# Epoch 34/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.1007 - my_iou_metric: 0.7578 - val_loss: 0.1487 - val_my_iou_metric: 0.7498
#
# Epoch 00034: val_my_iou_metric did not improve from 0.75400
# Epoch 35/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0965 - my_iou_metric: 0.7631 - val_loss: 0.1301 - val_my_iou_metric: 0.7521
#
# Epoch 00035: val_my_iou_metric did not improve from 0.75400
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 36/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0881 - my_iou_metric: 0.7716 - val_loss: 0.1370 - val_my_iou_metric: 0.7648
#
# Epoch 00036: val_my_iou_metric improved from 0.75400 to 0.76475, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 37/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0838 - my_iou_metric: 0.7771 - val_loss: 0.1473 - val_my_iou_metric: 0.7635
#
# Epoch 00037: val_my_iou_metric did not improve from 0.76475
# Epoch 38/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0830 - my_iou_metric: 0.7783 - val_loss: 0.1317 - val_my_iou_metric: 0.7703
#
# Epoch 00038: val_my_iou_metric improved from 0.76475 to 0.77025, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 39/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0800 - my_iou_metric: 0.7774 - val_loss: 0.1479 - val_my_iou_metric: 0.7606
#
# Epoch 00039: val_my_iou_metric did not improve from 0.77025
# Epoch 40/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0784 - my_iou_metric: 0.7819 - val_loss: 0.1294 - val_my_iou_metric: 0.7662
#
# Epoch 00040: val_my_iou_metric did not improve from 0.77025
# Epoch 41/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0782 - my_iou_metric: 0.7811 - val_loss: 0.1414 - val_my_iou_metric: 0.7630
#
# Epoch 00041: val_my_iou_metric did not improve from 0.77025
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 42/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0725 - my_iou_metric: 0.7861 - val_loss: 0.1388 - val_my_iou_metric: 0.7705
#
# Epoch 00042: val_my_iou_metric improved from 0.77025 to 0.77050, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 43/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0699 - my_iou_metric: 0.7869 - val_loss: 0.1361 - val_my_iou_metric: 0.7751
#
# Epoch 00043: val_my_iou_metric improved from 0.77050 to 0.77513, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 44/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0692 - my_iou_metric: 0.7894 - val_loss: 0.1434 - val_my_iou_metric: 0.7706
#
# Epoch 00044: val_my_iou_metric did not improve from 0.77513
# Epoch 45/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0701 - my_iou_metric: 0.7885 - val_loss: 0.1287 - val_my_iou_metric: 0.7689
#
# Epoch 00045: val_my_iou_metric did not improve from 0.77513
# Epoch 46/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0673 - my_iou_metric: 0.7902 - val_loss: 0.1289 - val_my_iou_metric: 0.7747
#
# Epoch 00046: val_my_iou_metric did not improve from 0.77513
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 47/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0670 - my_iou_metric: 0.7917 - val_loss: 0.1338 - val_my_iou_metric: 0.7719
#
# Epoch 00047: val_my_iou_metric did not improve from 0.77513
# Epoch 48/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0634 - my_iou_metric: 0.7975 - val_loss: 0.1466 - val_my_iou_metric: 0.7730
#
# Epoch 00048: val_my_iou_metric did not improve from 0.77513
# Epoch 49/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0629 - my_iou_metric: 0.7968 - val_loss: 0.1361 - val_my_iou_metric: 0.7805
#
# Epoch 00049: val_my_iou_metric improved from 0.77513 to 0.78050, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 50/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0628 - my_iou_metric: 0.7950 - val_loss: 0.1379 - val_my_iou_metric: 0.7755
#
# Epoch 00050: val_my_iou_metric did not improve from 0.78050
# Epoch 51/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0629 - my_iou_metric: 0.8008 - val_loss: 0.1341 - val_my_iou_metric: 0.7735
#
# Epoch 00051: val_my_iou_metric did not improve from 0.78050
# Epoch 52/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0622 - my_iou_metric: 0.7968 - val_loss: 0.1386 - val_my_iou_metric: 0.7728
#
# Epoch 00052: val_my_iou_metric did not improve from 0.78050
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 53/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0595 - my_iou_metric: 0.8041 - val_loss: 0.1422 - val_my_iou_metric: 0.7781
#
# Epoch 00053: val_my_iou_metric did not improve from 0.78050
# Epoch 54/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0593 - my_iou_metric: 0.8027 - val_loss: 0.1423 - val_my_iou_metric: 0.7757
#
# Epoch 00054: val_my_iou_metric did not improve from 0.78050
# Epoch 55/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0622 - my_iou_metric: 0.8001 - val_loss: 0.1413 - val_my_iou_metric: 0.7731
#
# Epoch 00055: val_my_iou_metric did not improve from 0.78050
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 56/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0591 - my_iou_metric: 0.8007 - val_loss: 0.1374 - val_my_iou_metric: 0.7770
#
# Epoch 00056: val_my_iou_metric did not improve from 0.78050
# Epoch 57/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0587 - my_iou_metric: 0.7998 - val_loss: 0.1385 - val_my_iou_metric: 0.7769
#
# Epoch 00057: val_my_iou_metric did not improve from 0.78050
# Epoch 58/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0605 - my_iou_metric: 0.8017 - val_loss: 0.1405 - val_my_iou_metric: 0.7794
#
# Epoch 00058: val_my_iou_metric did not improve from 0.78050
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 59/200
# 6400/6400 [==============================] - 61s 10ms/step - loss: 0.0578 - my_iou_metric: 0.8010 - val_loss: 0.1431 - val_my_iou_metric: 0.7752
#
# Epoch 00059: val_my_iou_metric did not improve from 0.78050
# Epoch 00059: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=4, min_lr=0.00001, verbose=1)
epochs = 200
batch_size = 32

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 110s 17ms/step - loss: -0.0383 - my_iou_metric_2: 0.7743 - val_loss: 0.1565 - val_my_iou_metric_2: 0.7452
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.74525, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.0920 - my_iou_metric_2: 0.7815 - val_loss: 0.1051 - val_my_iou_metric_2: 0.7460
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.74525 to 0.74600, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.0927 - my_iou_metric_2: 0.7794 - val_loss: 0.0860 - val_my_iou_metric_2: 0.7602
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.74600 to 0.76025, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1007 - my_iou_metric_2: 0.7846 - val_loss: 0.0365 - val_my_iou_metric_2: 0.7665
#
# Epoch 00004: val_my_iou_metric_2 improved from 0.76025 to 0.76650, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1159 - my_iou_metric_2: 0.7865 - val_loss: 0.1166 - val_my_iou_metric_2: 0.7521
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.76650
# Epoch 6/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1248 - my_iou_metric_2: 0.7888 - val_loss: 0.4524 - val_my_iou_metric_2: 0.6615
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.76650
# Epoch 7/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1380 - my_iou_metric_2: 0.7925 - val_loss: -0.0053 - val_my_iou_metric_2: 0.7791
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.76650 to 0.77913, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1626 - my_iou_metric_2: 0.7986 - val_loss: 0.0034 - val_my_iou_metric_2: 0.7734
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.77913
# Epoch 9/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1821 - my_iou_metric_2: 0.8027 - val_loss: -0.0534 - val_my_iou_metric_2: 0.7869
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.77913 to 0.78687, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1623 - my_iou_metric_2: 0.7955 - val_loss: 0.0627 - val_my_iou_metric_2: 0.7562
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.78687
# Epoch 11/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1579 - my_iou_metric_2: 0.7947 - val_loss: 0.3208 - val_my_iou_metric_2: 0.7179
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.78687
# Epoch 12/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.1937 - my_iou_metric_2: 0.8025 - val_loss: 0.3273 - val_my_iou_metric_2: 0.7206
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.78687
# Epoch 13/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.2077 - my_iou_metric_2: 0.8057 - val_loss: -0.0264 - val_my_iou_metric_2: 0.7800
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.78687
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 14/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.2853 - my_iou_metric_2: 0.8231 - val_loss: -0.0653 - val_my_iou_metric_2: 0.8006
#
# Epoch 00014: val_my_iou_metric_2 improved from 0.78687 to 0.80063, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3110 - my_iou_metric_2: 0.8268 - val_loss: -0.0485 - val_my_iou_metric_2: 0.7916
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.80063
# Epoch 16/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3205 - my_iou_metric_2: 0.8285 - val_loss: -0.0749 - val_my_iou_metric_2: 0.7960
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.80063
# Epoch 17/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3407 - my_iou_metric_2: 0.8329 - val_loss: -0.0329 - val_my_iou_metric_2: 0.8031
#
# Epoch 00017: val_my_iou_metric_2 improved from 0.80063 to 0.80312, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 18/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3327 - my_iou_metric_2: 0.8315 - val_loss: 0.0538 - val_my_iou_metric_2: 0.7611
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80312
# Epoch 19/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3333 - my_iou_metric_2: 0.8324 - val_loss: -0.0262 - val_my_iou_metric_2: 0.7891
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80312
# Epoch 20/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3511 - my_iou_metric_2: 0.8344 - val_loss: -0.0853 - val_my_iou_metric_2: 0.7981
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.80312
# Epoch 21/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.3675 - my_iou_metric_2: 0.8372 - val_loss: -0.0846 - val_my_iou_metric_2: 0.8031
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.80312
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 22/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4113 - my_iou_metric_2: 0.8460 - val_loss: -0.0654 - val_my_iou_metric_2: 0.8078
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.80312 to 0.80775, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4290 - my_iou_metric_2: 0.8489 - val_loss: -0.0756 - val_my_iou_metric_2: 0.7992
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.80775
# Epoch 24/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4384 - my_iou_metric_2: 0.8518 - val_loss: -0.0538 - val_my_iou_metric_2: 0.8061
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.80775
# Epoch 25/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4343 - my_iou_metric_2: 0.8502 - val_loss: -0.0131 - val_my_iou_metric_2: 0.7949
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.80775
# Epoch 26/200
# 6400/6400 [==============================] - 98s 15ms/step - loss: -0.4376 - my_iou_metric_2: 0.8525 - val_loss: -0.1035 - val_my_iou_metric_2: 0.8072
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.80775
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 27/200
# 6400/6400 [==============================] - 98s 15ms/step - loss: -0.4689 - my_iou_metric_2: 0.8576 - val_loss: -0.1059 - val_my_iou_metric_2: 0.8069
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.80775
# Epoch 28/200
# 6400/6400 [==============================] - 98s 15ms/step - loss: -0.4719 - my_iou_metric_2: 0.8564 - val_loss: -0.0764 - val_my_iou_metric_2: 0.8105
#
# Epoch 00028: val_my_iou_metric_2 improved from 0.80775 to 0.81050, saving model to ../model/resunet_deeper_cse_up_32_0.5.model
# Epoch 29/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4826 - my_iou_metric_2: 0.8594 - val_loss: -0.0978 - val_my_iou_metric_2: 0.8098
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.81050
# Epoch 30/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4904 - my_iou_metric_2: 0.8615 - val_loss: -0.0988 - val_my_iou_metric_2: 0.8070
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.81050
# Epoch 31/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4837 - my_iou_metric_2: 0.8587 - val_loss: -0.0888 - val_my_iou_metric_2: 0.8081
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.81050
# Epoch 32/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.4906 - my_iou_metric_2: 0.8612 - val_loss: -0.0461 - val_my_iou_metric_2: 0.8071
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.81050
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 33/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.5005 - my_iou_metric_2: 0.8632 - val_loss: -0.0874 - val_my_iou_metric_2: 0.8090
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.81050
# Epoch 34/200
# 6400/6400 [==============================] - 97s 15ms/step - loss: -0.5079 - my_iou_metric_2: 0.8629 - val_loss: -0.0868 - val_my_iou_metric_2: 0.8053
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.81050
# Epoch 35/200
# 5376/6400 [========================>.....] - ETA: 14s - loss: -0.5238 - my_iou_metric_2: 0.8667

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/res_unet_101.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = False, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
