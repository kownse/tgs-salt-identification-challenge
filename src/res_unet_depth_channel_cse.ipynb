# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
x_train = add_depth_bulk(x_train)
x_valid = add_depth_bulk(x_valid)
print(x_train.shape)
print(y_valid.shape)
# Out:
# HBox(children=(IntProgress(value=0, max=6400), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=800), HTML(value='')))
# (6400, 101, 101, 3)
# (800, 101, 101, 1)

# %%
start_feature = 32
dropout = 0.5
batch_size = 8
base_name = 'Unet_resnet_depthinchannel_cse_{}_{}'.format(batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 3))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# ../model/Unet_resnet_depthinchannel_cse_8_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 146s 23ms/step - loss: 0.5506 - my_iou_metric: 0.3557 - val_loss: 2.3858 - val_my_iou_metric: 0.1939
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.19388, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.4072 - my_iou_metric: 0.4292 - val_loss: 0.3902 - val_my_iou_metric: 0.5304
#
# Epoch 00002: val_my_iou_metric improved from 0.19388 to 0.53037, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.3684 - my_iou_metric: 0.4795 - val_loss: 0.4412 - val_my_iou_metric: 0.3821
#
# Epoch 00003: val_my_iou_metric did not improve from 0.53037
# Epoch 4/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.3351 - my_iou_metric: 0.5160 - val_loss: 0.3429 - val_my_iou_metric: 0.5570
#
# Epoch 00004: val_my_iou_metric improved from 0.53037 to 0.55700, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.2944 - my_iou_metric: 0.5446 - val_loss: 0.2874 - val_my_iou_metric: 0.5086
#
# Epoch 00005: val_my_iou_metric did not improve from 0.55700
# Epoch 6/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.2670 - my_iou_metric: 0.5578 - val_loss: 0.3405 - val_my_iou_metric: 0.5851
#
# Epoch 00006: val_my_iou_metric improved from 0.55700 to 0.58513, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.2406 - my_iou_metric: 0.5881 - val_loss: 0.2651 - val_my_iou_metric: 0.6230
#
# Epoch 00007: val_my_iou_metric improved from 0.58513 to 0.62300, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.2167 - my_iou_metric: 0.6201 - val_loss: 0.2441 - val_my_iou_metric: 0.5928
#
# Epoch 00008: val_my_iou_metric did not improve from 0.62300
# Epoch 9/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.2106 - my_iou_metric: 0.6292 - val_loss: 0.2291 - val_my_iou_metric: 0.6215
#
# Epoch 00009: val_my_iou_metric did not improve from 0.62300
# Epoch 10/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.2027 - my_iou_metric: 0.6377 - val_loss: 0.1982 - val_my_iou_metric: 0.6586
#
# Epoch 00010: val_my_iou_metric improved from 0.62300 to 0.65863, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1958 - my_iou_metric: 0.6530 - val_loss: 0.2108 - val_my_iou_metric: 0.6850
#
# Epoch 00011: val_my_iou_metric improved from 0.65863 to 0.68500, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 12/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.2005 - my_iou_metric: 0.6466 - val_loss: 0.1941 - val_my_iou_metric: 0.6502
#
# Epoch 00012: val_my_iou_metric did not improve from 0.68500
# Epoch 13/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1850 - my_iou_metric: 0.6570 - val_loss: 0.1738 - val_my_iou_metric: 0.7013
#
# Epoch 00013: val_my_iou_metric improved from 0.68500 to 0.70125, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1798 - my_iou_metric: 0.6718 - val_loss: 0.1856 - val_my_iou_metric: 0.6871
#
# Epoch 00014: val_my_iou_metric did not improve from 0.70125
# Epoch 15/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1830 - my_iou_metric: 0.6683 - val_loss: 0.1733 - val_my_iou_metric: 0.6989
#
# Epoch 00015: val_my_iou_metric did not improve from 0.70125
# Epoch 16/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1766 - my_iou_metric: 0.6752 - val_loss: 0.1803 - val_my_iou_metric: 0.6837
#
# Epoch 00016: val_my_iou_metric did not improve from 0.70125
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 17/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1541 - my_iou_metric: 0.6973 - val_loss: 0.1541 - val_my_iou_metric: 0.7185
#
# Epoch 00017: val_my_iou_metric improved from 0.70125 to 0.71850, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 18/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1528 - my_iou_metric: 0.6990 - val_loss: 0.1584 - val_my_iou_metric: 0.7169
#
# Epoch 00018: val_my_iou_metric did not improve from 0.71850
# Epoch 19/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1457 - my_iou_metric: 0.7022 - val_loss: 0.1560 - val_my_iou_metric: 0.7139
#
# Epoch 00019: val_my_iou_metric did not improve from 0.71850
# Epoch 20/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1416 - my_iou_metric: 0.7057 - val_loss: 0.1522 - val_my_iou_metric: 0.7319
#
# Epoch 00020: val_my_iou_metric improved from 0.71850 to 0.73187, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1426 - my_iou_metric: 0.7124 - val_loss: 0.1663 - val_my_iou_metric: 0.7309
#
# Epoch 00021: val_my_iou_metric did not improve from 0.73187
# Epoch 22/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1369 - my_iou_metric: 0.7138 - val_loss: 0.1443 - val_my_iou_metric: 0.7395
#
# Epoch 00022: val_my_iou_metric improved from 0.73187 to 0.73950, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1341 - my_iou_metric: 0.7143 - val_loss: 0.1620 - val_my_iou_metric: 0.7232
#
# Epoch 00023: val_my_iou_metric did not improve from 0.73950
# Epoch 24/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1361 - my_iou_metric: 0.7163 - val_loss: 0.1458 - val_my_iou_metric: 0.7311
#
# Epoch 00024: val_my_iou_metric did not improve from 0.73950
# Epoch 25/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1367 - my_iou_metric: 0.7195 - val_loss: 0.1591 - val_my_iou_metric: 0.7309
#
# Epoch 00025: val_my_iou_metric did not improve from 0.73950
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 26/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1225 - my_iou_metric: 0.7268 - val_loss: 0.1480 - val_my_iou_metric: 0.7439
#
# Epoch 00026: val_my_iou_metric improved from 0.73950 to 0.74387, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 27/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1163 - my_iou_metric: 0.7413 - val_loss: 0.1493 - val_my_iou_metric: 0.7464
#
# Epoch 00027: val_my_iou_metric improved from 0.74387 to 0.74637, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1139 - my_iou_metric: 0.7365 - val_loss: 0.1558 - val_my_iou_metric: 0.7459
#
# Epoch 00028: val_my_iou_metric did not improve from 0.74637
# Epoch 29/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1132 - my_iou_metric: 0.7407 - val_loss: 0.1455 - val_my_iou_metric: 0.7494
#
# Epoch 00029: val_my_iou_metric improved from 0.74637 to 0.74938, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1096 - my_iou_metric: 0.7447 - val_loss: 0.1639 - val_my_iou_metric: 0.7378
#
# Epoch 00030: val_my_iou_metric did not improve from 0.74938
# Epoch 31/200
# 6400/6400 [==============================] - 132s 21ms/step - loss: 0.1120 - my_iou_metric: 0.7417 - val_loss: 0.1510 - val_my_iou_metric: 0.7408
#
# Epoch 00031: val_my_iou_metric did not improve from 0.74938
# Epoch 32/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.1084 - my_iou_metric: 0.7429 - val_loss: 0.1538 - val_my_iou_metric: 0.7450
#
# Epoch 00032: val_my_iou_metric did not improve from 0.74938
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 33/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.1014 - my_iou_metric: 0.7500 - val_loss: 0.1528 - val_my_iou_metric: 0.7574
#
# Epoch 00033: val_my_iou_metric improved from 0.74938 to 0.75738, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 34/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0994 - my_iou_metric: 0.7500 - val_loss: 0.1530 - val_my_iou_metric: 0.7545
#
# Epoch 00034: val_my_iou_metric did not improve from 0.75738
# Epoch 35/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0990 - my_iou_metric: 0.7550 - val_loss: 0.1569 - val_my_iou_metric: 0.7527
#
# Epoch 00035: val_my_iou_metric did not improve from 0.75738
# Epoch 36/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0993 - my_iou_metric: 0.7500 - val_loss: 0.1559 - val_my_iou_metric: 0.7573
#
# Epoch 00036: val_my_iou_metric did not improve from 0.75738
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 37/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0940 - my_iou_metric: 0.7579 - val_loss: 0.1593 - val_my_iou_metric: 0.7556
#
# Epoch 00037: val_my_iou_metric did not improve from 0.75738
# Epoch 38/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0919 - my_iou_metric: 0.7601 - val_loss: 0.1566 - val_my_iou_metric: 0.7566
#
# Epoch 00038: val_my_iou_metric did not improve from 0.75738
# Epoch 39/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0916 - my_iou_metric: 0.7582 - val_loss: 0.1616 - val_my_iou_metric: 0.7570
#
# Epoch 00039: val_my_iou_metric did not improve from 0.75738
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 40/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0894 - my_iou_metric: 0.7614 - val_loss: 0.1627 - val_my_iou_metric: 0.7603
#
# Epoch 00040: val_my_iou_metric improved from 0.75738 to 0.76025, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 41/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0904 - my_iou_metric: 0.7597 - val_loss: 0.1618 - val_my_iou_metric: 0.7579
#
# Epoch 00041: val_my_iou_metric did not improve from 0.76025
# Epoch 42/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0858 - my_iou_metric: 0.7587 - val_loss: 0.1636 - val_my_iou_metric: 0.7576
#
# Epoch 00042: val_my_iou_metric did not improve from 0.76025
# Epoch 43/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0901 - my_iou_metric: 0.7596 - val_loss: 0.1617 - val_my_iou_metric: 0.7585
#
# Epoch 00043: val_my_iou_metric did not improve from 0.76025
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 44/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0851 - my_iou_metric: 0.7600 - val_loss: 0.1613 - val_my_iou_metric: 0.7600
#
# Epoch 00044: val_my_iou_metric did not improve from 0.76025
# Epoch 45/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0836 - my_iou_metric: 0.7643 - val_loss: 0.1626 - val_my_iou_metric: 0.7628
#
# Epoch 00045: val_my_iou_metric improved from 0.76025 to 0.76275, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 46/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0825 - my_iou_metric: 0.7679 - val_loss: 0.1647 - val_my_iou_metric: 0.7614
#
# Epoch 00046: val_my_iou_metric did not improve from 0.76275
# Epoch 47/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0854 - my_iou_metric: 0.7618 - val_loss: 0.1635 - val_my_iou_metric: 0.7605
#
# Epoch 00047: val_my_iou_metric did not improve from 0.76275
# Epoch 48/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0872 - my_iou_metric: 0.7647 - val_loss: 0.1615 - val_my_iou_metric: 0.7620
#
# Epoch 00048: val_my_iou_metric did not improve from 0.76275
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 49/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0857 - my_iou_metric: 0.7621 - val_loss: 0.1618 - val_my_iou_metric: 0.7610
#
# Epoch 00049: val_my_iou_metric did not improve from 0.76275
# Epoch 50/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0870 - my_iou_metric: 0.7650 - val_loss: 0.1623 - val_my_iou_metric: 0.7610
#
# Epoch 00050: val_my_iou_metric did not improve from 0.76275
# Epoch 51/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0862 - my_iou_metric: 0.7645 - val_loss: 0.1640 - val_my_iou_metric: 0.7635
#
# Epoch 00051: val_my_iou_metric improved from 0.76275 to 0.76350, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 52/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0840 - my_iou_metric: 0.7693 - val_loss: 0.1651 - val_my_iou_metric: 0.7620
#
# Epoch 00052: val_my_iou_metric did not improve from 0.76350
# Epoch 53/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0827 - my_iou_metric: 0.7692 - val_loss: 0.1648 - val_my_iou_metric: 0.7580
#
# Epoch 00053: val_my_iou_metric did not improve from 0.76350
# Epoch 54/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0824 - my_iou_metric: 0.7671 - val_loss: 0.1648 - val_my_iou_metric: 0.7601
#
# Epoch 00054: val_my_iou_metric did not improve from 0.76350
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 55/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0843 - my_iou_metric: 0.7659 - val_loss: 0.1658 - val_my_iou_metric: 0.7592
#
# Epoch 00055: val_my_iou_metric did not improve from 0.76350
# Epoch 56/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0851 - my_iou_metric: 0.7648 - val_loss: 0.1649 - val_my_iou_metric: 0.7610
#
# Epoch 00056: val_my_iou_metric did not improve from 0.76350
# Epoch 57/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0853 - my_iou_metric: 0.7658 - val_loss: 0.1651 - val_my_iou_metric: 0.7615
#
# Epoch 00057: val_my_iou_metric did not improve from 0.76350
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 58/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0856 - my_iou_metric: 0.7638 - val_loss: 0.1652 - val_my_iou_metric: 0.7615
#
# Epoch 00058: val_my_iou_metric did not improve from 0.76350
# Epoch 59/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0833 - my_iou_metric: 0.7675 - val_loss: 0.1650 - val_my_iou_metric: 0.7606
#
# Epoch 00059: val_my_iou_metric did not improve from 0.76350
# Epoch 60/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0840 - my_iou_metric: 0.7665 - val_loss: 0.1673 - val_my_iou_metric: 0.7610
#
# Epoch 00060: val_my_iou_metric did not improve from 0.76350
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 61/200
# 6400/6400 [==============================] - 133s 21ms/step - loss: 0.0852 - my_iou_metric: 0.7667 - val_loss: 0.1635 - val_my_iou_metric: 0.7609
#
# Epoch 00061: val_my_iou_metric did not improve from 0.76350
# Epoch 00061: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.00001, verbose=1)
epochs = 200

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 197s 31ms/step - loss: 0.1582 - my_iou_metric_2: 0.7330 - val_loss: 0.1498 - val_my_iou_metric_2: 0.7250
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.72500, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: 0.0847 - my_iou_metric_2: 0.7418 - val_loss: 0.1518 - val_my_iou_metric_2: 0.7278
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.72500 to 0.72775, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: 0.0479 - my_iou_metric_2: 0.7504 - val_loss: 0.0367 - val_my_iou_metric_2: 0.7570
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.72775 to 0.75700, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: 0.0847 - my_iou_metric_2: 0.7424 - val_loss: 0.0395 - val_my_iou_metric_2: 0.7533
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.75700
# Epoch 5/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: 0.0709 - my_iou_metric_2: 0.7432 - val_loss: 0.0459 - val_my_iou_metric_2: 0.7546
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.75700
# Epoch 6/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: 0.0315 - my_iou_metric_2: 0.7534 - val_loss: 0.1432 - val_my_iou_metric_2: 0.7387
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.75700
# Epoch 7/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: 0.0191 - my_iou_metric_2: 0.7549 - val_loss: 0.0918 - val_my_iou_metric_2: 0.7496
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.75700
# Epoch 8/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: 0.0089 - my_iou_metric_2: 0.7575 - val_loss: 0.0446 - val_my_iou_metric_2: 0.7653
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.75700 to 0.76525, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.0271 - my_iou_metric_2: 0.7636 - val_loss: 0.0487 - val_my_iou_metric_2: 0.7470
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.76525
# Epoch 10/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.0555 - my_iou_metric_2: 0.7732 - val_loss: -0.0183 - val_my_iou_metric_2: 0.7765
#
# Epoch 00010: val_my_iou_metric_2 improved from 0.76525 to 0.77650, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.0198 - my_iou_metric_2: 0.7607 - val_loss: 0.0714 - val_my_iou_metric_2: 0.7407
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.77650
# Epoch 12/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.0467 - my_iou_metric_2: 0.7679 - val_loss: 0.1646 - val_my_iou_metric_2: 0.7225
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.77650
# Epoch 13/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.0713 - my_iou_metric_2: 0.7738 - val_loss: -0.0375 - val_my_iou_metric_2: 0.7776
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.77650 to 0.77763, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: -0.0740 - my_iou_metric_2: 0.7726 - val_loss: 0.0888 - val_my_iou_metric_2: 0.7568
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.77763
# Epoch 15/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.0621 - my_iou_metric_2: 0.7742 - val_loss: -0.0398 - val_my_iou_metric_2: 0.7714
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.77763
# Epoch 16/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.1005 - my_iou_metric_2: 0.7813 - val_loss: -0.0435 - val_my_iou_metric_2: 0.7734
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.77763
# Epoch 17/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: -0.0444 - my_iou_metric_2: 0.7679 - val_loss: 0.0365 - val_my_iou_metric_2: 0.7649
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.77763
# Epoch 18/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.0553 - my_iou_metric_2: 0.7706 - val_loss: -0.0671 - val_my_iou_metric_2: 0.7847
#
# Epoch 00018: val_my_iou_metric_2 improved from 0.77763 to 0.78475, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: -0.1468 - my_iou_metric_2: 0.7906 - val_loss: -0.0920 - val_my_iou_metric_2: 0.7869
#
# Epoch 00019: val_my_iou_metric_2 improved from 0.78475 to 0.78687, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.1523 - my_iou_metric_2: 0.7920 - val_loss: -6.9829e-04 - val_my_iou_metric_2: 0.7663
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.78687
# Epoch 21/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.1299 - my_iou_metric_2: 0.7868 - val_loss: -0.0879 - val_my_iou_metric_2: 0.7946
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.78687 to 0.79462, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: -0.1579 - my_iou_metric_2: 0.7900 - val_loss: -0.0187 - val_my_iou_metric_2: 0.7711
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 23/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.1570 - my_iou_metric_2: 0.7928 - val_loss: -0.0689 - val_my_iou_metric_2: 0.7810
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 24/200
# 6400/6400 [==============================] - 181s 28ms/step - loss: -0.1536 - my_iou_metric_2: 0.7920 - val_loss: 0.0599 - val_my_iou_metric_2: 0.7686
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 25/200
# 6400/6400 [==============================] - 182s 28ms/step - loss: -0.1048 - my_iou_metric_2: 0.7810 - val_loss: -0.0435 - val_my_iou_metric_2: 0.7826
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 26/200
# 6400/6400 [==============================] - 182s 29ms/step - loss: -0.1842 - my_iou_metric_2: 0.7988 - val_loss: 0.0186 - val_my_iou_metric_2: 0.7559
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.79462
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 27/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.2403 - my_iou_metric_2: 0.8081 - val_loss: -0.1089 - val_my_iou_metric_2: 0.7958
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.79462 to 0.79575, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.2618 - my_iou_metric_2: 0.8117 - val_loss: -0.0153 - val_my_iou_metric_2: 0.7840
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.79575
# Epoch 29/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.2652 - my_iou_metric_2: 0.8134 - val_loss: -0.1147 - val_my_iou_metric_2: 0.7960
#
# Epoch 00029: val_my_iou_metric_2 improved from 0.79575 to 0.79600, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.2655 - my_iou_metric_2: 0.8136 - val_loss: -0.1074 - val_my_iou_metric_2: 0.7941
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.79600
# Epoch 31/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.2959 - my_iou_metric_2: 0.8189 - val_loss: -0.1401 - val_my_iou_metric_2: 0.8053
#
# Epoch 00031: val_my_iou_metric_2 improved from 0.79600 to 0.80525, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.2870 - my_iou_metric_2: 0.8169 - val_loss: -0.1065 - val_my_iou_metric_2: 0.7920
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 33/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3100 - my_iou_metric_2: 0.8203 - val_loss: -0.1283 - val_my_iou_metric_2: 0.8038
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 34/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3051 - my_iou_metric_2: 0.8219 - val_loss: -0.0887 - val_my_iou_metric_2: 0.7887
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 35/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3194 - my_iou_metric_2: 0.8254 - val_loss: -0.1105 - val_my_iou_metric_2: 0.7949
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 36/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3410 - my_iou_metric_2: 0.8291 - val_loss: -0.0640 - val_my_iou_metric_2: 0.7953
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.80525
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 37/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3548 - my_iou_metric_2: 0.8306 - val_loss: -0.1245 - val_my_iou_metric_2: 0.8036
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 38/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3637 - my_iou_metric_2: 0.8340 - val_loss: -0.1126 - val_my_iou_metric_2: 0.8024
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 39/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3761 - my_iou_metric_2: 0.8345 - val_loss: -0.0583 - val_my_iou_metric_2: 0.7980
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 40/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3963 - my_iou_metric_2: 0.8371 - val_loss: -0.0667 - val_my_iou_metric_2: 0.7961
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.80525
# Epoch 41/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3914 - my_iou_metric_2: 0.8383 - val_loss: -0.0869 - val_my_iou_metric_2: 0.8059
#
# Epoch 00041: val_my_iou_metric_2 improved from 0.80525 to 0.80587, saving model to ../model/Unet_resnet_depthinchannel_cse_8_0.5.model
# Epoch 42/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3953 - my_iou_metric_2: 0.8390 - val_loss: -0.0701 - val_my_iou_metric_2: 0.7993
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 43/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3853 - my_iou_metric_2: 0.8383 - val_loss: -0.0906 - val_my_iou_metric_2: 0.8025
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 44/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4008 - my_iou_metric_2: 0.8390 - val_loss: -0.1008 - val_my_iou_metric_2: 0.8050
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 45/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4167 - my_iou_metric_2: 0.8421 - val_loss: -0.0687 - val_my_iou_metric_2: 0.7979
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 46/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.3995 - my_iou_metric_2: 0.8387 - val_loss: -0.0835 - val_my_iou_metric_2: 0.8005
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.80587
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 47/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4302 - my_iou_metric_2: 0.8444 - val_loss: -0.0651 - val_my_iou_metric_2: 0.7955
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 48/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4411 - my_iou_metric_2: 0.8472 - val_loss: -0.0688 - val_my_iou_metric_2: 0.8009
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 49/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4470 - my_iou_metric_2: 0.8490 - val_loss: -0.0605 - val_my_iou_metric_2: 0.7999
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 50/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4362 - my_iou_metric_2: 0.8493 - val_loss: -0.0727 - val_my_iou_metric_2: 0.8027
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 51/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4429 - my_iou_metric_2: 0.8487 - val_loss: -0.0764 - val_my_iou_metric_2: 0.8030
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.80587
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 52/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4617 - my_iou_metric_2: 0.8515 - val_loss: -0.0592 - val_my_iou_metric_2: 0.8040
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 53/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4606 - my_iou_metric_2: 0.8518 - val_loss: -0.0621 - val_my_iou_metric_2: 0.8021
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 54/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4678 - my_iou_metric_2: 0.8528 - val_loss: -0.0578 - val_my_iou_metric_2: 0.8009
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 55/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4670 - my_iou_metric_2: 0.8520 - val_loss: -0.0662 - val_my_iou_metric_2: 0.7998
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 56/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4535 - my_iou_metric_2: 0.8493 - val_loss: -0.0680 - val_my_iou_metric_2: 0.8020
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.80587
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 57/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4760 - my_iou_metric_2: 0.8538 - val_loss: -0.0549 - val_my_iou_metric_2: 0.8024
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 58/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4801 - my_iou_metric_2: 0.8553 - val_loss: -0.0529 - val_my_iou_metric_2: 0.8022
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 59/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4703 - my_iou_metric_2: 0.8524 - val_loss: -0.0736 - val_my_iou_metric_2: 0.8041
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 60/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4806 - my_iou_metric_2: 0.8551 - val_loss: -0.0628 - val_my_iou_metric_2: 0.8020
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.80587
# Epoch 61/200
# 6400/6400 [==============================] - 183s 29ms/step - loss: -0.4793 - my_iou_metric_2: 0.8538 - val_loss: -0.0581 - val_my_iou_metric_2: 0.8032
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.80587
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 00061: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.805875 0.80775  0.80725  0.808625 0.810375 0.81     0.81125  0.811
#  0.811    0.8105   0.81125  0.8115   0.8125   0.811875 0.8125   0.811875
#  0.811875 0.812625 0.812    0.813125 0.812375 0.812    0.811125 0.810875
#  0.809625 0.80875  0.808    0.80725  0.806125 0.8055   0.804   ]

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target)
x_test = add_depth_bulk(x_test)

preds_test = predict_result(model,x_test,img_size_target)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Usedtime = 5.151927709579468 s
# save result
# upload result
# cmd: kaggle competitions submit -c tgs-salt-identification-challenge -f ../result/Unet_resnet_depthinchannel_cse_8_0.5.csv.7z -m "submit"
# Kernel run time = 5.507533628145854 hours
