# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
start_feature = 32
batch_size = 32
dropout = 0.5
base_name = 'resunet_deeper_cse_{}_{}'.format(batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# ../model/resunet_deeper_cse_32_0.5.model
# ../model/resunet_deeper_cse_32_0.5.csv

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/resunet_deeper_cse_16_0.5.model
# ../model/resunet_deeper_cse_16_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 92s 14ms/step - loss: 0.4969 - my_iou_metric: 0.3117 - val_loss: 1.9685 - val_my_iou_metric: 0.3900
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.39000, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 77s 12ms/step - loss: 0.4242 - my_iou_metric: 0.3865 - val_loss: 0.6018 - val_my_iou_metric: 0.3741
#
# Epoch 00002: val_my_iou_metric did not improve from 0.39000
# Epoch 3/200
# 6400/6400 [==============================] - 77s 12ms/step - loss: 0.3750 - my_iou_metric: 0.4641 - val_loss: 0.4738 - val_my_iou_metric: 0.3509
#
# Epoch 00003: val_my_iou_metric did not improve from 0.39000
# Epoch 4/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3338 - my_iou_metric: 0.5031 - val_loss: 0.4615 - val_my_iou_metric: 0.4042
#
# Epoch 00004: val_my_iou_metric improved from 0.39000 to 0.40425, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2793 - my_iou_metric: 0.5308 - val_loss: 0.2953 - val_my_iou_metric: 0.5072
#
# Epoch 00005: val_my_iou_metric improved from 0.40425 to 0.50725, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2841 - my_iou_metric: 0.5410 - val_loss: 0.5617 - val_my_iou_metric: 0.4804
#
# Epoch 00006: val_my_iou_metric did not improve from 0.50725
# Epoch 7/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2464 - my_iou_metric: 0.5613 - val_loss: 0.2437 - val_my_iou_metric: 0.6124
#
# Epoch 00007: val_my_iou_metric improved from 0.50725 to 0.61238, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2206 - my_iou_metric: 0.5988 - val_loss: 0.2352 - val_my_iou_metric: 0.6345
#
# Epoch 00008: val_my_iou_metric improved from 0.61238 to 0.63450, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2035 - my_iou_metric: 0.6228 - val_loss: 0.2128 - val_my_iou_metric: 0.6186
#
# Epoch 00009: val_my_iou_metric did not improve from 0.63450
# Epoch 10/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2048 - my_iou_metric: 0.6234 - val_loss: 0.1907 - val_my_iou_metric: 0.6808
#
# Epoch 00010: val_my_iou_metric improved from 0.63450 to 0.68075, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1956 - my_iou_metric: 0.6403 - val_loss: 0.2375 - val_my_iou_metric: 0.6547
#
# Epoch 00011: val_my_iou_metric did not improve from 0.68075
# Epoch 12/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2050 - my_iou_metric: 0.6291 - val_loss: 0.2333 - val_my_iou_metric: 0.6563
#
# Epoch 00012: val_my_iou_metric did not improve from 0.68075
# Epoch 13/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1844 - my_iou_metric: 0.6590 - val_loss: 0.1743 - val_my_iou_metric: 0.6935
#
# Epoch 00013: val_my_iou_metric improved from 0.68075 to 0.69350, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1741 - my_iou_metric: 0.6763 - val_loss: 0.2306 - val_my_iou_metric: 0.6076
#
# Epoch 00014: val_my_iou_metric did not improve from 0.69350
# Epoch 15/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1704 - my_iou_metric: 0.6773 - val_loss: 0.1743 - val_my_iou_metric: 0.6934
#
# Epoch 00015: val_my_iou_metric did not improve from 0.69350
# Epoch 16/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1600 - my_iou_metric: 0.6939 - val_loss: 0.1634 - val_my_iou_metric: 0.7190
#
# Epoch 00016: val_my_iou_metric improved from 0.69350 to 0.71900, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 77s 12ms/step - loss: 0.1562 - my_iou_metric: 0.6955 - val_loss: 0.1681 - val_my_iou_metric: 0.7147
#
# Epoch 00017: val_my_iou_metric did not improve from 0.71900
# Epoch 18/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1530 - my_iou_metric: 0.7041 - val_loss: 0.1544 - val_my_iou_metric: 0.7275
#
# Epoch 00018: val_my_iou_metric improved from 0.71900 to 0.72750, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1606 - my_iou_metric: 0.6974 - val_loss: 0.1511 - val_my_iou_metric: 0.7351
#
# Epoch 00019: val_my_iou_metric improved from 0.72750 to 0.73513, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1403 - my_iou_metric: 0.7231 - val_loss: 0.1474 - val_my_iou_metric: 0.7446
#
# Epoch 00020: val_my_iou_metric improved from 0.73513 to 0.74463, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1379 - my_iou_metric: 0.7244 - val_loss: 0.1791 - val_my_iou_metric: 0.6775
#
# Epoch 00021: val_my_iou_metric did not improve from 0.74463
# Epoch 22/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1365 - my_iou_metric: 0.7229 - val_loss: 0.2186 - val_my_iou_metric: 0.6590
#
# Epoch 00022: val_my_iou_metric did not improve from 0.74463
# Epoch 23/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1362 - my_iou_metric: 0.7270 - val_loss: 0.1761 - val_my_iou_metric: 0.7223
#
# Epoch 00023: val_my_iou_metric did not improve from 0.74463
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 24/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1177 - my_iou_metric: 0.7460 - val_loss: 0.1327 - val_my_iou_metric: 0.7573
#
# Epoch 00024: val_my_iou_metric improved from 0.74463 to 0.75725, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1178 - my_iou_metric: 0.7516 - val_loss: 0.1312 - val_my_iou_metric: 0.7705
#
# Epoch 00025: val_my_iou_metric improved from 0.75725 to 0.77050, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 26/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1113 - my_iou_metric: 0.7549 - val_loss: 0.1380 - val_my_iou_metric: 0.7372
#
# Epoch 00026: val_my_iou_metric did not improve from 0.77050
# Epoch 27/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1120 - my_iou_metric: 0.7583 - val_loss: 0.1298 - val_my_iou_metric: 0.7678
#
# Epoch 00027: val_my_iou_metric did not improve from 0.77050
# Epoch 28/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1055 - my_iou_metric: 0.7569 - val_loss: 0.1572 - val_my_iou_metric: 0.7344
#
# Epoch 00028: val_my_iou_metric did not improve from 0.77050
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 29/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0982 - my_iou_metric: 0.7717 - val_loss: 0.1252 - val_my_iou_metric: 0.7725
#
# Epoch 00029: val_my_iou_metric improved from 0.77050 to 0.77250, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 30/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0945 - my_iou_metric: 0.7761 - val_loss: 0.1485 - val_my_iou_metric: 0.7584
#
# Epoch 00030: val_my_iou_metric did not improve from 0.77250
# Epoch 31/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0931 - my_iou_metric: 0.7747 - val_loss: 0.1231 - val_my_iou_metric: 0.7777
#
# Epoch 00031: val_my_iou_metric improved from 0.77250 to 0.77775, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0897 - my_iou_metric: 0.7767 - val_loss: 0.1298 - val_my_iou_metric: 0.7714
#
# Epoch 00032: val_my_iou_metric did not improve from 0.77775
# Epoch 33/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0889 - my_iou_metric: 0.7742 - val_loss: 0.1231 - val_my_iou_metric: 0.7744
#
# Epoch 00033: val_my_iou_metric did not improve from 0.77775
# Epoch 34/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0864 - my_iou_metric: 0.7783 - val_loss: 0.1513 - val_my_iou_metric: 0.7776
#
# Epoch 00034: val_my_iou_metric did not improve from 0.77775
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 35/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0801 - my_iou_metric: 0.7882 - val_loss: 0.1357 - val_my_iou_metric: 0.7772
#
# Epoch 00035: val_my_iou_metric did not improve from 0.77775
# Epoch 36/200
# 6400/6400 [==============================] - 77s 12ms/step - loss: 0.0774 - my_iou_metric: 0.7842 - val_loss: 0.1246 - val_my_iou_metric: 0.7796
#
# Epoch 00036: val_my_iou_metric improved from 0.77775 to 0.77962, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 37/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0795 - my_iou_metric: 0.7871 - val_loss: 0.1262 - val_my_iou_metric: 0.7789
#
# Epoch 00037: val_my_iou_metric did not improve from 0.77962
# Epoch 38/200
# 6400/6400 [==============================] - 77s 12ms/step - loss: 0.0767 - my_iou_metric: 0.7894 - val_loss: 0.1253 - val_my_iou_metric: 0.7795
#
# Epoch 00038: val_my_iou_metric did not improve from 0.77962
# Epoch 39/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0768 - my_iou_metric: 0.7890 - val_loss: 0.1256 - val_my_iou_metric: 0.7812
#
# Epoch 00039: val_my_iou_metric improved from 0.77962 to 0.78125, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 40/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0736 - my_iou_metric: 0.7927 - val_loss: 0.1266 - val_my_iou_metric: 0.7859
#
# Epoch 00040: val_my_iou_metric improved from 0.78125 to 0.78587, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 41/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0730 - my_iou_metric: 0.7917 - val_loss: 0.1244 - val_my_iou_metric: 0.7790
#
# Epoch 00041: val_my_iou_metric did not improve from 0.78587
# Epoch 42/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0741 - my_iou_metric: 0.7918 - val_loss: 0.1272 - val_my_iou_metric: 0.7832
#
# Epoch 00042: val_my_iou_metric did not improve from 0.78587
# Epoch 43/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0708 - my_iou_metric: 0.7916 - val_loss: 0.1309 - val_my_iou_metric: 0.7697
#
# Epoch 00043: val_my_iou_metric did not improve from 0.78587
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 44/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0710 - my_iou_metric: 0.7956 - val_loss: 0.1274 - val_my_iou_metric: 0.7789
#
# Epoch 00044: val_my_iou_metric did not improve from 0.78587
# Epoch 45/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0682 - my_iou_metric: 0.7968 - val_loss: 0.1303 - val_my_iou_metric: 0.7800
#
# Epoch 00045: val_my_iou_metric did not improve from 0.78587
# Epoch 46/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0688 - my_iou_metric: 0.8002 - val_loss: 0.1343 - val_my_iou_metric: 0.7839
#
# Epoch 00046: val_my_iou_metric did not improve from 0.78587
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 47/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0664 - my_iou_metric: 0.7988 - val_loss: 0.1348 - val_my_iou_metric: 0.7783
#
# Epoch 00047: val_my_iou_metric did not improve from 0.78587
# Epoch 48/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0655 - my_iou_metric: 0.8014 - val_loss: 0.1295 - val_my_iou_metric: 0.7805
#
# Epoch 00048: val_my_iou_metric did not improve from 0.78587
# Epoch 49/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0663 - my_iou_metric: 0.8012 - val_loss: 0.1276 - val_my_iou_metric: 0.7835
#
# Epoch 00049: val_my_iou_metric did not improve from 0.78587
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 50/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.0638 - my_iou_metric: 0.8015 - val_loss: 0.1269 - val_my_iou_metric: 0.7813
#
# Epoch 00050: val_my_iou_metric did not improve from 0.78587
# Epoch 00050: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.00001, verbose=1)
epochs = 200

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 117s 18ms/step - loss: -0.1146 - my_iou_metric_2: 0.7909 - val_loss: 0.0564 - val_my_iou_metric_2: 0.7601
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.76013, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 100s 16ms/step - loss: -0.1423 - my_iou_metric_2: 0.7928 - val_loss: 0.1196 - val_my_iou_metric_2: 0.7642
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.76013 to 0.76425, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.1648 - my_iou_metric_2: 0.7967 - val_loss: -0.0324 - val_my_iou_metric_2: 0.7698
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.76425 to 0.76975, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2050 - my_iou_metric_2: 0.8057 - val_loss: 0.1650 - val_my_iou_metric_2: 0.7546
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.76975
# Epoch 5/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2188 - my_iou_metric_2: 0.8078 - val_loss: 0.0771 - val_my_iou_metric_2: 0.7679
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.76975
# Epoch 6/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2169 - my_iou_metric_2: 0.8072 - val_loss: 0.0311 - val_my_iou_metric_2: 0.7751
#
# Epoch 00006: val_my_iou_metric_2 improved from 0.76975 to 0.77513, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2324 - my_iou_metric_2: 0.8065 - val_loss: -0.0488 - val_my_iou_metric_2: 0.7926
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.77513 to 0.79262, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2652 - my_iou_metric_2: 0.8166 - val_loss: -0.0642 - val_my_iou_metric_2: 0.7711
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.79262
# Epoch 9/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2456 - my_iou_metric_2: 0.8110 - val_loss: 0.1617 - val_my_iou_metric_2: 0.7480
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.79262
# Epoch 10/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2651 - my_iou_metric_2: 0.8124 - val_loss: 0.1972 - val_my_iou_metric_2: 0.7551
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.79262
# Epoch 11/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2913 - my_iou_metric_2: 0.8208 - val_loss: 0.0039 - val_my_iou_metric_2: 0.7701
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.79262
# Epoch 12/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.2980 - my_iou_metric_2: 0.8228 - val_loss: 0.1158 - val_my_iou_metric_2: 0.7510
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.79262
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 13/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.3563 - my_iou_metric_2: 0.8322 - val_loss: -0.0914 - val_my_iou_metric_2: 0.8024
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.79262 to 0.80238, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.3812 - my_iou_metric_2: 0.8394 - val_loss: -0.0873 - val_my_iou_metric_2: 0.8065
#
# Epoch 00014: val_my_iou_metric_2 improved from 0.80238 to 0.80650, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.3909 - my_iou_metric_2: 0.8392 - val_loss: -0.0917 - val_my_iou_metric_2: 0.7985
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 16/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.3955 - my_iou_metric_2: 0.8401 - val_loss: -0.1169 - val_my_iou_metric_2: 0.8055
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 17/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4177 - my_iou_metric_2: 0.8459 - val_loss: -0.1404 - val_my_iou_metric_2: 0.8059
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 18/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4032 - my_iou_metric_2: 0.8427 - val_loss: -0.1174 - val_my_iou_metric_2: 0.8015
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80650
# Epoch 19/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4314 - my_iou_metric_2: 0.8469 - val_loss: -0.1176 - val_my_iou_metric_2: 0.8045
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80650
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 20/200
# 6400/6400 [==============================] - 100s 16ms/step - loss: -0.4552 - my_iou_metric_2: 0.8525 - val_loss: -0.1436 - val_my_iou_metric_2: 0.8093
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.80650 to 0.80925, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4717 - my_iou_metric_2: 0.8553 - val_loss: -0.1298 - val_my_iou_metric_2: 0.8074
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.80925
# Epoch 22/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4799 - my_iou_metric_2: 0.8557 - val_loss: -0.1153 - val_my_iou_metric_2: 0.8113
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.80925 to 0.81125, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4856 - my_iou_metric_2: 0.8587 - val_loss: -0.1116 - val_my_iou_metric_2: 0.8064
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.81125
# Epoch 24/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4870 - my_iou_metric_2: 0.8589 - val_loss: -0.1047 - val_my_iou_metric_2: 0.8123
#
# Epoch 00024: val_my_iou_metric_2 improved from 0.81125 to 0.81225, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4931 - my_iou_metric_2: 0.8586 - val_loss: -0.0934 - val_my_iou_metric_2: 0.8045
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.81225
# Epoch 26/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.4943 - my_iou_metric_2: 0.8608 - val_loss: -0.1062 - val_my_iou_metric_2: 0.8100
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.81225
# Epoch 27/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5012 - my_iou_metric_2: 0.8605 - val_loss: -0.1214 - val_my_iou_metric_2: 0.8096
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.81225
# Epoch 28/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5177 - my_iou_metric_2: 0.8649 - val_loss: -0.0742 - val_my_iou_metric_2: 0.8067
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.81225
# Epoch 29/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5112 - my_iou_metric_2: 0.8625 - val_loss: -0.0907 - val_my_iou_metric_2: 0.8006
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.81225
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 30/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5261 - my_iou_metric_2: 0.8651 - val_loss: -0.1054 - val_my_iou_metric_2: 0.8166
#
# Epoch 00030: val_my_iou_metric_2 improved from 0.81225 to 0.81663, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 31/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5388 - my_iou_metric_2: 0.8686 - val_loss: -0.0405 - val_my_iou_metric_2: 0.8076
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.81663
# Epoch 32/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5452 - my_iou_metric_2: 0.8697 - val_loss: -0.1059 - val_my_iou_metric_2: 0.8129
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.81663
# Epoch 33/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5326 - my_iou_metric_2: 0.8674 - val_loss: -0.0844 - val_my_iou_metric_2: 0.8119
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.81663
# Epoch 34/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5444 - my_iou_metric_2: 0.8685 - val_loss: -0.0960 - val_my_iou_metric_2: 0.8086
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.81663
# Epoch 35/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5430 - my_iou_metric_2: 0.8680 - val_loss: -0.1127 - val_my_iou_metric_2: 0.8125
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.81663
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 36/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5534 - my_iou_metric_2: 0.8715 - val_loss: -0.0817 - val_my_iou_metric_2: 0.8178
#
# Epoch 00036: val_my_iou_metric_2 improved from 0.81663 to 0.81775, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 37/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5582 - my_iou_metric_2: 0.8721 - val_loss: -0.0934 - val_my_iou_metric_2: 0.8156
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 38/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5553 - my_iou_metric_2: 0.8705 - val_loss: -0.0982 - val_my_iou_metric_2: 0.8122
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 39/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5600 - my_iou_metric_2: 0.8717 - val_loss: -0.0780 - val_my_iou_metric_2: 0.8149
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 40/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5639 - my_iou_metric_2: 0.8723 - val_loss: -0.0754 - val_my_iou_metric_2: 0.8134
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 41/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5632 - my_iou_metric_2: 0.8730 - val_loss: -0.0964 - val_my_iou_metric_2: 0.8166
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.81775
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 42/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5684 - my_iou_metric_2: 0.8743 - val_loss: -0.0665 - val_my_iou_metric_2: 0.8143
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 43/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5711 - my_iou_metric_2: 0.8747 - val_loss: -0.0874 - val_my_iou_metric_2: 0.8149
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 44/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5760 - my_iou_metric_2: 0.8751 - val_loss: -0.0608 - val_my_iou_metric_2: 0.8149
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 45/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5793 - my_iou_metric_2: 0.8755 - val_loss: -0.0742 - val_my_iou_metric_2: 0.8128
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 46/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5766 - my_iou_metric_2: 0.8755 - val_loss: -0.0746 - val_my_iou_metric_2: 0.8151
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.81775
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 47/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5762 - my_iou_metric_2: 0.8747 - val_loss: -0.0726 - val_my_iou_metric_2: 0.8139
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 48/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5733 - my_iou_metric_2: 0.8753 - val_loss: -0.0795 - val_my_iou_metric_2: 0.8152
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 49/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5753 - my_iou_metric_2: 0.8755 - val_loss: -0.0830 - val_my_iou_metric_2: 0.8136
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 50/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5811 - my_iou_metric_2: 0.8760 - val_loss: -0.0666 - val_my_iou_metric_2: 0.8149
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 51/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5766 - my_iou_metric_2: 0.8769 - val_loss: -0.0725 - val_my_iou_metric_2: 0.8162
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.81775
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 52/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5854 - my_iou_metric_2: 0.8777 - val_loss: -0.0672 - val_my_iou_metric_2: 0.8176
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.81775
# Epoch 53/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5728 - my_iou_metric_2: 0.8752 - val_loss: -0.0714 - val_my_iou_metric_2: 0.8180
#
# Epoch 00053: val_my_iou_metric_2 improved from 0.81775 to 0.81800, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 54/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5772 - my_iou_metric_2: 0.8762 - val_loss: -0.0699 - val_my_iou_metric_2: 0.8185
#
# Epoch 00054: val_my_iou_metric_2 improved from 0.81800 to 0.81850, saving model to ../model/resunet_deeper_cse_16_0.5.model
# Epoch 55/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5804 - my_iou_metric_2: 0.8757 - val_loss: -0.0737 - val_my_iou_metric_2: 0.8160
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.81850
# Epoch 56/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5800 - my_iou_metric_2: 0.8755 - val_loss: -0.0704 - val_my_iou_metric_2: 0.8167
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.81850
# Epoch 57/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: -0.5791 - my_iou_metric_2: 0.8755 - val_loss: -0.0733 - val_my_iou_metric_2: 0.8152
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.81850
# Epoch 58/200
#  768/6400 [==>...........................] - ETA: 1:23 - loss: -0.6086 - my_iou_metric_2: 0.8846
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c499e5419ee1> in <module>()
#      23                     batch_size=batch_size,
#      24                     callbacks=[board, model_checkpoint,reduce_lr,early_stopping],
# ---> 25                     verbose=1)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
save_model_name
# Out:
# '../model/resunet_deeper_cse_32_0.5.model'

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
score = model.evaluate(x_train, y_train, verbose=1)
# Out:
# 6400/6400 [==============================] - 49s 8ms/step

# %%
score
# Out:
# [-0.5888013701140881, 0.8794375000000001]

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.2, 0.8, 100)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# [0.785    0.7855   0.786    0.78625  0.786125 0.786    0.78675  0.7895
#  0.791    0.790875 0.790875 0.791    0.79125  0.791625 0.791875 0.792125
#  0.792    0.792    0.792125 0.793625 0.79475  0.795    0.795125 0.79475
#  0.794625 0.793625 0.793875 0.793375 0.793625 0.793625 0.79475  0.794875
#  0.794875 0.794625 0.794375 0.795625 0.79525  0.795125 0.795125 0.796125
#  0.796    0.795875 0.79625  0.796875 0.796875 0.79675  0.796125 0.795125
#  0.794875 0.796    0.795625 0.79675  0.79675  0.797625 0.797875 0.7975
#  0.79725  0.79825  0.800375 0.800375 0.8      0.801375 0.801375 0.801375
#  0.801    0.801125 0.80075  0.801    0.80075  0.800625 0.8      0.79975
#  0.79975  0.7995   0.7995   0.799375 0.799125 0.798125 0.798    0.79775
#  0.798    0.797625 0.796875 0.79675  0.796625 0.795875 0.795625 0.79625
#  0.795625 0.79475  0.794125 0.79325  0.7925   0.792125 0.79225  0.792375
#  0.791625 0.790875 0.790375 0.788875]

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = False, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
