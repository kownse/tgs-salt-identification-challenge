# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block_scSE(conv1,start_neurons * 1)
    conv1 = residual_block_scSE(conv1,start_neurons * 1)
    conv1 = residual_block_scSE(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block_scSE(conv2,start_neurons * 2)
    conv2 = residual_block_scSE(conv2,start_neurons * 2)
    conv2 = residual_block_scSE(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block_scSE(conv3,start_neurons * 4)
    conv3 = residual_block_scSE(conv3,start_neurons * 4)
    conv3 = residual_block_scSE(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block_scSE(conv4,start_neurons * 8)
    conv4 = residual_block_scSE(conv4,start_neurons * 8)
    conv4 = residual_block_scSE(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block_scSE(convm,start_neurons * 16)
    convm = residual_block_scSE(convm,start_neurons * 16)
    convm = residual_block_scSE(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_scSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_scSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_scSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_scSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_scSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_scSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_scSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_scSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_scSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_scSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_scSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_scSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
start_feature = 32
dropout = 0.5
basic_name = '../model/resunet_deeper_scse_{}_{}'.format(start_feature, dropout)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/resunet_deeper_scse_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# ../model/resunet_deeper_scse_32_0.5.model
# ../model/resunet_deeper_scse_32_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 112s 18ms/step - loss: 0.4545 - my_iou_metric: 0.3001 - val_loss: 1.2363 - val_my_iou_metric: 0.3900
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.39000, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.3790 - my_iou_metric: 0.4376 - val_loss: 1.1782 - val_my_iou_metric: 0.3991
#
# Epoch 00002: val_my_iou_metric improved from 0.39000 to 0.39913, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.3667 - my_iou_metric: 0.4623 - val_loss: 1.0779 - val_my_iou_metric: 0.0764
#
# Epoch 00003: val_my_iou_metric did not improve from 0.39913
# Epoch 4/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.3468 - my_iou_metric: 0.4996 - val_loss: 1.2906 - val_my_iou_metric: 0.3865
#
# Epoch 00004: val_my_iou_metric did not improve from 0.39913
# Epoch 5/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.3343 - my_iou_metric: 0.5150 - val_loss: 0.4624 - val_my_iou_metric: 0.4279
#
# Epoch 00005: val_my_iou_metric improved from 0.39913 to 0.42787, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 6/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.3061 - my_iou_metric: 0.5371 - val_loss: 0.8965 - val_my_iou_metric: 0.3592
#
# Epoch 00006: val_my_iou_metric did not improve from 0.42787
# Epoch 7/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.2751 - my_iou_metric: 0.5713 - val_loss: 0.9584 - val_my_iou_metric: 0.3990
#
# Epoch 00007: val_my_iou_metric did not improve from 0.42787
# Epoch 8/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.2621 - my_iou_metric: 0.5822 - val_loss: 0.5280 - val_my_iou_metric: 0.1423
#
# Epoch 00008: val_my_iou_metric did not improve from 0.42787
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 9/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.2208 - my_iou_metric: 0.6020 - val_loss: 0.2208 - val_my_iou_metric: 0.5980
#
# Epoch 00009: val_my_iou_metric improved from 0.42787 to 0.59800, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.2022 - my_iou_metric: 0.6231 - val_loss: 0.2130 - val_my_iou_metric: 0.6204
#
# Epoch 00010: val_my_iou_metric improved from 0.59800 to 0.62038, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1982 - my_iou_metric: 0.6305 - val_loss: 0.2488 - val_my_iou_metric: 0.5804
#
# Epoch 00011: val_my_iou_metric did not improve from 0.62038
# Epoch 12/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1833 - my_iou_metric: 0.6402 - val_loss: 0.3623 - val_my_iou_metric: 0.3900
#
# Epoch 00012: val_my_iou_metric did not improve from 0.62038
# Epoch 13/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1832 - my_iou_metric: 0.6485 - val_loss: 0.2056 - val_my_iou_metric: 0.6586
#
# Epoch 00013: val_my_iou_metric improved from 0.62038 to 0.65863, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1770 - my_iou_metric: 0.6567 - val_loss: 0.1948 - val_my_iou_metric: 0.6835
#
# Epoch 00014: val_my_iou_metric improved from 0.65863 to 0.68350, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1704 - my_iou_metric: 0.6680 - val_loss: 0.1802 - val_my_iou_metric: 0.6902
#
# Epoch 00015: val_my_iou_metric improved from 0.68350 to 0.69025, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1626 - my_iou_metric: 0.6770 - val_loss: 0.2265 - val_my_iou_metric: 0.6222
#
# Epoch 00016: val_my_iou_metric did not improve from 0.69025
# Epoch 17/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1607 - my_iou_metric: 0.6813 - val_loss: 0.1618 - val_my_iou_metric: 0.7018
#
# Epoch 00017: val_my_iou_metric improved from 0.69025 to 0.70175, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 18/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1587 - my_iou_metric: 0.6778 - val_loss: 0.1697 - val_my_iou_metric: 0.6963
#
# Epoch 00018: val_my_iou_metric did not improve from 0.70175
# Epoch 19/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1507 - my_iou_metric: 0.6846 - val_loss: 0.1756 - val_my_iou_metric: 0.6926
#
# Epoch 00019: val_my_iou_metric did not improve from 0.70175
# Epoch 20/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1501 - my_iou_metric: 0.6938 - val_loss: 0.1759 - val_my_iou_metric: 0.7091
#
# Epoch 00020: val_my_iou_metric improved from 0.70175 to 0.70913, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1489 - my_iou_metric: 0.7038 - val_loss: 0.1649 - val_my_iou_metric: 0.6954
#
# Epoch 00021: val_my_iou_metric did not improve from 0.70913
# Epoch 22/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1462 - my_iou_metric: 0.7006 - val_loss: 0.1696 - val_my_iou_metric: 0.7037
#
# Epoch 00022: val_my_iou_metric did not improve from 0.70913
# Epoch 23/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1360 - my_iou_metric: 0.7087 - val_loss: 0.1808 - val_my_iou_metric: 0.6990
#
# Epoch 00023: val_my_iou_metric did not improve from 0.70913
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 24/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1252 - my_iou_metric: 0.7229 - val_loss: 0.1508 - val_my_iou_metric: 0.7321
#
# Epoch 00024: val_my_iou_metric improved from 0.70913 to 0.73213, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1245 - my_iou_metric: 0.7232 - val_loss: 0.1596 - val_my_iou_metric: 0.7104
#
# Epoch 00025: val_my_iou_metric did not improve from 0.73213
# Epoch 26/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1215 - my_iou_metric: 0.7305 - val_loss: 0.1533 - val_my_iou_metric: 0.7261
#
# Epoch 00026: val_my_iou_metric did not improve from 0.73213
# Epoch 27/200
# 6400/6400 [==============================] - 96s 15ms/step - loss: 0.1170 - my_iou_metric: 0.7351 - val_loss: 0.1560 - val_my_iou_metric: 0.7314
#
# Epoch 00027: val_my_iou_metric did not improve from 0.73213
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 28/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1084 - my_iou_metric: 0.7466 - val_loss: 0.1445 - val_my_iou_metric: 0.7449
#
# Epoch 00028: val_my_iou_metric improved from 0.73213 to 0.74488, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 29/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1034 - my_iou_metric: 0.7478 - val_loss: 0.1491 - val_my_iou_metric: 0.7438
#
# Epoch 00029: val_my_iou_metric did not improve from 0.74488
# Epoch 30/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.1031 - my_iou_metric: 0.7488 - val_loss: 0.1516 - val_my_iou_metric: 0.7442
#
# Epoch 00030: val_my_iou_metric did not improve from 0.74488
# Epoch 31/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0980 - my_iou_metric: 0.7560 - val_loss: 0.1414 - val_my_iou_metric: 0.7406
#
# Epoch 00031: val_my_iou_metric did not improve from 0.74488
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 32/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0948 - my_iou_metric: 0.7593 - val_loss: 0.1506 - val_my_iou_metric: 0.7439
#
# Epoch 00032: val_my_iou_metric did not improve from 0.74488
# Epoch 33/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0938 - my_iou_metric: 0.7604 - val_loss: 0.1454 - val_my_iou_metric: 0.7518
#
# Epoch 00033: val_my_iou_metric improved from 0.74488 to 0.75175, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 34/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0926 - my_iou_metric: 0.7624 - val_loss: 0.1541 - val_my_iou_metric: 0.7483
#
# Epoch 00034: val_my_iou_metric did not improve from 0.75175
# Epoch 35/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0889 - my_iou_metric: 0.7666 - val_loss: 0.1576 - val_my_iou_metric: 0.7478
#
# Epoch 00035: val_my_iou_metric did not improve from 0.75175
# Epoch 36/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0905 - my_iou_metric: 0.7624 - val_loss: 0.1492 - val_my_iou_metric: 0.7434
#
# Epoch 00036: val_my_iou_metric did not improve from 0.75175
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 37/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0872 - my_iou_metric: 0.7652 - val_loss: 0.1487 - val_my_iou_metric: 0.7535
#
# Epoch 00037: val_my_iou_metric improved from 0.75175 to 0.75350, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 38/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0875 - my_iou_metric: 0.7696 - val_loss: 0.1526 - val_my_iou_metric: 0.7500
#
# Epoch 00038: val_my_iou_metric did not improve from 0.75350
# Epoch 39/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0877 - my_iou_metric: 0.7661 - val_loss: 0.1528 - val_my_iou_metric: 0.7481
#
# Epoch 00039: val_my_iou_metric did not improve from 0.75350
# Epoch 40/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0849 - my_iou_metric: 0.7693 - val_loss: 0.1584 - val_my_iou_metric: 0.7479
#
# Epoch 00040: val_my_iou_metric did not improve from 0.75350
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 41/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0823 - my_iou_metric: 0.7707 - val_loss: 0.1580 - val_my_iou_metric: 0.7512
#
# Epoch 00041: val_my_iou_metric did not improve from 0.75350
# Epoch 42/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0844 - my_iou_metric: 0.7691 - val_loss: 0.1538 - val_my_iou_metric: 0.7465
#
# Epoch 00042: val_my_iou_metric did not improve from 0.75350
# Epoch 43/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0808 - my_iou_metric: 0.7723 - val_loss: 0.1574 - val_my_iou_metric: 0.7491
#
# Epoch 00043: val_my_iou_metric did not improve from 0.75350
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 44/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0818 - my_iou_metric: 0.7720 - val_loss: 0.1579 - val_my_iou_metric: 0.7484
#
# Epoch 00044: val_my_iou_metric did not improve from 0.75350
# Epoch 45/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0803 - my_iou_metric: 0.7718 - val_loss: 0.1572 - val_my_iou_metric: 0.7482
#
# Epoch 00045: val_my_iou_metric did not improve from 0.75350
# Epoch 46/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0824 - my_iou_metric: 0.7691 - val_loss: 0.1565 - val_my_iou_metric: 0.7517
#
# Epoch 00046: val_my_iou_metric did not improve from 0.75350
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 47/200
# 6400/6400 [==============================] - 95s 15ms/step - loss: 0.0809 - my_iou_metric: 0.7695 - val_loss: 0.1564 - val_my_iou_metric: 0.7509
#
# Epoch 00047: val_my_iou_metric did not improve from 0.75350
# Epoch 00047: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)
epochs = 200
batch_size = 32

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 158s 25ms/step - loss: 0.1484 - my_iou_metric_2: 0.7289 - val_loss: 0.4132 - val_my_iou_metric_2: 0.6656
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.66563, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: 0.0984 - my_iou_metric_2: 0.7333 - val_loss: 0.4778 - val_my_iou_metric_2: 0.6369
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.66563
# Epoch 3/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: 0.0503 - my_iou_metric_2: 0.7397 - val_loss: 0.1281 - val_my_iou_metric_2: 0.7304
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.66563 to 0.73038, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: 0.0118 - my_iou_metric_2: 0.7505 - val_loss: 0.1390 - val_my_iou_metric_2: 0.7352
#
# Epoch 00004: val_my_iou_metric_2 improved from 0.73038 to 0.73525, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.0046 - my_iou_metric_2: 0.7519 - val_loss: 0.3195 - val_my_iou_metric_2: 0.7135
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.73525
# Epoch 6/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.0284 - my_iou_metric_2: 0.7564 - val_loss: 0.1971 - val_my_iou_metric_2: 0.7293
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.73525
# Epoch 7/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.0582 - my_iou_metric_2: 0.7658 - val_loss: 0.2487 - val_my_iou_metric_2: 0.7286
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.73525
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 8/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.1555 - my_iou_metric_2: 0.7855 - val_loss: 0.1589 - val_my_iou_metric_2: 0.7385
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.73525 to 0.73850, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.1779 - my_iou_metric_2: 0.7910 - val_loss: -0.0142 - val_my_iou_metric_2: 0.7554
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.73850 to 0.75538, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.2020 - my_iou_metric_2: 0.7931 - val_loss: -0.0285 - val_my_iou_metric_2: 0.7740
#
# Epoch 00010: val_my_iou_metric_2 improved from 0.75538 to 0.77400, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.1959 - my_iou_metric_2: 0.7941 - val_loss: 0.2395 - val_my_iou_metric_2: 0.7195
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.77400
# Epoch 12/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.2045 - my_iou_metric_2: 0.7961 - val_loss: -0.0134 - val_my_iou_metric_2: 0.7672
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.77400
# Epoch 13/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.2229 - my_iou_metric_2: 0.8001 - val_loss: -0.0280 - val_my_iou_metric_2: 0.7735
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.77400
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 14/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.2779 - my_iou_metric_2: 0.8092 - val_loss: -0.0929 - val_my_iou_metric_2: 0.7914
#
# Epoch 00014: val_my_iou_metric_2 improved from 0.77400 to 0.79138, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3012 - my_iou_metric_2: 0.8157 - val_loss: -0.0833 - val_my_iou_metric_2: 0.7890
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.79138
# Epoch 16/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3213 - my_iou_metric_2: 0.8206 - val_loss: -0.0996 - val_my_iou_metric_2: 0.7914
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.79138
# Epoch 17/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3204 - my_iou_metric_2: 0.8200 - val_loss: 0.0036 - val_my_iou_metric_2: 0.7881
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.79138
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 18/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3539 - my_iou_metric_2: 0.8278 - val_loss: -0.0102 - val_my_iou_metric_2: 0.7915
#
# Epoch 00018: val_my_iou_metric_2 improved from 0.79138 to 0.79150, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3745 - my_iou_metric_2: 0.8311 - val_loss: -0.0701 - val_my_iou_metric_2: 0.7940
#
# Epoch 00019: val_my_iou_metric_2 improved from 0.79150 to 0.79400, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3797 - my_iou_metric_2: 0.8326 - val_loss: -0.0819 - val_my_iou_metric_2: 0.7931
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.79400
# Epoch 21/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3750 - my_iou_metric_2: 0.8309 - val_loss: -0.0282 - val_my_iou_metric_2: 0.7906
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.79400
# Epoch 22/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3865 - my_iou_metric_2: 0.8337 - val_loss: -0.0456 - val_my_iou_metric_2: 0.7876
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.79400
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 23/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.3922 - my_iou_metric_2: 0.8357 - val_loss: -0.0770 - val_my_iou_metric_2: 0.8016
#
# Epoch 00023: val_my_iou_metric_2 improved from 0.79400 to 0.80162, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4133 - my_iou_metric_2: 0.8383 - val_loss: -0.0851 - val_my_iou_metric_2: 0.8005
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.80162
# Epoch 25/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4214 - my_iou_metric_2: 0.8410 - val_loss: -0.0795 - val_my_iou_metric_2: 0.8013
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.80162
# Epoch 26/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4191 - my_iou_metric_2: 0.8405 - val_loss: -0.0560 - val_my_iou_metric_2: 0.7993
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.80162
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 27/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4279 - my_iou_metric_2: 0.8417 - val_loss: -0.0666 - val_my_iou_metric_2: 0.8021
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.80162 to 0.80212, saving model to ../model/resunet_deeper_scse_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4343 - my_iou_metric_2: 0.8414 - val_loss: -0.0462 - val_my_iou_metric_2: 0.7985
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.80212
# Epoch 29/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4309 - my_iou_metric_2: 0.8427 - val_loss: -0.0503 - val_my_iou_metric_2: 0.8017
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.80212
# Epoch 30/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4455 - my_iou_metric_2: 0.8461 - val_loss: -0.0517 - val_my_iou_metric_2: 0.8005
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.80212
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 31/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4333 - my_iou_metric_2: 0.8436 - val_loss: -0.0483 - val_my_iou_metric_2: 0.7972
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.80212
# Epoch 32/200
# 6400/6400 [==============================] - 141s 22ms/step - loss: -0.4375 - my_iou_metric_2: 0.8435 - val_loss: -0.0436 - val_my_iou_metric_2: 0.8019
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.80212
# Epoch 33/200
# 2720/6400 [===========>..................] - ETA: 1:16 - loss: -0.4387 - my_iou_metric_2: 0.8383

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/resunet_scse.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = False, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
