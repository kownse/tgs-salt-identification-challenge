# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 128

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# Build model
def build_vgg_unet_model(input_shape, DropoutRatio = 0.5, weights = 'imagenet'):
    input_layer = Input(input_shape)
    
    # block 1
    conv1 = Conv2D(64, (3, 3), activation='relu', padding="same")(input_layer)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding="same")(conv1)
    pool1 = MaxPooling2D((2, 2), strides=(2,2))(conv1)

    # block 2
    conv2 = Conv2D(128, (3, 3), activation='relu', padding="same")(pool1)
    conv2 = Conv2D(128, (3, 3), activation='relu', padding="same")(conv2)
    pool2 = MaxPooling2D((2, 2), strides=(2,2))(conv2)
    
    # block3
    conv3 = Conv2D(256, (3, 3), activation='relu', padding="same")(pool2)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding="same")(conv3)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding="same")(conv3)
    pool3 = MaxPooling2D((2, 2), strides=(2,2))(conv3)
    
    # block4
    conv4 = Conv2D(512, (3, 3), activation='relu', padding="same")(pool3)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv4)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv4)
    pool4 = MaxPooling2D((2, 2), strides=(2,2))(conv4)
    
    # block5
    conv5 = Conv2D(512, (3, 3), activation='relu', padding="same")(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv5)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding="same")(conv5)
    pool5 = MaxPooling2D((2, 2), strides=(2,2))(conv5)
    
    # Middle
    if DropoutRatio > 0:
        pool5 = Dropout(DropoutRatio)(pool5)
    convm = Conv2D(1024, (3, 3), activation="relu", padding="same")(pool5)
    
    # uconv5
    deconv5 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv5 = concatenate([deconv5, conv5])
    if DropoutRatio > 0:
        uconv5 = Dropout(DropoutRatio)(uconv5)
    uconv5 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv5)
#     uconv5 = residual_block(uconv5,512)
    uconv5 = residual_block(uconv5,512, True)
    
    # uconv4
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(uconv5)
    uconv4 = concatenate([deconv4, conv4])
    if DropoutRatio > 0:
        uconv4 = Dropout(DropoutRatio)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
#     uconv4 = residual_block(uconv4,512)
    uconv4 = residual_block(uconv4,512, True)
    
    # uconv3
    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    if DropoutRatio > 0:
        uconv3 = Dropout(DropoutRatio)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
#     uconv3 = residual_block(uconv3,256)
    uconv3 = residual_block(uconv3,256, True)
    
    # uconv2
    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    if DropoutRatio > 0:
        uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
#     uconv2 = residual_block(uconv2,128)
    uconv2 = residual_block(uconv2,128, True)
    
    # uconv1
    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    if DropoutRatio > 0:
        uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
#     uconv1 = residual_block(uconv1,64)
    uconv1 = residual_block(uconv1,64, True)
    
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    model = Model(input_layer, output_layer)
    
    if weights == 'imagenet':
        vgg = VGG16(input_shape = input_shape, include_top = False, weights = 'imagenet')
        for i in range(1, len(vgg.layers)):
            model.layers[i].set_weights(vgg.layers[i].get_weights())
            model.layers[i].trainable = False
            
    return model

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=False)) for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 3), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 128, 128, 3)
# (800, 128, 128, 1)

# %%
batch_size = 32
dropout = 0.5
base_name = 'Unet_vgg_{}_{}'.format(batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
model1 = build_vgg_unet_model((img_size_target, img_size_target, 3), 
                              DropoutRatio = dropout, weights = 'imagenet')

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 200

history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)

from keras import backend as K
K.clear_session()
# Out:
# ../model/Unet_vgg_32_0.5.model
# ../model/Unet_vgg_32_0.5.csv
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 77s 12ms/step - loss: 0.3006 - my_iou_metric: 0.3739 - val_loss: 0.2306 - val_my_iou_metric: 0.4973
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.49725, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.2007 - my_iou_metric: 0.5526 - val_loss: 0.1931 - val_my_iou_metric: 0.6221
#
# Epoch 00002: val_my_iou_metric improved from 0.49725 to 0.62213, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1775 - my_iou_metric: 0.6141 - val_loss: 0.1811 - val_my_iou_metric: 0.6686
#
# Epoch 00003: val_my_iou_metric improved from 0.62213 to 0.66862, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1573 - my_iou_metric: 0.6393 - val_loss: 0.1760 - val_my_iou_metric: 0.6958
#
# Epoch 00004: val_my_iou_metric improved from 0.66862 to 0.69575, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1385 - my_iou_metric: 0.6670 - val_loss: 0.1670 - val_my_iou_metric: 0.6847
#
# Epoch 00005: val_my_iou_metric did not improve from 0.69575
# Epoch 6/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.1275 - my_iou_metric: 0.6880 - val_loss: 0.2114 - val_my_iou_metric: 0.6575
#
# Epoch 00006: val_my_iou_metric did not improve from 0.69575
# Epoch 7/200
# 6400/6400 [==============================] - 72s 11ms/step - loss: 0.1143 - my_iou_metric: 0.7047 - val_loss: 0.1723 - val_my_iou_metric: 0.6960
#
# Epoch 00007: val_my_iou_metric improved from 0.69575 to 0.69600, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0994 - my_iou_metric: 0.7224 - val_loss: 0.1616 - val_my_iou_metric: 0.6961
#
# Epoch 00008: val_my_iou_metric improved from 0.69600 to 0.69612, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0955 - my_iou_metric: 0.7246 - val_loss: 0.1671 - val_my_iou_metric: 0.6652
#
# Epoch 00009: val_my_iou_metric did not improve from 0.69612
# Epoch 10/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0752 - my_iou_metric: 0.7533 - val_loss: 0.1767 - val_my_iou_metric: 0.6977
#
# Epoch 00010: val_my_iou_metric improved from 0.69612 to 0.69775, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0680 - my_iou_metric: 0.7629 - val_loss: 0.1995 - val_my_iou_metric: 0.6857
#
# Epoch 00011: val_my_iou_metric did not improve from 0.69775
# Epoch 12/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0665 - my_iou_metric: 0.7655 - val_loss: 0.2000 - val_my_iou_metric: 0.6805
#
# Epoch 00012: val_my_iou_metric did not improve from 0.69775
# Epoch 13/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0535 - my_iou_metric: 0.7856 - val_loss: 0.2173 - val_my_iou_metric: 0.7031
#
# Epoch 00013: val_my_iou_metric improved from 0.69775 to 0.70312, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0508 - my_iou_metric: 0.7895 - val_loss: 0.2110 - val_my_iou_metric: 0.6629
#
# Epoch 00014: val_my_iou_metric did not improve from 0.70312
# Epoch 15/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0514 - my_iou_metric: 0.7971 - val_loss: 0.2494 - val_my_iou_metric: 0.7165
#
# Epoch 00015: val_my_iou_metric improved from 0.70312 to 0.71650, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 16/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0440 - my_iou_metric: 0.8112 - val_loss: 0.2401 - val_my_iou_metric: 0.6656
#
# Epoch 00016: val_my_iou_metric did not improve from 0.71650
# Epoch 17/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0432 - my_iou_metric: 0.8096 - val_loss: 0.2170 - val_my_iou_metric: 0.7116
#
# Epoch 00017: val_my_iou_metric did not improve from 0.71650
# Epoch 18/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0398 - my_iou_metric: 0.8209 - val_loss: 0.2107 - val_my_iou_metric: 0.7122
#
# Epoch 00018: val_my_iou_metric did not improve from 0.71650
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 19/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0324 - my_iou_metric: 0.8441 - val_loss: 0.2308 - val_my_iou_metric: 0.7119
#
# Epoch 00019: val_my_iou_metric did not improve from 0.71650
# Epoch 20/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0301 - my_iou_metric: 0.8495 - val_loss: 0.2383 - val_my_iou_metric: 0.7239
#
# Epoch 00020: val_my_iou_metric improved from 0.71650 to 0.72388, saving model to ../model/Unet_vgg_32_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0292 - my_iou_metric: 0.8539 - val_loss: 0.2524 - val_my_iou_metric: 0.7135
#
# Epoch 00021: val_my_iou_metric did not improve from 0.72388
# Epoch 22/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0277 - my_iou_metric: 0.8567 - val_loss: 0.2595 - val_my_iou_metric: 0.7092
#
# Epoch 00022: val_my_iou_metric did not improve from 0.72388
# Epoch 23/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0272 - my_iou_metric: 0.8607 - val_loss: 0.2740 - val_my_iou_metric: 0.7195
#
# Epoch 00023: val_my_iou_metric did not improve from 0.72388
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 24/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0257 - my_iou_metric: 0.8665 - val_loss: 0.2609 - val_my_iou_metric: 0.7167
#
# Epoch 00024: val_my_iou_metric did not improve from 0.72388
# Epoch 25/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0251 - my_iou_metric: 0.8701 - val_loss: 0.2589 - val_my_iou_metric: 0.7176
#
# Epoch 00025: val_my_iou_metric did not improve from 0.72388
# Epoch 26/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0243 - my_iou_metric: 0.8710 - val_loss: 0.2766 - val_my_iou_metric: 0.7131
#
# Epoch 00026: val_my_iou_metric did not improve from 0.72388
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 27/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0233 - my_iou_metric: 0.8775 - val_loss: 0.2744 - val_my_iou_metric: 0.7175
#
# Epoch 00027: val_my_iou_metric did not improve from 0.72388
# Epoch 28/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0232 - my_iou_metric: 0.8767 - val_loss: 0.2722 - val_my_iou_metric: 0.7183
#
# Epoch 00028: val_my_iou_metric did not improve from 0.72388
# Epoch 29/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0228 - my_iou_metric: 0.8783 - val_loss: 0.2666 - val_my_iou_metric: 0.7210
#
# Epoch 00029: val_my_iou_metric did not improve from 0.72388
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 30/200
# 6400/6400 [==============================] - 71s 11ms/step - loss: 0.0225 - my_iou_metric: 0.8774 - val_loss: 0.2774 - val_my_iou_metric: 0.7209
#
# Epoch 00030: val_my_iou_metric did not improve from 0.72388
# Epoch 00030: early stopping

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})

base_name = 'Unet_vgg_stage2_{}_{}'.format(batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.00001, verbose=1)
epochs = 200

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 126s 20ms/step - loss: -0.3402 - my_iou_metric_2: 0.7897 - val_loss: 0.3951 - val_my_iou_metric_2: 0.6824
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.68237, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.3731 - my_iou_metric_2: 0.7878 - val_loss: 0.2444 - val_my_iou_metric_2: 0.6849
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.68237 to 0.68488, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4258 - my_iou_metric_2: 0.7962 - val_loss: 0.4260 - val_my_iou_metric_2: 0.6808
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.68488
# Epoch 4/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4391 - my_iou_metric_2: 0.7959 - val_loss: 0.3513 - val_my_iou_metric_2: 0.6884
#
# Epoch 00004: val_my_iou_metric_2 improved from 0.68488 to 0.68837, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4447 - my_iou_metric_2: 0.7947 - val_loss: 0.4400 - val_my_iou_metric_2: 0.6649
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.68837
# Epoch 6/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4496 - my_iou_metric_2: 0.7965 - val_loss: 0.2286 - val_my_iou_metric_2: 0.6735
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.68837
# Epoch 7/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.4967 - my_iou_metric_2: 0.8027 - val_loss: 0.2787 - val_my_iou_metric_2: 0.6941
#
# Epoch 00007: val_my_iou_metric_2 improved from 0.68837 to 0.69412, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5288 - my_iou_metric_2: 0.8104 - val_loss: 0.3585 - val_my_iou_metric_2: 0.6856
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.69412
# Epoch 9/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5245 - my_iou_metric_2: 0.8093 - val_loss: 0.3141 - val_my_iou_metric_2: 0.6951
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.69412 to 0.69512, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5592 - my_iou_metric_2: 0.8137 - val_loss: 0.3715 - val_my_iou_metric_2: 0.6770
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.69512
# Epoch 11/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5676 - my_iou_metric_2: 0.8157 - val_loss: 0.3178 - val_my_iou_metric_2: 0.6944
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.69512
# Epoch 12/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5879 - my_iou_metric_2: 0.8181 - val_loss: 0.3003 - val_my_iou_metric_2: 0.6820
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.69512
# Epoch 13/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5862 - my_iou_metric_2: 0.8177 - val_loss: 0.3780 - val_my_iou_metric_2: 0.6967
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.69512 to 0.69675, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.5889 - my_iou_metric_2: 0.8174 - val_loss: 0.5039 - val_my_iou_metric_2: 0.6670
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.69675
# Epoch 15/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.5942 - my_iou_metric_2: 0.8179 - val_loss: 0.2883 - val_my_iou_metric_2: 0.6940
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.69675
# Epoch 16/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.6269 - my_iou_metric_2: 0.8250 - val_loss: 0.4389 - val_my_iou_metric_2: 0.6915
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.69675
# Epoch 17/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5881 - my_iou_metric_2: 0.8158 - val_loss: 0.4457 - val_my_iou_metric_2: 0.6903
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.69675
# Epoch 18/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.5989 - my_iou_metric_2: 0.8163 - val_loss: 0.5796 - val_my_iou_metric_2: 0.6805
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.69675
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 19/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.6485 - my_iou_metric_2: 0.8267 - val_loss: 0.3844 - val_my_iou_metric_2: 0.6911
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.69675
# Epoch 20/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.6730 - my_iou_metric_2: 0.8315 - val_loss: 0.3249 - val_my_iou_metric_2: 0.6990
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.69675 to 0.69900, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 21/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.6826 - my_iou_metric_2: 0.8330 - val_loss: 0.4545 - val_my_iou_metric_2: 0.6934
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.69900
# Epoch 22/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.6909 - my_iou_metric_2: 0.8341 - val_loss: 0.4482 - val_my_iou_metric_2: 0.6941
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.69900
# Epoch 23/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.6915 - my_iou_metric_2: 0.8347 - val_loss: 0.6082 - val_my_iou_metric_2: 0.6881
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.69900
# Epoch 24/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.6964 - my_iou_metric_2: 0.8361 - val_loss: 0.5008 - val_my_iou_metric_2: 0.6945
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.69900
# Epoch 25/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7000 - my_iou_metric_2: 0.8363 - val_loss: 0.4738 - val_my_iou_metric_2: 0.6984
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.69900
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 26/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7221 - my_iou_metric_2: 0.8389 - val_loss: 0.4564 - val_my_iou_metric_2: 0.6949
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.69900
# Epoch 27/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7299 - my_iou_metric_2: 0.8402 - val_loss: 0.4912 - val_my_iou_metric_2: 0.6994
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.69900 to 0.69938, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 28/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7335 - my_iou_metric_2: 0.8412 - val_loss: 0.5802 - val_my_iou_metric_2: 0.6901
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 29/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7352 - my_iou_metric_2: 0.8416 - val_loss: 0.5241 - val_my_iou_metric_2: 0.6929
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 30/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7404 - my_iou_metric_2: 0.8424 - val_loss: 0.5168 - val_my_iou_metric_2: 0.6989
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 31/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7402 - my_iou_metric_2: 0.8424 - val_loss: 0.5598 - val_my_iou_metric_2: 0.6944
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 32/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7443 - my_iou_metric_2: 0.8435 - val_loss: 0.5957 - val_my_iou_metric_2: 0.6964
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.69938
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 33/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7482 - my_iou_metric_2: 0.8440 - val_loss: 0.5401 - val_my_iou_metric_2: 0.6965
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 34/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7523 - my_iou_metric_2: 0.8443 - val_loss: 0.5434 - val_my_iou_metric_2: 0.6950
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 35/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7560 - my_iou_metric_2: 0.8449 - val_loss: 0.5782 - val_my_iou_metric_2: 0.6972
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 36/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7645 - my_iou_metric_2: 0.8454 - val_loss: 0.5989 - val_my_iou_metric_2: 0.6972
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 37/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7612 - my_iou_metric_2: 0.8455 - val_loss: 0.5953 - val_my_iou_metric_2: 0.6974
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.69938
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 38/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7644 - my_iou_metric_2: 0.8453 - val_loss: 0.5656 - val_my_iou_metric_2: 0.6972
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 39/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7659 - my_iou_metric_2: 0.8468 - val_loss: 0.5770 - val_my_iou_metric_2: 0.6977
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.69938
# Epoch 40/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7682 - my_iou_metric_2: 0.8458 - val_loss: 0.5673 - val_my_iou_metric_2: 0.6996
#
# Epoch 00040: val_my_iou_metric_2 improved from 0.69938 to 0.69963, saving model to ../model/Unet_vgg_stage2_32_0.5.model
# Epoch 41/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7655 - my_iou_metric_2: 0.8457 - val_loss: 0.5652 - val_my_iou_metric_2: 0.6985
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 42/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7662 - my_iou_metric_2: 0.8455 - val_loss: 0.5674 - val_my_iou_metric_2: 0.6981
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 43/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7716 - my_iou_metric_2: 0.8464 - val_loss: 0.5928 - val_my_iou_metric_2: 0.6969
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 44/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7675 - my_iou_metric_2: 0.8459 - val_loss: 0.5844 - val_my_iou_metric_2: 0.6980
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 45/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7708 - my_iou_metric_2: 0.8461 - val_loss: 0.5706 - val_my_iou_metric_2: 0.6996
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.69963
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 46/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7722 - my_iou_metric_2: 0.8477 - val_loss: 0.6043 - val_my_iou_metric_2: 0.6970
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 47/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7724 - my_iou_metric_2: 0.8472 - val_loss: 0.6025 - val_my_iou_metric_2: 0.6975
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 48/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7724 - my_iou_metric_2: 0.8466 - val_loss: 0.6167 - val_my_iou_metric_2: 0.6966
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 49/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7752 - my_iou_metric_2: 0.8461 - val_loss: 0.6135 - val_my_iou_metric_2: 0.6991
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 50/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7790 - my_iou_metric_2: 0.8478 - val_loss: 0.6282 - val_my_iou_metric_2: 0.6974
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.69963
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 51/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7734 - my_iou_metric_2: 0.8463 - val_loss: 0.6131 - val_my_iou_metric_2: 0.6966
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 52/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7755 - my_iou_metric_2: 0.8471 - val_loss: 0.6185 - val_my_iou_metric_2: 0.6964
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 53/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7776 - my_iou_metric_2: 0.8477 - val_loss: 0.6171 - val_my_iou_metric_2: 0.6959
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 54/200
# 6400/6400 [==============================] - 123s 19ms/step - loss: -0.7764 - my_iou_metric_2: 0.8476 - val_loss: 0.6339 - val_my_iou_metric_2: 0.6960
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 55/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7799 - my_iou_metric_2: 0.8476 - val_loss: 0.6318 - val_my_iou_metric_2: 0.6964
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.69963
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 56/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7775 - my_iou_metric_2: 0.8480 - val_loss: 0.6271 - val_my_iou_metric_2: 0.6965
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 57/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7774 - my_iou_metric_2: 0.8475 - val_loss: 0.6297 - val_my_iou_metric_2: 0.6960
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 58/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7797 - my_iou_metric_2: 0.8483 - val_loss: 0.6247 - val_my_iou_metric_2: 0.6964
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 59/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7785 - my_iou_metric_2: 0.8478 - val_loss: 0.6265 - val_my_iou_metric_2: 0.6973
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.69963
# Epoch 60/200
# 6400/6400 [==============================] - 122s 19ms/step - loss: -0.7777 - my_iou_metric_2: 0.8482 - val_loss: 0.6247 - val_my_iou_metric_2: 0.6956
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.69963
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 00060: early stopping

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.728875 0.728375 0.7275   0.72725  0.727    0.726625 0.726125 0.725375
#  0.725125 0.724625 0.7245   0.7245   0.724    0.723375 0.723375 0.72225
#  0.721625 0.721125 0.720875 0.72025  0.720875 0.721375 0.719875 0.71975
#  0.719125 0.71825  0.71775  0.718125 0.718    0.716375 0.716625]

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 3)

preds_test = predict_result(model,x_test,img_size_target)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f986c1bd14b8> in <module>()
# ----> 1 x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 3)
#       2
#       3 preds_test = predict_result(model,x_test,img_size_target)
#
# ValueError: cannot reshape array of size 183618000 into shape (128,128,3)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
