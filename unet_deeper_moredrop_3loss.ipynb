# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalAveragePooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer = Conv2D(1, (1,1), padding="same", activation='relu')(uconv1)
    
#     output_layer =  Activation('sigmoid')(output_layer_noActi)

    ga = GlobalAveragePooling2D()(convm)
    ga = Dropout(DropoutRatio)(ga)
    empty = Dense(256, kernel_initializer='he_uniform')(ga)
    empty = BatchActivate(empty)
    empty = Dropout(DropoutRatio)(empty)
    empty = Dense(64, kernel_initializer='he_uniform')(empty)
    empty = BatchActivate(empty)
    empty = Dropout(DropoutRatio)(empty)
    out_empty = Dense(1, activation='sigmoid', name='empty_out')(empty)
    
    final_out_noact = multiply([output_layer, out_empty])
    final_out_noact = BatchNormalization()(final_out_noact)
    final_out =  Activation('sigmoid', name = 'segment_out')(final_out_noact)
    
    return final_out, out_empty

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
train_df['empty'] = train_df['masks'].apply(lambda x: (x.max()!=0) * 1)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df['empty'].value_counts()
# Out:
# 1    2438
# 0    1562
# Name: empty, dtype: int64

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test, empty_train, empty_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
train_df['empty'].values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
empty_train = np.append(empty_train, empty_train, axis=0)
print(x_train.shape)
print(y_valid.shape)
print(empty_train.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)
# (6400,)

# %%
start_feature = 32
batch_size = 32
dropout = 0.5
base_name = 'Unet_resnet_3loss_moredrop_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)

# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer, out_empty = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, [output_layer, out_empty])

losses = {
    'empty_out' : 'binary_crossentropy',
    'segment_out': 'binary_crossentropy',
    #'final_out' : lovasz_loss,
}
lossWeights = {
    'empty_out' : 0.2,
    'segment_out':2,
    #'final_out' : 3,
}
c = optimizers.adam(lr = 0.01)
model1.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric])
# Out:
# ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# ../model/Unet_resnet_3loss_moredrop_32_32_0.5.csv

# %%
y_combine_rain = {
    'empty_out' : empty_train,
    'segment_out':y_train,
    #'final_out' : y_train,
}

y_combine_test = {
    'empty_out' : empty_test,
    'segment_out':y_valid,
    #'final_out' : y_valid,
}

epochs = 200

board = keras.callbacks.TensorBoard(log_dir='log/{}'.format(base_name),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric', mode = 'max',patience=12, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.00001, verbose=1)


history = model1.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 91s 14ms/step - loss: 1.1302 - segment_out_loss: 0.5005 - empty_out_loss: 0.6455 - segment_out_my_iou_metric: 0.3434 - empty_out_my_iou_metric: 0.6683 - val_loss: 1.4675 - val_segment_out_loss: 0.6026 - val_empty_out_loss: 1.3117 - val_segment_out_my_iou_metric: 0.3922 - val_empty_out_my_iou_metric: 0.4075
#
# Epoch 00001: val_segment_out_my_iou_metric improved from -inf to 0.39225, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.9031 - segment_out_loss: 0.3963 - empty_out_loss: 0.5524 - segment_out_my_iou_metric: 0.4735 - empty_out_my_iou_metric: 0.7492 - val_loss: 1.9381 - val_segment_out_loss: 0.6675 - val_empty_out_loss: 3.0148 - val_segment_out_my_iou_metric: 0.3850 - val_empty_out_my_iou_metric: 0.4213
#
# Epoch 00002: val_segment_out_my_iou_metric did not improve from 0.39225
# Epoch 3/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.7838 - segment_out_loss: 0.3409 - empty_out_loss: 0.5101 - segment_out_my_iou_metric: 0.5280 - empty_out_my_iou_metric: 0.7659 - val_loss: 1.1410 - val_segment_out_loss: 0.5124 - val_empty_out_loss: 0.5804 - val_segment_out_my_iou_metric: 0.2764 - val_empty_out_my_iou_metric: 0.7275
#
# Epoch 00003: val_segment_out_my_iou_metric did not improve from 0.39225
# Epoch 4/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.7261 - segment_out_loss: 0.3140 - empty_out_loss: 0.4901 - segment_out_my_iou_metric: 0.5545 - empty_out_my_iou_metric: 0.7628 - val_loss: 1.1938 - val_segment_out_loss: 0.4304 - val_empty_out_loss: 1.6652 - val_segment_out_my_iou_metric: 0.4960 - val_empty_out_my_iou_metric: 0.6550
#
# Epoch 00004: val_segment_out_my_iou_metric improved from 0.39225 to 0.49600, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 5/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.6784 - segment_out_loss: 0.2905 - empty_out_loss: 0.4870 - segment_out_my_iou_metric: 0.5749 - empty_out_my_iou_metric: 0.7592 - val_loss: 1.4171 - val_segment_out_loss: 0.5630 - val_empty_out_loss: 1.4557 - val_segment_out_my_iou_metric: 0.4044 - val_empty_out_my_iou_metric: 0.5813
#
# Epoch 00005: val_segment_out_my_iou_metric did not improve from 0.49600
# Epoch 6/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.6734 - segment_out_loss: 0.2889 - empty_out_loss: 0.4780 - segment_out_my_iou_metric: 0.5746 - empty_out_my_iou_metric: 0.7637 - val_loss: 1.8402 - val_segment_out_loss: 0.7554 - val_empty_out_loss: 1.6470 - val_segment_out_my_iou_metric: 0.3905 - val_empty_out_my_iou_metric: 0.5725
#
# Epoch 00006: val_segment_out_my_iou_metric did not improve from 0.49600
# Epoch 7/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.6289 - segment_out_loss: 0.2693 - empty_out_loss: 0.4512 - segment_out_my_iou_metric: 0.5921 - empty_out_my_iou_metric: 0.7767 - val_loss: 0.8337 - val_segment_out_loss: 0.3592 - val_empty_out_loss: 0.5769 - val_segment_out_my_iou_metric: 0.5799 - val_empty_out_my_iou_metric: 0.6750
#
# Epoch 00007: val_segment_out_my_iou_metric improved from 0.49600 to 0.57988, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.5882 - segment_out_loss: 0.2494 - empty_out_loss: 0.4467 - segment_out_my_iou_metric: 0.5998 - empty_out_my_iou_metric: 0.7717 - val_loss: 0.6591 - val_segment_out_loss: 0.2734 - val_empty_out_loss: 0.5612 - val_segment_out_my_iou_metric: 0.6394 - val_empty_out_my_iou_metric: 0.6262
#
# Epoch 00008: val_segment_out_my_iou_metric improved from 0.57988 to 0.63938, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.6052 - segment_out_loss: 0.2538 - empty_out_loss: 0.4885 - segment_out_my_iou_metric: 0.5946 - empty_out_my_iou_metric: 0.7223 - val_loss: 0.6578 - val_segment_out_loss: 0.2807 - val_empty_out_loss: 0.4816 - val_segment_out_my_iou_metric: 0.6010 - val_empty_out_my_iou_metric: 0.7475
#
# Epoch 00009: val_segment_out_my_iou_metric did not improve from 0.63938
# Epoch 10/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.5624 - segment_out_loss: 0.2376 - empty_out_loss: 0.4357 - segment_out_my_iou_metric: 0.6146 - empty_out_my_iou_metric: 0.7691 - val_loss: 0.6048 - val_segment_out_loss: 0.2552 - val_empty_out_loss: 0.4717 - val_segment_out_my_iou_metric: 0.6434 - val_empty_out_my_iou_metric: 0.7875
#
# Epoch 00010: val_segment_out_my_iou_metric improved from 0.63938 to 0.64337, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 11/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.5312 - segment_out_loss: 0.2230 - empty_out_loss: 0.4257 - segment_out_my_iou_metric: 0.6190 - empty_out_my_iou_metric: 0.7761 - val_loss: 0.5364 - val_segment_out_loss: 0.2235 - val_empty_out_loss: 0.4467 - val_segment_out_my_iou_metric: 0.6557 - val_empty_out_my_iou_metric: 0.7987
#
# Epoch 00011: val_segment_out_my_iou_metric improved from 0.64337 to 0.65575, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 12/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.5385 - segment_out_loss: 0.2264 - empty_out_loss: 0.4288 - segment_out_my_iou_metric: 0.6195 - empty_out_my_iou_metric: 0.7692 - val_loss: 0.6079 - val_segment_out_loss: 0.2558 - val_empty_out_loss: 0.4819 - val_segment_out_my_iou_metric: 0.6418 - val_empty_out_my_iou_metric: 0.6700
#
# Epoch 00012: val_segment_out_my_iou_metric did not improve from 0.65575
# Epoch 13/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.5081 - segment_out_loss: 0.2136 - empty_out_loss: 0.4047 - segment_out_my_iou_metric: 0.6463 - empty_out_my_iou_metric: 0.7939 - val_loss: 0.5158 - val_segment_out_loss: 0.2197 - val_empty_out_loss: 0.3822 - val_segment_out_my_iou_metric: 0.6809 - val_empty_out_my_iou_metric: 0.8413
#
# Epoch 00013: val_segment_out_my_iou_metric improved from 0.65575 to 0.68088, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 14/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4719 - segment_out_loss: 0.1982 - empty_out_loss: 0.3779 - segment_out_my_iou_metric: 0.6576 - empty_out_my_iou_metric: 0.8153 - val_loss: 0.7600 - val_segment_out_loss: 0.3275 - val_empty_out_loss: 0.5244 - val_segment_out_my_iou_metric: 0.5439 - val_empty_out_my_iou_metric: 0.7600
#
# Epoch 00014: val_segment_out_my_iou_metric did not improve from 0.68088
# Epoch 15/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4780 - segment_out_loss: 0.1992 - empty_out_loss: 0.3974 - segment_out_my_iou_metric: 0.6564 - empty_out_my_iou_metric: 0.8006 - val_loss: 0.5110 - val_segment_out_loss: 0.2135 - val_empty_out_loss: 0.4199 - val_segment_out_my_iou_metric: 0.6737 - val_empty_out_my_iou_metric: 0.8225
#
# Epoch 00015: val_segment_out_my_iou_metric did not improve from 0.68088
# Epoch 16/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4444 - segment_out_loss: 0.1850 - empty_out_loss: 0.3721 - segment_out_my_iou_metric: 0.6728 - empty_out_my_iou_metric: 0.8103 - val_loss: 0.4350 - val_segment_out_loss: 0.1829 - val_empty_out_loss: 0.3456 - val_segment_out_my_iou_metric: 0.7021 - val_empty_out_my_iou_metric: 0.8400
#
# Epoch 00016: val_segment_out_my_iou_metric improved from 0.68088 to 0.70213, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 17/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4548 - segment_out_loss: 0.1904 - empty_out_loss: 0.3696 - segment_out_my_iou_metric: 0.6755 - empty_out_my_iou_metric: 0.8223 - val_loss: 0.4903 - val_segment_out_loss: 0.2072 - val_empty_out_loss: 0.3792 - val_segment_out_my_iou_metric: 0.6769 - val_empty_out_my_iou_metric: 0.8337
#
# Epoch 00017: val_segment_out_my_iou_metric did not improve from 0.70213
# Epoch 18/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4243 - segment_out_loss: 0.1764 - empty_out_loss: 0.3575 - segment_out_my_iou_metric: 0.6940 - empty_out_my_iou_metric: 0.8334 - val_loss: 0.5731 - val_segment_out_loss: 0.2405 - val_empty_out_loss: 0.4603 - val_segment_out_my_iou_metric: 0.6796 - val_empty_out_my_iou_metric: 0.8187
#
# Epoch 00018: val_segment_out_my_iou_metric did not improve from 0.70213
# Epoch 19/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4121 - segment_out_loss: 0.1709 - empty_out_loss: 0.3509 - segment_out_my_iou_metric: 0.7030 - empty_out_my_iou_metric: 0.8283 - val_loss: 0.3950 - val_segment_out_loss: 0.1663 - val_empty_out_loss: 0.3121 - val_segment_out_my_iou_metric: 0.7264 - val_empty_out_my_iou_metric: 0.8475
#
# Epoch 00019: val_segment_out_my_iou_metric improved from 0.70213 to 0.72637, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 20/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4016 - segment_out_loss: 0.1674 - empty_out_loss: 0.3338 - segment_out_my_iou_metric: 0.7117 - empty_out_my_iou_metric: 0.8361 - val_loss: 0.5841 - val_segment_out_loss: 0.2513 - val_empty_out_loss: 0.4072 - val_segment_out_my_iou_metric: 0.6876 - val_empty_out_my_iou_metric: 0.8275
#
# Epoch 00020: val_segment_out_my_iou_metric did not improve from 0.72637
# Epoch 21/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.4003 - segment_out_loss: 0.1667 - empty_out_loss: 0.3347 - segment_out_my_iou_metric: 0.7142 - empty_out_my_iou_metric: 0.8444 - val_loss: 0.4695 - val_segment_out_loss: 0.1973 - val_empty_out_loss: 0.3748 - val_segment_out_my_iou_metric: 0.6971 - val_empty_out_my_iou_metric: 0.8387
#
# Epoch 00021: val_segment_out_my_iou_metric did not improve from 0.72637
# Epoch 22/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3947 - segment_out_loss: 0.1644 - empty_out_loss: 0.3294 - segment_out_my_iou_metric: 0.7223 - empty_out_my_iou_metric: 0.8464 - val_loss: 0.3804 - val_segment_out_loss: 0.1624 - val_empty_out_loss: 0.2784 - val_segment_out_my_iou_metric: 0.7215 - val_empty_out_my_iou_metric: 0.8650
#
# Epoch 00022: val_segment_out_my_iou_metric did not improve from 0.72637
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 23/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3588 - segment_out_loss: 0.1489 - empty_out_loss: 0.3048 - segment_out_my_iou_metric: 0.7364 - empty_out_my_iou_metric: 0.8550 - val_loss: 0.3439 - val_segment_out_loss: 0.1426 - val_empty_out_loss: 0.2933 - val_segment_out_my_iou_metric: 0.7390 - val_empty_out_my_iou_metric: 0.8475
#
# Epoch 00023: val_segment_out_my_iou_metric improved from 0.72637 to 0.73900, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3374 - segment_out_loss: 0.1390 - empty_out_loss: 0.2966 - segment_out_my_iou_metric: 0.7479 - empty_out_my_iou_metric: 0.8522 - val_loss: 0.3911 - val_segment_out_loss: 0.1628 - val_empty_out_loss: 0.3279 - val_segment_out_my_iou_metric: 0.7406 - val_empty_out_my_iou_metric: 0.8562
#
# Epoch 00024: val_segment_out_my_iou_metric improved from 0.73900 to 0.74062, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3309 - segment_out_loss: 0.1369 - empty_out_loss: 0.2851 - segment_out_my_iou_metric: 0.7479 - empty_out_my_iou_metric: 0.8614 - val_loss: 0.3333 - val_segment_out_loss: 0.1360 - val_empty_out_loss: 0.3067 - val_segment_out_my_iou_metric: 0.7616 - val_empty_out_my_iou_metric: 0.8800
#
# Epoch 00025: val_segment_out_my_iou_metric improved from 0.74062 to 0.76162, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 26/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3287 - segment_out_loss: 0.1357 - empty_out_loss: 0.2867 - segment_out_my_iou_metric: 0.7504 - empty_out_my_iou_metric: 0.8628 - val_loss: 0.3372 - val_segment_out_loss: 0.1383 - val_empty_out_loss: 0.3029 - val_segment_out_my_iou_metric: 0.7504 - val_empty_out_my_iou_metric: 0.8475
#
# Epoch 00026: val_segment_out_my_iou_metric did not improve from 0.76162
# Epoch 27/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3203 - segment_out_loss: 0.1316 - empty_out_loss: 0.2854 - segment_out_my_iou_metric: 0.7532 - empty_out_my_iou_metric: 0.8547 - val_loss: 0.3550 - val_segment_out_loss: 0.1470 - val_empty_out_loss: 0.3046 - val_segment_out_my_iou_metric: 0.7448 - val_empty_out_my_iou_metric: 0.8638
#
# Epoch 00027: val_segment_out_my_iou_metric did not improve from 0.76162
# Epoch 28/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.3141 - segment_out_loss: 0.1293 - empty_out_loss: 0.2773 - segment_out_my_iou_metric: 0.7614 - empty_out_my_iou_metric: 0.8739 - val_loss: 0.3517 - val_segment_out_loss: 0.1451 - val_empty_out_loss: 0.3069 - val_segment_out_my_iou_metric: 0.7517 - val_empty_out_my_iou_metric: 0.8363
#
# Epoch 00028: val_segment_out_my_iou_metric did not improve from 0.76162
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 29/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2906 - segment_out_loss: 0.1193 - empty_out_loss: 0.2597 - segment_out_my_iou_metric: 0.7699 - empty_out_my_iou_metric: 0.8794 - val_loss: 0.3339 - val_segment_out_loss: 0.1387 - val_empty_out_loss: 0.2828 - val_segment_out_my_iou_metric: 0.7583 - val_empty_out_my_iou_metric: 0.8688
#
# Epoch 00029: val_segment_out_my_iou_metric did not improve from 0.76162
# Epoch 30/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2780 - segment_out_loss: 0.1142 - empty_out_loss: 0.2477 - segment_out_my_iou_metric: 0.7744 - empty_out_my_iou_metric: 0.8913 - val_loss: 0.3589 - val_segment_out_loss: 0.1502 - val_empty_out_loss: 0.2928 - val_segment_out_my_iou_metric: 0.7586 - val_empty_out_my_iou_metric: 0.8612
#
# Epoch 00030: val_segment_out_my_iou_metric did not improve from 0.76162
# Epoch 31/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2775 - segment_out_loss: 0.1136 - empty_out_loss: 0.2516 - segment_out_my_iou_metric: 0.7755 - empty_out_my_iou_metric: 0.8892 - val_loss: 0.3176 - val_segment_out_loss: 0.1323 - val_empty_out_loss: 0.2645 - val_segment_out_my_iou_metric: 0.7675 - val_empty_out_my_iou_metric: 0.8875
#
# Epoch 00031: val_segment_out_my_iou_metric improved from 0.76162 to 0.76750, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2751 - segment_out_loss: 0.1130 - empty_out_loss: 0.2459 - segment_out_my_iou_metric: 0.7788 - empty_out_my_iou_metric: 0.8913 - val_loss: 0.3041 - val_segment_out_loss: 0.1249 - val_empty_out_loss: 0.2713 - val_segment_out_my_iou_metric: 0.7694 - val_empty_out_my_iou_metric: 0.8725
#
# Epoch 00032: val_segment_out_my_iou_metric improved from 0.76750 to 0.76938, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 33/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2706 - segment_out_loss: 0.1110 - empty_out_loss: 0.2435 - segment_out_my_iou_metric: 0.7784 - empty_out_my_iou_metric: 0.8972 - val_loss: 0.3205 - val_segment_out_loss: 0.1306 - val_empty_out_loss: 0.2962 - val_segment_out_my_iou_metric: 0.7734 - val_empty_out_my_iou_metric: 0.8700
#
# Epoch 00033: val_segment_out_my_iou_metric improved from 0.76938 to 0.77337, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 34/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2677 - segment_out_loss: 0.1087 - empty_out_loss: 0.2512 - segment_out_my_iou_metric: 0.7792 - empty_out_my_iou_metric: 0.8837 - val_loss: 0.3220 - val_segment_out_loss: 0.1346 - val_empty_out_loss: 0.2640 - val_segment_out_my_iou_metric: 0.7675 - val_empty_out_my_iou_metric: 0.8838
#
# Epoch 00034: val_segment_out_my_iou_metric did not improve from 0.77337
# Epoch 35/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2621 - segment_out_loss: 0.1077 - empty_out_loss: 0.2335 - segment_out_my_iou_metric: 0.7838 - empty_out_my_iou_metric: 0.8942 - val_loss: 0.3026 - val_segment_out_loss: 0.1266 - val_empty_out_loss: 0.2469 - val_segment_out_my_iou_metric: 0.7806 - val_empty_out_my_iou_metric: 0.8938
#
# Epoch 00035: val_segment_out_my_iou_metric improved from 0.77337 to 0.78063, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 36/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2617 - segment_out_loss: 0.1064 - empty_out_loss: 0.2442 - segment_out_my_iou_metric: 0.7829 - empty_out_my_iou_metric: 0.8866 - val_loss: 0.3008 - val_segment_out_loss: 0.1247 - val_empty_out_loss: 0.2572 - val_segment_out_my_iou_metric: 0.7794 - val_empty_out_my_iou_metric: 0.8788
#
# Epoch 00036: val_segment_out_my_iou_metric did not improve from 0.78063
# Epoch 37/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2654 - segment_out_loss: 0.1083 - empty_out_loss: 0.2446 - segment_out_my_iou_metric: 0.7833 - empty_out_my_iou_metric: 0.8856 - val_loss: 0.2953 - val_segment_out_loss: 0.1216 - val_empty_out_loss: 0.2599 - val_segment_out_my_iou_metric: 0.7762 - val_empty_out_my_iou_metric: 0.8838
#
# Epoch 00037: val_segment_out_my_iou_metric did not improve from 0.78063
# Epoch 38/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2515 - segment_out_loss: 0.1026 - empty_out_loss: 0.2311 - segment_out_my_iou_metric: 0.7895 - empty_out_my_iou_metric: 0.8978 - val_loss: 0.3244 - val_segment_out_loss: 0.1318 - val_empty_out_loss: 0.3044 - val_segment_out_my_iou_metric: 0.7781 - val_empty_out_my_iou_metric: 0.8750
#
# Epoch 00038: val_segment_out_my_iou_metric did not improve from 0.78063
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 39/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2299 - segment_out_loss: 0.0942 - empty_out_loss: 0.2072 - segment_out_my_iou_metric: 0.7994 - empty_out_my_iou_metric: 0.9089 - val_loss: 0.3069 - val_segment_out_loss: 0.1254 - val_empty_out_loss: 0.2805 - val_segment_out_my_iou_metric: 0.7853 - val_empty_out_my_iou_metric: 0.8825
#
# Epoch 00039: val_segment_out_my_iou_metric improved from 0.78063 to 0.78525, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 40/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2253 - segment_out_loss: 0.0918 - empty_out_loss: 0.2092 - segment_out_my_iou_metric: 0.7990 - empty_out_my_iou_metric: 0.9047 - val_loss: 0.2779 - val_segment_out_loss: 0.1158 - val_empty_out_loss: 0.2314 - val_segment_out_my_iou_metric: 0.7944 - val_empty_out_my_iou_metric: 0.8888
#
# Epoch 00040: val_segment_out_my_iou_metric improved from 0.78525 to 0.79437, saving model to ../model/Unet_resnet_3loss_moredrop_32_32_0.5.model
# Epoch 41/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2268 - segment_out_loss: 0.0923 - empty_out_loss: 0.2114 - segment_out_my_iou_metric: 0.7996 - empty_out_my_iou_metric: 0.9103 - val_loss: 0.2908 - val_segment_out_loss: 0.1199 - val_empty_out_loss: 0.2546 - val_segment_out_my_iou_metric: 0.7941 - val_empty_out_my_iou_metric: 0.8862
#
# Epoch 00041: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 42/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2113 - segment_out_loss: 0.0853 - empty_out_loss: 0.2032 - segment_out_my_iou_metric: 0.8047 - empty_out_my_iou_metric: 0.9180 - val_loss: 0.3112 - val_segment_out_loss: 0.1289 - val_empty_out_loss: 0.2673 - val_segment_out_my_iou_metric: 0.7828 - val_empty_out_my_iou_metric: 0.8788
#
# Epoch 00042: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 43/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2197 - segment_out_loss: 0.0887 - empty_out_loss: 0.2121 - segment_out_my_iou_metric: 0.8016 - empty_out_my_iou_metric: 0.9089 - val_loss: 0.2968 - val_segment_out_loss: 0.1237 - val_empty_out_loss: 0.2471 - val_segment_out_my_iou_metric: 0.7811 - val_empty_out_my_iou_metric: 0.8800
#
# Epoch 00043: val_segment_out_my_iou_metric did not improve from 0.79437
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 44/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2036 - segment_out_loss: 0.0819 - empty_out_loss: 0.1996 - segment_out_my_iou_metric: 0.8092 - empty_out_my_iou_metric: 0.9164 - val_loss: 0.2878 - val_segment_out_loss: 0.1195 - val_empty_out_loss: 0.2443 - val_segment_out_my_iou_metric: 0.7899 - val_empty_out_my_iou_metric: 0.8800
#
# Epoch 00044: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 45/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.2012 - segment_out_loss: 0.0811 - empty_out_loss: 0.1947 - segment_out_my_iou_metric: 0.8108 - empty_out_my_iou_metric: 0.9163 - val_loss: 0.3055 - val_segment_out_loss: 0.1286 - val_empty_out_loss: 0.2420 - val_segment_out_my_iou_metric: 0.7929 - val_empty_out_my_iou_metric: 0.8838
#
# Epoch 00045: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 46/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1976 - segment_out_loss: 0.0796 - empty_out_loss: 0.1918 - segment_out_my_iou_metric: 0.8114 - empty_out_my_iou_metric: 0.9189 - val_loss: 0.3390 - val_segment_out_loss: 0.1398 - val_empty_out_loss: 0.2969 - val_segment_out_my_iou_metric: 0.7896 - val_empty_out_my_iou_metric: 0.8762
#
# Epoch 00046: val_segment_out_my_iou_metric did not improve from 0.79437
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 47/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1950 - segment_out_loss: 0.0790 - empty_out_loss: 0.1847 - segment_out_my_iou_metric: 0.8123 - empty_out_my_iou_metric: 0.9216 - val_loss: 0.3118 - val_segment_out_loss: 0.1312 - val_empty_out_loss: 0.2468 - val_segment_out_my_iou_metric: 0.7909 - val_empty_out_my_iou_metric: 0.8838
#
# Epoch 00047: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 48/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1976 - segment_out_loss: 0.0802 - empty_out_loss: 0.1858 - segment_out_my_iou_metric: 0.8108 - empty_out_my_iou_metric: 0.9208 - val_loss: 0.3110 - val_segment_out_loss: 0.1306 - val_empty_out_loss: 0.2487 - val_segment_out_my_iou_metric: 0.7889 - val_empty_out_my_iou_metric: 0.8800
#
# Epoch 00048: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 49/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1873 - segment_out_loss: 0.0759 - empty_out_loss: 0.1774 - segment_out_my_iou_metric: 0.8156 - empty_out_my_iou_metric: 0.9303 - val_loss: 0.3129 - val_segment_out_loss: 0.1319 - val_empty_out_loss: 0.2453 - val_segment_out_my_iou_metric: 0.7899 - val_empty_out_my_iou_metric: 0.8812
#
# Epoch 00049: val_segment_out_my_iou_metric did not improve from 0.79437
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 50/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1919 - segment_out_loss: 0.0776 - empty_out_loss: 0.1833 - segment_out_my_iou_metric: 0.8127 - empty_out_my_iou_metric: 0.9209 - val_loss: 0.3130 - val_segment_out_loss: 0.1318 - val_empty_out_loss: 0.2468 - val_segment_out_my_iou_metric: 0.7921 - val_empty_out_my_iou_metric: 0.8838
#
# Epoch 00050: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 51/200
# 6400/6400 [==============================] - 79s 12ms/step - loss: 0.1896 - segment_out_loss: 0.0769 - empty_out_loss: 0.1792 - segment_out_my_iou_metric: 0.8184 - empty_out_my_iou_metric: 0.9284 - val_loss: 0.3229 - val_segment_out_loss: 0.1352 - val_empty_out_loss: 0.2627 - val_segment_out_my_iou_metric: 0.7875 - val_empty_out_my_iou_metric: 0.8825
#
# Epoch 00051: val_segment_out_my_iou_metric did not improve from 0.79437
# Epoch 52/200
# 6400/6400 [==============================] - 78s 12ms/step - loss: 0.1882 - segment_out_loss: 0.0764 - empty_out_loss: 0.1767 - segment_out_my_iou_metric: 0.8146 - empty_out_my_iou_metric: 0.9238 - val_loss: 0.3285 - val_segment_out_loss: 0.1384 - val_empty_out_loss: 0.2584 - val_segment_out_my_iou_metric: 0.7885 - val_empty_out_my_iou_metric: 0.8788
#
# Epoch 00052: val_segment_out_my_iou_metric did not improve from 0.79437
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 00052: early stopping

# %%
base_name = 'Unet_resnet_3loss_moredrop_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'

model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})

# %%
base_name = 'Unet_resnet_3loss_moredrop_stage2_{}_{}_{}'.format(start_feature, batch_size, dropout)
basic_name = '../model/{}'.format(base_name)
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

input_x = model1.layers[0].input
model1.layers[-1].name = 'segment_out_old'

output_layer = model1.layers[-2]
output_layer.name = 'segment_out'
output_layer = output_layer.output

empty_out = model1.get_layer("empty_out").output
model = Model(input_x, [output_layer, empty_out])
c = optimizers.adam(lr = 0.01)

losses = {
    'empty_out' : 'binary_crossentropy',
    'segment_out': lovasz_loss,
    #'final_out' : lovasz_loss,
}
lossWeights = {
    'empty_out' : 0.2,
    'segment_out':2,
    #'final_out' : 3,
}
model.compile(loss=losses, loss_weights=lossWeights, optimizer=c, metrics=[my_iou_metric_2])

early_stopping = EarlyStopping(monitor='val_segment_out_my_iou_metric_2', mode = 'max',patience=16, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_segment_out_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_segment_out_my_iou_metric_2', mode = 'max',factor=0.5, patience=4, min_lr=0.00001, verbose=1)


history = model.fit(x_train, y_combine_rain,
                    validation_data=[x_valid, y_combine_test], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 137s 21ms/step - loss: -0.0599 - segment_out_loss: -0.0579 - empty_out_loss: 0.2798 - segment_out_my_iou_metric_2: 0.7670 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.0570 - val_segment_out_loss: -0.0523 - val_empty_out_loss: 0.2382 - val_segment_out_my_iou_metric_2: 0.7726 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00001: val_segment_out_my_iou_metric_2 improved from -inf to 0.77262, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.1228 - segment_out_loss: -0.0885 - empty_out_loss: 0.2713 - segment_out_my_iou_metric_2: 0.7743 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.0515 - val_segment_out_loss: 7.5910e-04 - val_empty_out_loss: 0.2499 - val_segment_out_my_iou_metric_2: 0.7585 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00002: val_segment_out_my_iou_metric_2 did not improve from 0.77262
# Epoch 3/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.1553 - segment_out_loss: -0.1043 - empty_out_loss: 0.2669 - segment_out_my_iou_metric_2: 0.7753 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.1466 - val_segment_out_loss: 0.0325 - val_empty_out_loss: 0.4081 - val_segment_out_my_iou_metric_2: 0.7659 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00003: val_segment_out_my_iou_metric_2 did not improve from 0.77262
# Epoch 4/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.2087 - segment_out_loss: -0.1301 - empty_out_loss: 0.2578 - segment_out_my_iou_metric_2: 0.7753 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1339 - val_segment_out_loss: -0.0942 - val_empty_out_loss: 0.2724 - val_segment_out_my_iou_metric_2: 0.7640 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00004: val_segment_out_my_iou_metric_2 did not improve from 0.77262
# Epoch 5/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.2459 - segment_out_loss: -0.1480 - empty_out_loss: 0.2509 - segment_out_my_iou_metric_2: 0.7815 - empty_out_my_iou_metric_2: 0.6094 - val_loss: 0.9217 - val_segment_out_loss: 0.4083 - val_empty_out_loss: 0.5252 - val_segment_out_my_iou_metric_2: 0.7076 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00005: val_segment_out_my_iou_metric_2 did not improve from 0.77262
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 6/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.3831 - segment_out_loss: -0.2148 - empty_out_loss: 0.2323 - segment_out_my_iou_metric_2: 0.7983 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1501 - val_segment_out_loss: -0.1003 - val_empty_out_loss: 0.2529 - val_segment_out_my_iou_metric_2: 0.7866 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00006: val_segment_out_my_iou_metric_2 improved from 0.77262 to 0.78662, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 7/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.4426 - segment_out_loss: -0.2426 - empty_out_loss: 0.2133 - segment_out_my_iou_metric_2: 0.8037 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1470 - val_segment_out_loss: -0.1086 - val_empty_out_loss: 0.3515 - val_segment_out_my_iou_metric_2: 0.7996 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00007: val_segment_out_my_iou_metric_2 improved from 0.78662 to 0.79962, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 8/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.4791 - segment_out_loss: -0.2607 - empty_out_loss: 0.2115 - segment_out_my_iou_metric_2: 0.8066 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3134 - val_segment_out_loss: -0.1810 - val_empty_out_loss: 0.2433 - val_segment_out_my_iou_metric_2: 0.7904 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00008: val_segment_out_my_iou_metric_2 did not improve from 0.79962
# Epoch 9/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.4957 - segment_out_loss: -0.2684 - empty_out_loss: 0.2052 - segment_out_my_iou_metric_2: 0.8107 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3127 - val_segment_out_loss: -0.1802 - val_empty_out_loss: 0.2386 - val_segment_out_my_iou_metric_2: 0.7943 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00009: val_segment_out_my_iou_metric_2 did not improve from 0.79962
# Epoch 10/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.5354 - segment_out_loss: -0.2878 - empty_out_loss: 0.2006 - segment_out_my_iou_metric_2: 0.8140 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2944 - val_segment_out_loss: -0.1728 - val_empty_out_loss: 0.2560 - val_segment_out_my_iou_metric_2: 0.7844 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00010: val_segment_out_my_iou_metric_2 did not improve from 0.79962
# Epoch 11/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.5564 - segment_out_loss: -0.2977 - empty_out_loss: 0.1953 - segment_out_my_iou_metric_2: 0.8136 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.1866 - val_segment_out_loss: -0.1200 - val_empty_out_loss: 0.2675 - val_segment_out_my_iou_metric_2: 0.7919 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00011: val_segment_out_my_iou_metric_2 did not improve from 0.79962
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 12/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.6479 - segment_out_loss: -0.3422 - empty_out_loss: 0.1825 - segment_out_my_iou_metric_2: 0.8252 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3378 - val_segment_out_loss: -0.1937 - val_empty_out_loss: 0.2476 - val_segment_out_my_iou_metric_2: 0.8099 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00012: val_segment_out_my_iou_metric_2 improved from 0.79962 to 0.80988, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.6989 - segment_out_loss: -0.3654 - empty_out_loss: 0.1592 - segment_out_my_iou_metric_2: 0.8300 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3026 - val_segment_out_loss: -0.1751 - val_empty_out_loss: 0.2386 - val_segment_out_my_iou_metric_2: 0.8034 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00013: val_segment_out_my_iou_metric_2 did not improve from 0.80988
# Epoch 14/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.6955 - segment_out_loss: -0.3647 - empty_out_loss: 0.1698 - segment_out_my_iou_metric_2: 0.8280 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2364 - val_segment_out_loss: -0.1447 - val_empty_out_loss: 0.2648 - val_segment_out_my_iou_metric_2: 0.7986 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00014: val_segment_out_my_iou_metric_2 did not improve from 0.80988
# Epoch 15/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.7052 - segment_out_loss: -0.3689 - empty_out_loss: 0.1631 - segment_out_my_iou_metric_2: 0.8301 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3344 - val_segment_out_loss: -0.1893 - val_empty_out_loss: 0.2208 - val_segment_out_my_iou_metric_2: 0.8026 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00015: val_segment_out_my_iou_metric_2 did not improve from 0.80988
# Epoch 16/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.7282 - segment_out_loss: -0.3806 - empty_out_loss: 0.1653 - segment_out_my_iou_metric_2: 0.8336 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2268 - val_segment_out_loss: -0.1457 - val_empty_out_loss: 0.3230 - val_segment_out_my_iou_metric_2: 0.8086 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00016: val_segment_out_my_iou_metric_2 did not improve from 0.80988
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 17/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.7820 - segment_out_loss: -0.4060 - empty_out_loss: 0.1499 - segment_out_my_iou_metric_2: 0.8376 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3384 - val_segment_out_loss: -0.1970 - val_empty_out_loss: 0.2780 - val_segment_out_my_iou_metric_2: 0.8053 - val_empty_out_my_iou_metric_2: 0.6100
# Epoch 00017: val_segment_out_my_iou_metric_2 did not improve from 0.80988
# Epoch 18/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8053 - segment_out_loss: -0.4168 - empty_out_loss: 0.1421 - segment_out_my_iou_metric_2: 0.8423 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3784 - val_segment_out_loss: -0.2138 - val_empty_out_loss: 0.2462 - val_segment_out_my_iou_metric_2: 0.8120 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00018: val_segment_out_my_iou_metric_2 improved from 0.80988 to 0.81200, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 19/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8070 - segment_out_loss: -0.4181 - empty_out_loss: 0.1462 - segment_out_my_iou_metric_2: 0.8408 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3002 - val_segment_out_loss: -0.1788 - val_empty_out_loss: 0.2876 - val_segment_out_my_iou_metric_2: 0.8107 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00019: val_segment_out_my_iou_metric_2 did not improve from 0.81200
# Epoch 20/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8282 - segment_out_loss: -0.4280 - empty_out_loss: 0.1387 - segment_out_my_iou_metric_2: 0.8419 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3089 - val_segment_out_loss: -0.1810 - val_empty_out_loss: 0.2652 - val_segment_out_my_iou_metric_2: 0.8061 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00020: val_segment_out_my_iou_metric_2 did not improve from 0.81200
# Epoch 21/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8341 - segment_out_loss: -0.4302 - empty_out_loss: 0.1315 - segment_out_my_iou_metric_2: 0.8429 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3347 - val_segment_out_loss: -0.1929 - val_empty_out_loss: 0.2556 - val_segment_out_my_iou_metric_2: 0.8133 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00021: val_segment_out_my_iou_metric_2 improved from 0.81200 to 0.81325, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8389 - segment_out_loss: -0.4328 - empty_out_loss: 0.1337 - segment_out_my_iou_metric_2: 0.8441 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3033 - val_segment_out_loss: -0.1799 - val_empty_out_loss: 0.2822 - val_segment_out_my_iou_metric_2: 0.8054 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00022: val_segment_out_my_iou_metric_2 did not improve from 0.81325
# Epoch 23/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8650 - segment_out_loss: -0.4450 - empty_out_loss: 0.1253 - segment_out_my_iou_metric_2: 0.8462 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2645 - val_segment_out_loss: -0.1603 - val_empty_out_loss: 0.2804 - val_segment_out_my_iou_metric_2: 0.8036 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00023: val_segment_out_my_iou_metric_2 did not improve from 0.81325
# Epoch 24/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8795 - segment_out_loss: -0.4524 - empty_out_loss: 0.1261 - segment_out_my_iou_metric_2: 0.8495 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3030 - val_segment_out_loss: -0.1783 - val_empty_out_loss: 0.2679 - val_segment_out_my_iou_metric_2: 0.8144 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00024: val_segment_out_my_iou_metric_2 improved from 0.81325 to 0.81437, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 25/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8628 - segment_out_loss: -0.4442 - empty_out_loss: 0.1281 - segment_out_my_iou_metric_2: 0.8481 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3367 - val_segment_out_loss: -0.1973 - val_empty_out_loss: 0.2890 - val_segment_out_my_iou_metric_2: 0.8121 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00025: val_segment_out_my_iou_metric_2 did not improve from 0.81437
# Epoch 26/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.8991 - segment_out_loss: -0.4619 - empty_out_loss: 0.1228 - segment_out_my_iou_metric_2: 0.8501 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2637 - val_segment_out_loss: -0.1583 - val_empty_out_loss: 0.2647 - val_segment_out_my_iou_metric_2: 0.8074 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00026: val_segment_out_my_iou_metric_2 did not improve from 0.81437
# Epoch 27/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.9012 - segment_out_loss: -0.4628 - empty_out_loss: 0.1216 - segment_out_my_iou_metric_2: 0.8495 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2982 - val_segment_out_loss: -0.1768 - val_empty_out_loss: 0.2775 - val_segment_out_my_iou_metric_2: 0.8112 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00027: val_segment_out_my_iou_metric_2 did not improve from 0.81437
# Epoch 28/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.9051 - segment_out_loss: -0.4650 - empty_out_loss: 0.1244 - segment_out_my_iou_metric_2: 0.8476 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3070 - val_segment_out_loss: -0.1816 - val_empty_out_loss: 0.2817 - val_segment_out_my_iou_metric_2: 0.8146 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00028: val_segment_out_my_iou_metric_2 improved from 0.81437 to 0.81463, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 29/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.9201 - segment_out_loss: -0.4713 - empty_out_loss: 0.1119 - segment_out_my_iou_metric_2: 0.8514 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2056 - val_segment_out_loss: -0.1321 - val_empty_out_loss: 0.2934 - val_segment_out_my_iou_metric_2: 0.8070 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00029: val_segment_out_my_iou_metric_2 did not improve from 0.81463
# Epoch 30/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.9291 - segment_out_loss: -0.4765 - empty_out_loss: 0.1194 - segment_out_my_iou_metric_2: 0.8523 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2882 - val_segment_out_loss: -0.1705 - val_empty_out_loss: 0.2646 - val_segment_out_my_iou_metric_2: 0.8094 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00030: val_segment_out_my_iou_metric_2 did not improve from 0.81463
# Epoch 31/200
# 6400/6400 [==============================] - 124s 19ms/step - loss: -0.9383 - segment_out_loss: -0.4804 - empty_out_loss: 0.1129 - segment_out_my_iou_metric_2: 0.8549 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2505 - val_segment_out_loss: -0.1545 - val_empty_out_loss: 0.2924 - val_segment_out_my_iou_metric_2: 0.8190 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00031: val_segment_out_my_iou_metric_2 improved from 0.81463 to 0.81900, saving model to ../model/Unet_resnet_3loss_moredrop_stage2_32_32_0.5.model
# Epoch 32/200
# 6400/6400 [==============================] - 125s 19ms/step - loss: -0.9159 - segment_out_loss: -0.4699 - empty_out_loss: 0.1193 - segment_out_my_iou_metric_2: 0.8512 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.3182 - val_segment_out_loss: -0.1860 - val_empty_out_loss: 0.2687 - val_segment_out_my_iou_metric_2: 0.8151 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00032: val_segment_out_my_iou_metric_2 did not improve from 0.81900
# Epoch 33/200
# 6400/6400 [==============================] - 125s 19ms/step - loss: -0.9599 - segment_out_loss: -0.4902 - empty_out_loss: 0.1021 - segment_out_my_iou_metric_2: 0.8532 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2892 - val_segment_out_loss: -0.1727 - val_empty_out_loss: 0.2808 - val_segment_out_my_iou_metric_2: 0.8143 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00033: val_segment_out_my_iou_metric_2 did not improve from 0.81900
# Epoch 34/200
# 6400/6400 [==============================] - 125s 20ms/step - loss: -0.9434 - segment_out_loss: -0.4832 - empty_out_loss: 0.1145 - segment_out_my_iou_metric_2: 0.8559 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2470 - val_segment_out_loss: -0.1515 - val_empty_out_loss: 0.2801 - val_segment_out_my_iou_metric_2: 0.8083 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00034: val_segment_out_my_iou_metric_2 did not improve from 0.81900
# Epoch 35/200
# 6400/6400 [==============================] - 125s 19ms/step - loss: -0.9520 - segment_out_loss: -0.4873 - empty_out_loss: 0.1126 - segment_out_my_iou_metric_2: 0.8554 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2352 - val_segment_out_loss: -0.1465 - val_empty_out_loss: 0.2891 - val_segment_out_my_iou_metric_2: 0.8096 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00035: val_segment_out_my_iou_metric_2 did not improve from 0.81900
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 36/200
# 6400/6400 [==============================] - 125s 20ms/step - loss: -0.9968 - segment_out_loss: -0.5081 - empty_out_loss: 0.0973 - segment_out_my_iou_metric_2: 0.8590 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2801 - val_segment_out_loss: -0.1680 - val_empty_out_loss: 0.2794 - val_segment_out_my_iou_metric_2: 0.8123 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00036: val_segment_out_my_iou_metric_2 did not improve from 0.81900
# Epoch 37/200
# 6400/6400 [==============================] - 125s 19ms/step - loss: -1.0054 - segment_out_loss: -0.5121 - empty_out_loss: 0.0937 - segment_out_my_iou_metric_2: 0.8617 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2734 - val_segment_out_loss: -0.1670 - val_empty_out_loss: 0.3028 - val_segment_out_my_iou_metric_2: 0.8124 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00037: val_segment_out_my_iou_metric_2 did not improve from 0.81900
# Epoch 38/200
# 6400/6400 [==============================] - 125s 19ms/step - loss: -1.0140 - segment_out_loss: -0.5162 - empty_out_loss: 0.0917 - segment_out_my_iou_metric_2: 0.8592 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2813 - val_segment_out_loss: -0.1678 - val_empty_out_loss: 0.2720 - val_segment_out_my_iou_metric_2: 0.8120 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00038: val_segment_out_my_iou_metric_2 did not improve from 0.81900
# Epoch 39/200
# 6400/6400 [==============================] - 125s 19ms/step - loss: -1.0003 - segment_out_loss: -0.5098 - empty_out_loss: 0.0963 - segment_out_my_iou_metric_2: 0.8595 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2920 - val_segment_out_loss: -0.1729 - val_empty_out_loss: 0.2685 - val_segment_out_my_iou_metric_2: 0.8110 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00039: val_segment_out_my_iou_metric_2 did not improve from 0.81900
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 40/200
# 6400/6400 [==============================] - 125s 19ms/step - loss: -1.0252 - segment_out_loss: -0.5219 - empty_out_loss: 0.0926 - segment_out_my_iou_metric_2: 0.8616 - empty_out_my_iou_metric_2: 0.6094 - val_loss: -0.2673 - val_segment_out_loss: -0.1624 - val_empty_out_loss: 0.2877 - val_segment_out_my_iou_metric_2: 0.8110 - val_empty_out_my_iou_metric_2: 0.6100
#
# Epoch 00040: val_segment_out_my_iou_metric_2 did not improve from 0.81900
# Epoch 41/200
# 3392/6400 [==============>...............] - ETA: 55s - loss: -1.0042 - segment_out_loss: -0.5123 - empty_out_loss: 0.1016 - segment_out_my_iou_metric_2: 0.8564 - empty_out_my_iou_metric_2: 0.6058

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/{}.csv'.format(base_name), 
                        competition = 'tgs-salt-identification-challenge', 
                        send = True, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
