# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import keras
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
from kaggle_util import *
from models import *

t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)


# Build model

def build_model_deeper(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1)
    conv1 = residual_block_cSE(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2)
    conv2 = residual_block_cSE(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4)
    conv3 = residual_block_cSE(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8)
    conv4 = residual_block_cSE(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16)
    convm = residual_block_cSE(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8)
    uconv4 = residual_block_cSE(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4)
    uconv3 = residual_block_cSE(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2)
    uconv2 = residual_block_cSE(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1)
    uconv1 = residual_block_cSE(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../input/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../input/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)

train_df["images"] = [np.array(load_img("../input/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("../input/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kownse/.local/lib/python3.6/site-packages/keras_preprocessing/image.py:487: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df['z'] = (train_df['z'] - train_df['z'].min()) / (train_df['z'].max() - train_df['z'].min())

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
train_df.index.values,
np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target), 
np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
train_df.coverage.values,
train_df.z.values,
test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
depth_train = np.append(depth_train, depth_train)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101)
# (800, 101, 101, 1)

# %%
depth_test[:10]
# Out:
# array([0.70594714, 0.27863436, 0.91519824, 0.46365639, 0.35792952,
#        0.38325991, 0.11894273, 0.90748899, 0.81828194, 0.69052863])

# %%
x_train = add_depth_bulk_act(x_train, depth_train)
x_valid = add_depth_bulk_act(x_valid, depth_test)
# Out:
# HBox(children=(IntProgress(value=0, max=6400), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=800), HTML(value='')))

# %%
start_feature = 32
dropout = 0.5
basic_name = '../model/Unet_resnet_depth_cse_{}_{}'.format(start_feature, dropout)
save_model_name = basic_name + '_stage1.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# ../model/Unet_resnet_depth_cse_32_0.5.csv

# %%
# model
input_layer = Input((img_size_target, img_size_target, 3))
output_layer = build_model_deeper(input_layer, start_feature,dropout)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

board = keras.callbacks.TensorBoard(log_dir='log/resunet_depth_cse_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=15, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',factor=0.5, patience=4, min_lr=0.000001, verbose=1)

epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, early_stopping, model_checkpoint,reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 101s 16ms/step - loss: 0.5209 - my_iou_metric: 0.3391 - val_loss: 7.9470 - val_my_iou_metric: 0.2000
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.20000, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 2/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.3948 - my_iou_metric: 0.4287 - val_loss: 2.6345 - val_my_iou_metric: 0.3132
#
# Epoch 00002: val_my_iou_metric improved from 0.20000 to 0.31325, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 3/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.3566 - my_iou_metric: 0.4786 - val_loss: 1.2123 - val_my_iou_metric: 0.3900
#
# Epoch 00003: val_my_iou_metric improved from 0.31325 to 0.39000, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 4/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.3301 - my_iou_metric: 0.4987 - val_loss: 0.9634 - val_my_iou_metric: 0.3816
#
# Epoch 00004: val_my_iou_metric did not improve from 0.39000
# Epoch 5/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.3079 - my_iou_metric: 0.5090 - val_loss: 0.8138 - val_my_iou_metric: 0.3879
#
# Epoch 00005: val_my_iou_metric did not improve from 0.39000
# Epoch 6/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.2799 - my_iou_metric: 0.5463 - val_loss: 0.5001 - val_my_iou_metric: 0.4244
#
# Epoch 00006: val_my_iou_metric improved from 0.39000 to 0.42438, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 7/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.2535 - my_iou_metric: 0.5767 - val_loss: 0.2691 - val_my_iou_metric: 0.6041
#
# Epoch 00007: val_my_iou_metric improved from 0.42438 to 0.60413, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 8/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.2365 - my_iou_metric: 0.5964 - val_loss: 0.2566 - val_my_iou_metric: 0.5805
#
# Epoch 00008: val_my_iou_metric did not improve from 0.60413
# Epoch 9/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.2182 - my_iou_metric: 0.6163 - val_loss: 0.2457 - val_my_iou_metric: 0.6158
#
# Epoch 00009: val_my_iou_metric improved from 0.60413 to 0.61575, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 10/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.2104 - my_iou_metric: 0.6332 - val_loss: 0.2327 - val_my_iou_metric: 0.6474
#
# Epoch 00010: val_my_iou_metric improved from 0.61575 to 0.64737, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 11/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1980 - my_iou_metric: 0.6468 - val_loss: 0.2009 - val_my_iou_metric: 0.6656
#
# Epoch 00011: val_my_iou_metric improved from 0.64737 to 0.66563, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 12/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1847 - my_iou_metric: 0.6634 - val_loss: 0.2045 - val_my_iou_metric: 0.6624
#
# Epoch 00012: val_my_iou_metric did not improve from 0.66563
# Epoch 13/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1731 - my_iou_metric: 0.6723 - val_loss: 0.2246 - val_my_iou_metric: 0.6383
#
# Epoch 00013: val_my_iou_metric did not improve from 0.66563
# Epoch 14/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1754 - my_iou_metric: 0.6764 - val_loss: 0.2186 - val_my_iou_metric: 0.6765
#
# Epoch 00014: val_my_iou_metric improved from 0.66563 to 0.67650, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 15/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1732 - my_iou_metric: 0.6796 - val_loss: 0.1905 - val_my_iou_metric: 0.6731
#
# Epoch 00015: val_my_iou_metric did not improve from 0.67650
# Epoch 16/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1564 - my_iou_metric: 0.6910 - val_loss: 0.2059 - val_my_iou_metric: 0.7186
#
# Epoch 00016: val_my_iou_metric improved from 0.67650 to 0.71863, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 17/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1564 - my_iou_metric: 0.6970 - val_loss: 0.2454 - val_my_iou_metric: 0.6510
#
# Epoch 00017: val_my_iou_metric did not improve from 0.71863
# Epoch 18/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1555 - my_iou_metric: 0.7020 - val_loss: 0.1617 - val_my_iou_metric: 0.7141
#
# Epoch 00018: val_my_iou_metric did not improve from 0.71863
# Epoch 19/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1460 - my_iou_metric: 0.7132 - val_loss: 0.1784 - val_my_iou_metric: 0.7180
#
# Epoch 00019: val_my_iou_metric did not improve from 0.71863
# Epoch 20/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1529 - my_iou_metric: 0.7069 - val_loss: 0.2029 - val_my_iou_metric: 0.6522
#
# Epoch 00020: val_my_iou_metric did not improve from 0.71863
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 21/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1302 - my_iou_metric: 0.7280 - val_loss: 0.1501 - val_my_iou_metric: 0.7394
#
# Epoch 00021: val_my_iou_metric improved from 0.71863 to 0.73937, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 22/200
# 6400/6400 [==============================] - 88s 14ms/step - loss: 0.1264 - my_iou_metric: 0.7296 - val_loss: 0.1587 - val_my_iou_metric: 0.7184
#
# Epoch 00022: val_my_iou_metric did not improve from 0.73937
# Epoch 23/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1199 - my_iou_metric: 0.7385 - val_loss: 0.1721 - val_my_iou_metric: 0.7340
#
# Epoch 00023: val_my_iou_metric did not improve from 0.73937
# Epoch 24/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1230 - my_iou_metric: 0.7418 - val_loss: 0.1555 - val_my_iou_metric: 0.7350
#
# Epoch 00024: val_my_iou_metric did not improve from 0.73937
# Epoch 25/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1120 - my_iou_metric: 0.7446 - val_loss: 0.1653 - val_my_iou_metric: 0.7459
#
# Epoch 00025: val_my_iou_metric improved from 0.73937 to 0.74587, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 26/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1150 - my_iou_metric: 0.7471 - val_loss: 0.1497 - val_my_iou_metric: 0.7512
#
# Epoch 00026: val_my_iou_metric improved from 0.74587 to 0.75125, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 27/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1103 - my_iou_metric: 0.7485 - val_loss: 0.1388 - val_my_iou_metric: 0.7509
#
# Epoch 00027: val_my_iou_metric did not improve from 0.75125
# Epoch 28/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1025 - my_iou_metric: 0.7608 - val_loss: 0.1931 - val_my_iou_metric: 0.7358
#
# Epoch 00028: val_my_iou_metric did not improve from 0.75125
# Epoch 29/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0987 - my_iou_metric: 0.7591 - val_loss: 0.1760 - val_my_iou_metric: 0.7223
#
# Epoch 00029: val_my_iou_metric did not improve from 0.75125
# Epoch 30/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1012 - my_iou_metric: 0.7604 - val_loss: 0.1888 - val_my_iou_metric: 0.7518
#
# Epoch 00030: val_my_iou_metric improved from 0.75125 to 0.75175, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 31/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1004 - my_iou_metric: 0.7634 - val_loss: 0.1645 - val_my_iou_metric: 0.7501
#
# Epoch 00031: val_my_iou_metric did not improve from 0.75175
# Epoch 32/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.1060 - my_iou_metric: 0.7580 - val_loss: 0.1455 - val_my_iou_metric: 0.7570
#
# Epoch 00032: val_my_iou_metric improved from 0.75175 to 0.75700, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 33/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0951 - my_iou_metric: 0.7669 - val_loss: 0.1546 - val_my_iou_metric: 0.7387
#
# Epoch 00033: val_my_iou_metric did not improve from 0.75700
# Epoch 34/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0956 - my_iou_metric: 0.7690 - val_loss: 0.1585 - val_my_iou_metric: 0.7497
#
# Epoch 00034: val_my_iou_metric did not improve from 0.75700
# Epoch 35/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0899 - my_iou_metric: 0.7723 - val_loss: 0.1833 - val_my_iou_metric: 0.7516
#
# Epoch 00035: val_my_iou_metric did not improve from 0.75700
# Epoch 36/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0887 - my_iou_metric: 0.7746 - val_loss: 0.1976 - val_my_iou_metric: 0.7385
#
# Epoch 00036: val_my_iou_metric did not improve from 0.75700
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 37/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0753 - my_iou_metric: 0.7905 - val_loss: 0.1510 - val_my_iou_metric: 0.7676
#
# Epoch 00037: val_my_iou_metric improved from 0.75700 to 0.76762, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 38/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0719 - my_iou_metric: 0.7935 - val_loss: 0.1606 - val_my_iou_metric: 0.7559
#
# Epoch 00038: val_my_iou_metric did not improve from 0.76762
# Epoch 39/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0690 - my_iou_metric: 0.7942 - val_loss: 0.1770 - val_my_iou_metric: 0.7484
#
# Epoch 00039: val_my_iou_metric did not improve from 0.76762
# Epoch 40/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0701 - my_iou_metric: 0.7962 - val_loss: 0.1826 - val_my_iou_metric: 0.7570
#
# Epoch 00040: val_my_iou_metric did not improve from 0.76762
# Epoch 41/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0680 - my_iou_metric: 0.7941 - val_loss: 0.1795 - val_my_iou_metric: 0.7675
#
# Epoch 00041: val_my_iou_metric did not improve from 0.76762
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 42/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0613 - my_iou_metric: 0.8049 - val_loss: 0.1751 - val_my_iou_metric: 0.7629
#
# Epoch 00042: val_my_iou_metric did not improve from 0.76762
# Epoch 43/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0587 - my_iou_metric: 0.8100 - val_loss: 0.1783 - val_my_iou_metric: 0.7661
#
# Epoch 00043: val_my_iou_metric did not improve from 0.76762
# Epoch 44/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0577 - my_iou_metric: 0.8107 - val_loss: 0.1808 - val_my_iou_metric: 0.7640
#
# Epoch 00044: val_my_iou_metric did not improve from 0.76762
# Epoch 45/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0576 - my_iou_metric: 0.8036 - val_loss: 0.1770 - val_my_iou_metric: 0.7577
#
# Epoch 00045: val_my_iou_metric did not improve from 0.76762
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 46/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0534 - my_iou_metric: 0.8149 - val_loss: 0.1846 - val_my_iou_metric: 0.7702
#
# Epoch 00046: val_my_iou_metric improved from 0.76762 to 0.77025, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 47/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0529 - my_iou_metric: 0.8152 - val_loss: 0.1819 - val_my_iou_metric: 0.7700
#
# Epoch 00047: val_my_iou_metric did not improve from 0.77025
# Epoch 48/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0523 - my_iou_metric: 0.8157 - val_loss: 0.1900 - val_my_iou_metric: 0.7686
#
# Epoch 00048: val_my_iou_metric did not improve from 0.77025
# Epoch 49/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0516 - my_iou_metric: 0.8152 - val_loss: 0.1800 - val_my_iou_metric: 0.7730
#
# Epoch 00049: val_my_iou_metric improved from 0.77025 to 0.77300, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 50/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0510 - my_iou_metric: 0.8185 - val_loss: 0.1839 - val_my_iou_metric: 0.7721
#
# Epoch 00050: val_my_iou_metric did not improve from 0.77300
# Epoch 51/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0500 - my_iou_metric: 0.8169 - val_loss: 0.1895 - val_my_iou_metric: 0.7720
#
# Epoch 00051: val_my_iou_metric did not improve from 0.77300
# Epoch 52/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0497 - my_iou_metric: 0.8221 - val_loss: 0.1962 - val_my_iou_metric: 0.7740
#
# Epoch 00052: val_my_iou_metric improved from 0.77300 to 0.77400, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 53/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0492 - my_iou_metric: 0.8193 - val_loss: 0.1900 - val_my_iou_metric: 0.7692
#
# Epoch 00053: val_my_iou_metric did not improve from 0.77400
# Epoch 54/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0507 - my_iou_metric: 0.8220 - val_loss: 0.1866 - val_my_iou_metric: 0.7696
#
# Epoch 00054: val_my_iou_metric did not improve from 0.77400
# Epoch 55/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0478 - my_iou_metric: 0.8215 - val_loss: 0.1910 - val_my_iou_metric: 0.7632
#
# Epoch 00055: val_my_iou_metric did not improve from 0.77400
# Epoch 56/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0504 - my_iou_metric: 0.8197 - val_loss: 0.1923 - val_my_iou_metric: 0.7700
#
# Epoch 00056: val_my_iou_metric did not improve from 0.77400
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 57/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0478 - my_iou_metric: 0.8227 - val_loss: 0.1918 - val_my_iou_metric: 0.7736
#
# Epoch 00057: val_my_iou_metric did not improve from 0.77400
# Epoch 58/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0455 - my_iou_metric: 0.8242 - val_loss: 0.1922 - val_my_iou_metric: 0.7753
#
# Epoch 00058: val_my_iou_metric improved from 0.77400 to 0.77525, saving model to ../model/Unet_resnet_depth_cse_32_0.5_stage1.model
# Epoch 59/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0461 - my_iou_metric: 0.8242 - val_loss: 0.1968 - val_my_iou_metric: 0.7746
#
# Epoch 00059: val_my_iou_metric did not improve from 0.77525
# Epoch 60/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0451 - my_iou_metric: 0.8283 - val_loss: 0.1908 - val_my_iou_metric: 0.7701
#
# Epoch 00060: val_my_iou_metric did not improve from 0.77525
# Epoch 61/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0475 - my_iou_metric: 0.8227 - val_loss: 0.1892 - val_my_iou_metric: 0.7705
#
# Epoch 00061: val_my_iou_metric did not improve from 0.77525
# Epoch 62/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0456 - my_iou_metric: 0.8254 - val_loss: 0.1977 - val_my_iou_metric: 0.7724
#
# Epoch 00062: val_my_iou_metric did not improve from 0.77525
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 63/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0447 - my_iou_metric: 0.8281 - val_loss: 0.1995 - val_my_iou_metric: 0.7694
#
# Epoch 00063: val_my_iou_metric did not improve from 0.77525
# Epoch 64/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0464 - my_iou_metric: 0.8239 - val_loss: 0.1968 - val_my_iou_metric: 0.7666
#
# Epoch 00064: val_my_iou_metric did not improve from 0.77525
# Epoch 65/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0443 - my_iou_metric: 0.8251 - val_loss: 0.1949 - val_my_iou_metric: 0.7679
#
# Epoch 00065: val_my_iou_metric did not improve from 0.77525
# Epoch 66/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0434 - my_iou_metric: 0.8288 - val_loss: 0.2007 - val_my_iou_metric: 0.7715
#
# Epoch 00066: val_my_iou_metric did not improve from 0.77525
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 67/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0458 - my_iou_metric: 0.8264 - val_loss: 0.1981 - val_my_iou_metric: 0.7721
#
# Epoch 00067: val_my_iou_metric did not improve from 0.77525
# Epoch 68/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0442 - my_iou_metric: 0.8267 - val_loss: 0.2004 - val_my_iou_metric: 0.7721
#
# Epoch 00068: val_my_iou_metric did not improve from 0.77525
# Epoch 69/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0437 - my_iou_metric: 0.8259 - val_loss: 0.2011 - val_my_iou_metric: 0.7723
#
# Epoch 00069: val_my_iou_metric did not improve from 0.77525
# Epoch 70/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0435 - my_iou_metric: 0.8296 - val_loss: 0.2004 - val_my_iou_metric: 0.7720
#
# Epoch 00070: val_my_iou_metric did not improve from 0.77525
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 71/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0432 - my_iou_metric: 0.8297 - val_loss: 0.1991 - val_my_iou_metric: 0.7726
#
# Epoch 00071: val_my_iou_metric did not improve from 0.77525
# Epoch 72/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0429 - my_iou_metric: 0.8329 - val_loss: 0.1985 - val_my_iou_metric: 0.7731
#
# Epoch 00072: val_my_iou_metric did not improve from 0.77525
# Epoch 73/200
# 6400/6400 [==============================] - 87s 14ms/step - loss: 0.0447 - my_iou_metric: 0.8279 - val_loss: 0.1998 - val_my_iou_metric: 0.7694
#
# Epoch 00073: val_my_iou_metric did not improve from 0.77525
# Epoch 00073: early stopping

# %%
save_model_name = basic_name + '_stage1.model'
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
save_model_name = basic_name + '.model'
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()
board = keras.callbacks.TensorBoard(log_dir='log/resunet_depth_cse_{}_{}'.format(start_feature, dropout),
                       histogram_freq=0, write_graph=True, write_images=False)
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.000001, verbose=1)
epochs = 200
batch_size = 16

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[board, model_checkpoint,reduce_lr,early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
# 6400/6400 [==============================] - 164s 26ms/step - loss: 0.0423 - my_iou_metric_2: 0.7562 - val_loss: 0.2314 - val_my_iou_metric_2: 0.7172
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.71725, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 2/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: 0.0095 - my_iou_metric_2: 0.7585 - val_loss: 0.2105 - val_my_iou_metric_2: 0.7256
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.71725 to 0.72562, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 3/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.0420 - my_iou_metric_2: 0.7727 - val_loss: 0.0896 - val_my_iou_metric_2: 0.7630
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.72562 to 0.76300, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 4/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.0549 - my_iou_metric_2: 0.7695 - val_loss: 0.0989 - val_my_iou_metric_2: 0.7460
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.76300
# Epoch 5/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.0489 - my_iou_metric_2: 0.7684 - val_loss: 0.0423 - val_my_iou_metric_2: 0.7619
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.76300
# Epoch 6/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.0982 - my_iou_metric_2: 0.7786 - val_loss: 0.0200 - val_my_iou_metric_2: 0.7619
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.76300
# Epoch 7/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.0844 - my_iou_metric_2: 0.7767 - val_loss: 0.0636 - val_my_iou_metric_2: 0.7344
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.76300
# Epoch 8/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.1251 - my_iou_metric_2: 0.7838 - val_loss: -0.0390 - val_my_iou_metric_2: 0.7745
#
# Epoch 00008: val_my_iou_metric_2 improved from 0.76300 to 0.77450, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 9/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.1291 - my_iou_metric_2: 0.7850 - val_loss: -0.0409 - val_my_iou_metric_2: 0.7821
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.77450 to 0.78212, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 10/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.1454 - my_iou_metric_2: 0.7890 - val_loss: 0.0053 - val_my_iou_metric_2: 0.7738
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.78212
# Epoch 11/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.1574 - my_iou_metric_2: 0.7917 - val_loss: 0.0049 - val_my_iou_metric_2: 0.7606
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.78212
# Epoch 12/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.1706 - my_iou_metric_2: 0.7954 - val_loss: -0.1019 - val_my_iou_metric_2: 0.7891
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.78212 to 0.78913, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 13/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.1806 - my_iou_metric_2: 0.7957 - val_loss: -0.0684 - val_my_iou_metric_2: 0.7823
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.78913
# Epoch 14/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.1905 - my_iou_metric_2: 0.8008 - val_loss: -0.0992 - val_my_iou_metric_2: 0.7951
#
# Epoch 00014: val_my_iou_metric_2 improved from 0.78913 to 0.79513, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 15/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.2136 - my_iou_metric_2: 0.8032 - val_loss: -0.0821 - val_my_iou_metric_2: 0.7886
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.79513
# Epoch 16/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.2063 - my_iou_metric_2: 0.8014 - val_loss: -0.0581 - val_my_iou_metric_2: 0.7769
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.79513
# Epoch 17/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.2352 - my_iou_metric_2: 0.8084 - val_loss: -0.0996 - val_my_iou_metric_2: 0.7849
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.79513
# Epoch 18/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.2394 - my_iou_metric_2: 0.8096 - val_loss: -0.0536 - val_my_iou_metric_2: 0.7859
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.79513
# Epoch 19/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.2578 - my_iou_metric_2: 0.8119 - val_loss: 0.0137 - val_my_iou_metric_2: 0.7692
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.79513
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 20/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.3411 - my_iou_metric_2: 0.8282 - val_loss: -0.1114 - val_my_iou_metric_2: 0.7919
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.79513
# Epoch 21/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.3611 - my_iou_metric_2: 0.8316 - val_loss: -0.1219 - val_my_iou_metric_2: 0.8020
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.79513 to 0.80200, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 22/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.3791 - my_iou_metric_2: 0.8355 - val_loss: -0.1195 - val_my_iou_metric_2: 0.8074
#
# Epoch 00022: val_my_iou_metric_2 improved from 0.80200 to 0.80738, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 23/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.3999 - my_iou_metric_2: 0.8407 - val_loss: -0.1256 - val_my_iou_metric_2: 0.8079
#
# Epoch 00023: val_my_iou_metric_2 improved from 0.80738 to 0.80787, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 24/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.4142 - my_iou_metric_2: 0.8439 - val_loss: -0.0590 - val_my_iou_metric_2: 0.7936
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.80787
# Epoch 25/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.4212 - my_iou_metric_2: 0.8439 - val_loss: -0.0891 - val_my_iou_metric_2: 0.8006
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.80787
# Epoch 26/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.4089 - my_iou_metric_2: 0.8430 - val_loss: -0.0622 - val_my_iou_metric_2: 0.7929
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.80787
# Epoch 27/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.4328 - my_iou_metric_2: 0.8471 - val_loss: -0.1073 - val_my_iou_metric_2: 0.8000
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.80787
# Epoch 28/200
# 6400/6400 [==============================] - 150s 23ms/step - loss: -0.4433 - my_iou_metric_2: 0.8485 - val_loss: -0.0212 - val_my_iou_metric_2: 0.7997
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.80787
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 29/200
# 6400/6400 [==============================] - 150s 23ms/step - loss: -0.4870 - my_iou_metric_2: 0.8559 - val_loss: -0.0040 - val_my_iou_metric_2: 0.7993
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.80787
# Epoch 30/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5124 - my_iou_metric_2: 0.8609 - val_loss: -0.0395 - val_my_iou_metric_2: 0.8106
#
# Epoch 00030: val_my_iou_metric_2 improved from 0.80787 to 0.81063, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 31/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5213 - my_iou_metric_2: 0.8629 - val_loss: -0.0516 - val_my_iou_metric_2: 0.7997
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 32/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5239 - my_iou_metric_2: 0.8631 - val_loss: 3.5499e-04 - val_my_iou_metric_2: 0.8097
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 33/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5292 - my_iou_metric_2: 0.8637 - val_loss: 0.0654 - val_my_iou_metric_2: 0.8055
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 34/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5374 - my_iou_metric_2: 0.8649 - val_loss: 0.0014 - val_my_iou_metric_2: 0.8071
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 35/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5382 - my_iou_metric_2: 0.8646 - val_loss: 0.0167 - val_my_iou_metric_2: 0.8051
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.81063
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 36/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5551 - my_iou_metric_2: 0.8702 - val_loss: 0.0250 - val_my_iou_metric_2: 0.8046
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 37/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5711 - my_iou_metric_2: 0.8713 - val_loss: 0.0330 - val_my_iou_metric_2: 0.8066
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 38/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5764 - my_iou_metric_2: 0.8727 - val_loss: 0.0586 - val_my_iou_metric_2: 0.8029
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 39/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5765 - my_iou_metric_2: 0.8737 - val_loss: 0.0233 - val_my_iou_metric_2: 0.8073
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 40/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5850 - my_iou_metric_2: 0.8756 - val_loss: 0.0235 - val_my_iou_metric_2: 0.8057
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.81063
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 41/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5943 - my_iou_metric_2: 0.8779 - val_loss: 0.0440 - val_my_iou_metric_2: 0.8067
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.81063
# Epoch 42/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5942 - my_iou_metric_2: 0.8785 - val_loss: 0.0510 - val_my_iou_metric_2: 0.8129
#
# Epoch 00042: val_my_iou_metric_2 improved from 0.81063 to 0.81287, saving model to ../model/Unet_resnet_depth_cse_32_0.5.model
# Epoch 43/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6058 - my_iou_metric_2: 0.8813 - val_loss: 0.0811 - val_my_iou_metric_2: 0.8101
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 44/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5996 - my_iou_metric_2: 0.8772 - val_loss: 0.0666 - val_my_iou_metric_2: 0.8065
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 45/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.5997 - my_iou_metric_2: 0.8797 - val_loss: 0.0871 - val_my_iou_metric_2: 0.8084
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 46/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6158 - my_iou_metric_2: 0.8805 - val_loss: 0.0897 - val_my_iou_metric_2: 0.8115
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 47/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6050 - my_iou_metric_2: 0.8796 - val_loss: 0.0844 - val_my_iou_metric_2: 0.8079
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.81287
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 48/200
# 6400/6400 [==============================] - 148s 23ms/step - loss: -0.6067 - my_iou_metric_2: 0.8807 - val_loss: 0.0735 - val_my_iou_metric_2: 0.8086
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 49/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6155 - my_iou_metric_2: 0.8824 - val_loss: 0.0768 - val_my_iou_metric_2: 0.8076
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 50/200
# 6400/6400 [==============================] - 148s 23ms/step - loss: -0.6168 - my_iou_metric_2: 0.8826 - val_loss: 0.0624 - val_my_iou_metric_2: 0.8057
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 51/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6229 - my_iou_metric_2: 0.8834 - val_loss: 0.0890 - val_my_iou_metric_2: 0.8066
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 52/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6156 - my_iou_metric_2: 0.8827 - val_loss: 0.0873 - val_my_iou_metric_2: 0.8077
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.81287
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 53/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6196 - my_iou_metric_2: 0.8826 - val_loss: 0.0847 - val_my_iou_metric_2: 0.8079
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 54/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6207 - my_iou_metric_2: 0.8843 - val_loss: 0.1001 - val_my_iou_metric_2: 0.8059
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 55/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6200 - my_iou_metric_2: 0.8842 - val_loss: 0.0889 - val_my_iou_metric_2: 0.8083
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 56/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6203 - my_iou_metric_2: 0.8834 - val_loss: 0.1011 - val_my_iou_metric_2: 0.8071
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 57/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6188 - my_iou_metric_2: 0.8822 - val_loss: 0.0994 - val_my_iou_metric_2: 0.8074
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.81287
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 58/200
# 6400/6400 [==============================] - 149s 23ms/step - loss: -0.6291 - my_iou_metric_2: 0.8855 - val_loss: 0.1069 - val_my_iou_metric_2: 0.8060
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 59/200
# 6400/6400 [==============================] - 150s 23ms/step - loss: -0.6234 - my_iou_metric_2: 0.8846 - val_loss: 0.1065 - val_my_iou_metric_2: 0.8073
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.81287
# Epoch 60/200
# 5088/6400 [======================>.......] - ETA: 28s - loss: -0.6251 - my_iou_metric_2: 0.8853

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
preds_valid = predict_result(model,x_valid,img_size_target)
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)

# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
x_test = np.array([(np.array(load_img("../input/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target)
x_test = add_depth_bulk(x_test)

preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")

sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub = sub.reset_index()
save_result(sub, '../result/res_depthinchannel.csv', 
                        competition = 'tgs-salt-identification-challenge', 
                        send = False, index = False)

t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
